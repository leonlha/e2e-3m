# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# /home/phong/Documents/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/phong/Documents/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/phong/Documents/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/phong/Documents/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/phong/Documents/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/phong/Documents/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1720065342068203731
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 1123354717307078323
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_GPU:1"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 16843844467893471641
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_GPU:2"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 9750839199386850501
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 16434433891812847752
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 16102781748
# locality {
#   bus_id: 1
#   links {
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 2
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 7360358929212289803
# physical_device_desc: "device: 0, name: Quadro P5000, pci bus id: 0000:3d:00.0, compute capability: 6.1"
# , name: "/device:GPU:1"
# device_type: "GPU"
# memory_limit: 16102781748
# locality {
#   bus_id: 1
#   links {
#     link {
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 2
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 15502092865914474561
# physical_device_desc: "device: 1, name: Quadro P5000, pci bus id: 0000:3f:00.0, compute capability: 6.1"
# , name: "/device:GPU:2"
# device_type: "GPU"
# memory_limit: 16102781748
# locality {
#   bus_id: 1
#   links {
#     link {
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 8277710678613340190
# physical_device_desc: "device: 2, name: Quadro P5000, pci bus id: 0000:41:00.0, compute capability: 6.1"
# ]

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0,1,2"

# %%
# !wget http://ufldl.stanford.edu/housenumbers/train_32x32.mat

# %%
# !wget http://ufldl.stanford.edu/housenumbers/extra_32x32.mat

# %%
ls

# %%
# !wget http://ufldl.stanford.edu/housenumbers/test_32x32.mat

# %%
from PIL import Image
import numpy

def convert_img_square(im_pth='', dest_path='', desired_size=224):
#     print(im_pth)
    
    im = Image.open(im_pth)
    old_size = im.size  # (width, height) format

    ratio = float(desired_size)/max(old_size)
    new_size = tuple([int(x*ratio) for x in old_size])

#     new_im = im.resize(new_size, Image.ANTIALIAS)
    new_im = im.resize(new_size)
    
    new_im = new_im.convert('RGB')
    
    new_im.save(dest_path)

    return True
    
# path = 'train/0/twinjet_s_001442.png'
# dest_path = 't1/test4.jpg'

# orig_arr = convert_img_square(path, dest_path, 499)   

# #convert to RGB and Save
# # orig_arr = orig_arr.convert('RGB')
# # orig_arr.save('t1/test2.jpg')

# from IPython.display import Image 
# Image(filename='t1/test4.jpg')

# %%
ls -l

# %%
import os
import numpy as np
import struct
import scipy.io as sio
import matplotlib.pyplot as plt


def save_svhn():
    dir_name = "./svhn_train"
    if not os.path.isdir(dir_name):
        os.mkdir(dir_name)
    print("Loading matlab train of SVHN")
    mat = sio.loadmat("train_32x32.mat")
    data = mat['X']
    folders = mat['y']
    
    for i in range(data.shape[3]):
        if not os.path.isfile(os.path.join(dir_name, str(folders[i][0]), "%05d.png" % i)):  
            # create folder if not existed
            if not os.path.exists(os.path.join(dir_name, str(folders[i][0]))):
                os.makedirs(os.path.join(dir_name, str(folders[i][0])))

            plt.imsave(os.path.join(dir_name, str(folders[i][0]), "%05d.png" % i), data[..., i])
            
    print("Program done!")

save_svhn()

# %%
import os
import numpy as np
import struct
import scipy.io as sio
import matplotlib.pyplot as plt


def save_svhn():
    dir_name = "./svhn_extra"
    if not os.path.isdir(dir_name):
        os.mkdir(dir_name)
    print("Loading matlab data of SVHN")
    mat = sio.loadmat("extra_32x32.mat")
    data = mat['X']
    folders = mat['y']
    
    for i in range(data.shape[3]):
        if not os.path.isfile(os.path.join(dir_name, str(folders[i][0]), "%05d.png" % i)):  
            # create folder if not existed
            if not os.path.exists(os.path.join(dir_name, str(folders[i][0]))):
                os.makedirs(os.path.join(dir_name, str(folders[i][0])))

            plt.imsave(os.path.join(dir_name, str(folders[i][0]), "%05d.png" % i), data[..., i])
            
    print("Program done!")

save_svhn()

# %%
import os
import numpy as np
import struct
import scipy.io as sio
import matplotlib.pyplot as plt


def save_svhn_test():
    dir_name = "./svhn_test"
    if not os.path.isdir(dir_name):
        os.mkdir(dir_name)
    print("Loading matlab data of SVHN")
    mat = sio.loadmat("test_32x32.mat")
    data = mat['X']
    folders = mat['y']
    
    for i in range(data.shape[3]):
        if not os.path.isfile(os.path.join(dir_name, str(folders[i][0]), "%05d.png" % i)):  
            # create folder if not existed
            if not os.path.exists(os.path.join(dir_name, str(folders[i][0]))):
                os.makedirs(os.path.join(dir_name, str(folders[i][0])))

            plt.imsave(os.path.join(dir_name, str(folders[i][0]), "%05d.png" % i), data[..., i])
            
    print("done!")

save_svhn_test()

# %%
ls

# %%
####=======================
import glob
import os
import shutil
import random
from PIL import Image
import numpy

#move class folder from classname_# to classname/#

def get_image_parts(image_path):
    """Given a full path to an image, return its parts."""
    parts = image_path.split(os.path.sep)
    #print(parts)
    filename = parts[2]
    filename_no_ext = filename.split('.')[0]
    classname = parts[1]
    train_or_test = parts[0]
    
    return train_or_test, classname, filename_no_ext, filename

move_folders = ['svhn_train']
dest_folder = 'train_resized_299'
data_file = []

# look for all images in sub-folders
for folder in move_folders:
    class_folders = glob.glob(os.path.join(folder, '*'))
    print('folder %s' %class_folders)
    
#     for sub_folder in class_folders:
#         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
#         print('sub folder %s' %sub_class_folders)
        
    for iid_class in class_folders:
        print(iid_class)
        
        class_files = glob.glob(os.path.join(iid_class, '*.png'))
        
#         #Determize Set# (No Suffle)
        set = len(class_files)
        inner = range(0*set, 1*set) #all

        print('moving %d files' %(len(inner)))

#         random_list = random.sample(range(len(class_files)), int(len(class_files)/5)) #1/5 dataset
#         for idx in range(len(random_list)):

        for idx in range(len(inner)):
            src = class_files[inner[idx]]

            train_or_test, classname, filename_no_ext, filename = get_image_parts(src)
            dst = os.path.join(dest_folder, classname, 'train_'+filename)

            # image directory
            img_directory = os.path.join(dest_folder, classname)

            # create folder if not existed
            if not os.path.exists(img_directory):
                os.makedirs(img_directory)
                
            # convert image
            convert_img_square(src, dst, 299)
            #moving file
            # shutil.move(src, dst)
#                 shutil.copy(src, dst)

# %%
####=======================
import glob
import os
import shutil
import random
from PIL import Image
import numpy

#move class folder from classname_# to classname/#

def get_image_parts(image_path):
    """Given a full path to an image, return its parts."""
    parts = image_path.split(os.path.sep)
    #print(parts)
    filename = parts[2]
    filename_no_ext = filename.split('.')[0]
    classname = parts[1]
    train_or_test = parts[0]
    
    return train_or_test, classname, filename_no_ext, filename

move_folders = ['svhn_extra']
dest_folder = 'train_resized_299'
data_file = []

# look for all images in sub-folders
for folder in move_folders:
    class_folders = glob.glob(os.path.join(folder, '*'))
    print('folder %s' %class_folders)
    
#     for sub_folder in class_folders:
#         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
#         print('sub folder %s' %sub_class_folders)
        
    for iid_class in class_folders:
        print(iid_class)
        
        class_files = glob.glob(os.path.join(iid_class, '*.png'))
        
#         #Determize Set# (No Suffle)
        set = len(class_files)
        inner = range(0*set, 1*set) #all

        print('moving %d files' %(len(inner)))

#         random_list = random.sample(range(len(class_files)), int(len(class_files)/5)) #1/5 dataset
#         for idx in range(len(random_list)):

        for idx in range(len(inner)):
            src = class_files[inner[idx]]

            train_or_test, classname, filename_no_ext, filename = get_image_parts(src)
            dst = os.path.join(dest_folder, classname, 'extra_'+filename)

            # image directory
            img_directory = os.path.join(dest_folder, classname)

            # create folder if not existed
            if not os.path.exists(img_directory):
                os.makedirs(img_directory)
                
            # convert image
            convert_img_square(src, dst, 299)
            #moving file
            # shutil.move(src, dst)
#                 shutil.copy(src, dst)

# %%
####=======================
import glob
import os
import shutil
import random
from PIL import Image
import numpy

#move class folder from classname_# to classname/#

def get_image_parts(image_path):
    """Given a full path to an image, return its parts."""
    parts = image_path.split(os.path.sep)
    #print(parts)
    filename = parts[2]
    filename_no_ext = filename.split('.')[0]
    classname = parts[1]
    train_or_test = parts[0]
    
    return train_or_test, classname, filename_no_ext, filename

move_folders = ['svhn_test']
dest_folder = 'test_resized_299'
data_file = []

# look for all images in sub-folders
for folder in move_folders:
    class_folders = glob.glob(os.path.join(folder, '*'))
    print('folder %s' %class_folders)
    
#     for sub_folder in class_folders:
#         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
#         print('sub folder %s' %sub_class_folders)
        
    for iid_class in class_folders:
        print(iid_class)
        
        class_files = glob.glob(os.path.join(iid_class, '*.png'))
        
#         #Determize Set# (No Suffle)
        set = len(class_files)
        inner = range(0*set, 1*set) #all

        print('moving %d files' %(len(inner)))

#         random_list = random.sample(range(len(class_files)), int(len(class_files)/5)) #1/5 dataset
#         for idx in range(len(random_list)):

        for idx in range(len(inner)):
            src = class_files[inner[idx]]

            train_or_test, classname, filename_no_ext, filename = get_image_parts(src)
            dst = os.path.join(dest_folder, classname, filename)

            # image directory
            img_directory = os.path.join(dest_folder, classname)

            # create folder if not existed
            if not os.path.exists(img_directory):
                os.makedirs(img_directory)
                
            # convert image
            convert_img_square(src, dst, 299)
            #moving file
            # shutil.move(src, dst)
#                 shutil.copy(src, dst)

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# %%
# !zip -r svhn_train_resized_229.zip svhn_train_resized_229
# !zip -r svhn_test_resized_229.zip svhn_test_resized_229

# %%
# %cp svhn_train_resized_229.zip gdrive/My\ Drive/svhn_train_resized_229.zip
# %cp svhn_test_resized_229.zip gdrive/My\ Drive/svhn_test_resized_229.zip

# %%
# %cp gdrive/My\ Drive/svhn_train.zip svhn_train_32.zip 
# %cp gdrive/My\ Drive/svhn_test.zip svhn_test_32.zip

# %%
# !unzip -q svhn_train_32.zip
# !unzip -q svhn_test_32.zip

# %%
# !pip3 install -U git+https://github.com/qubvel/efficientnet

# %%
#MUL 1 - Inception - ST

# from keras.applications import InceptionV3
# from keras.applications import Xception
# from keras.applications.inception_resnet_v2 import InceptionResNetV2

from keras.models import Model
from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, SimpleRNN, LSTM, Flatten, GRU, Reshape
# from keras.applications.inception_v3 import preprocess_input

from efficientnet.keras import preprocess_input
# from keras.applications.xception import preprocess_input

from keras.layers import GaussianNoise

import efficientnet.keras as efn

f1_base = efn.EfficientNetB5(include_top=False, weights='imagenet', 
                input_shape=(299, 299, 3), 
                pooling='avg')

# f1_base = Xception(weights='imagenet', include_top=False, input_shape=(299,299,3))

# f1_base = EfficientNetB4((224,224,3), classes=1000, include_top=False, weights='imagenet')
f1_x = f1_base.output

# f1_x = f1_base.layers[-151].output   #layer 5

# f1_x = GlobalAveragePooling2D()(f1_x)
# f1_x = Flatten()(f1_x)

# f1_x = Reshape([1,1280])(f1_x)  
# f1_x = SimpleRNN(2048, 
#             return_sequences=False,                       
# #             dropout=0.8                                     
#             input_shape=[1,1280])(f1_x)

#Regularization with noise
f1_x = GaussianNoise(0.1)(f1_x)

f1_x = Dense(1024, activation='relu')(f1_x)
f1_x = Dense(10, activation='softmax')(f1_x)
model_1 = Model(inputs=[f1_base.input],outputs=[f1_x])

model_1.summary()
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /home/phong/Documents/venv/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/phong/Documents/venv/lib/python3.6/site-packages/tensorflow/python/framework/function.py:1007: calling Graph.create_op (from tensorflow.python.framework.ops) with compute_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# Shapes are always computed; don't use the compute_shapes as it has no effect.
# WARNING:tensorflow:From /home/phong/Documents/venv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 150, 150, 48) 1296        input_1[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 150, 150, 48) 192         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 150, 150, 48) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 150, 150, 48) 432         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 150, 150, 48) 192         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 150, 150, 48) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 48)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 48)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 12)     588         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 48)     624         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 150, 150, 48) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 150, 150, 24) 1152        block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 150, 150, 24) 96          block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 150, 150, 24) 216         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 150, 150, 24) 96          block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 150, 150, 24) 0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 24)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 24)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 6)      150         block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 24)     168         block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 150, 150, 24) 0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 150, 150, 24) 576         block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 150, 150, 24) 96          block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (FixedDropout)     (None, 150, 150, 24) 0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 150, 150, 24) 0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1c_dwconv (DepthwiseConv2D (None, 150, 150, 24) 216         block1b_add[0][0]
# __________________________________________________________________________________________________
# block1c_bn (BatchNormalization) (None, 150, 150, 24) 96          block1c_dwconv[0][0]
# __________________________________________________________________________________________________
# block1c_activation (Activation) (None, 150, 150, 24) 0           block1c_bn[0][0]
# __________________________________________________________________________________________________
# block1c_se_squeeze (GlobalAvera (None, 24)           0           block1c_activation[0][0]
# __________________________________________________________________________________________________
# block1c_se_reshape (Reshape)    (None, 1, 1, 24)     0           block1c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1c_se_reduce (Conv2D)      (None, 1, 1, 6)      150         block1c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1c_se_expand (Conv2D)      (None, 1, 1, 24)     168         block1c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1c_se_excite (Multiply)    (None, 150, 150, 24) 0           block1c_activation[0][0]
#                                                                  block1c_se_expand[0][0]
# __________________________________________________________________________________________________
# block1c_project_conv (Conv2D)   (None, 150, 150, 24) 576         block1c_se_excite[0][0]
# __________________________________________________________________________________________________
# block1c_project_bn (BatchNormal (None, 150, 150, 24) 96          block1c_project_conv[0][0]
# __________________________________________________________________________________________________
# block1c_drop (FixedDropout)     (None, 150, 150, 24) 0           block1c_project_bn[0][0]
# __________________________________________________________________________________________________
# block1c_add (Add)               (None, 150, 150, 24) 0           block1c_drop[0][0]
#                                                                  block1b_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 150, 150, 144 3456        block1c_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 150, 150, 144 576         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 150, 150, 144 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 75, 75, 144)  1296        block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 75, 75, 144)  576         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 75, 75, 144)  0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 144)          0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 75, 75, 144)  0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 75, 75, 40)   5760        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 75, 75, 40)   160         block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 75, 75, 240)  9600        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 75, 75, 240)  960         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 75, 75, 240)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 75, 75, 240)  2160        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 75, 75, 240)  960         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 75, 75, 240)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 240)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 240)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 75, 75, 240)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 75, 75, 40)   9600        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 75, 75, 40)   160         block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (FixedDropout)     (None, 75, 75, 40)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 75, 75, 40)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 75, 75, 240)  9600        block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 75, 75, 240)  960         block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 75, 75, 240)  0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 75, 75, 240)  2160        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 75, 75, 240)  960         block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 75, 75, 240)  0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 240)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 240)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 75, 75, 240)  0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 75, 75, 40)   9600        block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 75, 75, 40)   160         block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (FixedDropout)     (None, 75, 75, 40)   0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 75, 75, 40)   0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_conv (Conv2D)    (None, 75, 75, 240)  9600        block2c_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_bn (BatchNormali (None, 75, 75, 240)  960         block2d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2d_expand_activation (Acti (None, 75, 75, 240)  0           block2d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2d_dwconv (DepthwiseConv2D (None, 75, 75, 240)  2160        block2d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2d_bn (BatchNormalization) (None, 75, 75, 240)  960         block2d_dwconv[0][0]
# __________________________________________________________________________________________________
# block2d_activation (Activation) (None, 75, 75, 240)  0           block2d_bn[0][0]
# __________________________________________________________________________________________________
# block2d_se_squeeze (GlobalAvera (None, 240)          0           block2d_activation[0][0]
# __________________________________________________________________________________________________
# block2d_se_reshape (Reshape)    (None, 1, 1, 240)    0           block2d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2d_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block2d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2d_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block2d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2d_se_excite (Multiply)    (None, 75, 75, 240)  0           block2d_activation[0][0]
#                                                                  block2d_se_expand[0][0]
# __________________________________________________________________________________________________
# block2d_project_conv (Conv2D)   (None, 75, 75, 40)   9600        block2d_se_excite[0][0]
# __________________________________________________________________________________________________
# block2d_project_bn (BatchNormal (None, 75, 75, 40)   160         block2d_project_conv[0][0]
# __________________________________________________________________________________________________
# block2d_drop (FixedDropout)     (None, 75, 75, 40)   0           block2d_project_bn[0][0]
# __________________________________________________________________________________________________
# block2d_add (Add)               (None, 75, 75, 40)   0           block2d_drop[0][0]
#                                                                  block2c_add[0][0]
# __________________________________________________________________________________________________
# block2e_expand_conv (Conv2D)    (None, 75, 75, 240)  9600        block2d_add[0][0]
# __________________________________________________________________________________________________
# block2e_expand_bn (BatchNormali (None, 75, 75, 240)  960         block2e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2e_expand_activation (Acti (None, 75, 75, 240)  0           block2e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2e_dwconv (DepthwiseConv2D (None, 75, 75, 240)  2160        block2e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2e_bn (BatchNormalization) (None, 75, 75, 240)  960         block2e_dwconv[0][0]
# __________________________________________________________________________________________________
# block2e_activation (Activation) (None, 75, 75, 240)  0           block2e_bn[0][0]
# __________________________________________________________________________________________________
# block2e_se_squeeze (GlobalAvera (None, 240)          0           block2e_activation[0][0]
# __________________________________________________________________________________________________
# block2e_se_reshape (Reshape)    (None, 1, 1, 240)    0           block2e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2e_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block2e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2e_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block2e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2e_se_excite (Multiply)    (None, 75, 75, 240)  0           block2e_activation[0][0]
#                                                                  block2e_se_expand[0][0]
# __________________________________________________________________________________________________
# block2e_project_conv (Conv2D)   (None, 75, 75, 40)   9600        block2e_se_excite[0][0]
# __________________________________________________________________________________________________
# block2e_project_bn (BatchNormal (None, 75, 75, 40)   160         block2e_project_conv[0][0]
# __________________________________________________________________________________________________
# block2e_drop (FixedDropout)     (None, 75, 75, 40)   0           block2e_project_bn[0][0]
# __________________________________________________________________________________________________
# block2e_add (Add)               (None, 75, 75, 40)   0           block2e_drop[0][0]
#                                                                  block2d_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 75, 75, 240)  9600        block2e_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 75, 75, 240)  960         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 75, 75, 240)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 38, 38, 240)  6000        block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 38, 38, 240)  960         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 38, 38, 240)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 240)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 240)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 38, 38, 240)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 38, 38, 64)   15360       block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 38, 38, 64)   256         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 38, 38, 384)  24576       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 38, 38, 384)  1536        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 38, 38, 384)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 38, 38, 384)  9600        block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 38, 38, 384)  1536        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 38, 38, 384)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 384)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 384)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 16)     6160        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 384)    6528        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 38, 38, 384)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 38, 38, 64)   24576       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 38, 38, 64)   256         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (FixedDropout)     (None, 38, 38, 64)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 38, 38, 64)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 38, 38, 384)  24576       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 38, 38, 384)  1536        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 38, 38, 384)  0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 38, 38, 384)  9600        block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 38, 38, 384)  1536        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 38, 38, 384)  0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 384)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 384)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 16)     6160        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 384)    6528        block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 38, 38, 384)  0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 38, 38, 64)   24576       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 38, 38, 64)   256         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (FixedDropout)     (None, 38, 38, 64)   0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 38, 38, 64)   0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_conv (Conv2D)    (None, 38, 38, 384)  24576       block3c_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_bn (BatchNormali (None, 38, 38, 384)  1536        block3d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3d_expand_activation (Acti (None, 38, 38, 384)  0           block3d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3d_dwconv (DepthwiseConv2D (None, 38, 38, 384)  9600        block3d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3d_bn (BatchNormalization) (None, 38, 38, 384)  1536        block3d_dwconv[0][0]
# __________________________________________________________________________________________________
# block3d_activation (Activation) (None, 38, 38, 384)  0           block3d_bn[0][0]
# __________________________________________________________________________________________________
# block3d_se_squeeze (GlobalAvera (None, 384)          0           block3d_activation[0][0]
# __________________________________________________________________________________________________
# block3d_se_reshape (Reshape)    (None, 1, 1, 384)    0           block3d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3d_se_reduce (Conv2D)      (None, 1, 1, 16)     6160        block3d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3d_se_expand (Conv2D)      (None, 1, 1, 384)    6528        block3d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3d_se_excite (Multiply)    (None, 38, 38, 384)  0           block3d_activation[0][0]
#                                                                  block3d_se_expand[0][0]
# __________________________________________________________________________________________________
# block3d_project_conv (Conv2D)   (None, 38, 38, 64)   24576       block3d_se_excite[0][0]
# __________________________________________________________________________________________________
# block3d_project_bn (BatchNormal (None, 38, 38, 64)   256         block3d_project_conv[0][0]
# __________________________________________________________________________________________________
# block3d_drop (FixedDropout)     (None, 38, 38, 64)   0           block3d_project_bn[0][0]
# __________________________________________________________________________________________________
# block3d_add (Add)               (None, 38, 38, 64)   0           block3d_drop[0][0]
#                                                                  block3c_add[0][0]
# __________________________________________________________________________________________________
# block3e_expand_conv (Conv2D)    (None, 38, 38, 384)  24576       block3d_add[0][0]
# __________________________________________________________________________________________________
# block3e_expand_bn (BatchNormali (None, 38, 38, 384)  1536        block3e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3e_expand_activation (Acti (None, 38, 38, 384)  0           block3e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3e_dwconv (DepthwiseConv2D (None, 38, 38, 384)  9600        block3e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3e_bn (BatchNormalization) (None, 38, 38, 384)  1536        block3e_dwconv[0][0]
# __________________________________________________________________________________________________
# block3e_activation (Activation) (None, 38, 38, 384)  0           block3e_bn[0][0]
# __________________________________________________________________________________________________
# block3e_se_squeeze (GlobalAvera (None, 384)          0           block3e_activation[0][0]
# __________________________________________________________________________________________________
# block3e_se_reshape (Reshape)    (None, 1, 1, 384)    0           block3e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3e_se_reduce (Conv2D)      (None, 1, 1, 16)     6160        block3e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3e_se_expand (Conv2D)      (None, 1, 1, 384)    6528        block3e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3e_se_excite (Multiply)    (None, 38, 38, 384)  0           block3e_activation[0][0]
#                                                                  block3e_se_expand[0][0]
# __________________________________________________________________________________________________
# block3e_project_conv (Conv2D)   (None, 38, 38, 64)   24576       block3e_se_excite[0][0]
# __________________________________________________________________________________________________
# block3e_project_bn (BatchNormal (None, 38, 38, 64)   256         block3e_project_conv[0][0]
# __________________________________________________________________________________________________
# block3e_drop (FixedDropout)     (None, 38, 38, 64)   0           block3e_project_bn[0][0]
# __________________________________________________________________________________________________
# block3e_add (Add)               (None, 38, 38, 64)   0           block3e_drop[0][0]
#                                                                  block3d_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 38, 38, 384)  24576       block3e_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 38, 38, 384)  1536        block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 38, 38, 384)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 19, 19, 384)  3456        block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 19, 19, 384)  1536        block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 19, 19, 384)  0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 384)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 384)    0           block4a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 16)     6160        block4a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 384)    6528        block4a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 19, 19, 384)  0           block4a_activation[0][0]
#                                                                  block4a_se_expand[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, 19, 19, 128)  49152       block4a_se_excite[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 19, 19, 128)  512         block4a_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, 19, 19, 768)  98304       block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 19, 19, 768)  3072        block4b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 19, 19, 768)  0           block4b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, 19, 19, 768)  6912        block4b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 19, 19, 768)  3072        block4b_dwconv[0][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 19, 19, 768)  0           block4b_bn[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 768)          0           block4b_activation[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 768)    0           block4b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 32)     24608       block4b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 768)    25344       block4b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 19, 19, 768)  0           block4b_activation[0][0]
#                                                                  block4b_se_expand[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, 19, 19, 128)  98304       block4b_se_excite[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 19, 19, 128)  512         block4b_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_drop (FixedDropout)     (None, 19, 19, 128)  0           block4b_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 19, 19, 128)  0           block4b_drop[0][0]
#                                                                  block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_expand_conv (Conv2D)    (None, 19, 19, 768)  98304       block4b_add[0][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 19, 19, 768)  3072        block4c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 19, 19, 768)  0           block4c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4c_dwconv (DepthwiseConv2D (None, 19, 19, 768)  6912        block4c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 19, 19, 768)  3072        block4c_dwconv[0][0]
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 19, 19, 768)  0           block4c_bn[0][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 768)          0           block4c_activation[0][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 768)    0           block4c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4c_se_reduce (Conv2D)      (None, 1, 1, 32)     24608       block4c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4c_se_expand (Conv2D)      (None, 1, 1, 768)    25344       block4c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 19, 19, 768)  0           block4c_activation[0][0]
# ...
# block6h_activation (Activation) (None, 10, 10, 1824) 0           block6h_bn[0][0]
# __________________________________________________________________________________________________
# block6h_se_squeeze (GlobalAvera (None, 1824)         0           block6h_activation[0][0]
# __________________________________________________________________________________________________
# block6h_se_reshape (Reshape)    (None, 1, 1, 1824)   0           block6h_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6h_se_reduce (Conv2D)      (None, 1, 1, 76)     138700      block6h_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6h_se_expand (Conv2D)      (None, 1, 1, 1824)   140448      block6h_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6h_se_excite (Multiply)    (None, 10, 10, 1824) 0           block6h_activation[0][0]
#                                                                  block6h_se_expand[0][0]
# __________________________________________________________________________________________________
# block6h_project_conv (Conv2D)   (None, 10, 10, 304)  554496      block6h_se_excite[0][0]
# __________________________________________________________________________________________________
# block6h_project_bn (BatchNormal (None, 10, 10, 304)  1216        block6h_project_conv[0][0]
# __________________________________________________________________________________________________
# block6h_drop (FixedDropout)     (None, 10, 10, 304)  0           block6h_project_bn[0][0]
# __________________________________________________________________________________________________
# block6h_add (Add)               (None, 10, 10, 304)  0           block6h_drop[0][0]
#                                                                  block6g_add[0][0]
# __________________________________________________________________________________________________
# block6i_expand_conv (Conv2D)    (None, 10, 10, 1824) 554496      block6h_add[0][0]
# __________________________________________________________________________________________________
# block6i_expand_bn (BatchNormali (None, 10, 10, 1824) 7296        block6i_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6i_expand_activation (Acti (None, 10, 10, 1824) 0           block6i_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6i_dwconv (DepthwiseConv2D (None, 10, 10, 1824) 45600       block6i_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6i_bn (BatchNormalization) (None, 10, 10, 1824) 7296        block6i_dwconv[0][0]
# __________________________________________________________________________________________________
# block6i_activation (Activation) (None, 10, 10, 1824) 0           block6i_bn[0][0]
# __________________________________________________________________________________________________
# block6i_se_squeeze (GlobalAvera (None, 1824)         0           block6i_activation[0][0]
# __________________________________________________________________________________________________
# block6i_se_reshape (Reshape)    (None, 1, 1, 1824)   0           block6i_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6i_se_reduce (Conv2D)      (None, 1, 1, 76)     138700      block6i_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6i_se_expand (Conv2D)      (None, 1, 1, 1824)   140448      block6i_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6i_se_excite (Multiply)    (None, 10, 10, 1824) 0           block6i_activation[0][0]
#                                                                  block6i_se_expand[0][0]
# __________________________________________________________________________________________________
# block6i_project_conv (Conv2D)   (None, 10, 10, 304)  554496      block6i_se_excite[0][0]
# __________________________________________________________________________________________________
# block6i_project_bn (BatchNormal (None, 10, 10, 304)  1216        block6i_project_conv[0][0]
# __________________________________________________________________________________________________
# block6i_drop (FixedDropout)     (None, 10, 10, 304)  0           block6i_project_bn[0][0]
# __________________________________________________________________________________________________
# block6i_add (Add)               (None, 10, 10, 304)  0           block6i_drop[0][0]
#                                                                  block6h_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 10, 10, 1824) 554496      block6i_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 10, 10, 1824) 7296        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 10, 10, 1824) 0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 10, 10, 1824) 16416       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 10, 10, 1824) 7296        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 10, 10, 1824) 0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1824)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1824)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 76)     138700      block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 1824)   140448      block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 10, 10, 1824) 0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 10, 10, 512)  933888      block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 10, 10, 512)  2048        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, 10, 10, 3072) 1572864     block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, 10, 10, 3072) 12288       block7b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, 10, 10, 3072) 0           block7b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, 10, 10, 3072) 27648       block7b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, 10, 10, 3072) 12288       block7b_dwconv[0][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, 10, 10, 3072) 0           block7b_bn[0][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 3072)         0           block7b_activation[0][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 3072)   0           block7b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 128)    393344      block7b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 3072)   396288      block7b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, 10, 10, 3072) 0           block7b_activation[0][0]
#                                                                  block7b_se_expand[0][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, 10, 10, 512)  1572864     block7b_se_excite[0][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, 10, 10, 512)  2048        block7b_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_drop (FixedDropout)     (None, 10, 10, 512)  0           block7b_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, 10, 10, 512)  0           block7b_drop[0][0]
#                                                                  block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7c_expand_conv (Conv2D)    (None, 10, 10, 3072) 1572864     block7b_add[0][0]
# __________________________________________________________________________________________________
# block7c_expand_bn (BatchNormali (None, 10, 10, 3072) 12288       block7c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7c_expand_activation (Acti (None, 10, 10, 3072) 0           block7c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7c_dwconv (DepthwiseConv2D (None, 10, 10, 3072) 27648       block7c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7c_bn (BatchNormalization) (None, 10, 10, 3072) 12288       block7c_dwconv[0][0]
# __________________________________________________________________________________________________
# block7c_activation (Activation) (None, 10, 10, 3072) 0           block7c_bn[0][0]
# __________________________________________________________________________________________________
# block7c_se_squeeze (GlobalAvera (None, 3072)         0           block7c_activation[0][0]
# __________________________________________________________________________________________________
# block7c_se_reshape (Reshape)    (None, 1, 1, 3072)   0           block7c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7c_se_reduce (Conv2D)      (None, 1, 1, 128)    393344      block7c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7c_se_expand (Conv2D)      (None, 1, 1, 3072)   396288      block7c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7c_se_excite (Multiply)    (None, 10, 10, 3072) 0           block7c_activation[0][0]
#                                                                  block7c_se_expand[0][0]
# __________________________________________________________________________________________________
# block7c_project_conv (Conv2D)   (None, 10, 10, 512)  1572864     block7c_se_excite[0][0]
# __________________________________________________________________________________________________
# block7c_project_bn (BatchNormal (None, 10, 10, 512)  2048        block7c_project_conv[0][0]
# __________________________________________________________________________________________________
# block7c_drop (FixedDropout)     (None, 10, 10, 512)  0           block7c_project_bn[0][0]
# __________________________________________________________________________________________________
# block7c_add (Add)               (None, 10, 10, 512)  0           block7c_drop[0][0]
#                                                                  block7b_add[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 10, 10, 2048) 1048576     block7c_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 10, 10, 2048) 8192        top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 10, 10, 2048) 0           top_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           top_activation[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_1 (GaussianNoise (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         2098176     gaussian_noise_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           10250       dense_1[0][0]
# ==================================================================================================
# Total params: 30,621,946
# Trainable params: 30,449,210
# Non-trainable params: 172,736
# __________________________________________________________________________________________________

# %%
## fix for multi_gpu_model prediction time longer
from keras.layers import Lambda, concatenate
from keras import Model
import tensorflow as tf

def multi_gpu_model(model, gpus):
    if isinstance(gpus, (list, tuple)):
        num_gpus = len(gpus)
        target_gpu_ids = gpus
    else:
        num_gpus = gpus
        target_gpu_ids = range(num_gpus)

    def get_slice(data, i, parts):
        shape = tf.shape(data)
        batch_size = shape[:1]
        input_shape = shape[1:]
        step = batch_size // parts
        if i == num_gpus - 1:
            size = batch_size - step * i
        else:
            size = step
        size = tf.concat([size, input_shape], axis=0)
        stride = tf.concat([step, input_shape * 0], axis=0)
        start = stride * i
        return tf.slice(data, start, size)

    all_outputs = []
    for i in range(len(model.outputs)):
        all_outputs.append([])

    # Place a copy of the model on each GPU,
    # each getting a slice of the inputs.
    for i, gpu_id in enumerate(target_gpu_ids):
        with tf.device('/gpu:%d' % gpu_id):
            with tf.name_scope('replica_%d' % gpu_id):
                inputs = []
                # Retrieve a slice of the input.
                for x in model.inputs:
                    input_shape = tuple(x.get_shape().as_list())[1:]
                    slice_i = Lambda(get_slice,
                                   output_shape=input_shape,
                                   arguments={'i': i,
                                              'parts': num_gpus})(x)
                    inputs.append(slice_i)

                # Apply model on slice
                # (creating a model replica on the target device).
                outputs = model(inputs)
                if not isinstance(outputs, list):
                    outputs = [outputs]

                # Save the outputs for merging back together later.
                for o in range(len(outputs)):
                    all_outputs[o].append(outputs[o])

    # Merge outputs on CPU.
    with tf.device('/cpu:0'):
        merged = []
        for name, outputs in zip(model.output_names, all_outputs):
            merged.append(concatenate(outputs,
                                    axis=0, name=name))
        return Model(model.inputs, merged)

# %%
from keras.callbacks import Callback
import pickle
import sys

#Stop training on val_acc
class EarlyStoppingByAccVal(Callback):
    def __init__(self, monitor='val_acc', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current >= self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping" % epoch)
            self.model.stop_training = True

#Save large model using pickle formate instead of h5            
class SaveCheckPoint(Callback):
    def __init__(self, model, dest_folder):
        super(Callback, self).__init__()
        self.model = model
        self.dest_folder = dest_folder
        
        #initiate
        self.best_val_acc = 0
        self.best_val_loss = sys.maxsize #get max value
          
    def on_epoch_end(self, epoch, logs={}):
        val_acc = logs['val_acc']
        val_loss = logs['val_loss']

        if val_acc > self.best_val_acc:
            self.best_val_acc = val_acc
            
            # Save weights in pickle format instead of h5
            print('\nSaving val_acc %f at %s' %(self.best_val_acc, self.dest_folder))
            weigh= self.model.get_weights()

            #now, use pickle to save your model weights, instead of .h5
            #for heavy model architectures, .h5 file is unsupported.
            fpkl= open(self.dest_folder, 'wb') #Python 3
            pickle.dump(weigh, fpkl, protocol= pickle.HIGHEST_PROTOCOL)
            fpkl.close()
            
#             model.save('tmp.h5')
        elif val_acc == self.best_val_acc:
            if val_loss < self.best_val_loss:
                self.best_val_loss=val_loss
                
                # Save weights in pickle format instead of h5
                print('\nSaving val_acc %f at %s' %(self.best_val_acc, self.dest_folder))
                weigh= self.model.get_weights()

                #now, use pickle to save your model weights, instead of .h5
                #for heavy model architectures, .h5 file is unsupported.
                fpkl= open(self.dest_folder, 'wb') #Python 3
                pickle.dump(weigh, fpkl, protocol= pickle.HIGHEST_PROTOCOL)
                fpkl.close()

# %%
import numpy as np
import keras.backend as K
from PIL import Image

def get_cutout_v2(p=0.5, n_holes=2, length=20):
    def cutout(np_img):
        # print(type(image))
        # h = img.size(1)
        # w = img.size(2)
        img = Image.fromarray(((np_img)).astype(np.uint8))

        w, h = img.size
        mask = np.ones((h, w), np.float32)
        
        length = np.random.randint(low=w//16, high=w//4) #w=h

        for n in range(n_holes):
            y = np.random.randint(h)
            x = np.random.randint(w)

            y1 = np.clip(y - length // 2, 0, h)
            y2 = np.clip(y + length // 2, 0, h)
            x1 = np.clip(x - length // 2, 0, w)
            x2 = np.clip(x + length // 2, 0, w)

            mask[y1: y2, x1: x2] = 0.

        # mask = torch.from_numpy(mask)

        # ary = np.random.normal(size=(2, 2))
        # mask = K.cast(mask, dtype='float32')

        # mask = mask.expand_as(img)

        mask = np.expand_dims(mask, axis=2)

        re_img = img * mask

        return preprocess_input(re_img)
        # return re_img

    return cutout

# %%
ls -l

# %%
mkdir checkpoints

# %%
# %mkdir svhn_output
# %mkdir svhn_output/logs

# %%
#Non-Groups
#Split training and validation
#Using Expert Data

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil
import multiprocessing

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
#     horizontal_flip=True,
#     vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    # preprocessing_function=get_cutout_v2(),
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

NUM_GPU = 3
batch_size = 48

train_set = train_datagen.flow_from_directory('train_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('test_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'st'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'SVHN_EffB5_299_v2.hdf5')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('svhn_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('svhn_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.9900, verbose=1)

#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    model_mul = multi_gpu_model(model_1, gpus=NUM_GPU)
else:
    model_mul = model_1
    
epochs = 20##!!!
lr = 1e-3
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

step_size_train=ceil(train_set.n/train_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[earlystopping],
    callbacks=[csv_logger, checkpointer, earlystopping],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# Found 604388 images belonging to 10 classes.
# Found 26032 images belonging to 10 classes.
# Epoch 1/20
#  5670/12592 [============>.................] - ETA: 3:36:28 - loss: 0.2472 - acc: 0.9269
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 12592/12592 [==============================] - 22436s 2s/step - loss: 0.1858 - acc: 0.9457 - val_loss: 0.1136 - val_acc: 0.9741
#
# Epoch 00001: val_acc improved from -inf to 0.97411, saving model to checkpoints/SVHN_EffB5_299_v2.hdf5
# Epoch 2/20
#  2254/12592 [====>.........................] - ETA: 4:03:12 - loss: 0.1151 - acc: 0.9682
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#  8170/12592 [==================>...........] - ETA: 1:43:49 - loss: 0.1060 - acc: 0.9706
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#  4947/12592 [==========>...................] - ETA: 3:00:27 - loss: 0.0843 - acc: 0.9765
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 12592/12592 [==============================] - 18002s 1s/step - loss: 0.0826 - acc: 0.9773 - val_loss: 0.0869 - val_acc: 0.9802
#
# Epoch 00003: val_acc improved from 0.97803 to 0.98022, saving model to checkpoints/SVHN_EffB5_299_v2.hdf5
# Epoch 4/20
#  1174/12592 [=>............................] - ETA: 4:25:58 - loss: 0.0775 - acc: 0.9793
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#  9770/12592 [======================>.......] - ETA: 1:05:44 - loss: 0.0734 - acc: 0.9801
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#  3194/12592 [======>.......................] - ETA: 3:43:27 - loss: 0.0670 - acc: 0.9820
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 12592/12592 [==============================] - 18178s 1s/step - loss: 0.0659 - acc: 0.9824 - val_loss: 0.0751 - val_acc: 0.9837
#
# Epoch 00005: val_acc improved from 0.98244 to 0.98371, saving model to checkpoints/SVHN_EffB5_299_v2.hdf5
# Epoch 6/20
#  4170/12592 [========>.....................] - ETA: 3:20:14 - loss: 0.0630 - acc: 0.9834
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 12592/12592 [==============================] - 18136s 1s/step - loss: 0.0614 - acc: 0.9837 - val_loss: 0.0695 - val_acc: 0.9847
#
# Epoch 00006: val_acc improved from 0.98371 to 0.98471, saving model to checkpoints/SVHN_EffB5_299_v2.hdf5
# Epoch 7/20
#   428/12592 [>.............................] - ETA: 4:47:43 - loss: 0.0554 - acc: 0.9862
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#  8906/12592 [====================>.........] - ETA: 1:27:13 - loss: 0.0572 - acc: 0.9850
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#  9554/12592 [=====================>........] - ETA: 1:11:47 - loss: 0.0548 - acc: 0.9857
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#  5445/12592 [===========>..................] - ETA: 2:48:37 - loss: 0.0513 - acc: 0.9865
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 11810/12592 [===========================>..] - ETA: 18:30 - loss: 0.0521 - acc: 0.9864
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 11239/12592 [=========================>....] - ETA: 32:07 - loss: 0.0493 - acc: 0.9872
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#  6667/12592 [==============>...............] - ETA: 2:19:06 - loss: 0.0485 - acc: 0.9874
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 12592/12592 [==============================] - 18043s 1s/step - loss: 0.0484 - acc: 0.9875 - val_loss: 0.0694 - val_acc: 0.9857
#
# Epoch 00011: val_acc did not improve from 0.98671
# Epoch 12/20
#  2182/12592 [====>.........................] - ETA: 4:05:29 - loss: 0.0463 - acc: 0.9876
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#  9830/12592 [======================>.......] - ETA: 1:05:38 - loss: 0.0460 - acc: 0.9882
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#    45/12592 [..............................] - ETA: 4:51:19 - loss: 0.0464 - acc: 0.9889

# %%
#Non-Groups
#Split training and validation
#Using Expert Data

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil
import multiprocessing

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
#     horizontal_flip=True,
#     vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    # preprocessing_function=get_cutout_v2(),
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

NUM_GPU = 3
batch_size = 48

train_set = train_datagen.flow_from_directory('train_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('test_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'st'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'SVHN_EffB5_299_v2_tmp.hdf5')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('svhn_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('svhn_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.9900, verbose=1)

#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    model_mul = multi_gpu_model(model_1, gpus=NUM_GPU)
else:
    model_mul = model_1
    
epochs = 20##!!!
lr = 1e-3
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

step_size_train=ceil(train_set.n/train_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[earlystopping],
    callbacks=[csv_logger, checkpointer, earlystopping],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# Found 604388 images belonging to 10 classes.
# Found 26032 images belonging to 10 classes.
# WARNING:tensorflow:From /home/phong/Documents/venv/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
#    83/12592 [..............................] - ETA: 8:51:51 - loss: 1.3136 - acc: 0.5512
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-8258bb599223> in <module>
#      99     callbacks=[csv_logger, checkpointer, earlystopping],
#     100 #     callbacks=[tb, csv_logger, checkpointer, earlystopping],
# --> 101     verbose=1)
#
# ~/Documents/venv/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/Documents/venv/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# ~/Documents/venv/lib/python3.6/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# ~/Documents/venv/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# ~/Documents/venv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/Documents/venv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/Documents/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
model_mul.load_weights(os.path.join('checkpoints', 'SVHN_EffB2_299_v2.hdf5'))

# %%
#Non-Groups
#Split training and validation
#Using Expert Data

savedfilename = os.path.join('checkpoints', 'SVHN_EffB5_299_v2_L2.hdf5')
checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

epochs = 15##!!!
lr = 1e-4
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[earlystopping, checkpointer],
    callbacks=[csv_logger, checkpointer, earlystopping],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# Epoch 1/15
# 12592/12592 [==============================] - 14590s 1s/step - loss: 0.0441 - acc: 0.9888 - val_loss: 0.0684 - val_acc: 0.9863
#
# Epoch 00001: val_acc improved from -inf to 0.98632, saving model to checkpoints/SVHN_EffB5_299_v2_L2.hdf5
# Epoch 2/15
# 12592/12592 [==============================] - 14716s 1s/step - loss: 0.0434 - acc: 0.9890 - val_loss: 0.0665 - val_acc: 0.9867
#
# Epoch 00002: val_acc improved from 0.98632 to 0.98675, saving model to checkpoints/SVHN_EffB5_299_v2_L2.hdf5
# Epoch 3/15
# 12592/12592 [==============================] - 14631s 1s/step - loss: 0.0430 - acc: 0.9890 - val_loss: 0.0688 - val_acc: 0.9867
#
# Epoch 00003: val_acc did not improve from 0.98675
# Epoch 4/15
# 12592/12592 [==============================] - 14587s 1s/step - loss: 0.0419 - acc: 0.9893 - val_loss: 0.0713 - val_acc: 0.9869
#
# Epoch 00004: val_acc improved from 0.98675 to 0.98690, saving model to checkpoints/SVHN_EffB5_299_v2_L2.hdf5
# Epoch 5/15
# 12592/12592 [==============================] - 14647s 1s/step - loss: 0.0410 - acc: 0.9895 - val_loss: 0.0672 - val_acc: 0.9869
#
# Epoch 00005: val_acc improved from 0.98690 to 0.98694, saving model to checkpoints/SVHN_EffB5_299_v2_L2.hdf5
# Epoch 6/15
# 12592/12592 [==============================] - 14615s 1s/step - loss: 0.0398 - acc: 0.9898 - val_loss: 0.0640 - val_acc: 0.9874
#
# Epoch 00006: val_acc improved from 0.98694 to 0.98744, saving model to checkpoints/SVHN_EffB5_299_v2_L2.hdf5
# Epoch 7/15
# 11043/12592 [=========================>....] - ETA: 29:21 - loss: 0.0397 - acc: 0.9900
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 12592/12592 [==============================] - 15679s 1s/step - loss: 0.0390 - acc: 0.9901 - val_loss: 0.0691 - val_acc: 0.9867
#
# Epoch 00008: val_acc did not improve from 0.98744
# Epoch 9/15
# 12592/12592 [==============================] - 17951s 1s/step - loss: 0.0380 - acc: 0.9903 - val_loss: 0.0686 - val_acc: 0.9871
#
# Epoch 00009: val_acc did not improve from 0.98744
# Epoch 10/15
# 12592/12592 [==============================] - 14790s 1s/step - loss: 0.0367 - acc: 0.9907 - val_loss: 0.0668 - val_acc: 0.9871
#
# Epoch 00010: val_acc did not improve from 0.98744
# Epoch 11/15
#  4001/12592 [========>.....................] - ETA: 2:41:51 - loss: 0.0374 - acc: 0.9904
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-3bb7482968e0> in <module>
#      25     callbacks=[csv_logger, checkpointer, earlystopping],
#      26 #     callbacks=[tb, csv_logger, checkpointer, earlystopping],
# ---> 27     verbose=1)
#
# ~/Documents/venv/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/Documents/venv/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# ~/Documents/venv/lib/python3.6/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# ~/Documents/venv/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# ~/Documents/venv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/Documents/venv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/Documents/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
model_mul.load_weights(os.path.join('checkpoints', 'SVHN_EffB2_299_v2_L2.hdf5'))

# %%
#Non-Groups
#Split training and validation
#Using Expert Data

savedfilename = os.path.join('checkpoints', 'SVHN_EffB0_299_v2_L3.hdf5')
checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

epochs = 15##!!!
lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[earlystopping, checkpointer],
    callbacks=[csv_logger, checkpointer, earlystopping],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)

# %%
model_mul.load_weights(os.path.join('checkpoints', 'SVHN_EffB5_299_v2_L2.hdf5'))

# %%
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
import time, os
from math import ceil

# PREDICT ON OFFICIAL TEST
train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
#     horizontal_flip=True,
#     vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

test_datagen1 = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

batch_size = 36

train_set = train_datagen.flow_from_directory('train_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

test_set1 = test_datagen1.flow_from_directory('test_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

# if NUM_GPU != 1:
predict1=model_mul.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
# else:
#     predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
predicted_class_indices=np.argmax(predict1,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions1 = [labels[k] for k in predicted_class_indices]

import pandas as pd

filenames=test_set1.filenames
results=pd.DataFrame({"file_name":filenames,
                      "predicted1":predictions1,
                      })
results.to_csv('SVHN_Eff_B5_299_v2_L2_0610.csv')
results.head()
# Out:
# Found 604388 images belonging to 10 classes.
# Found 26032 images belonging to 10 classes.
# 724/724 [==============================] - 293s 405ms/step
#      file_name predicted1
# 0  1/00002.png          1
# 1  1/00005.png          1
# 2  1/00007.png          1
# 3  1/00008.png          1
# 4  1/00013.png          1

# %%
np.save(os.path.join('pred_npy','SVHN_Eff_B5_299_v2_L2_0610.npy'), predict1)
