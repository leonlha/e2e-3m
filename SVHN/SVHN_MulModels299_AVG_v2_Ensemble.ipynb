# %%
ls -l

# %%
cd /media/datastorage/Phong/svhn_v2
# Out:
# /media/datastorage/Phong/svhn_v2

# %%
ls -l

# %%
mkdir pred_npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_Eff_B0_299_v2.npy pred_npy/SVHN_Eff_B0_299_v2.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_Eff_B0_299_v2_L2_2109.npy pred_npy/SVHN_Eff_B0_299_v2_L2_2109.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_Eff_B2_299_v2_2409.npy pred_npy/SVHN_Eff_B2_299_v2_2409.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_Eff_B2_299_v2_L2_2609.npy pred_npy/SVHN_Eff_B2_299_v2_L2_2609.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_Eff_B3_299_v2_2909.npy pred_npy/SVHN_Eff_B3_299_v2_2909.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_Eff_B3_299_v2_L2_0110.npy pred_npy/SVHN_Eff_B3_299_v2_L2_0110.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_Eff_B5_299_v2_0410.npy pred_npy/SVHN_Eff_B5_299_v2_0410.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_Eff_B5_299_v2_L2_0610.npy pred_npy/SVHN_Eff_B5_299_v2_L2_0610.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_MulModels299_v2_InpResNetV2_L2.npy pred_npy/SVHN_MulModels299_v2_InpResNetV2_L2.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_Xception_299_v2_1310_01.npy pred_npy/SVHN_Xception_299_v2_1310.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_SVHN_IcpResNetV2_299_v2_r2.npy pred_npy/SVHN_IcpResNetV2_299_v2_r2.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_Xception_299_v2_L2_1610_01.npy pred_npy/SVHN_Xception_299_v2_L2_1610_01.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_IcpResNetV2_299_v2_r2_L2_1710.npy pred_npy/SVHN_IcpResNetV2_299_v2_r2_L2_1710.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_Xception_299_v2_512_2010_v1.npy pred_npy/SVHN_Xception_299_v2_512_2010_v1.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_Xception_299_v2_3GPU_2110_v1.npy pred_npy/SVHN_Xception_299_v2_3GPU_2110_v1.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_Xception_299_v2_512_L2_2310_v1.npy pred_npy/SVHN_Xception_299_v2_512_L2_2310_v1.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_Xception_299_v2_3GPU_L2_2310_v1.npy pred_npy/SVHN_Xception_299_v2_3GPU_L2_2310_v1.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_EffB0_299_v2_upgraded_0411.npy pred_npy/SVHN_EffB0_299_v2_upgraded_0411.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_EffB0_299_v2_upgraded_r2_1111.npy pred_npy/SVHN_EffB0_299_v2_upgraded_r2_1111.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_EffB0_299_v2_upgraded_r2_L2_1511.npy pred_npy/SVHN_EffB0_299_v2_upgraded_r2_L2_1511.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_EffB3_299_v2_upgraded_2211.npy pred_npy/SVHN_EffB3_299_v2_upgraded_2211.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_EffB3_299_v2_upgraded_L2_2611.npy pred_npy/SVHN_EffB3_299_v2_upgraded_L2_2611.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_IcpResNetV2_299_v3_upgraded_0112.npy pred_npy/SVHN_IcpResNetV2_299_v3_upgraded_0112.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_IcpResNetV2_299_v3_upgraded_L2_r1_0312.npy pred_npy/SVHN_IcpResNetV2_299_v3_upgraded_L2_r1_0312.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_IcpResNetV2_299_v4_upgraded_1012.npy pred_npy/SVHN_IcpResNetV2_299_v4_upgraded_1012.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_IcpResNetV2_299_v4_upgraded_L2_1312.npy pred_npy/SVHN_IcpResNetV2_299_v4_upgraded_L2_1312.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_IcpResNetV2_299_v4_upgraded_L3_1412.npy pred_npy/SVHN_IcpResNetV2_299_v4_upgraded_L3_1412.npy

# %%
cp /home/bribeiro/Phong/Nat19/SVHN_Xception_299_v3_upgraded_L2_2612.npy pred_npy/SVHN_Xception_299_v3_upgraded_L2_2612.npy

# %%
import numpy as np
import os

# mean_pred3_1 = np.load(os.path.join('pred_npy','SVHN_Eff_B0_299_v2.npy'))
# mean_pred3_2 = np.load(os.path.join('pred_npy','SVHN_EffB4_299_v2.npy'))
mean_pred3_3 = np.load(os.path.join('pred_npy','SVHN_EffB4_299_v2_L3.npy'))
mean_pred3_4 = np.load(os.path.join('pred_npy','SVHN_Eff_B0_299_v2_L2_2109.npy'))
mean_pred3_5 = np.load(os.path.join('pred_npy','SVHN_EffB1_299_v2.npy'))
# mean_pred3_6 = np.load(os.path.join('pred_npy','SVHN_Eff_B2_299_v2_2409.npy'))
mean_pred3_7 = np.load(os.path.join('pred_npy','SVHN_Eff_B2_299_v2_L2_2609.npy'))
# mean_pred3_8 = np.load(os.path.join('pred_npy','SVHN_Eff_B3_299_v2_2909.npy'))
mean_pred3_9 = np.load(os.path.join('pred_npy','SVHN_Eff_B3_299_v2_L2_0110.npy'))
mean_pred3_10 = np.load(os.path.join('pred_npy','SVHN_EffB7_299_v2.npy'))
# mean_pred3_11 = np.load(os.path.join('pred_npy','SVHN_Eff_B5_299_v2_0410.npy'))
# mean_pred3_12 = np.load(os.path.join('pred_npy','SVHN_Eff_B7_299_v2_L2_0510.npy'))
mean_pred3_13 = np.load(os.path.join('pred_npy','SVHN_Eff_B5_299_v2_L2_0610.npy'))
mean_pred3_14 = np.load(os.path.join('pred_npy','SVHN_Eff_B6_299_v2_0810.npy'))
mean_pred3_15 = np.load(os.path.join('pred_npy','SVHN_Eff_B6_299_v2_L2_1010.npy'))
mean_pred3_16 = np.load(os.path.join('pred_npy','SVHN_MulModels299_v2_InpResNetV2_L2.npy'))
mean_pred3_17 = np.load(os.path.join('pred_npy','SVHN_SEResNext101_299_v2.npy'))
mean_pred3_18 = np.load(os.path.join('pred_npy','SVHN_Xception_299_v2_1310.npy'))
mean_pred3_19 = np.load(os.path.join('pred_npy','SVHN_IcpResNetV2_299_v2_r2.npy'))
mean_pred3_20 = np.load(os.path.join('pred_npy','SVHN_SEResNext101_299_v2_L2_1510.npy'))
mean_pred3_21 = np.load(os.path.join('pred_npy','SVHN_Xception_299_v2_L2_1610_01.npy'))
mean_pred3_21_v2 = np.load(os.path.join('pred_npy','SVHN_Xception_299_v2_L2_1610_01.npy'))
mean_pred3_22 = np.load(os.path.join('pred_npy','SVHN_EffB1_299_v2_L2_1710.npy'))
mean_pred3_23 = np.load(os.path.join('pred_npy','SVHN_IcpResNetV2_299_v2_r2_L2_1710.npy'))
mean_pred3_24 = np.load(os.path.join('pred_npy','SVHN_Xception_299_v2_512_2010_v1.npy'))
mean_pred3_25 = np.load(os.path.join('pred_npy','SVHN_Xception_299_v2_3GPU_2110_v1.npy'))
mean_pred3_26 = np.load(os.path.join('pred_npy','SVHN_EffB1_299_v2_upgraded_2110.npy'))
mean_pred3_27 = np.load(os.path.join('pred_npy','SVHN_Xception_299_v2_512_L2_2310_v1.npy'))
mean_pred3_28 = np.load(os.path.join('pred_npy','SVHN_Xception_299_v2_3GPU_L2_2310_v1.npy'))
mean_pred3_29 = np.load(os.path.join('pred_npy','SVHN_EffB1_299_v2_upgraded_L2_2310.npy'))
mean_pred3_30 = np.load(os.path.join('pred_npy','SVHN_EffB4_299_v2_upgraded_2510.npy'))
mean_pred3_31 = np.load(os.path.join('pred_npy','SVHN_EffB4_299_v2_upgraded_L2_2710.npy'))
mean_pred3_32 = np.load(os.path.join('pred_npy','SVHN_EffB4_299_v2_upgraded_batch64_3010.npy'))
mean_pred3_33 = np.load(os.path.join('pred_npy','SVHN_EffB2_299_v2_upgraded_0111.npy'))
mean_pred3_34 = np.load(os.path.join('pred_npy','SVHN_EffB2_299_v2_upgraded_L2_0411.npy'))
mean_pred3_35 = np.load(os.path.join('pred_npy','SVHN_EffB0_299_v2_upgraded_0411.npy'))
mean_pred3_36 = np.load(os.path.join('pred_npy','SVHN_EffB2_299_v2_upgraded_r2_0711.npy'))
mean_pred3_37 = np.load(os.path.join('pred_npy','SVHN_EffB2_299_v2_upgraded_r2_L2_0911.npy'))
mean_pred3_38 = np.load(os.path.join('pred_npy','SVHN_EffB0_299_v2_upgraded_r2_1111.npy'))
mean_pred3_39 = np.load(os.path.join('pred_npy','SVHN_EffB5_299_v2_upgraded_1211.npy'))
mean_pred3_40 = np.load(os.path.join('pred_npy','SVHN_EffB5_299_v2_upgraded_L2_1411.npy'))
mean_pred3_41 = np.load(os.path.join('pred_npy','SVHN_EffB0_299_v2_upgraded_r2_L2_1511.npy'))
mean_pred3_42 = np.load(os.path.join('pred_npy','SVHN_EffB6_299_v2_upgraded_1811.npy'))
mean_pred3_43 = np.load(os.path.join('pred_npy','SVHN_EffB6_299_v2_upgraded_2211.npy'))
mean_pred3_44 = np.load(os.path.join('pred_npy','SVHN_EffB3_299_v2_upgraded_2211.npy'))
mean_pred3_45 = np.load(os.path.join('pred_npy','SVHN_EffB7_299_v2_upgraded_2611.npy'))
mean_pred3_46 = np.load(os.path.join('pred_npy','SVHN_EffB3_299_v2_upgraded_L2_2611.npy'))
mean_pred3_47 = np.load(os.path.join('pred_npy','SVHN_EffB7_299_v2_L2_upgraded_2911.npy'))
mean_pred3_48 = np.load(os.path.join('pred_npy','SVHN_IcpResNetV2_299_v3_upgraded_0112.npy'))
mean_pred3_49 = np.load(os.path.join('pred_npy','SVHN_EffB1_299_v3_upgraded_0212.npy'))
mean_pred3_50 = np.load(os.path.join('pred_npy','SVHN_IcpResNetV2_299_v3_upgraded_L2_r1_0312.npy'))
mean_pred3_51 = np.load(os.path.join('pred_npy','SVHN_EffB1_299_v3_upgraded_L2_0311.npy'))
mean_pred3_52 = np.load(os.path.join('pred_npy','SVHN_EffB1_299_v4_upgraded_0812.npy'))
mean_pred3_53 = np.load(os.path.join('pred_npy','SVHN_EffB1_299_v4_upgraded_1012.npy'))
mean_pred3_54 = np.load(os.path.join('pred_npy','SVHN_EffB1_299_v4_upgraded_L3_1112.npy'))
mean_pred3_55 = np.load(os.path.join('pred_npy','SVHN_IcpResNetV2_299_v4_upgraded_1012.npy'))
mean_pred3_56 = np.load(os.path.join('pred_npy','SVHN_IcpResNetV2_299_v4_upgraded_L2_1312.npy'))
mean_pred3_57 = np.load(os.path.join('pred_npy','SVHN_IcpResNetV2_299_v4_upgraded_L3_1412.npy'))
mean_pred3_58 = np.load(os.path.join('pred_npy','SVHN_EffB2_299_v4_upgraded_1712.npy'))
mean_pred3_59 = np.load(os.path.join('pred_npy','SVHN_EffB2_299_v4_upgraded_L2_1912.npy'))
mean_pred3_60 = np.load(os.path.join('pred_npy','SVHN_EffB2_299_v4_upgraded_L3_2112.npy'))

# %%
mean_pred3_61 = np.load(os.path.join('pred_npy','SVHN_EffB1_299_v5_upgraded_L1_2410.npy'))
mean_pred3_62 = np.load(os.path.join('pred_npy','SVHN_EffB1_299_v5_upgraded_L2_2410.npy'))
mean_pred3_63 = np.load(os.path.join('pred_npy','SVHN_EffB5_299_v5_upgraded_2512.npy'))

# %%
mean_pred3_64 = np.load(os.path.join('pred_npy','SVHN_Xception_299_v3_upgraded_L2_2612.npy'))

# %%
a1 = mean_pred3_1
a2 = mean_pred3_2
a3 = mean_pred3_3
a4 = mean_pred3_4
a5 = mean_pred3_5

# %%
# mean_a12 = (mean_pred3_1+mean_pred3_2)/2
# mean_a13 = (mean_pred3_1+mean_pred3_3)/2
# mean_a23 = (mean_pred3_2+mean_pred3_3)/2
# mean_a34 = (mean_pred3_3+mean_pred3_4)/2
# mean_a123 = (mean_pred3_1+mean_pred3_2+mean_pred3_3)/3
# mean_a234 = (mean_pred3_2+mean_pred3_3+mean_pred3_4)/3
# mean_a345 = (mean_pred3_3+mean_pred3_4+mean_pred3_5)/3
# mean_a3456 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_6)/4
# mean_a3457 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_7)/4
# mean_a347 = (mean_pred3_3+mean_pred3_4+mean_pred3_7)/3
# mean_a3478 = (mean_pred3_3+mean_pred3_4+mean_pred3_7+mean_pred3_8)/4
# mean_a3458 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_8)/4
mean_a3459 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_9)/4
mean_a345910 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_9+mean_pred3_10)/5
# mean_a34591011 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_9+mean_pred3_10+mean_pred3_11)/6
# mean_a3451011 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_10+mean_pred3_11)/5
# mean_a345912 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_9+mean_pred3_12)/5
mean_a34591013 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_9+mean_pred3_10+mean_pred3_13)/6
mean_a34591014713 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_7+mean_pred3_13)/8
mean_a3459101416 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_16)/7
mean_a345910141617 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_16+mean_pred3_17)/8
mean_a345910141618 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_16+mean_pred3_18)/8
mean_a34591014161718 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_16+mean_pred3_17+mean_pred3_18)/9
mean_a3459101419 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19)/7
mean_a345910141920 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_20)/8
mean_a345910141921 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_21)/8
mean_a345910141921_v2 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_21_v2)/8
mean_a345910141922 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_22)/8
mean_a3459101423 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_23)/7
mean_a345910141925 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_25)/8
mean_a345910141926 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_26)/8
mean_a34910141926 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_26)/7
mean_a345910141927 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_27)/8
mean_a345910141928 = (mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_28)/8
mean_a34910141929 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_29)/7
mean_a491014192930 = (mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_29+mean_pred3_30)/7
mean_a491014192931 = (mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_29+mean_pred3_31)/7
mean_a491014192932 = (mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_29+mean_pred3_32)/7
mean_a3491014192933 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_29+mean_pred3_33)/8
mean_a3491014192934 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_29+mean_pred3_34)/8
mean_a3491014192935 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_29+mean_pred3_35)/8
mean_a34910141934 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_34)/7
mean_a3491014192936 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_29+mean_pred3_36)/8
mean_a3491014192937 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_29+mean_pred3_37)/8
mean_a391014192938 = (mean_pred3_3+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_29+mean_pred3_38)/7
mean_a3491014192939 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_29+mean_pred3_39)/8
mean_a3491014192940 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_29+mean_pred3_40)/8
mean_a39101419293941 = (mean_pred3_3+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_29+mean_pred3_39+mean_pred3_41)/8
mean_a3491019293942 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_19+mean_pred3_29+mean_pred3_39+mean_pred3_42)/8
mean_a3491019293943 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_19+mean_pred3_29+mean_pred3_39+mean_pred3_43)/8
mean_a34101419293944 = (mean_pred3_3+mean_pred3_4+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_29+mean_pred3_39+mean_pred3_44)/8
mean_a3491419293945 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_14+mean_pred3_19+mean_pred3_29+mean_pred3_39+mean_pred3_45)/8
mean_a3491014192939_v2 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_29+mean_pred3_39)/8
mean_a34101419293946 = (mean_pred3_3+mean_pred3_4+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_29+mean_pred3_39+mean_pred3_46)/8
mean_a3491419293947 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_14+mean_pred3_19+mean_pred3_29+mean_pred3_39+mean_pred3_47)/8
mean_a3491014293948 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_29+mean_pred3_39+mean_pred3_48)/8
mean_a3491014394849 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_39+mean_pred3_48+mean_pred3_49)/8
mean_a3491014293950 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_29+mean_pred3_39+mean_pred3_50)/8
mean_a3491014394851 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_39+mean_pred3_48+mean_pred3_51)/8
mean_a3491014394852 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_39+mean_pred3_48+mean_pred3_52)/8
mean_a3491014394853 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_39+mean_pred3_48+mean_pred3_53)/8
mean_a3491014394854 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_39+mean_pred3_48+mean_pred3_54)/8
mean_a3491014293955 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_29+mean_pred3_39+mean_pred3_55)/8
mean_a3491014293956 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_29+mean_pred3_39+mean_pred3_56)/8
mean_a3491014293957 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_29+mean_pred3_39+mean_pred3_57)/8
mean_a349101429394858 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_29+mean_pred3_39+mean_pred3_48+mean_pred3_58)/9
mean_a349101429394859 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_29+mean_pred3_39+mean_pred3_48+mean_pred3_59)/9
mean_a349101429394860 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_29+mean_pred3_39+mean_pred3_48+mean_pred3_60)/9

# %%
mean_a34910141961 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_61)/7
mean_a34910141962 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_62)/7
mean_a3491014196263 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_62+mean_pred3_63)/8
mean_a3491014196239 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_62+mean_pred3_39)/8

# %%
mean_a349101419396264 = (mean_pred3_3+mean_pred3_4+mean_pred3_9+mean_pred3_10+mean_pred3_14+mean_pred3_19+mean_pred3_39+mean_pred3_62+mean_pred3_64)/9

# %%
from keras.preprocessing.image import ImageDataGenerator
from math import ceil
import numpy as np

batch_size = 20

#Crop-Official Test
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

def crop_generator(batches, crop_length):
    """Generate random crops from the image batches"""
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

train_datagen = ImageDataGenerator(

)

train_set = train_datagen.flow_from_directory('train_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )
        
test_datagen_crop = ImageDataGenerator(
)

testing_set_crop = test_datagen_crop.flow_from_directory('test_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="training"
                                              )
#customized generator
test_crops = crop_generator(testing_set_crop, 299)

step_size_test_crop = ceil(testing_set_crop.n/testing_set_crop.batch_size)

predicted_class_indices_mean=np.argmax(mean_a349101419396264,axis=1)####!!!!
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('SVHN_2612_mean_a349101419396264_v1.csv')####!!!!
results.head(5)
# Out:
# Found 604388 images belonging to 10 classes.
# Found 26032 images belonging to 10 classes.
#             id predicted
# 0  1/00002.png         1
# 1  1/00005.png         1
# 2  1/00007.png         1
# 3  1/00008.png         1
# 4  1/00013.png         1

# %%
cp SVHN_2612_mean_a349101419396264_v1.csv /home/bribeiro/Phong/Nat19/SVHN_2612_mean_a349101419396264_v1.csv

# %%
ls
# Out:
# checkpoints/
# Cifar100_MulModels299_AVG_Assembe_2408_meanx34.csv
# cuda/
# cudnn-11.1-linux-x64-v8.0.4.30.tgz
# extra_32x32.mat
# libcudnn8_8.0.3.33-1+cuda11.0_amd64.deb
# pred_npy/
# SVHN_Eff_B1_299_v2_2309.csv
# SVHN_EffB1_299_v2_L2_1710.csv
# SVHN_EffB1_299_v2_upgraded_1910.csv
# SVHN_EffB1_299_v2_upgraded_2110.csv
# SVHN_EffB1_299_v2_upgraded_L2_2310.csv
# SVHN_EffB2_299_v2_upgraded_0111.csv
# SVHN_EffB2_299_v2_upgraded_L2_0411.csv
# SVHN_EffB2_299_v2_upgraded_r2_0711.csv
# SVHN_EffB2_299_v2_upgraded_r2_L2_0911.csv
# SVHN_Eff_B4_224_STD_L2_0709_v1.csv
# SVHN_Eff_B4_224_STD_L2_0909_v1.csv
# SVHN_Eff_B4_299_L2_1509_v1.csv
# SVHN_Eff_B4_299_v2_2009.csv
# SVHN_Eff_B4_299_v2_L3_2109.csv
# SVHN_EffB4_299_v2_upgraded_2510.csv
# SVHN_EffB4_299_v2_upgraded_batch64_3010.csv
# SVHN_EffB4_299_v2_upgraded_L2_2710.csv
# SVHN_EffB5_299_v2_upgraded_1211.csv
# SVHN_EffB5_299_v2_upgraded_L2_1411.csv
# SVHN_Eff_B6_299_v2_0810.csv
# SVHN_Eff_B6_299_v2_L2_1010.csv
# ...

# %%
#1&3
predicted_class_indices_mean=np.argmax(mean_a13,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_2408_meana13.csv')

# %%
cp Cifar100_MulModels299_AVG_Assembe_2408_meana13.csv /home/bribeiro/Phong/Nat19/Cifar100_2408_meana13.csv

# %%
#2&3
predicted_class_indices_mean=np.argmax(mean_a23,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_2408_meana23.csv')

# %%
cp Cifar100_MulModels299_AVG_Assembe_2408_meana23.csv /home/bribeiro/Phong/Nat19/Cifar100_2408_meana23.csv

# %%
#x1
for i in range(len(x1)):
    i_max = np.argmax(x1[i], axis=0)
    for idx in range(10):
        if idx != i_max:
            x1[i][idx] = 0
        else:
            x1[i][idx] = 1            
# print(a1)

# %%
#x2
for i in range(len(x2)):
    i_max = np.argmax(x2[i], axis=0)
    for idx in range(10):
        if idx != i_max:
            x2[i][idx] = 0
        else:
            x2[i][idx] = 1            
# print(a1)

# %%
#x3
for i in range(len(x3)):
    i_max = np.argmax(x3[i], axis=0)
    for idx in range(10):
        if idx != i_max:
            x3[i][idx] = 0
        else:
            x3[i][idx] = 1            
# print(a1)

# %%
#x4
for i in range(len(x4)):
    i_max = np.argmax(x4[i], axis=0)
    for idx in range(10):
        if idx != i_max:
            x4[i][idx] = 0
        else:
            x4[i][idx] = 1            
# print(a1)

# %%
#x5
for i in range(len(x5)):
    i_max = np.argmax(x5[i], axis=0)
    for idx in range(10):
        if idx != i_max:
            x5[i][idx] = 0
        else:
            x5[i][idx] = 1            
# print(a1)

# %%
mean_x34 = (x3+x4)/2

# %%
from keras.preprocessing.image import ImageDataGenerator
from math import ceil
import numpy as np

batch_size = 20

#Crop-Official Test
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

def crop_generator(batches, crop_length):
    """Generate random crops from the image batches"""
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

train_datagen = ImageDataGenerator(

)

train_set = train_datagen.flow_from_directory('train_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )
        
test_datagen_crop = ImageDataGenerator(
)

testing_set_crop = test_datagen_crop.flow_from_directory('test_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="training"
                                              )
#customized generator
test_crops = crop_generator(testing_set_crop, 299)

step_size_test_crop = ceil(testing_set_crop.n/testing_set_crop.batch_size)

predicted_class_indices_mean=np.argmax(mean_x34,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('SVHN_MulModels299_AVG_Assembe_2109_meanx34.csv')
results.head(5)
# Out:
# Found 604388 images belonging to 10 classes.
# Found 26032 images belonging to 10 classes.
#             id predicted
# 0  1/00002.png         1
# 1  1/00005.png         1
# 2  1/00007.png         1
# 3  1/00008.png         1
# 4  1/00013.png         1

# %%
cp SVHN_MulModels299_AVG_Assembe_2109_meanx34.csv /home/bribeiro/Phong/Nat19/SVHN_2109_meanx34.csv

# %%
mean_x34_v2 = mean_a34

#x1
for i in range(len(mean_x34_v2)):
    i_max = np.argmax(mean_x34_v2[i], axis=0)
    for idx in range(10):
        if idx != i_max:
            mean_x34_v2[i][idx] = 0
        else:
            mean_x34_v2[i][idx] = 1            
# print(a1)

# %%
predicted_class_indices_mean=np.argmax(mean_x34_v2,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('SVHN_MulModels299_AVG_Assembe_2109_meanx34_v2_l2.csv')
results.head(5)
# Out:
#             id predicted
# 0  1/00002.png         1
# 1  1/00005.png         1
# 2  1/00007.png         1
# 3  1/00008.png         1
# 4  1/00013.png         1

# %%
cp SVHN_MulModels299_AVG_Assembe_2109_meanx34_v2_l2.csv /home/bribeiro/Phong/Nat19/SVHN_2109_meanx34_v2_l2.csv

# %%
mean_x12 = (x1+x2)/2
mean_x13 = (x1+x3)/2
mean_x23 = (x2+x3)/2

# %%
mean_x123 = (x1+x2+x3)/3
mean_x1234 = (x1+x2+x3+x4)/4
mean_x12345 = (x1+x2+x3+x4+x5)/5

# %%
#1&2
predicted_class_indices_mean=np.argmax(mean_x12,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_2408_mean_x12.csv')

# %%
cp Cifar100_MulModels299_AVG_Assembe_2408_mean_x12.csv /home/bribeiro/Phong/Nat19/Cifar100_mean_x12.csv

# %%
#1&3
predicted_class_indices_mean=np.argmax(mean_x13,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_2408_mean_x13.csv')

# %%
cp Cifar100_MulModels299_AVG_Assembe_2408_mean_x13.csv /home/bribeiro/Phong/Nat19/Cifar100_mean_x13.csv

# %%
#2&3
predicted_class_indices_mean=np.argmax(mean_x23,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_2408_mean_x23.csv')

# %%
cp Cifar100_MulModels299_AVG_Assembe_2408_mean_x23.csv /home/bribeiro/Phong/Nat19/Cifar100_mean_x23.csv

# %%
#1&2&3
predicted_class_indices_mean=np.argmax(mean_a123,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_2408_mean_a123.csv')

# %%
cp Cifar100_MulModels299_AVG_Assembe_2408_mean_a123.csv /home/bribeiro/Phong/Nat19/Cifar100_mean_a123.csv

# %%
#1&2&3
predicted_class_indices_mean=np.argmax(mean_x123,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_2408_mean_x123.csv')

# %%
cp Cifar100_MulModels299_AVG_Assembe_2408_mean_x123.csv /home/bribeiro/Phong/Nat19/Cifar100_mean_x123.csv

# %%
#1&2&3&4
predicted_class_indices_mean=np.argmax(mean_a1234,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_2408_mean_a1234.csv')

# %%
cp Cifar100_MulModels299_AVG_Assembe_2408_mean_a1234.csv /home/bribeiro/Phong/Nat19/Cifar100_mean_a1234.csv

# %%
#1&2&3&4
predicted_class_indices_mean=np.argmax(mean_x1234,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_2408_mean_x1234.csv')

# %%
cp Cifar100_MulModels299_AVG_Assembe_2408_mean_x1234.csv /home/bribeiro/Phong/Nat19/Cifar100_mean_x1234.csv

# %%
#1&2&3&4&5
predicted_class_indices_mean=np.argmax(mean_a12345,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_2408_mean_a12345.csv')

# %%
cp Cifar100_MulModels299_AVG_Assembe_2408_mean_a12345.csv /home/bribeiro/Phong/Nat19/Cifar100_mean_a12345.csv

# %%
#1&2&3&4&5
predicted_class_indices_mean=np.argmax(mean_x12345,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_2408_mean_x12345.csv')

# %%
cp Cifar100_MulModels299_AVG_Assembe_2408_mean_x12345.csv /home/bribeiro/Phong/Nat19/Cifar100_mean_x12345.csv

# %%
voting_a12345 = (a2*4+a1*2+a5*2+a3*1+a4*1)/10

# %%
#voting 1&2&3&4&5
predicted_class_indices_mean=np.argmax(voting_a12345,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_2408_voting_a12345.csv')

# %%
cp Cifar100_MulModels299_AVG_Assembe_2408_voting_a12345.csv /home/bribeiro/Phong/Nat19/Cifar100_voting_a12345.csv

# %%
mean_pred3_6 = np.load(os.path.join('pred_npy','Cifar100_InpResNet_LRG299_Mul.npy'))

# %%
a6 = mean_pred3_6
mean_a123456 = (mean_pred3_1+mean_pred3_2+mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_6)/6
x6 = a6

# %%
#x6
for i in range(len(x6)):
    i_max = np.argmax(x6[i], axis=0)
    for idx in range(10):
        if idx != i_max:
            x6[i][idx] = 0
        else:
            x6[i][idx] = 1            
# print(a1)

# %%
#mean 1&2&3&4&5&6
predicted_class_indices_mean=np.argmax(mean_a123456,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_2408_mean_a123456.csv')

# %%
cp Cifar100_MulModels299_AVG_Assembe_2408_mean_a123456.csv /home/bribeiro/Phong/Nat19/Cifar100_mean_a123456.csv

# %%
mean_x123456 = (x1+x2+x3+x4+x5+x6)/6

# %%
#mean x 1&2&3&4&5&6
predicted_class_indices_mean=np.argmax(mean_x123456,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_2408_mean_x123456.csv')

# %%
cp Cifar100_MulModels299_AVG_Assembe_2408_mean_x123456.csv /home/bribeiro/Phong/Nat19/Cifar100_mean_x123456.csv

# %%
mean_pred3_7 = np.load(os.path.join('pred_npy','Cifar100_InceptionV3_LRG299_Mul.npy'))
a7 = mean_pred3_7
mean_a1234567 = (mean_pred3_1+mean_pred3_2+mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_6+mean_pred3_7)/7
x7 = a7

# %%
#mean 1&2&3&4&5&6
predicted_class_indices_mean=np.argmax(mean_a1234567,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_2508_mean_a1234567.csv')

# %%
cp Cifar100_MulModels299_AVG_Assembe_2508_mean_a1234567.csv /home/bribeiro/Phong/Nat19/Cifar100_mean_a1234567.csv

# %%
#x7
for i in range(len(x7)):
    i_max = np.argmax(x7[i], axis=0)
    for idx in range(10):
        if idx != i_max:
            x7[i][idx] = 0
        else:
            x7[i][idx] = 1            
# print(a1)

# %%
mean_x1234567 = (x1+x2+x3+x4+x5+x6+x7)/7

# %%
#mean x 1&2&3&4&5&6&7
predicted_class_indices_mean=np.argmax(mean_x1234567,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_2508_mean_x1234567.csv')

# %%
cp Cifar100_MulModels299_AVG_Assembe_2508_mean_x1234567.csv /home/bribeiro/Phong/Nat19/Cifar100_mean_x1234567.csv

# %%
mean_pred3_8 = np.load(os.path.join('pred_npy','Cifar100_Eff_B6_299_L3.npy'))
a8 = mean_pred3_8

# %%
mean_a1234568 = (mean_pred3_1+mean_pred3_2+mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_6+mean_pred3_8)/7

# %%
from keras.preprocessing.image import ImageDataGenerator
from math import ceil
import numpy as np

batch_size = 20

train_datagen = ImageDataGenerator(

)

train_set = train_datagen.flow_from_directory('train_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )
        
test_datagen_crop = ImageDataGenerator(
)

testing_set_crop = test_datagen_crop.flow_from_directory('test_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="training"
                                              )

predicted_class_indices_mean=np.argmax(mean_a1234568,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_0109_v1.csv')
results.head(5)

# %%
cp Cifar100_MulModels299_AVG_Assembe_0109_v1.csv /home/bribeiro/Phong/Nat19/Cifar100_mean_a1234568.csv

# %%
mean_pred3_9 = np.load(os.path.join('pred_npy','Cifar100_Eff_B5_299_L3.npy'))
a9 = mean_pred3_9
mean_a12345689 = (mean_pred3_1+mean_pred3_2+mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_6+mean_pred3_8
                  +mean_pred3_9)/8

# %%
predicted_class_indices_mean=np.argmax(mean_a12345689,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_0109_v2.csv')
results.head(5)

# %%
cp Cifar100_MulModels299_AVG_Assembe_0109_v2.csv /home/bribeiro/Phong/Nat19/Cifar100_0109_v2.csv

# %%
mean_pred3_10 = np.load(os.path.join('pred_npy','Cifar100_Eff_B3_299_L2.npy'))
a10 = mean_pred3_10
mean_a1234568910 = (mean_pred3_1+mean_pred3_2+mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_6+mean_pred3_8
                  +mean_pred3_9+mean_pred3_10)/9

# %%
predicted_class_indices_mean=np.argmax(mean_a1234568910,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_0209_v1.csv')
results.head(5)

# %%
cp Cifar100_MulModels299_AVG_Assembe_0209_v1.csv /home/bribeiro/Phong/Nat19/Cifar100_0209_v1.csv

# %%
mean289 = (mean_pred3_2+mean_pred3_8+mean_pred3_9)/3

predicted_class_indices_mean=np.argmax(mean289,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_0209_v2.csv')
results.head(5)

# %%
cp Cifar100_MulModels299_AVG_Assembe_0209_v2.csv /home/bribeiro/Phong/Nat19/Cifar100_0209_v2.csv

# %%
mean258910 = (mean_pred3_2+mean_pred3_5+mean_pred3_8+mean_pred3_9+mean_pred3_10)/5

predicted_class_indices_mean=np.argmax(mean258910,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_0209_v3.csv')
results.head(5)

# %%
cp Cifar100_MulModels299_AVG_Assembe_0209_v3.csv /home/bribeiro/Phong/Nat19/Cifar100_0209_v3.csv

# %%
mean_pred3_11 = np.load(os.path.join('pred_npy','Cifar100_Eff_B2_299_L3.npy'))
mean_pred3_12 = np.load(os.path.join('pred_npy','Cifar100_Eff_B1_299_L3.npy'))

a11 = mean_pred3_11
a12 = mean_pred3_12

# %%
mean_a123456891011 = (mean_pred3_1+mean_pred3_2+mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_6+mean_pred3_8
                  +mean_pred3_9+mean_pred3_10+mean_pred3_11)/10

# %%
# mean258910 = (mean_pred3_2+mean_pred3_5+mean_pred3_8+mean_pred3_9+mean_pred3_10)/5

from keras.preprocessing.image import ImageDataGenerator
from math import ceil
import numpy as np

batch_size = 20

train_datagen = ImageDataGenerator(

)

train_set = train_datagen.flow_from_directory('train_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )
        
test_datagen_crop = ImageDataGenerator(
)

testing_set_crop = test_datagen_crop.flow_from_directory('test_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="training"
                                              )

predicted_class_indices_mean=np.argmax(mean_a123456891011,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_0309_v3.csv')
results.head(5)

# %%
cp Cifar100_MulModels299_AVG_Assembe_0309_v3.csv /home/bribeiro/Phong/Nat19/Cifar100_0309_v3.csv

# %%
mean_a12345689101112 = (mean_pred3_1+mean_pred3_2+mean_pred3_3+mean_pred3_4+mean_pred3_5+mean_pred3_6+mean_pred3_8
                  +mean_pred3_9+mean_pred3_10+mean_pred3_11+mean_pred3_12)/11

predicted_class_indices_mean=np.argmax(mean_a12345689101112,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar100_MulModels299_AVG_Assembe_0309_v4.csv')
results.head(5)

# %%
cp Cifar100_MulModels299_AVG_Assembe_0309_v4.csv /home/bribeiro/Phong/Nat19/Cifar100_0309_v4.csv

# %%
from IPython.display import Image 
pil_img = Image(filename='svhn_test/1/00193.png')
display(pil_img)

# %%
pil_img = Image(filename='svhn_test/1/00642.png')
display(pil_img)

# %%
pil_img = Image(filename='svhn_test/1/01317.png')
display(pil_img)

# %%
pil_img = Image(filename='svhn_test/1/01317.png')
display(pil_img)

# %%
# !pip3 install ipyplot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 20.2.1; however, version 20.2.3 is available.
# You should consider upgrading via the '/usr/bin/python3.6 -m pip install --upgrade pip' command.

# %%
import ipyplot

images_list = ['svhn_test/1/00193.png',
               'svhn_test/1/00642.png',
               'svhn_test/1/01317.png'
              ]
ipyplot.plot_images(images_list,max_images=20, img_width=150)
# Out:
# <div style="display: inline-block; width: 170px; vertical-align: top; text-align: center;"><h4 style="font-size: 12px">0</h4><h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 90%; word-wrap: break-word; white-space: normal;">svhn_test/1/00193.png</h4><img src="svhn_test/1/00193.png" style="margin: 1px; width: 150px; border: 2px solid #ddd;"/></div><div style="display: inline-block; width: 170px; vertical-align: top; text-align: center;"><h4 style="font-size: 12px">1</h4><h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 90%; word-wrap: break-word; white-space: normal;">svhn_test/1/00642.png</h4><img src="svhn_test/1/00642.png" style="margin: 1px; width: 150px; border: 2px solid #ddd;"/></div><div style="display: inline-block; width: 170px; vertical-align: top; text-align: center;"><h4 style="font-size: 12px">2</h4><h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 90%; word-wrap: break-word; white-space: normal;
# ...

# %%
import matplotlib.pyplot as plt
from PIL import Image

images_list = ['svhn_test/1/00193.png',
               'svhn_test/1/00642.png',
               'svhn_test/1/01317.png',
               'svhn_test/1/01606.png',
               'svhn_test/1/03759.png',
               'svhn_test/1/03805.png',
               'svhn_test/1/03916.png',
               'svhn_test/1/04013.png',
               'svhn_test/1/04516.png',
               'svhn_test/1/04580.png',
               
              ]

images = []
for filename in images_list:
    im=Image.open(filename)
    images.append(im)
    
for i in range(10):
    plt.figure()
    plt.imshow(images[i])

# %%
#Images/n02105855-Shetland_sheepdog/n02105855_9415.jpg

import glob
import os

import numpy as np
from matplotlib.image import imread
# %matplotlib inline
import matplotlib.pyplot as plt

# get image parts
def get_image_parts(image_path):
    """Given a full path to an image, return its parts."""
    parts = image_path.split(os.path.sep)
    #print(parts)
    filename = parts[2]
    filename_no_ext = filename.split('.')[0]
    classname = parts[1]
    train_or_test = parts[0]
    
    return train_or_test, classname, filename_no_ext, filename
    
    
sample_images = list(glob.glob(os.path.join('svhn_test/', '*/*'), recursive=True))
np.random.seed(7)
rand_imgs = np.random.choice(sample_images, size=15*15)
fig, axarr = plt.subplots(15, 15, figsize=(15, 15))

for i, rand_img in enumerate(rand_imgs):
    train_or_test, classname, filename_no_ext, filename = get_image_parts(rand_img)
    
    j = i // 15
    k = i % 15
    axarr[j][k].imshow(imread(rand_img))
    axarr[j][k].title.set_text(classname)
    axarr[j][k].grid(False)

# %%
import keras
keras.__version__
# Out:
# '2.4.3'

# %%
import sys
print(sys.version)
# Out:
# 3.6.9 (default, Oct  8 2020, 12:12:24)
# [GCC 8.4.0]

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.3.0'
