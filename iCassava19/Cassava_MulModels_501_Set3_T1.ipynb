# %%
# SET 3

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0,1,2,3"

# %%
cd /media/datastorage/Phong/cassava/cv/1
# Out:
# /media/datastorage/Phong/cassava/cv/1

# %%
mkdir train_rnd

# %%
# ####=======================
# # Rename files with random indexes
# ####=======================

# import csv
# import glob
# import os
# import shutil
# import random

# # get parts of image's path
# def get_image_parts(image_path):
#     """Given a full path to an image, return its parts."""
#     parts = image_path.split(os.path.sep)
#     #print(parts)
#     filename = parts[2]
#     filename_no_ext = filename.split('.')[0]
#     classname = parts[1]
# #     sub_folder = parts[1]
#     train_or_test = parts[0]

#     return train_or_test, classname, filename_no_ext, filename

# move_folders = ['train']
# dest_folder = 'train_rnd'

# data_file =[]

# # look for all images in sub-folders
# for folder in move_folders:
#     class_folders = glob.glob(os.path.join(folder, '*'))
# #     print('folder %s' %class_folders)
    
# #     for sub_folder in class_folders:
# #         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
# #         print('sub folder %s' %sub_class_folders)
        
#     for iid_class in class_folders:
#         class_files = glob.glob(os.path.join(iid_class, '*.jpg'))

#         print('moving %d files' %(len(class_files)))

# #             random_list = random.sample(range(len(class_files)), int(len(class_files))) #All dataset
#         random_list = range(0,len(class_files)) #All dataset

#         #suffle list
#         suffle_list = random.sample(range(len(class_files)), int(len(class_files)))

#         for idx in range(len(random_list)):
#             src = class_files[random_list[idx]]

#             train_or_test, classname, _, filename = get_image_parts(src)
#             dst = os.path.join(dest_folder, classname, '{:07d}'.format(suffle_list[idx])+'_'+filename)

#             # image directory
#             img_directory = os.path.join(dest_folder, classname)

#             # create folder if not existed
#             if not os.path.exists(img_directory):
#                 os.makedirs(img_directory)

#             # moving file
#             shutil.move(src, dst) 

# #             #recording
# #             data_file.append([src, dst])

# # with open('nat_data_file.csv', 'w') as fout:
# #     writer = csv.writer(fout)
# #     writer.writerows(data_file)

# %%
import os
os.listdir("train_rnd/cbb/")

# %%
mkdir train_all

# %%
cp -r train_rnd/* train_all

# %%
# !rm -r train_1
# !rm -r valid_1

# %%
# !mkdir train_1
# !cp -r train_all/* train_1
# !mkdir valid_1

# %%
# ####=======================
# import glob
# import os
# import shutil
# import random

# #move images from train to eval
# #split = 0.2

# # get parts of image's path
# # ('Expert_TrainEdited', 'Adult', 'whippet 2-5 M', 'whippet 2-5 M.png')
# def get_image_parts(image_path):
#     """Given a full path to an image, return its parts."""
#     parts = image_path.split(os.path.sep)
# #     print(parts)
#     filename = parts[2]
#     filename_no_ext = filename.split('.')[0]
#     classname = parts[1]
# # #     sub_folder = parts[1]
#     train_or_test = parts[0]
#     return train_or_test, classname, filename_no_ext, filename

# move_folders = ['train_1']
# dest_folder = 'valid_1'
# # data_file = []

# # look for all images in sub-folders
# for folder in move_folders:
#     class_folders = glob.glob(os.path.join(folder, '*'))
# #     print('folder %s' %class_folders)
    
# #     for sub_folder in class_folders:
# #         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
# #         print('sub folder %s' %sub_class_folders)
        
#     for iid_class in class_folders:
#         class_files = glob.glob(os.path.join(iid_class, '*.jpg'))

# #         print('moving %d files' %(len(class_files)/10))

#         #Determize Set# 
#         set = int(len(class_files)/5)#Number of Sets

#         inner = range(0*set, 1*set) #Set 0

#         print('moving %d files' %(len(inner)))

# #         random_list = random.sample(range(len(class_files)), int(len(class_files)/5)) #1/5 dataset
# #         for idx in range(len(random_list)):

#         for idx in range(len(inner)):
#             src = class_files[inner[idx]]
# #             src = class_files[random_list[idx]]

#             #record paths
# #                 data_file.append(src)

#             train_or_test, classname, _, filename = get_image_parts(src)
#             dst = os.path.join(dest_folder, classname, filename)

#             # image directory
#             img_directory = os.path.join(dest_folder, classname)

#             # create folder if not existed
#             if not os.path.exists(img_directory):
#                 os.makedirs(img_directory)
                
# #             # image sub-directory
# #             img_sub_directory = os.path.join(dest_folder, class_name_part1, class_name_part2)

# #             # create sub-folder if not existed
# #             if not os.path.exists(img_sub_directory):
# #                 os.makedirs(img_sub_directory)                

#             #moving file
#             shutil.move(src, dst)
# #                 shutil.copy(src, dst)

# # #save recorded paths
# # with open('data_file.csv', 'w') as fout:
# #     writer = csv.writer(fout)
# #     writer.writerows(data_file)

# %%
# !rm -r train_2
# !rm -r valid_2
# !mkdir train_2
# !cp -r train_all/* train_2
# !mkdir valid_2

# %%
# #set 5
# #valid -> train
# ####=======================
# import glob
# import os
# import shutil
# import random

# #move images from train to eval
# #split = 0.2

# # get parts of image's path
# # ('Expert_TrainEdited', 'Adult', 'whippet 2-5 M', 'whippet 2-5 M.png')
# def get_image_parts(image_path):
#     """Given a full path to an image, return its parts."""
#     parts = image_path.split(os.path.sep)
# #     print(parts)
#     filename = parts[2]
#     filename_no_ext = filename.split('.')[0]
#     classname = parts[1]
# # #     sub_folder = parts[1]
#     train_or_test = parts[0]
#     return train_or_test, classname, filename_no_ext, filename

# move_folders = ['valid_5']
# dest_folder = 'train_5'
# # data_file = []

# # look for all images in sub-folders
# for folder in move_folders:
#     class_folders = glob.glob(os.path.join(folder, '*'))
# #     print('folder %s' %class_folders)
    
# #     for sub_folder in class_folders:
# #         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
# #         print('sub folder %s' %sub_class_folders)
        
#     for iid_class in class_folders:
#         class_files = glob.glob(os.path.join(iid_class, '*.jpg'))

# #         print('moving %d files' %(len(class_files)/10))

#         #Determize Set# 
#         set = int(len(class_files))#all

#         inner = range(0*set, 1*set) #all

#         print('moving %d files' %(len(inner)))

# #         random_list = random.sample(range(len(class_files)), int(len(class_files)/5)) #1/5 dataset
# #         for idx in range(len(random_list)):

#         for idx in range(len(inner)):
#             src = class_files[inner[idx]]
# #             src = class_files[random_list[idx]]

#             #record paths
# #                 data_file.append(src)

#             train_or_test, classname, _, filename = get_image_parts(src)
#             dst = os.path.join(dest_folder, classname, filename)

#             # image directory
#             img_directory = os.path.join(dest_folder, classname)

#             # create folder if not existed
#             if not os.path.exists(img_directory):
#                 os.makedirs(img_directory)
                
# #             # image sub-directory
# #             img_sub_directory = os.path.join(dest_folder, class_name_part1, class_name_part2)

# #             # create sub-folder if not existed
# #             if not os.path.exists(img_sub_directory):
# #                 os.makedirs(img_sub_directory)                

#             #moving file
#             shutil.move(src, dst)
# #                 shutil.copy(src, dst)

# # #save recorded paths
# # with open('data_file.csv', 'w') as fout:
# #     writer = csv.writer(fout)
# #     writer.writerows(data_file)

# %%
# #set 5
# ####=======================
# import glob
# import os
# import shutil
# import random

# #move images from train to eval
# #split = 0.2

# # get parts of image's path
# # ('Expert_TrainEdited', 'Adult', 'whippet 2-5 M', 'whippet 2-5 M.png')
# def get_image_parts(image_path):
#     """Given a full path to an image, return its parts."""
#     parts = image_path.split(os.path.sep)
# #     print(parts)
#     filename = parts[2]
#     filename_no_ext = filename.split('.')[0]
#     classname = parts[1]
# # #     sub_folder = parts[1]
#     train_or_test = parts[0]
#     return train_or_test, classname, filename_no_ext, filename

# move_folders = ['train_5']
# dest_folder = 'valid_5'
# # data_file = []

# # look for all images in sub-folders
# for folder in move_folders:
#     class_folders = glob.glob(os.path.join(folder, '*'))
# #     print('folder %s' %class_folders)
    
# #     for sub_folder in class_folders:
# #         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
# #         print('sub folder %s' %sub_class_folders)
        
#     for iid_class in class_folders:
#         class_files = glob.glob(os.path.join(iid_class, '*.jpg'))

# #         print('moving %d files' %(len(class_files)/10))

#         #Determize Set# 
#         set = int(len(class_files)/5)

#         inner = range(4*set, 5*set) #Set 5

#         print('moving %d files' %(len(inner)))

# #         random_list = random.sample(range(len(class_files)), int(len(class_files)/5)) #1/5 dataset
# #         for idx in range(len(random_list)):

#         for idx in range(len(inner)):
#             src = class_files[inner[idx]]
# #             src = class_files[random_list[idx]]

#             #record paths
# #                 data_file.append(src)

#             train_or_test, classname, _, filename = get_image_parts(src)
#             dst = os.path.join(dest_folder, classname, filename)

#             # image directory
#             img_directory = os.path.join(dest_folder, classname)

#             # create folder if not existed
#             if not os.path.exists(img_directory):
#                 os.makedirs(img_directory)
                
# #             # image sub-directory
# #             img_sub_directory = os.path.join(dest_folder, class_name_part1, class_name_part2)

# #             # create sub-folder if not existed
# #             if not os.path.exists(img_sub_directory):
# #                 os.makedirs(img_sub_directory)                

#             #moving file
#             shutil.move(src, dst)
# #                 shutil.copy(src, dst)

# # #save recorded paths
# # with open('data_file.csv', 'w') as fout:
# #     writer = csv.writer(fout)
# #     writer.writerows(data_file)

# %%
## fix for multi_gpu_model prediction time longer
from keras.layers import Lambda, concatenate
from keras import Model
import tensorflow as tf

def multi_gpu_model(model, gpus):
    if isinstance(gpus, (list, tuple)):
        num_gpus = len(gpus)
        target_gpu_ids = gpus
    else:
        num_gpus = gpus
        target_gpu_ids = range(num_gpus)

    def get_slice(data, i, parts):
        shape = tf.shape(data)
        batch_size = shape[:1]
        input_shape = shape[1:]
        step = batch_size // parts
        if i == num_gpus - 1:
            size = batch_size - step * i
        else:
            size = step
        size = tf.concat([size, input_shape], axis=0)
        stride = tf.concat([step, input_shape * 0], axis=0)
        start = stride * i
        return tf.slice(data, start, size)

    all_outputs = []
    for i in range(len(model.outputs)):
        all_outputs.append([])

    # Place a copy of the model on each GPU,
    # each getting a slice of the inputs.
    for i, gpu_id in enumerate(target_gpu_ids):
        with tf.device('/gpu:%d' % gpu_id):
            with tf.name_scope('replica_%d' % gpu_id):
                inputs = []
                # Retrieve a slice of the input.
                for x in model.inputs:
                    input_shape = tuple(x.get_shape().as_list())[1:]
                    slice_i = Lambda(get_slice,
                                   output_shape=input_shape,
                                   arguments={'i': i,
                                              'parts': num_gpus})(x)
                    inputs.append(slice_i)

                # Apply model on slice
                # (creating a model replica on the target device).
                outputs = model(inputs)
                if not isinstance(outputs, list):
                    outputs = [outputs]

                # Save the outputs for merging back together later.
                for o in range(len(outputs)):
                    all_outputs[o].append(outputs[o])

    # Merge outputs on CPU.
    with tf.device('/cpu:0'):
        merged = []
        for name, outputs in zip(model.output_names, all_outputs):
            merged.append(concatenate(outputs,
                                    axis=0, name=name))
        return Model(model.inputs, merged)
# Out:
# Using TensorFlow backend.

# %%
from keras.callbacks import Callback
import pickle
import sys

#Stop training on val_acc
class EarlyStoppingByAccVal(Callback):
    def __init__(self, monitor='val_acc', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current >= self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping" % epoch)
            self.model.stop_training = True

#Save large model using pickle formate instead of h5            
class SaveCheckPoint(Callback):
    def __init__(self, model, dest_folder):
        super(Callback, self).__init__()
        self.model = model
        self.dest_folder = dest_folder
        
        #initiate
        self.best_val_acc = 0
        self.best_val_loss = sys.maxsize #get max value
          
    def on_epoch_end(self, epoch, logs={}):
        val_acc = logs['val_acc']
        val_loss = logs['val_loss']

        if val_acc > self.best_val_acc:
            self.best_val_acc = val_acc
            
            # Save weights in pickle format instead of h5
            print('\nSaving val_acc %f at %s' %(self.best_val_acc, self.dest_folder))
            weigh= self.model.get_weights()

            #now, use pickle to save your model weights, instead of .h5
            #for heavy model architectures, .h5 file is unsupported.
            fpkl= open(self.dest_folder, 'wb') #Python 3
            pickle.dump(weigh, fpkl, protocol= pickle.HIGHEST_PROTOCOL)
            fpkl.close()
            
#             model.save('tmp.h5')
        elif val_acc == self.best_val_acc:
            if val_loss < self.best_val_loss:
                self.best_val_loss=val_loss
                
                # Save weights in pickle format instead of h5
                print('\nSaving val_acc %f at %s' %(self.best_val_acc, self.dest_folder))
                weigh= self.model.get_weights()

                #now, use pickle to save your model weights, instead of .h5
                #for heavy model architectures, .h5 file is unsupported.
                fpkl= open(self.dest_folder, 'wb') #Python 3
                pickle.dump(weigh, fpkl, protocol= pickle.HIGHEST_PROTOCOL)
                fpkl.close()

# %%
#SET 3

from classification_models.keras import Classifiers
from keras.models import Model
# from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM
# from keras.applications.inception_v3 import preprocess_input

from keras.layers import GaussianNoise

senet, preprocess_input = Classifiers.get('seresnext101')

f2_base = senet(input_shape=(501,501,3), weights='imagenet', include_top=False)
f2_x = GlobalAveragePooling2D()(f2_base.output)

# # #Regularization with noise
f2_x = GaussianNoise(0.1)(f2_x)

f2_x = Dense(2048, activation='relu')(f2_x)
f2_x = Dense(5, activation='softmax')(f2_x)
model_2 = Model(inputs=[f2_base.input],outputs=[f2_x])

print(model_2.summary())
# # print(f2_base.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 501, 501, 3)  0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 507, 507, 3)  0           input[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 251, 251, 64) 9408        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 251, 251, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 251, 251, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 253, 253, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 126, 126, 64) 0           zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 126, 126, 128 8192        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 126, 126, 128 512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 126, 126, 128 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 128, 128, 128 0           activation_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 126, 126, 4)  144         lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 126, 126, 4)  144         lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 126, 126, 4)  144         lambda_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 126, 126, 4)  144         lambda_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 126, 126, 4)  144         lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 126, 126, 4)  144         lambda_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 126, 126, 4)  144         lambda_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 126, 126, 4)  144         lambda_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 126, 126, 4)  144         lambda_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 126, 126, 4)  144         lambda_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 126, 126, 4)  144         lambda_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 126, 126, 4)  144         lambda_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 126, 126, 4)  144         lambda_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 126, 126, 4)  144         lambda_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 126, 126, 4)  144         lambda_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 126, 126, 4)  144         lambda_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 126, 126, 4)  144         lambda_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 126, 126, 4)  144         lambda_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 126, 126, 4)  144         lambda_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 126, 126, 4)  144         lambda_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 126, 126, 4)  144         lambda_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 126, 126, 4)  144         lambda_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 126, 126, 4)  144         lambda_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 126, 126, 4)  144         lambda_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 126, 126, 4)  144         lambda_25[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 126, 126, 4)  144         lambda_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 126, 126, 4)  144         lambda_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 126, 126, 4)  144         lambda_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 126, 126, 4)  144         lambda_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 126, 126, 4)  144         lambda_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 126, 126, 4)  144         lambda_31[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 126, 126, 4)  144         lambda_32[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 126, 126, 128 0           conv2d_3[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
#                                                                  conv2d_9[0][0]
#                                                                  conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
#                                                                  conv2d_15[0][0]
#                                                                  conv2d_16[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_18[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
#                                                                  conv2d_21[0][0]
#                                                                  conv2d_22[0][0]
#                                                                  conv2d_23[0][0]
#                                                                  conv2d_24[0][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_27[0][0]
#                                                                  conv2d_28[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_30[0][0]
#                                                                  conv2d_31[0][0]
#                                                                  conv2d_32[0][0]
#                                                                  conv2d_33[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 126, 126, 128 512         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 126, 126, 128 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 126, 126, 256 32768       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 126, 126, 256 1024        conv2d_35[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 256)          0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 1, 1, 256)    0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 1, 1, 16)     4112        lambda_33[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1, 1, 16)     0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 1, 1, 256)    4352        activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 1, 1, 256)    0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 126, 126, 256 16384       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 126, 126, 256 0           batch_normalization_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 126, 126, 256 1024        conv2d_36[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 126, 126, 256 0           multiply_1[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 126, 126, 256 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 126, 126, 128 32768       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 126, 126, 128 512         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 126, 126, 128 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 128, 128, 128 0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_52 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_53 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_54 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_55 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_56 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_57 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_58 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_59 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_60 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_61 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_62 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_63 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_64 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_65 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 126, 126, 4)  144         lambda_34[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 126, 126, 4)  144         lambda_35[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 126, 126, 4)  144         lambda_36[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 126, 126, 4)  144         lambda_37[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 126, 126, 4)  144         lambda_38[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 126, 126, 4)  144         lambda_39[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 126, 126, 4)  144         lambda_40[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 126, 126, 4)  144         lambda_41[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 126, 126, 4)  144         lambda_42[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 126, 126, 4)  144         lambda_43[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 126, 126, 4)  144         lambda_44[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 126, 126, 4)  144         lambda_45[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 126, 126, 4)  144         lambda_46[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 126, 126, 4)  144         lambda_47[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 126, 126, 4)  144         lambda_48[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 126, 126, 4)  144         lambda_49[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 126, 126, 4)  144         lambda_50[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 126, 126, 4)  144         lambda_51[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 126, 126, 4)  144         lambda_52[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 126, 126, 4)  144         lambda_53[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 126, 126, 4)  144         lambda_54[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 126, 126, 4)  144         lambda_55[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 126, 126, 4)  144         lambda_56[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 126, 126, 4)  144         lambda_57[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 126, 126, 4)  144         lambda_58[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 126, 126, 4)  144         lambda_59[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 126, 126, 4)  144         lambda_60[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 126, 126, 4)  144         lambda_61[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 126, 126, 4)  144         lambda_62[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 126, 126, 4)  144         lambda_63[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 126, 126, 4)  144         lambda_64[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 126, 126, 4)  144         lambda_65[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 126, 126, 128 0           conv2d_40[0][0]
#                                                                  conv2d_41[0][0]
#                                                                  conv2d_42[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
#                                                                  conv2d_45[0][0]
#                                                                  conv2d_46[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_48[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_50[0][0]
#                                                                  conv2d_51[0][0]
#                                                                  conv2d_52[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_54[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_56[0][0]
#                                                                  conv2d_57[0][0]
#                                                                  conv2d_58[0][0]
#                                                                  conv2d_59[0][0]
#                                                                  conv2d_60[0][0]
#                                                                  conv2d_61[0][0]
#                                                                  conv2d_62[0][0]
#                                                                  conv2d_63[0][0]
#                                                                  conv2d_64[0][0]
#                                                                  conv2d_65[0][0]
#                                                                  conv2d_66[0][0]
#                                                                  conv2d_67[0][0]
#                                                                  conv2d_68[0][0]
#                                                                  conv2d_69[0][0]
#                                                                  conv2d_70[0][0]
#                                                                  conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 126, 126, 128 512         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 126, 126, 128 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 126, 126, 256 32768       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 126, 126, 256 1024        conv2d_72[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 256)          0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# lambda_66 (Lambda)              (None, 1, 1, 256)    0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 1, 1, 16)     4112        lambda_66[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 1, 1, 16)     0           conv2d_73[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 1, 1, 256)    4352        activation_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 1, 1, 256)    0           conv2d_74[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 126, 126, 256 0           batch_normalization_8[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 126, 126, 256 0           multiply_2[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 126, 126, 256 0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 126, 126, 128 32768       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 126, 126, 128 512         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 126, 126, 128 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 128, 128, 128 0           activation_12[0][0]
# __________________________________________________________________________________________________
# lambda_67 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_68 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_69 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_70 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_71 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_72 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_73 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_74 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_75 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_76 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_77 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_78 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_79 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_80 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_81 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_82 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_83 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_84 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_85 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_86 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_87 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_88 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_89 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_90 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_91 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_92 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_93 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_94 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_95 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_96 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_97 (Lambda)              (None, 128, 128, 4)  0           zero_padding2d_5[0][0]
# ...
# lambda_1076 (Lambda)            (None, 18, 18, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1077 (Lambda)            (None, 18, 18, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1078 (Lambda)            (None, 18, 18, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1079 (Lambda)            (None, 18, 18, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1080 (Lambda)            (None, 18, 18, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1081 (Lambda)            (None, 18, 18, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1082 (Lambda)            (None, 18, 18, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1083 (Lambda)            (None, 18, 18, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1084 (Lambda)            (None, 18, 18, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1085 (Lambda)            (None, 18, 18, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1086 (Lambda)            (None, 18, 18, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1087 (Lambda)            (None, 18, 18, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1088 (Lambda)            (None, 18, 18, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_1159 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1057[0][0]
# __________________________________________________________________________________________________
# conv2d_1160 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1058[0][0]
# __________________________________________________________________________________________________
# conv2d_1161 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1059[0][0]
# __________________________________________________________________________________________________
# conv2d_1162 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1060[0][0]
# __________________________________________________________________________________________________
# conv2d_1163 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1061[0][0]
# __________________________________________________________________________________________________
# conv2d_1164 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1062[0][0]
# __________________________________________________________________________________________________
# conv2d_1165 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1063[0][0]
# __________________________________________________________________________________________________
# conv2d_1166 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1064[0][0]
# __________________________________________________________________________________________________
# conv2d_1167 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1065[0][0]
# __________________________________________________________________________________________________
# conv2d_1168 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1066[0][0]
# __________________________________________________________________________________________________
# conv2d_1169 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1067[0][0]
# __________________________________________________________________________________________________
# conv2d_1170 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1068[0][0]
# __________________________________________________________________________________________________
# conv2d_1171 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1069[0][0]
# __________________________________________________________________________________________________
# conv2d_1172 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1070[0][0]
# __________________________________________________________________________________________________
# conv2d_1173 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1071[0][0]
# __________________________________________________________________________________________________
# conv2d_1174 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1072[0][0]
# __________________________________________________________________________________________________
# conv2d_1175 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1073[0][0]
# __________________________________________________________________________________________________
# conv2d_1176 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1074[0][0]
# __________________________________________________________________________________________________
# conv2d_1177 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1075[0][0]
# __________________________________________________________________________________________________
# conv2d_1178 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1076[0][0]
# __________________________________________________________________________________________________
# conv2d_1179 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1077[0][0]
# __________________________________________________________________________________________________
# conv2d_1180 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1078[0][0]
# __________________________________________________________________________________________________
# conv2d_1181 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1079[0][0]
# __________________________________________________________________________________________________
# conv2d_1182 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1080[0][0]
# __________________________________________________________________________________________________
# conv2d_1183 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1081[0][0]
# __________________________________________________________________________________________________
# conv2d_1184 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1082[0][0]
# __________________________________________________________________________________________________
# conv2d_1185 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1083[0][0]
# __________________________________________________________________________________________________
# conv2d_1186 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1084[0][0]
# __________________________________________________________________________________________________
# conv2d_1187 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1085[0][0]
# __________________________________________________________________________________________________
# conv2d_1188 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1086[0][0]
# __________________________________________________________________________________________________
# conv2d_1189 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1087[0][0]
# __________________________________________________________________________________________________
# conv2d_1190 (Conv2D)            (None, 16, 16, 32)   9216        lambda_1088[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 16, 16, 1024) 0           conv2d_1159[0][0]
#                                                                  conv2d_1160[0][0]
#                                                                  conv2d_1161[0][0]
#                                                                  conv2d_1162[0][0]
#                                                                  conv2d_1163[0][0]
#                                                                  conv2d_1164[0][0]
#                                                                  conv2d_1165[0][0]
#                                                                  conv2d_1166[0][0]
#                                                                  conv2d_1167[0][0]
#                                                                  conv2d_1168[0][0]
#                                                                  conv2d_1169[0][0]
#                                                                  conv2d_1170[0][0]
#                                                                  conv2d_1171[0][0]
#                                                                  conv2d_1172[0][0]
#                                                                  conv2d_1173[0][0]
#                                                                  conv2d_1174[0][0]
#                                                                  conv2d_1175[0][0]
#                                                                  conv2d_1176[0][0]
#                                                                  conv2d_1177[0][0]
#                                                                  conv2d_1178[0][0]
#                                                                  conv2d_1179[0][0]
#                                                                  conv2d_1180[0][0]
#                                                                  conv2d_1181[0][0]
#                                                                  conv2d_1182[0][0]
#                                                                  conv2d_1183[0][0]
#                                                                  conv2d_1184[0][0]
#                                                                  conv2d_1185[0][0]
#                                                                  conv2d_1186[0][0]
#                                                                  conv2d_1187[0][0]
#                                                                  conv2d_1188[0][0]
#                                                                  conv2d_1189[0][0]
#                                                                  conv2d_1190[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 16, 16, 1024) 4096        concatenate_33[0][0]
# __________________________________________________________________________________________________
# activation_163 (Activation)     (None, 16, 16, 1024) 0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_1191 (Conv2D)            (None, 16, 16, 2048) 2097152     activation_163[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 16, 16, 2048) 8192        conv2d_1191[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_33 (Gl (None, 2048)         0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# lambda_1089 (Lambda)            (None, 1, 1, 2048)   0           global_average_pooling2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_1192 (Conv2D)            (None, 1, 1, 128)    262272      lambda_1089[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, 1, 1, 128)    0           conv2d_1192[0][0]
# __________________________________________________________________________________________________
# conv2d_1193 (Conv2D)            (None, 1, 1, 2048)   264192      activation_164[0][0]
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, 1, 1, 2048)   0           conv2d_1193[0][0]
# __________________________________________________________________________________________________
# multiply_33 (Multiply)          (None, 16, 16, 2048) 0           batch_normalization_104[0][0]
#                                                                  activation_165[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 16, 16, 2048) 0           multiply_33[0][0]
#                                                                  activation_161[0][0]
# __________________________________________________________________________________________________
# activation_166 (Activation)     (None, 16, 16, 2048) 0           add_33[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_34 (Gl (None, 2048)         0           activation_166[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_1 (GaussianNoise (None, 2048)         0           global_average_pooling2d_34[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2048)         4196352     gaussian_noise_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 5)            10245       dense_1[0][0]
# ==================================================================================================
# Total params: 51,250,869
# Trainable params: 51,113,013
# Non-trainable params: 137,856
# __________________________________________________________________________________________________
# None

# %%
#Non-Groups
#Split training and validation
#Using Expert Data

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil
import multiprocessing

NUM_GPU = 4
batch_size = 20
#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    model_mul = multi_gpu_model(model_2, gpus=NUM_GPU)

# print('Loading pretrained weights')
# if NUM_GPU != 1:
#     model_mul.load_weights(savedfilename)
# # else:
# #     model.load_weights(savedfilename)

epochs = 10##!!!
lr = 2*1e-4
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

if NUM_GPU != 1:
    model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

train_set = train_datagen.flow_from_directory('train_3',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('valid_3',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cassava_NonGrp_Set3_T1_SEResNext101_LRG501_Mul_STD.pkl')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.99, verbose=1)
savecheckpoint = SaveCheckPoint(model_2, savedfilename)

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('cassava_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('cassava_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

# number of steps each epoch
step_size_train=ceil(train_set.n/train_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[earlystopping, savecheckpoint],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# Found 4527 images belonging to 5 classes.
# Found 1129 images belonging to 5 classes.
# Epoch 1/10
# 226/227 [============================>.] - ETA: 1s - loss: 0.6958 - acc: 0.7594
# Saving val_acc 0.844110 at checkpoints/Cassava_NonGrp_Set3_T1_SEResNext101_LRG501_Mul_STD.pkl
# 227/227 [==============================] - 331s 1s/step - loss: 0.6951 - acc: 0.7596 - val_loss: 0.6498 - val_acc: 0.8441
# Epoch 2/10
# 226/227 [============================>.] - ETA: 1s - loss: 0.4705 - acc: 0.8408
# Saving val_acc 0.883968 at checkpoints/Cassava_NonGrp_Set3_T1_SEResNext101_LRG501_Mul_STD.pkl
# 227/227 [==============================] - 275s 1s/step - loss: 0.4705 - acc: 0.8410 - val_loss: 0.4218 - val_acc: 0.8840
# Epoch 3/10
# 227/227 [==============================] - 274s 1s/step - loss: 0.3825 - acc: 0.8737 - val_loss: 0.5495 - val_acc: 0.8229
# Epoch 4/10
# 227/227 [==============================] - 274s 1s/step - loss: 0.3638 - acc: 0.8875 - val_loss: 0.4253 - val_acc: 0.8831
# Epoch 5/10
# 226/227 [============================>.] - ETA: 1s - loss: 0.3300 - acc: 0.8949
# Saving val_acc 0.897254 at checkpoints/Cassava_NonGrp_Set3_T1_SEResNext101_LRG501_Mul_STD.pkl
# 227/227 [==============================] - 275s 1s/step - loss: 0.3298 - acc: 0.8952 - val_loss: 0.4210 - val_acc: 0.8973
# Epoch 6/10
# 227/227 [==============================] - 276s 1s/step - loss: 0.3030 - acc: 0.8996 - val_loss: 0.5988 - val_acc: 0.8530
# Epoch 7/10
# 227/227 [==============================] - 276s 1s/step - loss: 0.2972 - acc: 0.9011 - val_loss: 0.4366 - val_acc: 0.8778
# Epoch 8/10
# 227/227 [==============================] - 275s 1s/step - loss: 0.2665 - acc: 0.9075 - val_loss: 0.4539 - val_acc: 0.8778
# Epoch 9/10
# 227/227 [==============================] - 275s 1s/step - loss: 0.2554 - acc: 0.9161 - val_loss: 0.4644 - val_acc: 0.8716
# Epoch 10/10
# 227/227 [==============================] - 275s 1s/step - loss: 0.2366 - acc: 0.9172 - val_loss: 0.4120 - val_acc: 0.8937

# %%
#use pickle to load model weights
import os
import pickle

savedfilename = os.path.join('checkpoints', 'Cassava_NonGrp_Set3_T1_SEResNext101_LRG501_Mul_STD.pkl')
pklfile= savedfilename

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

# NUM_GPU = 4
# #Using multiple models if more than 1 GPU
# if NUM_GPU != 1:
#     model_mul = multi_gpu_model(model_2, gpus=NUM_GPU)

# restoredmodel= mymodel()
#use set_weights to load the modelweights into the model architecture
model_mul.set_weights(weigh)

# %%
max(result.history['val_acc']),min(result.history['val_acc'])
# Out:
# (0.8972542038842363, 0.8228520814880426)

# %%
# Visualize training history
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy

# list all data in history
# history = result.history
#print(history.history.keys())
# summarize history for accuracy
plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('SeNet - 501 - Noise model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('SeNet - 501 - Noise model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# # reload weights before prediction
# import numpy as np
# batch_size = 20

# # PREDICT ON OFFICIAL TEST
# train_datagen = ImageDataGenerator(
# #     rescale = 1./255,
#     rotation_range=30,
#     width_shift_range=0.3,
#     height_shift_range=0.3,
#     shear_range=0.3,
#     zoom_range=0.3,
#     horizontal_flip=True,
#     vertical_flip=True,##
# #     brightness_range=[0.5, 1.5],##
#     channel_shift_range=10,##
#     fill_mode='nearest',
#     preprocessing_function=preprocess_input,
# )

# train_set = train_datagen.flow_from_directory('train_3',
#                                                  target_size = (501, 501),
#                                                  batch_size = batch_size,
#                                                  class_mode = 'categorical',
#                                                  shuffle=True,
#                                                  seed=7,
# #                                                  subset="training"
#                                               )

# test_datagen1 = ImageDataGenerator(
# #     rescale = 1./255,
#     preprocessing_function=preprocess_input
# )

# test_set1 = test_datagen1.flow_from_directory('test',
#                                                  target_size = (501, 501),
#                                                  batch_size = batch_size,
#                                                  class_mode = 'categorical',
#                                                  shuffle=False,
#                                                  seed=7,
# #                                                  subset="validation"
#                                              )

# if NUM_GPU != 1:
#     predict1=model_mul.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
# # else:
# #     predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
# predicted_class_indices=np.argmax(predict1,axis=1)
# labels = (train_set.class_indices)
# labels = dict((v,k) for k,v in labels.items())
# predictions1 = [labels[k] for k in predicted_class_indices]

# import pandas as pd

# filenames=test_set1.filenames
# results=pd.DataFrame({"file_name":filenames,
#                       "predicted1":predictions1,
#                       })
# results.to_csv('Cassava_NonGrp_MulModels540_2708_v13.csv')
# results.head()

# %%
# cp Cassava_NonGrp_MulModels540_2708_v13.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels540_2708_v13.csv

# %%
# np.save(os.path.join('pred_npy','Cassava_NonGrp_Set5_T1_L1_0Crop_SEResNext101_LRG501_Mul_STD.npy'), predict1)

# %%
# mv pred_npy/Cassava_NonGrp_Set5_T1_L1_0Crop_SEResNext101_LRG501_Mul_STD.npy pred_npy/Cassava_NonGrp_Set3_T1_L1_0Crop_SEResNext101_LRG501_Mul_STD.npy

# %%
#Change Learning Rate

import time, os
NUM_GPU = 4
batch_size = 20

# print('Loading pretrained weights')
# if NUM_GPU != 1:
#     model_mul.load_weights(savedfilename)
# # else:
# #     model.load_weights(savedfilename)

epochs = 10##!!!
lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cassava_NonGrp_Set3_T1_SEResNext101_LRG501_Mul_STD_L2.pkl')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.99, verbose=1)
savecheckpoint = SaveCheckPoint(model_2, savedfilename)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[earlystopping, savecheckpoint],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# Epoch 1/10
# 226/227 [============================>.] - ETA: 1s - loss: 0.3143 - acc: 0.8958
# Saving val_acc 0.890168 at checkpoints/Cassava_NonGrp_Set3_T1_SEResNext101_LRG501_Mul_STD_L2.pkl
# 227/227 [==============================] - 287s 1s/step - loss: 0.3134 - acc: 0.8960 - val_loss: 0.3920 - val_acc: 0.8902
# Epoch 2/10
# 227/227 [==============================] - 275s 1s/step - loss: 0.2917 - acc: 0.9011 - val_loss: 0.4147 - val_acc: 0.8866
# Epoch 3/10
# 227/227 [==============================] - 274s 1s/step - loss: 0.2668 - acc: 0.9117 - val_loss: 0.4490 - val_acc: 0.8857
# Epoch 4/10
# 227/227 [==============================] - 275s 1s/step - loss: 0.2662 - acc: 0.9148 - val_loss: 0.4250 - val_acc: 0.8857
# Epoch 5/10
# 226/227 [============================>.] - ETA: 1s - loss: 0.2432 - acc: 0.9162
# Saving val_acc 0.899026 at checkpoints/Cassava_NonGrp_Set3_T1_SEResNext101_LRG501_Mul_STD_L2.pkl
# 227/227 [==============================] - 276s 1s/step - loss: 0.2441 - acc: 0.9161 - val_loss: 0.3806 - val_acc: 0.8990
# Epoch 6/10
# 227/227 [==============================] - 274s 1s/step - loss: 0.2314 - acc: 0.9255 - val_loss: 0.3618 - val_acc: 0.8937
# Epoch 7/10
# 227/227 [==============================] - 274s 1s/step - loss: 0.2200 - acc: 0.9238 - val_loss: 0.5164 - val_acc: 0.8654
# Epoch 8/10
# 227/227 [==============================] - 275s 1s/step - loss: 0.2089 - acc: 0.9273 - val_loss: 0.3813 - val_acc: 0.8973
# Epoch 9/10
# 226/227 [============================>.] - ETA: 1s - loss: 0.1981 - acc: 0.9350
# Saving val_acc 0.900797 at checkpoints/Cassava_NonGrp_Set3_T1_SEResNext101_LRG501_Mul_STD_L2.pkl
# 227/227 [==============================] - 276s 1s/step - loss: 0.1978 - acc: 0.9353 - val_loss: 0.4056 - val_acc: 0.9008
# Epoch 10/10
# 227/227 [==============================] - 275s 1s/step - loss: 0.1950 - acc: 0.9317 - val_loss: 0.5603 - val_acc: 0.8618

# %%
#use pickle to load model weights
import os
import pickle

savedfilename = os.path.join('checkpoints', 'Cassava_NonGrp_Set3_T1_SEResNext101_LRG501_Mul_STD_L2.pkl')
pklfile= savedfilename

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

# NUM_GPU = 4
# #Using multiple models if more than 1 GPU
# if NUM_GPU != 1:
#     model_mul = multi_gpu_model(model_2, gpus=NUM_GPU)

# restoredmodel= mymodel()
#use set_weights to load the modelweights into the model architecture
model_mul.set_weights(weigh)

# %%
#L3
#Non-Groups
#Split training and validation
#Using Expert Data

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil
import multiprocessing

NUM_GPU = 4
batch_size = 20
#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    model_mul = multi_gpu_model(model_2, gpus=NUM_GPU)

# print('Loading pretrained weights')
# if NUM_GPU != 1:
#     model_mul.load_weights(savedfilename)
# # else:
# #     model.load_weights(savedfilename)

epochs = 10##!!!
lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

if NUM_GPU != 1:
    model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

train_set = train_datagen.flow_from_directory('train_3',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('valid_3',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cassava_NonGrp_Set3_T1_SEResNext101_LRG501_Mul_STD_L3.pkl')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.99, verbose=1)
savecheckpoint = SaveCheckPoint(model_2, savedfilename)

# number of steps each epoch
step_size_train=ceil(train_set.n/train_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[earlystopping, savecheckpoint],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# Found 4527 images belonging to 5 classes.
# Found 1129 images belonging to 5 classes.
# Epoch 1/10
# 226/227 [============================>.] - ETA: 1s - loss: 0.1283 - acc: 0.9589
# Saving val_acc 0.914969 at checkpoints/Cassava_NonGrp_Set3_T1_SEResNext101_LRG501_Mul_STD_L3.pkl
# 227/227 [==============================] - 325s 1s/step - loss: 0.1299 - acc: 0.9582 - val_loss: 0.3685 - val_acc: 0.9150
# Epoch 2/10
# 227/227 [==============================] - 265s 1s/step - loss: 0.1062 - acc: 0.9670 - val_loss: 0.3754 - val_acc: 0.9132
# Epoch 3/10
# 227/227 [==============================] - 265s 1s/step - loss: 0.0968 - acc: 0.9667 - val_loss: 0.3953 - val_acc: 0.9070
# Epoch 4/10
# 227/227 [==============================] - 265s 1s/step - loss: 0.0962 - acc: 0.9650 - val_loss: 0.3898 - val_acc: 0.9150
# Epoch 5/10
# 227/227 [==============================] - 265s 1s/step - loss: 0.0846 - acc: 0.9718 - val_loss: 0.3997 - val_acc: 0.9123
# Epoch 6/10
# 227/227 [==============================] - 264s 1s/step - loss: 0.0744 - acc: 0.9738 - val_loss: 0.4016 - val_acc: 0.9123
# Epoch 7/10
# 226/227 [============================>.] - ETA: 1s - loss: 0.0859 - acc: 0.9697
# Saving val_acc 0.916740 at checkpoints/Cassava_NonGrp_Set3_T1_SEResNext101_LRG501_Mul_STD_L3.pkl
# 227/227 [==============================] - 266s 1s/step - loss: 0.0856 - acc: 0.9698 - val_loss: 0.4080 - val_acc: 0.9167
# Epoch 8/10
# 227/227 [==============================] - 264s 1s/step - loss: 0.0723 - acc: 0.9729 - val_loss: 0.4088 - val_acc: 0.9123
# Epoch 9/10
# 227/227 [==============================] - 265s 1s/step - loss: 0.0689 - acc: 0.9753 - val_loss: 0.4289 - val_acc: 0.9132
# Epoch 10/10
# 227/227 [==============================] - 265s 1s/step - loss: 0.0651 - acc: 0.9793 - val_loss: 0.4395 - val_acc: 0.9035

# %%
#use pickle to load model weights
import os
import pickle

savedfilename = os.path.join('checkpoints', 'Cassava_NonGrp_Set3_T1_SEResNext101_LRG501_Mul_STD_L3.pkl')
pklfile= savedfilename

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

# NUM_GPU = 4
# #Using multiple models if more than 1 GPU
# if NUM_GPU != 1:
#     model_mul = multi_gpu_model(model_2, gpus=NUM_GPU)

# restoredmodel= mymodel()
#use set_weights to load the modelweights into the model architecture
model_mul.set_weights(weigh)

# %%
# reload weights before prediction
from keras.preprocessing.image import ImageDataGenerator
from math import ceil
import numpy as np

batch_size = 20

# PREDICT ON OFFICIAL TEST
train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

train_set = train_datagen.flow_from_directory('train_3',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

test_datagen1 = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

test_set1 = test_datagen1.flow_from_directory('test',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

if NUM_GPU != 1:
    predict1=model_mul.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
# else:
#     predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
predicted_class_indices=np.argmax(predict1,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions1 = [labels[k] for k in predicted_class_indices]

import pandas as pd

filenames=test_set1.filenames
results=pd.DataFrame({"file_name":filenames,
                      "predicted1":predictions1,
                      })
results.to_csv('Cassava_NonGrp_MulModels540_2708_v26.csv')
results.head()
# Out:
# Found 4527 images belonging to 5 classes.
# Found 3774 images belonging to 1 classes.
# 189/189 [==============================] - 74s 394ms/step
#              file_name predicted1
# 0     0/test-img-0.jpg       cbsd
# 1     0/test-img-1.jpg       cbsd
# 2    0/test-img-10.jpg        cmd
# 3   0/test-img-100.jpg        cgm
# 4  0/test-img-1000.jpg       cbsd

# %%
cp Cassava_NonGrp_MulModels540_2708_v26.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels540_2708_v26.csv

# %%
np.save(os.path.join('pred_npy','Cassava_NonGrp_Set3_T1_0Crop_SEResNext101_LRG501_Mul_STD_L3.npy'), predict1)

# %%
from keras.preprocessing.image import ImageDataGenerator
from math import ceil
import numpy as np

batch_size = 20

#Crop-Official Test
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

def crop_generator(batches, crop_length):
    """Generate random crops from the image batches"""
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

test_datagen_crop = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

testing_set_crop = test_datagen_crop.flow_from_directory('test',
                                                 target_size = (540, 540),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="training"
                                              )
#customized generator
test_crops = crop_generator(testing_set_crop, 501)

step_size_test_crop = ceil(testing_set_crop.n/testing_set_crop.batch_size)

tta_steps = 3
predictions = []

# import tensorflow as tf
# with tf.device('/gpu:0'):
for i in range(tta_steps):
    print(i)
    testing_set_crop.reset()
    if NUM_GPU != 1:
        preds=model_mul.predict_generator(test_crops, 
                                           steps = step_size_test_crop,
#                                            max_queue_size=16,
#                                                use_multiprocessing=True,
#                                            workers=1,
                                           verbose=1)    
#     else:
#         preds=model.predict_generator(test_crops, 
#                                            steps = step_size_test_crop,
#                                            max_queue_size=16,
# #                                                use_multiprocessing=True,
#                                            workers=1,
#                                            verbose=1)  
#     preds=model_2.predict_generator(test_crops,steps = step_size_test_crop,verbose=1)  
    predictions.append(preds)

mean_pred = np.mean(predictions, axis=0)

predicted_class_indices_mean=np.argmax(mean_pred,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cassava_NonGrp_MulModels540_2708_v28.csv')
results.head(10)
# Out:
# Found 3774 images belonging to 1 classes.
# 0
# 189/189 [==============================] - 78s 411ms/step
# 1
# 189/189 [==============================] - 78s 411ms/step
# 2
# 189/189 [==============================] - 78s 412ms/step
#                     id predicted
# 0     0/test-img-0.jpg      cbsd
# 1     0/test-img-1.jpg      cbsd
# 2    0/test-img-10.jpg       cmd
# 3   0/test-img-100.jpg       cgm
# 4  0/test-img-1000.jpg      cbsd
# 5  0/test-img-1001.jpg       cmd
# 6  0/test-img-1002.jpg       cmd
# 7  0/test-img-1003.jpg       cmd
# 8  0/test-img-1004.jpg       cmd
# 9  0/test-img-1005.jpg       cgm

# %%
np.save(os.path.join('pred_npy','Cassava_NonGrp_Set3_T1_3Crop_SEResNext101_LRG501_Mul_STD_L3.npy'), mean_pred)

# %%
cp Cassava_NonGrp_MulModels540_2708_v28.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels540_2708_v28.csv

# %%
# # Save weights in pickle format instead of h5
# # Set 3
# import pickle

# #use get_weights() command to get your model weights
# weigh= model_2.get_weights()

# #now, use pickle to save your model weights, instead of .h5
# #for heavy model architectures, .h5 file is unsupported.
# pklfile= os.path.join('checkpoints', 'Cassava_NonGrp_Set2_SEResNext101_LRG501_Mul_STD.pkl')

# fpkl= open(pklfile, 'wb') #Python 3
# pickle.dump(weigh, fpkl, protocol= pickle.HIGHEST_PROTOCOL)
# fpkl.close()

# %%
# os.listdir("checkpoints")

# %%
# os.listdir("pred_npy")

# %%
# #use pickle to load model weights

# pklfile= os.path.join('checkpoints', 'Cassava_NonGrp_S1_SEResNext101_LRG501_Mul_Pretrained_STD_L5.pkl')

# f= open(pklfile, 'rb')     #Python 3                 
# weigh= pickle.load(f);                
# f.close();

# # restoredmodel= mymodel()
# #use set_weights to load the modelweights into the model architecture
# model_mul.set_weights(weigh)

# %%
# model_mul.save_weights(savedfilename)
# f2_sgl = model_mul.layers[-2]
# f2_sgl.save(os.path.join('checkpoints', 'Cassava_NonGrp_S1_SEResNext50_LRG450_Mul_Pretrained_STD_L3_SGL.hdf5'))

# %%
# len(model_mul.to_json())

# %%
# np.asarray([layer.name.encode('utf8') for layer in model_mul.layers]).nbytes

# %%
# len(model_2.to_json())

# %%
# np.asarray([layer.name.encode('utf8') for layer in model_2.layers]).nbytes

# %%
cd /media/datastorage/Phong/cassava/cv/1/

# %%
#Set 1
#MUL 1 - Xception

# from keras.applications import InceptionV3
from keras.applications import Xception
# from keras.applications.inception_resnet_v2 import InceptionResNetV2

from keras.models import Model
from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM
from keras.applications.inception_v3 import preprocess_input

from keras.layers import GaussianNoise

f1_base = Xception(weights='imagenet', include_top=False, input_shape=(501,501,3))  
f1_x = f1_base.output
f1_x = GlobalAveragePooling2D()(f1_x)

#Regularization with noise
f1_x = GaussianNoise(0.1)(f1_x)

f1_x = Dense(2048, activation='relu')(f1_x)
f1_x = Dense(5, activation='softmax')(f1_x)
model_1 = Model(inputs=[f1_base.input],outputs=[f1_x])

print(model_1.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 501, 501, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 250, 250, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 250, 250, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 250, 250, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 248, 248, 64) 18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 248, 248, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 248, 248, 64) 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 248, 248, 128 8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 248, 248, 128 512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 248, 248, 128 0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 248, 248, 128 17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 248, 248, 128 512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 124, 124, 128 8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 124, 124, 128 0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 124, 124, 128 512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 124, 124, 128 0           block2_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 124, 124, 128 0           add_1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 124, 124, 256 33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 124, 124, 256 1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 124, 124, 256 0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 124, 124, 256 67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 124, 124, 256 1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 62, 62, 256)  32768       add_1[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 62, 62, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 62, 62, 256)  1024        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 62, 62, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 62, 62, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 62, 62, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 62, 62, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 62, 62, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 62, 62, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 62, 62, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 31, 31, 728)  186368      add_2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 31, 31, 728)  0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 31, 31, 728)  2912        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 31, 31, 728)  0           block4_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 31, 31, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 31, 31, 728)  536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 31, 31, 728)  2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 31, 31, 728)  0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 31, 31, 728)  536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 31, 31, 728)  2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 31, 31, 728)  0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 31, 31, 728)  536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 31, 31, 728)  2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 31, 31, 728)  0           block5_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 31, 31, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 31, 31, 728)  536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 31, 31, 728)  2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 31, 31, 728)  0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 31, 31, 728)  536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 31, 31, 728)  2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 31, 31, 728)  0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 31, 31, 728)  536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 31, 31, 728)  2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 31, 31, 728)  0           block6_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 31, 31, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 31, 31, 728)  536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 31, 31, 728)  2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 31, 31, 728)  0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 31, 31, 728)  536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 31, 31, 728)  2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 31, 31, 728)  0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 31, 31, 728)  536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 31, 31, 728)  2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 31, 31, 728)  0           block7_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 31, 31, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 31, 31, 728)  536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 31, 31, 728)  2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 31, 31, 728)  0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 31, 31, 728)  536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 31, 31, 728)  2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 31, 31, 728)  0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 31, 31, 728)  536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 31, 31, 728)  2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 31, 31, 728)  0           block8_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 31, 31, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 31, 31, 728)  536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 31, 31, 728)  2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 31, 31, 728)  0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 31, 31, 728)  536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 31, 31, 728)  2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 31, 31, 728)  0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 31, 31, 728)  536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 31, 31, 728)  2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 31, 31, 728)  0           block9_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 31, 31, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 31, 31, 728)  536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 31, 31, 728)  2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 31, 31, 728)  0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 31, 31, 728)  536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 31, 31, 728)  2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 31, 31, 728)  0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 31, 31, 728)  536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 31, 31, 728)  2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 31, 31, 728)  0           block10_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 31, 31, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 31, 31, 728)  536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 31, 31, 728)  2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 31, 31, 728)  0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 31, 31, 728)  536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 31, 31, 728)  2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 31, 31, 728)  0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 31, 31, 728)  536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 31, 31, 728)  2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 31, 31, 728)  0           block11_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 31, 31, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 31, 31, 728)  536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 31, 31, 728)  2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 31, 31, 728)  0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 31, 31, 728)  536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 31, 31, 728)  2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 31, 31, 728)  0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 31, 31, 728)  536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 31, 31, 728)  2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 31, 31, 728)  0           block12_sepconv3_bn[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 31, 31, 728)  0           add_11[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 31, 31, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 31, 31, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 31, 31, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 31, 31, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 31, 31, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 1024) 745472      add_11[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 16, 16, 1024) 0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 1024) 4096        conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 16, 16, 1024) 0           block13_pool[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 16, 16, 1536) 1582080     add_12[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 16, 16, 1536) 6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 16, 16, 1536) 0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 16, 16, 2048) 3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 16, 16, 2048) 8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 16, 16, 2048) 0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_1 (GaussianNoise (None, 2048)         0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2048)         4196352     gaussian_noise_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 5)            10245       dense_1[0][0]
# ==================================================================================================
# Total params: 25,068,077
# Trainable params: 25,013,549
# Non-trainable params: 54,528
# __________________________________________________________________________________________________
# None

# %%
#Non-Groups
#Split training and validation
#Using Expert Data

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil
import multiprocessing

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

NUM_GPU = 4
batch_size = 20

train_set = train_datagen.flow_from_directory('train_3',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('valid_3',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cassava_NonGrp_Set3_T1_Xception_LRG501_Mul_STD.hdf5')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('cassava_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('cassava_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.9900, verbose=1)

#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    model_mul = multi_gpu_model(model_1, gpus=NUM_GPU)

epochs = 10##!!!
lr = 2*1e-4
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

step_size_train=ceil(train_set.n/train_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[earlystopping],
    callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# Found 4527 images belonging to 5 classes.
# Found 1129 images belonging to 5 classes.
# Epoch 1/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.8352 - acc: 0.7021Epoch 00001: val_acc improved from -inf to 0.76971, saving model to checkpoints/Cassava_NonGrp_Set3_T1_Xception_LRG501_Mul_STD.hdf5
# 227/227 [==============================] - 203s 895ms/step - loss: 0.8328 - acc: 0.7030 - val_loss: 0.7226 - val_acc: 0.7697
# Epoch 2/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.5522 - acc: 0.8098Epoch 00002: val_acc improved from 0.76971 to 0.83702, saving model to checkpoints/Cassava_NonGrp_Set3_T1_Xception_LRG501_Mul_STD.hdf5
# 227/227 [==============================] - 196s 865ms/step - loss: 0.5515 - acc: 0.8102 - val_loss: 0.5708 - val_acc: 0.8370
# Epoch 3/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.4755 - acc: 0.8406Epoch 00003: val_acc improved from 0.83702 to 0.83880, saving model to checkpoints/Cassava_NonGrp_Set3_T1_Xception_LRG501_Mul_STD.hdf5
# 227/227 [==============================] - 199s 875ms/step - loss: 0.4747 - acc: 0.8409 - val_loss: 0.5937 - val_acc: 0.8388
# Epoch 4/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.4390 - acc: 0.8547Epoch 00004: val_acc improved from 0.83880 to 0.85828, saving model to checkpoints/Cassava_NonGrp_Set3_T1_Xception_LRG501_Mul_STD.hdf5
# 227/227 [==============================] - 198s 874ms/step - loss: 0.4415 - acc: 0.8541 - val_loss: 0.5381 - val_acc: 0.8583
# Epoch 5/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.4075 - acc: 0.8726Epoch 00005: val_acc improved from 0.85828 to 0.87777, saving model to checkpoints/Cassava_NonGrp_Set3_T1_Xception_LRG501_Mul_STD.hdf5
# 227/227 [==============================] - 198s 874ms/step - loss: 0.4075 - acc: 0.8727 - val_loss: 0.4787 - val_acc: 0.8778
# Epoch 6/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.3627 - acc: 0.8791Epoch 00006: val_acc did not improve
# 227/227 [==============================] - 199s 875ms/step - loss: 0.3618 - acc: 0.8794 - val_loss: 0.5165 - val_acc: 0.8725
# Epoch 7/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.3723 - acc: 0.8812Epoch 00007: val_acc did not improve
# 227/227 [==============================] - 199s 875ms/step - loss: 0.3721 - acc: 0.8813 - val_loss: 0.5078 - val_acc: 0.8636
# Epoch 8/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.3274 - acc: 0.8918Epoch 00008: val_acc did not improve
# 227/227 [==============================] - 196s 863ms/step - loss: 0.3272 - acc: 0.8919 - val_loss: 0.6724 - val_acc: 0.8441
# Epoch 9/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.3075 - acc: 0.8956Epoch 00009: val_acc did not improve
# 227/227 [==============================] - 200s 879ms/step - loss: 0.3078 - acc: 0.8956 - val_loss: 0.5456 - val_acc: 0.8609
# Epoch 10/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.2990 - acc: 0.8965Epoch 00010: val_acc improved from 0.87777 to 0.89105, saving model to checkpoints/Cassava_NonGrp_Set3_T1_Xception_LRG501_Mul_STD.hdf5
# 227/227 [==============================] - 196s 863ms/step - loss: 0.2993 - acc: 0.8961 - val_loss: 0.4367 - val_acc: 0.8911

# %%
#use hdf5
hdf5file= os.path.join('checkpoints', 'Cassava_NonGrp_Set3_T1_Xception_LRG501_Mul_STD.hdf5')

model_mul.load_weights(hdf5file)

# %%
# # reload weights before prediction
# from keras.preprocessing.image import ImageDataGenerator
# from math import ceil
# import numpy as np

# batch_size = 20

# # PREDICT ON OFFICIAL TEST
# train_datagen = ImageDataGenerator(
# #     rescale = 1./255,
#     rotation_range=30,
#     width_shift_range=0.3,
#     height_shift_range=0.3,
#     shear_range=0.3,
#     zoom_range=0.3,
#     horizontal_flip=True,
#     vertical_flip=True,##
# #     brightness_range=[0.5, 1.5],##
#     channel_shift_range=10,##
#     fill_mode='nearest',
#     preprocessing_function=preprocess_input,
# )

# train_set = train_datagen.flow_from_directory('train_4',
#                                                  target_size = (501, 501),
#                                                  batch_size = batch_size,
#                                                  class_mode = 'categorical',
#                                                  shuffle=True,
#                                                  seed=7,
# #                                                  subset="training"
#                                               )

# test_datagen1 = ImageDataGenerator(
# #     rescale = 1./255,
#     preprocessing_function=preprocess_input
# )

# test_set1 = test_datagen1.flow_from_directory('test',
#                                                  target_size = (501, 501),
#                                                  batch_size = batch_size,
#                                                  class_mode = 'categorical',
#                                                  shuffle=False,
#                                                  seed=7,
# #                                                  subset="validation"
#                                              )

# if NUM_GPU != 1:
#     predict1=model_mul.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
# # else:
# #     predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
# predicted_class_indices=np.argmax(predict1,axis=1)
# labels = (train_set.class_indices)
# labels = dict((v,k) for k,v in labels.items())
# predictions1 = [labels[k] for k in predicted_class_indices]

# import pandas as pd

# filenames=test_set1.filenames
# results=pd.DataFrame({"file_name":filenames,
#                       "predicted1":predictions1,
#                       })
# results.to_csv('Cassava_NonGrp_MulModels540_2608_v25.csv')
# results.head()

# %%
# cp Cassava_NonGrp_MulModels540_2608_v25.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels540_2608_v25.csv

# %%
# np.save(os.path.join('pred_npy','Cassava_NonGrp_Set5_0Crop_Xception_LRG501_Mul_STD.npy'), predict1)

# %%
# from keras.preprocessing.image import ImageDataGenerator
# from math import ceil
# import numpy as np

# batch_size = 20

# #Crop-Official Test
# def random_crop(img, random_crop_size):
#     # Note: image_data_format is 'channel_last'
#     assert img.shape[2] == 3
#     height, width = img.shape[0], img.shape[1]
#     dy, dx = random_crop_size
#     x = np.random.randint(0, width - dx + 1)
#     y = np.random.randint(0, height - dy + 1)
#     return img[y:(y+dy), x:(x+dx), :]

# def crop_generator(batches, crop_length):
#     """Generate random crops from the image batches"""
#     while True:
#         batch_x, batch_y = next(batches)
#         batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
#         for i in range(batch_x.shape[0]):
#             batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
#         yield (batch_crops, batch_y)

# test_datagen_crop = ImageDataGenerator(
# #     rescale = 1./255,
#     preprocessing_function=preprocess_input
# )

# testing_set_crop = test_datagen_crop.flow_from_directory('test',
#                                                  target_size = (540, 540),
#                                                  batch_size = batch_size,
#                                                  class_mode = 'categorical',
#                                                  shuffle=False,
#                                                  seed=7,
# #                                                  subset="training"
#                                               )
# #customized generator
# test_crops = crop_generator(testing_set_crop, 501)

# step_size_test_crop = ceil(testing_set_crop.n/testing_set_crop.batch_size)

# tta_steps = 3
# predictions = []

# # import tensorflow as tf
# # with tf.device('/gpu:0'):
# for i in range(tta_steps):
#     print(i)
#     testing_set_crop.reset()
#     if NUM_GPU != 1:
#         preds=model_mul.predict_generator(test_crops, 
#                                            steps = step_size_test_crop,
# #                                            max_queue_size=16,
# #                                                use_multiprocessing=True,
# #                                            workers=1,
#                                            verbose=1)    
# #     else:
# #         preds=model.predict_generator(test_crops, 
# #                                            steps = step_size_test_crop,
# #                                            max_queue_size=16,
# # #                                                use_multiprocessing=True,
# #                                            workers=1,
# #                                            verbose=1)  
# #     preds=model_2.predict_generator(test_crops,steps = step_size_test_crop,verbose=1)  
#     predictions.append(preds)

# mean_pred = np.mean(predictions, axis=0)

# predicted_class_indices_mean=np.argmax(mean_pred,axis=1)
# labels = (train_set.class_indices)
# labels = dict((v,k) for k,v in labels.items())
# finalpre = [labels[k] for k in predicted_class_indices_mean]

# import pandas as pd
# filenames=testing_set_crop.filenames
# results=pd.DataFrame({"id":filenames,
#                       "predicted":finalpre,
#                       })
# results.to_csv('Cassava_NonGrp_MulModels540_2608_v26.csv')
# results.head(10)

# %%
# cp Cassava_NonGrp_MulModels540_2608_v26.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels540_2608_v26.csv

# %%
epochs = 10##!!!
lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

savedfilename = os.path.join('checkpoints', 'Cassava_NonGrp_Set3_T1_Xception_LRG501_Mul_STD_L2.hdf5')
earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.99, verbose=1)

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[earlystopping],
    callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# Epoch 1/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.2177 - acc: 0.9261Epoch 00001: val_acc improved from -inf to 0.90257, saving model to checkpoints/Cassava_NonGrp_Set3_T1_Xception_LRG501_Mul_STD_L2.hdf5
# 227/227 [==============================] - 206s 908ms/step - loss: 0.2170 - acc: 0.9264 - val_loss: 0.4198 - val_acc: 0.9026
# Epoch 2/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.2091 - acc: 0.9290Epoch 00002: val_acc did not improve
# 227/227 [==============================] - 195s 859ms/step - loss: 0.2096 - acc: 0.9289 - val_loss: 0.4255 - val_acc: 0.8981
# Epoch 3/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.1867 - acc: 0.9396Epoch 00003: val_acc did not improve
# 227/227 [==============================] - 199s 875ms/step - loss: 0.1868 - acc: 0.9394 - val_loss: 0.4417 - val_acc: 0.8973
# Epoch 4/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.1821 - acc: 0.9383Epoch 00004: val_acc did not improve
# 227/227 [==============================] - 198s 872ms/step - loss: 0.1816 - acc: 0.9386 - val_loss: 0.4473 - val_acc: 0.9008
# Epoch 5/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.1807 - acc: 0.9375Epoch 00005: val_acc did not improve
# 227/227 [==============================] - 198s 873ms/step - loss: 0.1819 - acc: 0.9373 - val_loss: 0.4460 - val_acc: 0.9008
# Epoch 6/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.1736 - acc: 0.9400Epoch 00006: val_acc did not improve
# 227/227 [==============================] - 198s 872ms/step - loss: 0.1731 - acc: 0.9403 - val_loss: 0.4492 - val_acc: 0.8990
# Epoch 7/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.1640 - acc: 0.9425Epoch 00007: val_acc did not improve
# 227/227 [==============================] - 198s 873ms/step - loss: 0.1643 - acc: 0.9425 - val_loss: 0.4472 - val_acc: 0.8990
# Epoch 8/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.1534 - acc: 0.9487Epoch 00008: val_acc did not improve
# 227/227 [==============================] - 195s 861ms/step - loss: 0.1552 - acc: 0.9485 - val_loss: 0.4558 - val_acc: 0.8919
# Epoch 9/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.1612 - acc: 0.9443Epoch 00009: val_acc did not improve
# 227/227 [==============================] - 198s 874ms/step - loss: 0.1606 - acc: 0.9445 - val_loss: 0.4616 - val_acc: 0.8937
# Epoch 10/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.1526 - acc: 0.9504Epoch 00010: val_acc did not improve
# 227/227 [==============================] - 198s 873ms/step - loss: 0.1530 - acc: 0.9502 - val_loss: 0.4907 - val_acc: 0.8911

# %%
#use hdf5
#set 3
import os
# model_mul = multi_gpu_model(model_1, gpus=4)

hdf5file= os.path.join('checkpoints', 'Cassava_NonGrp_Set3_T1_Xception_LRG501_Mul_STD_L2.hdf5')
model_mul.load_weights(hdf5file)

# %%
# reload weights before prediction
from keras.preprocessing.image import ImageDataGenerator
from math import ceil
import numpy as np

batch_size = 20

# PREDICT ON OFFICIAL TEST
train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

train_set = train_datagen.flow_from_directory('train_3',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

test_datagen1 = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

test_set1 = test_datagen1.flow_from_directory('test',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

if NUM_GPU != 1:
    predict1=model_mul.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
# else:
#     predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
predicted_class_indices=np.argmax(predict1,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions1 = [labels[k] for k in predicted_class_indices]

import pandas as pd

filenames=test_set1.filenames
results=pd.DataFrame({"file_name":filenames,
                      "predicted1":predictions1,
                      })
results.to_csv('Cassava_NonGrp_MulModels540_2708_v22.csv')
results.head()
# Out:
# Found 4527 images belonging to 5 classes.
# Found 3774 images belonging to 1 classes.
# 189/189 [==============================] - 50s 265ms/step
#              file_name predicted1
# 0     0/test-img-0.jpg       cbsd
# 1     0/test-img-1.jpg       cbsd
# 2    0/test-img-10.jpg        cmd
# 3   0/test-img-100.jpg        cgm
# 4  0/test-img-1000.jpg       cbsd

# %%
cp Cassava_NonGrp_MulModels540_2708_v22.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels540_2708_v22.csv

# %%
np.save(os.path.join('pred_npy','Cassava_NonGrp_Set3_T1_0Crop_Xception_LRG501_Mul_STD.npy'), predict1)

# %%
# model_mul.load_weights(os.path.join('checkpoints', 'Cassava_NonGrp_Set5_Xception_LRG501_Mul_STD_L2.hdf5'))

# %%
# os.listdir('pred_npy')

# %%
from keras.preprocessing.image import ImageDataGenerator
from math import ceil
import numpy as np

batch_size = 20

#Crop-Official Test
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

def crop_generator(batches, crop_length):
    """Generate random crops from the image batches"""
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

test_datagen_crop = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

testing_set_crop = test_datagen_crop.flow_from_directory('test',
                                                 target_size = (540, 540),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="training"
                                              )
#customized generator
test_crops = crop_generator(testing_set_crop, 501)

step_size_test_crop = ceil(testing_set_crop.n/testing_set_crop.batch_size)

tta_steps = 3
predictions = []

# import tensorflow as tf
# with tf.device('/gpu:0'):
for i in range(tta_steps):
    print(i)
    testing_set_crop.reset()
    if NUM_GPU != 1:
        preds=model_mul.predict_generator(test_crops, 
                                           steps = step_size_test_crop,
#                                            max_queue_size=16,
#                                                use_multiprocessing=True,
#                                            workers=1,
                                           verbose=1)    
#     else:
#         preds=model.predict_generator(test_crops, 
#                                            steps = step_size_test_crop,
#                                            max_queue_size=16,
# #                                                use_multiprocessing=True,
#                                            workers=1,
#                                            verbose=1)  
#     preds=model_2.predict_generator(test_crops,steps = step_size_test_crop,verbose=1)  
    predictions.append(preds)

mean_pred = np.mean(predictions, axis=0)

predicted_class_indices_mean=np.argmax(mean_pred,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cassava_NonGrp_MulModels540_2708_v23.csv')
results.head(10)
# Out:
# Found 3774 images belonging to 1 classes.
# 0
# 189/189 [==============================] - 61s 324ms/step
# 1
# 189/189 [==============================] - 61s 325ms/step
# 2
# 189/189 [==============================] - 61s 323ms/step
#                     id predicted
# 0     0/test-img-0.jpg      cbsd
# 1     0/test-img-1.jpg      cbsd
# 2    0/test-img-10.jpg       cmd
# 3   0/test-img-100.jpg       cgm
# 4  0/test-img-1000.jpg      cbsd
# 5  0/test-img-1001.jpg       cmd
# 6  0/test-img-1002.jpg       cmd
# 7  0/test-img-1003.jpg       cmd
# 8  0/test-img-1004.jpg       cmd
# 9  0/test-img-1005.jpg       cgm

# %%
cp Cassava_NonGrp_MulModels540_2708_v23.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels540_2708_v23.csv

# %%
np.save(os.path.join('pred_npy','Cassava_NonGrp_Set3_T1_3Crop_Xception_LRG501_Mul_STD.npy'), mean_pred)

# %%
#L3
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil
import multiprocessing

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

NUM_GPU = 4
batch_size = 20

train_set = train_datagen.flow_from_directory('train_3',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('valid_3',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cassava_NonGrp_Set3_T1_Xception_LRG501_Mul_STD_L3.hdf5')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('cassava_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('cassava_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.9900, verbose=1)

#Using multiple models if more than 1 GPU
# if NUM_GPU != 1:
#     model_mul = multi_gpu_model(model_1, gpus=NUM_GPU)

epochs = 12##!!!
lr = 1e-4
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

step_size_train=ceil(train_set.n/train_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[earlystopping],
    callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# Found 4527 images belonging to 5 classes.
# Found 1129 images belonging to 5 classes.
# Epoch 1/12
# 226/227 [============================>.] - ETA: 0s - loss: 0.2251 - acc: 0.9259Epoch 00001: val_acc improved from -inf to 0.87511, saving model to checkpoints/Cassava_NonGrp_Set3_T1_Xception_LRG501_Mul_STD_L3.hdf5
# 227/227 [==============================] - 204s 898ms/step - loss: 0.2244 - acc: 0.9262 - val_loss: 0.5704 - val_acc: 0.8751
# Epoch 2/12
# 226/227 [============================>.] - ETA: 0s - loss: 0.2104 - acc: 0.9288Epoch 00002: val_acc did not improve
# 227/227 [==============================] - 198s 871ms/step - loss: 0.2123 - acc: 0.9283 - val_loss: 0.5181 - val_acc: 0.8698
# Epoch 3/12
# 226/227 [============================>.] - ETA: 0s - loss: 0.1897 - acc: 0.9341Epoch 00003: val_acc improved from 0.87511 to 0.89371, saving model to checkpoints/Cassava_NonGrp_Set3_T1_Xception_LRG501_Mul_STD_L3.hdf5
# 227/227 [==============================] - 196s 864ms/step - loss: 0.1904 - acc: 0.9333 - val_loss: 0.4756 - val_acc: 0.8937
# Epoch 4/12
# 226/227 [============================>.] - ETA: 0s - loss: 0.1797 - acc: 0.9381Epoch 00004: val_acc did not improve
# 227/227 [==============================] - 199s 875ms/step - loss: 0.1790 - acc: 0.9384 - val_loss: 0.4360 - val_acc: 0.8911
# Epoch 5/12
# 226/227 [============================>.] - ETA: 0s - loss: 0.1703 - acc: 0.9449Epoch 00005: val_acc did not improve
# 227/227 [==============================] - 196s 863ms/step - loss: 0.1702 - acc: 0.9449 - val_loss: 0.4807 - val_acc: 0.8875
# Epoch 6/12
# 226/227 [============================>.] - ETA: 0s - loss: 0.1610 - acc: 0.9460Epoch 00006: val_acc did not improve
# 227/227 [==============================] - 196s 865ms/step - loss: 0.1611 - acc: 0.9458 - val_loss: 0.4921 - val_acc: 0.8857
# Epoch 7/12
# 226/227 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.9469Epoch 00007: val_acc did not improve
# 227/227 [==============================] - 199s 878ms/step - loss: 0.1511 - acc: 0.9469 - val_loss: 0.5339 - val_acc: 0.8893
# Epoch 8/12
# 226/227 [============================>.] - ETA: 0s - loss: 0.1437 - acc: 0.9518Epoch 00008: val_acc did not improve
# 227/227 [==============================] - 199s 876ms/step - loss: 0.1435 - acc: 0.9518 - val_loss: 0.6099 - val_acc: 0.8804
# Epoch 9/12
# 226/227 [============================>.] - ETA: 0s - loss: 0.1374 - acc: 0.9529Epoch 00009: val_acc did not improve
# 227/227 [==============================] - 200s 879ms/step - loss: 0.1368 - acc: 0.9531 - val_loss: 0.7078 - val_acc: 0.8601
# Epoch 10/12
#  89/227 [==========>...................] - ETA: 1:42 - loss: 0.1315 - acc: 0.9528
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-274c2e29047c> in <module>
#      92 #     callbacks=[earlystopping],
#      93     callbacks=[tb, csv_logger, checkpointer, earlystopping],
# ---> 94     verbose=1)
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2145                     outs = self.train_on_batch(x, y,
#    2146                                                sample_weight=sample_weight,
# -> 2147                                                class_weight=class_weight)
#    2148
#    2149                     if not isinstance(outs, list):
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1837             ins = x + y + sample_weights
#    1838         self._make_train_function()
# -> 1839         outputs = self.train_function(ins)
#    1840         if len(outputs) == 1:
#    1841             return outputs[0]
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2355         session = get_session()
#    2356         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2357                               **self.session_kwargs)
#    2358         return updated[:len(self.outputs)]
#    2359
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
mkdir checkpoints

# %%
#501
#MUL 3 InceptionResNetV2
# from keras.applications import InceptionV3
# from keras.applications import Xception
from keras.applications.inception_resnet_v2 import InceptionResNetV2

from keras.preprocessing import image
from keras.models import Model
from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM
from keras.applications.inception_v3 import preprocess_input

from keras.layers import GaussianNoise

f3_base = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(501,501,3))  
# for layer in f3_base.layers:
#     layer.trainable = False 
f3_x = f3_base.output
f3_x = GlobalAveragePooling2D()(f3_x)

#Regularization with noise
f3_x = GaussianNoise(0.1)(f3_x)

f3_x = Dense(2048, activation='relu')(f3_x)
f3_x = Dense(5, activation='softmax')(f3_x)
model_3 = Model(inputs=[f3_base.input],outputs=[f3_x])

print(model_3.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 501, 501, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 250, 250, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 250, 250, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 250, 250, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 248, 248, 32) 9216        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 248, 248, 32) 96          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 248, 248, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 248, 248, 64) 18432       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 248, 248, 64) 192         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 248, 248, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 123, 123, 64) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 123, 123, 80) 5120        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 123, 123, 80) 240         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 123, 123, 80) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 121, 121, 192 138240      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 121, 121, 192 576         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 121, 121, 192 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 60, 60, 192)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 60, 60, 64)   12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 60, 60, 64)   192         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 60, 60, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 60, 60, 48)   9216        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 60, 60, 96)   55296       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 60, 60, 48)   144         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 60, 60, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 60, 60, 48)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 60, 60, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 60, 60, 192)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 60, 60, 96)   18432       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 60, 60, 64)   76800       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 60, 60, 96)   82944       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 60, 60, 64)   12288       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 60, 60, 96)   288         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 60, 60, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 60, 60, 96)   288         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 60, 60, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 60, 60, 96)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 60, 60, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 60, 60, 96)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 60, 60, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# mixed_5b (Concatenate)          (None, 60, 60, 320)  0           activation_6[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 60, 60, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 60, 60, 32)   96          conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 60, 60, 32)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 60, 60, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 60, 60, 48)   13824       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 60, 60, 32)   96          conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 60, 60, 48)   144         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 60, 60, 32)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 60, 60, 48)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 60, 60, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 60, 60, 32)   9216        activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 60, 60, 64)   27648       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 60, 60, 32)   96          conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 60, 60, 32)   96          conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 60, 60, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 60, 60, 32)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 60, 60, 32)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 60, 60, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# block35_1_mixed (Concatenate)   (None, 60, 60, 128)  0           activation_13[0][0]
#                                                                  activation_15[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# block35_1_conv (Conv2D)         (None, 60, 60, 320)  41280       block35_1_mixed[0][0]
# __________________________________________________________________________________________________
# block35_1 (Lambda)              (None, 60, 60, 320)  0           mixed_5b[0][0]
#                                                                  block35_1_conv[0][0]
# __________________________________________________________________________________________________
# block35_1_ac (Activation)       (None, 60, 60, 320)  0           block35_1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 60, 60, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 60, 60, 32)   96          conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 60, 60, 32)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 60, 60, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 60, 60, 48)   13824       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 60, 60, 32)   96          conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 60, 60, 48)   144         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 60, 60, 32)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 60, 60, 48)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 60, 60, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 60, 60, 32)   9216        activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 60, 60, 64)   27648       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 60, 60, 32)   96          conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 60, 60, 32)   96          conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 60, 60, 64)   192         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 60, 60, 32)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 60, 60, 32)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 60, 60, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# block35_2_mixed (Concatenate)   (None, 60, 60, 128)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# block35_2_conv (Conv2D)         (None, 60, 60, 320)  41280       block35_2_mixed[0][0]
# __________________________________________________________________________________________________
# block35_2 (Lambda)              (None, 60, 60, 320)  0           block35_1_ac[0][0]
#                                                                  block35_2_conv[0][0]
# __________________________________________________________________________________________________
# block35_2_ac (Activation)       (None, 60, 60, 320)  0           block35_2[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 60, 60, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 60, 60, 32)   96          conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 60, 60, 32)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 60, 60, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 60, 60, 48)   13824       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 60, 60, 32)   96          conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 60, 60, 48)   144         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 60, 60, 32)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 60, 60, 48)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 60, 60, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 60, 60, 32)   9216        activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 60, 60, 64)   27648       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 60, 60, 32)   96          conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 60, 60, 32)   96          conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 60, 60, 64)   192         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 60, 60, 32)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 60, 60, 32)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 60, 60, 64)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# block35_3_mixed (Concatenate)   (None, 60, 60, 128)  0           activation_25[0][0]
#                                                                  activation_27[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# block35_3_conv (Conv2D)         (None, 60, 60, 320)  41280       block35_3_mixed[0][0]
# __________________________________________________________________________________________________
# block35_3 (Lambda)              (None, 60, 60, 320)  0           block35_2_ac[0][0]
#                                                                  block35_3_conv[0][0]
# __________________________________________________________________________________________________
# block35_3_ac (Activation)       (None, 60, 60, 320)  0           block35_3[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 60, 60, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 60, 60, 32)   96          conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 60, 60, 32)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 60, 60, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 60, 60, 48)   13824       activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 60, 60, 32)   96          conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 60, 60, 48)   144         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 60, 60, 32)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 60, 60, 48)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 60, 60, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 60, 60, 32)   9216        activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 60, 60, 64)   27648       activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 60, 60, 32)   96          conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 60, 60, 32)   96          conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 60, 60, 64)   192         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 60, 60, 32)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 60, 60, 32)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 60, 60, 64)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# block35_4_mixed (Concatenate)   (None, 60, 60, 128)  0           activation_31[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_36[0][0]
# __________________________________________________________________________________________________
# block35_4_conv (Conv2D)         (None, 60, 60, 320)  41280       block35_4_mixed[0][0]
# __________________________________________________________________________________________________
# block35_4 (Lambda)              (None, 60, 60, 320)  0           block35_3_ac[0][0]
#                                                                  block35_4_conv[0][0]
# __________________________________________________________________________________________________
# block35_4_ac (Activation)       (None, 60, 60, 320)  0           block35_4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 60, 60, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 60, 60, 32)   96          conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 60, 60, 32)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 60, 60, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 60, 60, 48)   13824       activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 60, 60, 32)   96          conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 60, 60, 48)   144         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 60, 60, 32)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 60, 60, 48)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 60, 60, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 60, 60, 32)   9216        activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 60, 60, 64)   27648       activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 60, 60, 32)   96          conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 60, 60, 32)   96          conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 60, 60, 64)   192         conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 60, 60, 32)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 60, 60, 32)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 60, 60, 64)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# block35_5_mixed (Concatenate)   (None, 60, 60, 128)  0           activation_37[0][0]
#                                                                  activation_39[0][0]
#                                                                  activation_42[0][0]
# __________________________________________________________________________________________________
# block35_5_conv (Conv2D)         (None, 60, 60, 320)  41280       block35_5_mixed[0][0]
# __________________________________________________________________________________________________
# block35_5 (Lambda)              (None, 60, 60, 320)  0           block35_4_ac[0][0]
#                                                                  block35_5_conv[0][0]
# __________________________________________________________________________________________________
# block35_5_ac (Activation)       (None, 60, 60, 320)  0           block35_5[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 60, 60, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 60, 60, 32)   96          conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 60, 60, 32)   0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 60, 60, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 60, 60, 48)   13824       activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 60, 60, 32)   96          conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 60, 60, 48)   144         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 60, 60, 32)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 60, 60, 48)   0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 60, 60, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 60, 60, 32)   9216        activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 60, 60, 64)   27648       activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 60, 60, 32)   96          conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 60, 60, 32)   96          conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 60, 60, 64)   192         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 60, 60, 32)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 60, 60, 32)   0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 60, 60, 64)   0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# block35_6_mixed (Concatenate)   (None, 60, 60, 128)  0           activation_43[0][0]
#                                                                  activation_45[0][0]
#                                                                  activation_48[0][0]
# __________________________________________________________________________________________________
# block35_6_conv (Conv2D)         (None, 60, 60, 320)  41280       block35_6_mixed[0][0]
# __________________________________________________________________________________________________
# block35_6 (Lambda)              (None, 60, 60, 320)  0           block35_5_ac[0][0]
#                                                                  block35_6_conv[0][0]
# __________________________________________________________________________________________________
# block35_6_ac (Activation)       (None, 60, 60, 320)  0           block35_6[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 60, 60, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 60, 60, 32)   96          conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 60, 60, 32)   0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 60, 60, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 60, 60, 48)   13824       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 60, 60, 32)   96          conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 60, 60, 48)   144         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 60, 60, 32)   0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 60, 60, 48)   0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 60, 60, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 60, 60, 32)   9216        activation_50[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 60, 60, 64)   27648       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 60, 60, 32)   96          conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 60, 60, 32)   96          conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 60, 60, 64)   192         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 60, 60, 32)   0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 60, 60, 32)   0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 60, 60, 64)   0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# block35_7_mixed (Concatenate)   (None, 60, 60, 128)  0           activation_49[0][0]
#                                                                  activation_51[0][0]
#                                                                  activation_54[0][0]
# __________________________________________________________________________________________________
# block35_7_conv (Conv2D)         (None, 60, 60, 320)  41280       block35_7_mixed[0][0]
# __________________________________________________________________________________________________
# block35_7 (Lambda)              (None, 60, 60, 320)  0           block35_6_ac[0][0]
#                                                                  block35_7_conv[0][0]
# __________________________________________________________________________________________________
# block35_7_ac (Activation)       (None, 60, 60, 320)  0           block35_7[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 60, 60, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 60, 60, 32)   96          conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 60, 60, 32)   0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 60, 60, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 60, 60, 48)   13824       activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 60, 60, 32)   96          conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 60, 60, 48)   144         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 60, 60, 32)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 60, 60, 48)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 60, 60, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 60, 60, 32)   9216        activation_56[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 60, 60, 64)   27648       activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 60, 60, 32)   96          conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 60, 60, 32)   96          conv2d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 60, 60, 64)   192         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 60, 60, 32)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 60, 60, 32)   0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 60, 60, 64)   0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# block35_8_mixed (Concatenate)   (None, 60, 60, 128)  0           activation_55[0][0]
#                                                                  activation_57[0][0]
#                                                                  activation_60[0][0]
# __________________________________________________________________________________________________
# block35_8_conv (Conv2D)         (None, 60, 60, 320)  41280       block35_8_mixed[0][0]
# __________________________________________________________________________________________________
# block35_8 (Lambda)              (None, 60, 60, 320)  0           block35_7_ac[0][0]
#                                                                  block35_8_conv[0][0]
# __________________________________________________________________________________________________
# block35_8_ac (Activation)       (None, 60, 60, 320)  0           block35_8[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 60, 60, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 60, 60, 32)   96          conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 60, 60, 32)   0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 60, 60, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 60, 60, 48)   13824       activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 60, 60, 32)   96          conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 60, 60, 48)   144         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 60, 60, 32)   0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 60, 60, 48)   0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 60, 60, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# block8_6_mixed (Concatenate)    (None, 14, 14, 448)  0           activation_184[0][0]
#                                                                  activation_187[0][0]
# __________________________________________________________________________________________________
# block8_6_conv (Conv2D)          (None, 14, 14, 2080) 933920      block8_6_mixed[0][0]
# __________________________________________________________________________________________________
# block8_6 (Lambda)               (None, 14, 14, 2080) 0           block8_5_ac[0][0]
#                                                                  block8_6_conv[0][0]
# __________________________________________________________________________________________________
# block8_6_ac (Activation)        (None, 14, 14, 2080) 0           block8_6[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 14, 14, 192)  399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 14, 14, 192)  576         conv2d_189[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 14, 14, 192)  0           batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 14, 14, 224)  129024      activation_189[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, 14, 14, 224)  672         conv2d_190[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 14, 14, 224)  0           batch_normalization_190[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 14, 14, 192)  399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 14, 14, 256)  172032      activation_190[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 14, 14, 192)  576         conv2d_188[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 14, 14, 256)  768         conv2d_191[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 14, 14, 192)  0           batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 14, 14, 256)  0           batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# block8_7_mixed (Concatenate)    (None, 14, 14, 448)  0           activation_188[0][0]
#                                                                  activation_191[0][0]
# __________________________________________________________________________________________________
# block8_7_conv (Conv2D)          (None, 14, 14, 2080) 933920      block8_7_mixed[0][0]
# __________________________________________________________________________________________________
# block8_7 (Lambda)               (None, 14, 14, 2080) 0           block8_6_ac[0][0]
#                                                                  block8_7_conv[0][0]
# __________________________________________________________________________________________________
# block8_7_ac (Activation)        (None, 14, 14, 2080) 0           block8_7[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 14, 14, 192)  399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 14, 14, 192)  576         conv2d_193[0][0]
# __________________________________________________________________________________________________
# activation_193 (Activation)     (None, 14, 14, 192)  0           batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 14, 14, 224)  129024      activation_193[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, 14, 14, 224)  672         conv2d_194[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, 14, 14, 224)  0           batch_normalization_194[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 14, 14, 192)  399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 14, 14, 256)  172032      activation_194[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 14, 14, 192)  576         conv2d_192[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 14, 14, 256)  768         conv2d_195[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 14, 14, 192)  0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# activation_195 (Activation)     (None, 14, 14, 256)  0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# block8_8_mixed (Concatenate)    (None, 14, 14, 448)  0           activation_192[0][0]
#                                                                  activation_195[0][0]
# __________________________________________________________________________________________________
# block8_8_conv (Conv2D)          (None, 14, 14, 2080) 933920      block8_8_mixed[0][0]
# __________________________________________________________________________________________________
# block8_8 (Lambda)               (None, 14, 14, 2080) 0           block8_7_ac[0][0]
#                                                                  block8_8_conv[0][0]
# __________________________________________________________________________________________________
# block8_8_ac (Activation)        (None, 14, 14, 2080) 0           block8_8[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 14, 14, 192)  399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, 14, 14, 192)  576         conv2d_197[0][0]
# __________________________________________________________________________________________________
# activation_197 (Activation)     (None, 14, 14, 192)  0           batch_normalization_197[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 14, 14, 224)  129024      activation_197[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, 14, 14, 224)  672         conv2d_198[0][0]
# __________________________________________________________________________________________________
# activation_198 (Activation)     (None, 14, 14, 224)  0           batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 14, 14, 192)  399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, 14, 14, 256)  172032      activation_198[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 14, 14, 192)  576         conv2d_196[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199 (BatchN (None, 14, 14, 256)  768         conv2d_199[0][0]
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, 14, 14, 192)  0           batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# activation_199 (Activation)     (None, 14, 14, 256)  0           batch_normalization_199[0][0]
# __________________________________________________________________________________________________
# block8_9_mixed (Concatenate)    (None, 14, 14, 448)  0           activation_196[0][0]
#                                                                  activation_199[0][0]
# __________________________________________________________________________________________________
# block8_9_conv (Conv2D)          (None, 14, 14, 2080) 933920      block8_9_mixed[0][0]
# __________________________________________________________________________________________________
# block8_9 (Lambda)               (None, 14, 14, 2080) 0           block8_8_ac[0][0]
#                                                                  block8_9_conv[0][0]
# __________________________________________________________________________________________________
# block8_9_ac (Activation)        (None, 14, 14, 2080) 0           block8_9[0][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, 14, 14, 192)  399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201 (BatchN (None, 14, 14, 192)  576         conv2d_201[0][0]
# __________________________________________________________________________________________________
# activation_201 (Activation)     (None, 14, 14, 192)  0           batch_normalization_201[0][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, 14, 14, 224)  129024      activation_201[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202 (BatchN (None, 14, 14, 224)  672         conv2d_202[0][0]
# __________________________________________________________________________________________________
# activation_202 (Activation)     (None, 14, 14, 224)  0           batch_normalization_202[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, 14, 14, 192)  399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_203 (Conv2D)             (None, 14, 14, 256)  172032      activation_202[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, 14, 14, 192)  576         conv2d_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_203 (BatchN (None, 14, 14, 256)  768         conv2d_203[0][0]
# __________________________________________________________________________________________________
# activation_200 (Activation)     (None, 14, 14, 192)  0           batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# activation_203 (Activation)     (None, 14, 14, 256)  0           batch_normalization_203[0][0]
# __________________________________________________________________________________________________
# block8_10_mixed (Concatenate)   (None, 14, 14, 448)  0           activation_200[0][0]
#                                                                  activation_203[0][0]
# __________________________________________________________________________________________________
# block8_10_conv (Conv2D)         (None, 14, 14, 2080) 933920      block8_10_mixed[0][0]
# __________________________________________________________________________________________________
# block8_10 (Lambda)              (None, 14, 14, 2080) 0           block8_9_ac[0][0]
#                                                                  block8_10_conv[0][0]
# __________________________________________________________________________________________________
# conv_7b (Conv2D)                (None, 14, 14, 1536) 3194880     block8_10[0][0]
# __________________________________________________________________________________________________
# conv_7b_bn (BatchNormalization) (None, 14, 14, 1536) 4608        conv_7b[0][0]
# __________________________________________________________________________________________________
# conv_7b_ac (Activation)         (None, 14, 14, 1536) 0           conv_7b_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 1536)         0           conv_7b_ac[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_1 (GaussianNoise (None, 1536)         0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2048)         3147776     gaussian_noise_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 5)            10245       dense_1[0][0]
# ==================================================================================================
# Total params: 57,494,757
# Trainable params: 57,434,213
# Non-trainable params: 60,544
# __________________________________________________________________________________________________
# None

# %%
#Non-Groups
#Split training and validation
#Using Expert Data

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil
import multiprocessing

NUM_GPU = 4
batch_size = 20
#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    model_mul = multi_gpu_model(model_3, gpus=NUM_GPU)

# print('Loading pretrained weights')
# if NUM_GPU != 1:
#     model_mul.load_weights(savedfilename)
# # else:
# #     model.load_weights(savedfilename)

epochs = 10##!!!
lr = 2*1e-4
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

if NUM_GPU != 1:
    model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

train_set = train_datagen.flow_from_directory('train_3',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('valid_3',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cassava_NonGrp_Set3_T1_IcpResNetV2_LRG501_Mul_STD.pkl')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.99, verbose=1)
savecheckpoint = SaveCheckPoint(model_3, savedfilename)

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('cassava_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('cassava_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

# number of steps each epoch
step_size_train=ceil(train_set.n/train_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[earlystopping, savecheckpoint],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# Found 4527 images belonging to 5 classes.
# Found 1129 images belonging to 5 classes.
# Epoch 1/10
# 226/227 [============================>.] - ETA: 1s - loss: 0.8119 - acc: 0.7134
# Saving val_acc 0.850310 at checkpoints/Cassava_NonGrp_Set3_T1_IcpResNetV2_LRG501_Mul_STD.pkl
# 227/227 [==============================] - 261s 1s/step - loss: 0.8107 - acc: 0.7140 - val_loss: 0.4637 - val_acc: 0.8503
# Epoch 2/10
# 227/227 [==============================] - 216s 953ms/step - loss: 0.5600 - acc: 0.8130 - val_loss: 0.4882 - val_acc: 0.8477
# Epoch 3/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.4795 - acc: 0.8428
# Saving val_acc 0.860053 at checkpoints/Cassava_NonGrp_Set3_T1_IcpResNetV2_LRG501_Mul_STD.pkl
# 227/227 [==============================] - 217s 957ms/step - loss: 0.4784 - acc: 0.8433 - val_loss: 0.5596 - val_acc: 0.8601
# Epoch 4/10
# 227/227 [==============================] - 216s 953ms/step - loss: 0.4404 - acc: 0.8560 - val_loss: 0.6036 - val_acc: 0.8087
# Epoch 5/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.4080 - acc: 0.8712
# Saving val_acc 0.882197 at checkpoints/Cassava_NonGrp_Set3_T1_IcpResNetV2_LRG501_Mul_STD.pkl
# 227/227 [==============================] - 217s 955ms/step - loss: 0.4095 - acc: 0.8703 - val_loss: 0.4205 - val_acc: 0.8822
# Epoch 6/10
# 227/227 [==============================] - 216s 951ms/step - loss: 0.3765 - acc: 0.8728 - val_loss: 0.7393 - val_acc: 0.8096
# Epoch 7/10
# 227/227 [==============================] - 216s 952ms/step - loss: 0.3648 - acc: 0.8855 - val_loss: 0.4870 - val_acc: 0.8645
# Epoch 8/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.3339 - acc: 0.8927
# Saving val_acc 0.889283 at checkpoints/Cassava_NonGrp_Set3_T1_IcpResNetV2_LRG501_Mul_STD.pkl
# 227/227 [==============================] - 217s 955ms/step - loss: 0.3341 - acc: 0.8930 - val_loss: 0.4155 - val_acc: 0.8893
# Epoch 9/10
# 227/227 [==============================] - 216s 951ms/step - loss: 0.3235 - acc: 0.8945 - val_loss: 0.4060 - val_acc: 0.8813
# Epoch 10/10
# 227/227 [==============================] - 216s 953ms/step - loss: 0.3036 - acc: 0.8954 - val_loss: 0.4239 - val_acc: 0.8787

# %%
#set 3
#use pickle to load model weights
pklfile= os.path.join('checkpoints', 'Cassava_NonGrp_Set3_T1_IcpResNetV2_LRG501_Mul_STD.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

# restoredmodel= mymodel()
#use set_weights to load the modelweights into the model architecture
model_mul.set_weights(weigh)

# %%
# Change LR
import time, os

NUM_GPU = 4
batch_size = 20

# print('Loading pretrained weights')
# if NUM_GPU != 1:
#     model_mul.load_weights(savedfilename)
# # else:
# #     model.load_weights(savedfilename)

epochs = 10##!!!
lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cassava_NonGrp_Set3_T1_IcpResNetV2_LRG501_Mul_STD_L2.pkl')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.99, verbose=1)
savecheckpoint = SaveCheckPoint(model_3, savedfilename)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[earlystopping, savecheckpoint],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# Epoch 1/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.3158 - acc: 0.8998
# Saving val_acc 0.871568 at checkpoints/Cassava_NonGrp_Set3_T1_IcpResNetV2_LRG501_Mul_STD_L2.pkl
# 227/227 [==============================] - 226s 996ms/step - loss: 0.3151 - acc: 0.9000 - val_loss: 0.4784 - val_acc: 0.8716
# Epoch 2/10
# 227/227 [==============================] - 215s 949ms/step - loss: 0.3208 - acc: 0.8957 - val_loss: 0.5821 - val_acc: 0.8415
# Epoch 3/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.2900 - acc: 0.9060
# Saving val_acc 0.879539 at checkpoints/Cassava_NonGrp_Set3_T1_IcpResNetV2_LRG501_Mul_STD_L2.pkl
# 227/227 [==============================] - 216s 952ms/step - loss: 0.2899 - acc: 0.9060 - val_loss: 0.4057 - val_acc: 0.8795
# Epoch 4/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.2857 - acc: 0.9031
# Saving val_acc 0.891940 at checkpoints/Cassava_NonGrp_Set3_T1_IcpResNetV2_LRG501_Mul_STD_L2.pkl
# 227/227 [==============================] - 216s 953ms/step - loss: 0.2856 - acc: 0.9031 - val_loss: 0.4043 - val_acc: 0.8919
# Epoch 5/10
# 227/227 [==============================] - 216s 950ms/step - loss: 0.2754 - acc: 0.9155 - val_loss: 0.4224 - val_acc: 0.8866
# Epoch 6/10
# 227/227 [==============================] - 216s 950ms/step - loss: 0.2628 - acc: 0.9095 - val_loss: 0.4669 - val_acc: 0.8689
# Epoch 7/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.2600 - acc: 0.9166
# Saving val_acc 0.898140 at checkpoints/Cassava_NonGrp_Set3_T1_IcpResNetV2_LRG501_Mul_STD_L2.pkl
# 227/227 [==============================] - 216s 953ms/step - loss: 0.2602 - acc: 0.9161 - val_loss: 0.3871 - val_acc: 0.8981
# Epoch 8/10
# 227/227 [==============================] - 215s 946ms/step - loss: 0.2527 - acc: 0.9174 - val_loss: 0.6089 - val_acc: 0.8291
# Epoch 9/10
# 227/227 [==============================] - 216s 950ms/step - loss: 0.2403 - acc: 0.9199 - val_loss: 0.4853 - val_acc: 0.8866
# Epoch 10/10
# 227/227 [==============================] - 216s 949ms/step - loss: 0.2322 - acc: 0.9216 - val_loss: 0.5122 - val_acc: 0.8477

# %%
#use pickle to load model weights
#set 3
pklfile= os.path.join('checkpoints', 'Cassava_NonGrp_Set3_T1_IcpResNetV2_LRG501_Mul_STD_L2.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

# restoredmodel= mymodel()
#use set_weights to load the modelweights into the model architecture
model_mul.set_weights(weigh)

# %%
# reload weights before prediction
from keras.preprocessing.image import ImageDataGenerator
from math import ceil
import numpy as np

batch_size = 20

# PREDICT ON OFFICIAL TEST
train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

train_set = train_datagen.flow_from_directory('train_3',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

test_datagen1 = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

test_set1 = test_datagen1.flow_from_directory('test',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

if NUM_GPU != 1:
    predict1=model_mul.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
# else:
#     predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
predicted_class_indices=np.argmax(predict1,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions1 = [labels[k] for k in predicted_class_indices]

import pandas as pd

filenames=test_set1.filenames
results=pd.DataFrame({"file_name":filenames,
                      "predicted1":predictions1,
                      })
results.to_csv('Cassava_NonGrp_MulModels540_2708_v23.csv')
results.head()
# Out:
# Found 4527 images belonging to 5 classes.
# Found 3774 images belonging to 1 classes.
# 189/189 [==============================] - 60s 317ms/step
#              file_name predicted1
# 0     0/test-img-0.jpg       cbsd
# 1     0/test-img-1.jpg       cbsd
# 2    0/test-img-10.jpg        cmd
# 3   0/test-img-100.jpg        cgm
# 4  0/test-img-1000.jpg       cbsd

# %%
cp Cassava_NonGrp_MulModels540_2708_v23.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels540_2708_v23.csv

# %%
np.save(os.path.join('pred_npy','Cassava_NonGrp_Set3_T1_0Crop_IcpResNetV2_LRG501_Mul_STD.npy'), predict1)

# %%
os.listdir('pred_npy')

# %%
#L3

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil

NUM_GPU = 4
batch_size = 20
#Using multiple models if more than 1 GPU
# if NUM_GPU != 1:
#     model_mul = multi_gpu_model(model_3, gpus=NUM_GPU)

epochs = 10##!!!
lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

if NUM_GPU != 1:
    model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

train_set = train_datagen.flow_from_directory('train_3',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('valid_3',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cassava_NonGrp_Set3_T1_IcpResNetV2_LRG501_Mul_STD_L3.pkl')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.99, verbose=1)
savecheckpoint = SaveCheckPoint(model_3, savedfilename)

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('cassava_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('cassava_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

# number of steps each epoch
step_size_train=ceil(train_set.n/train_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[earlystopping, savecheckpoint],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# Found 4527 images belonging to 5 classes.
# Found 1129 images belonging to 5 classes.
# Epoch 1/10
# 226/227 [============================>.] - ETA: 1s - loss: 0.1932 - acc: 0.9359
# Saving val_acc 0.901683 at checkpoints/Cassava_NonGrp_Set3_T1_IcpResNetV2_LRG501_Mul_STD_L3.pkl
# 227/227 [==============================] - 264s 1s/step - loss: 0.1930 - acc: 0.9359 - val_loss: 0.3852 - val_acc: 0.9017
# Epoch 2/10
# 227/227 [==============================] - 216s 953ms/step - loss: 0.1702 - acc: 0.9436 - val_loss: 0.3872 - val_acc: 0.8973
# Epoch 3/10
# 226/227 [============================>.] - ETA: 0s - loss: 0.1570 - acc: 0.9454
# Saving val_acc 0.904340 at checkpoints/Cassava_NonGrp_Set3_T1_IcpResNetV2_LRG501_Mul_STD_L3.pkl
# 227/227 [==============================] - 218s 958ms/step - loss: 0.1574 - acc: 0.9454 - val_loss: 0.3793 - val_acc: 0.9043
# Epoch 4/10
# 227/227 [==============================] - 217s 955ms/step - loss: 0.1537 - acc: 0.9458 - val_loss: 0.3793 - val_acc: 0.9008
# Epoch 5/10
# 227/227 [==============================] - 217s 957ms/step - loss: 0.1463 - acc: 0.9474 - val_loss: 0.3768 - val_acc: 0.9035
# Epoch 6/10
# 227/227 [==============================] - 216s 951ms/step - loss: 0.1341 - acc: 0.9555 - val_loss: 0.3808 - val_acc: 0.9035
# Epoch 7/10
# 227/227 [==============================] - 216s 953ms/step - loss: 0.1351 - acc: 0.9570 - val_loss: 0.3950 - val_acc: 0.9026
# Epoch 8/10
# 227/227 [==============================] - 216s 952ms/step - loss: 0.1277 - acc: 0.9595 - val_loss: 0.4003 - val_acc: 0.9008
# Epoch 9/10
# 227/227 [==============================] - 216s 953ms/step - loss: 0.1214 - acc: 0.9599 - val_loss: 0.4099 - val_acc: 0.8990
# Epoch 10/10
# 227/227 [==============================] - 216s 952ms/step - loss: 0.1225 - acc: 0.9575 - val_loss: 0.3979 - val_acc: 0.9026

# %%
#use pickle to load model weights
#set 3
pklfile= os.path.join('checkpoints', 'Cassava_NonGrp_Set3_T1_IcpResNetV2_LRG501_Mul_STD_L3.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

# restoredmodel= mymodel()
#use set_weights to load the modelweights into the model architecture
model_mul.set_weights(weigh)

# %%
# reload weights before prediction
from keras.preprocessing.image import ImageDataGenerator
from math import ceil
import numpy as np

batch_size = 20

# PREDICT ON OFFICIAL TEST
train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

train_set = train_datagen.flow_from_directory('train_3',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

test_datagen1 = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

test_set1 = test_datagen1.flow_from_directory('test',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

if NUM_GPU != 1:
    predict1=model_mul.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
# else:
#     predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
predicted_class_indices=np.argmax(predict1,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions1 = [labels[k] for k in predicted_class_indices]

import pandas as pd

filenames=test_set1.filenames
results=pd.DataFrame({"file_name":filenames,
                      "predicted1":predictions1,
                      })
results.to_csv('Cassava_NonGrp_MulModels540_2808_v03.csv')
results.head()
# Out:
# Found 4527 images belonging to 5 classes.
# Found 3774 images belonging to 1 classes.
# 189/189 [==============================] - 52s 276ms/step
#              file_name predicted1
# 0     0/test-img-0.jpg       cbsd
# 1     0/test-img-1.jpg       cbsd
# 2    0/test-img-10.jpg        cmd
# 3   0/test-img-100.jpg        cgm
# 4  0/test-img-1000.jpg       cbsd

# %%
cp Cassava_NonGrp_MulModels540_2808_v03.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels540_2808_v03.csv

# %%
np.save(os.path.join('pred_npy','Cassava_NonGrp_Set3_T1_0Crop_IcpResNetV2_LRG501_Mul_STD_L3.npy'), predict1)

# %%
from keras.preprocessing.image import ImageDataGenerator
from math import ceil
import numpy as np

batch_size = 20

#Crop-Official Test
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

def crop_generator(batches, crop_length):
    """Generate random crops from the image batches"""
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

test_datagen_crop = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

testing_set_crop = test_datagen_crop.flow_from_directory('test',
                                                 target_size = (540, 540),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="training"
                                              )
#customized generator
test_crops = crop_generator(testing_set_crop, 501)

step_size_test_crop = ceil(testing_set_crop.n/testing_set_crop.batch_size)

tta_steps = 3
predictions = []

# import tensorflow as tf
# with tf.device('/gpu:0'):
for i in range(tta_steps):
    print(i)
    testing_set_crop.reset()
    if NUM_GPU != 1:
        preds=model_mul.predict_generator(test_crops, 
                                           steps = step_size_test_crop,
#                                            max_queue_size=16,
#                                                use_multiprocessing=True,
#                                            workers=1,
                                           verbose=1)    
#     else:
#         preds=model.predict_generator(test_crops, 
#                                            steps = step_size_test_crop,
#                                            max_queue_size=16,
# #                                                use_multiprocessing=True,
#                                            workers=1,
#                                            verbose=1)  
#     preds=model_2.predict_generator(test_crops,steps = step_size_test_crop,verbose=1)  
    predictions.append(preds)

mean_pred = np.mean(predictions, axis=0)

predicted_class_indices_mean=np.argmax(mean_pred,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cassava_NonGrp_MulModels540_2808_v04.csv')
results.head(10)
# Out:
# Found 3774 images belonging to 1 classes.
# 0
# 189/189 [==============================] - 62s 330ms/step
# 1
# 189/189 [==============================] - 62s 330ms/step
# 2
# 189/189 [==============================] - 63s 333ms/step
#                     id predicted
# 0     0/test-img-0.jpg      cbsd
# 1     0/test-img-1.jpg      cbsd
# 2    0/test-img-10.jpg       cmd
# 3   0/test-img-100.jpg       cgm
# 4  0/test-img-1000.jpg      cbsd
# 5  0/test-img-1001.jpg       cmd
# 6  0/test-img-1002.jpg       cmd
# 7  0/test-img-1003.jpg       cmd
# 8  0/test-img-1004.jpg       cmd
# 9  0/test-img-1005.jpg       cgm

# %%
cp Cassava_NonGrp_MulModels540_2808_v04.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels540_2808_v04.csv

# %%
np.save(os.path.join('pred_npy','Cassava_NonGrp_Set3_T1_3Crop_IcpResNetV2_LRG501_Mul_STD.npy'), mean_pred)

# %%
import numpy as np

mean_pred1 = np.load(os.path.join('pred_npy','Cassava_NonGrp_Set3_T1_L2_3Crop_SEResNext101_LRG501_Mul_STD.npy'))
mean_pred2 = np.load(os.path.join('pred_npy','Cassava_NonGrp_Set3_T1_3Crop_Xception_LRG501_Mul_STD.npy'))
mean_pred3 = np.load(os.path.join('pred_npy','Cassava_NonGrp_Set3_T1_3Crop_IcpResNetV2_LRG501_Mul_STD.npy'))

mean_pred = (mean_pred1+mean_pred2+mean_pred3)/3

# %%
np.save(os.path.join('pred_npy','Cassava_NonGrp_Set3_T1_3M_STD.npy'), mean_pred)

# %%
from keras.preprocessing.image import ImageDataGenerator
from math import ceil
import numpy as np

batch_size = 20

#Crop-Official Test
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

def crop_generator(batches, crop_length):
    """Generate random crops from the image batches"""
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

train_datagen = ImageDataGenerator(

)

train_set = train_datagen.flow_from_directory('train_3',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )
        
test_datagen_crop = ImageDataGenerator(
)

testing_set_crop = test_datagen_crop.flow_from_directory('test',
                                                 target_size = (540, 540),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="training"
                                              )
#customized generator
test_crops = crop_generator(testing_set_crop, 501)

step_size_test_crop = ceil(testing_set_crop.n/testing_set_crop.batch_size)

predicted_class_indices_mean=np.argmax(mean_pred,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cassava_NonGrp_MulModels540_2708_v25.csv')
results.head(10)
# Out:
# Found 4527 images belonging to 5 classes.
# Found 3774 images belonging to 1 classes.
#                     id predicted
# 0     0/test-img-0.jpg      cbsd
# 1     0/test-img-1.jpg      cbsd
# 2    0/test-img-10.jpg       cmd
# 3   0/test-img-100.jpg       cgm
# 4  0/test-img-1000.jpg      cbsd
# 5  0/test-img-1001.jpg       cmd
# 6  0/test-img-1002.jpg       cmd
# 7  0/test-img-1003.jpg       cmd
# 8  0/test-img-1004.jpg       cmd
# 9  0/test-img-1005.jpg       cgm

# %%
cp Cassava_NonGrp_MulModels540_2708_v25.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels540_2708_v25.csv

# %%
from keras.preprocessing.image import ImageDataGenerator
from math import ceil
import numpy as np

batch_size = 20

#Crop-Official Test
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

def crop_generator(batches, crop_length):
    """Generate random crops from the image batches"""
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

test_datagen_crop = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

testing_set_crop = test_datagen_crop.flow_from_directory('test',
                                                 target_size = (540, 540),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="training"
                                              )
#customized generator
test_crops = crop_generator(testing_set_crop, 501)

step_size_test_crop = ceil(testing_set_crop.n/testing_set_crop.batch_size)

tta_steps = 3
predictions = []

# import tensorflow as tf
# with tf.device('/gpu:0'):
for i in range(tta_steps):
    print(i)
    testing_set_crop.reset()
    if NUM_GPU != 1:
        preds=model_mul.predict_generator(test_crops, 
                                           steps = step_size_test_crop,
#                                            max_queue_size=16,
#                                                use_multiprocessing=True,
#                                            workers=1,
                                           verbose=1)    
#     else:
#         preds=model.predict_generator(test_crops, 
#                                            steps = step_size_test_crop,
#                                            max_queue_size=16,
# #                                                use_multiprocessing=True,
#                                            workers=1,
#                                            verbose=1)  
#     preds=model_2.predict_generator(test_crops,steps = step_size_test_crop,verbose=1)  
    predictions.append(preds)

mean_pred = np.mean(predictions, axis=0)

predicted_class_indices_mean=np.argmax(mean_pred,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cassava_NonGrp_MulModels540_2708_v03.csv')
results.head(10)

# %%
cp Cassava_NonGrp_MulModels540_2708_v03.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels540_2708_v03.csv

# %%
import os
os.listdir('checkpoints/')

# %%
# model 3 - IcpResNetV2
# load to multi gpu
NUM_GPU = 4
model_mul = multi_gpu_model(model_3, gpus=NUM_GPU)

#load model the saved weights
pklfile= os.path.join('checkpoints', 'Cassava_NonGrp_Set5_IcpResNetV2_LRG501_Mul_STD_L2.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

#set the saved weight to mul-gpus model
model_mul.set_weights(weigh)

f3_sgl = model_mul.layers[-2]

#get weight from single gpu
weigh= f3_sgl.get_weights()

#now, use pickle to save your model weights, instead of .h5
#for heavy model architectures, .h5 file is unsupported.
pklfile= os.path.join('checkpoints', 'Cassava_NonGrp_Set5_IcpResNetV2_LRG501_Mul_STD_L2_SGL.pkl')

fpkl= open(pklfile, 'wb') #Python 3
pickle.dump(weigh, fpkl, protocol= pickle.HIGHEST_PROTOCOL)
fpkl.close()

# %%
#model_3
#load model the saved weights
pklfile= os.path.join('checkpoints', 'Cassava_NonGrp_Set5_IcpResNetV2_LRG501_Mul_STD_L2_SGL.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

#set the saved weight to mul-gpus model
model_3.set_weights(weigh)

# %%
# model 2 - SeResNext101
# load to multi gpu
NUM_GPU = 4
model_mul = multi_gpu_model(model_2, gpus=NUM_GPU)

#load model the saved weights
pklfile= os.path.join('checkpoints', 'Cassava_NonGrp_Set5_SEResNext101_LRG501_Mul_STD.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

#set the saved weight to mul-gpus model
model_mul.set_weights(weigh)

f2_sgl = model_mul.layers[-2]

#get weight from single gpu
weigh= f2_sgl.get_weights()

#now, use pickle to save your model weights, instead of .h5
#for heavy model architectures, .h5 file is unsupported.
pklfile= os.path.join('checkpoints', 'Cassava_NonGrp_Set5_SEResNext101_LRG501_Mul_STD_SGL.pkl')

fpkl= open(pklfile, 'wb') #Python 3
pickle.dump(weigh, fpkl, protocol= pickle.HIGHEST_PROTOCOL)
fpkl.close()

# %%
#model 2 - SEResNext101
#load model the saved weights
pklfile= os.path.join('checkpoints', 'Cassava_NonGrp_Set5_SEResNext101_LRG501_Mul_STD_SGL.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

#set the saved weight to mul-gpus model
model_2.set_weights(weigh)

# %%
#model 1 - Xception
# load to multi gpu

#use hdf5
NUM_GPU = 4
model_mul = multi_gpu_model(model_1, gpus=NUM_GPU)

hdf5file= os.path.join('checkpoints', 'Cassava_NonGrp_Set5_Xception_LRG501_Mul_STD_L2.hdf5')
model_mul.load_weights(hdf5file)

f1_sgl = model_mul.layers[-2]
f1_sgl.save(os.path.join('checkpoints', 'Cassava_NonGrp_Set5_Xception_LRG501_Mul_STD_L2_SGL.hdf5'))

# %%
model_1.load_weights(os.path.join('checkpoints', 'Cassava_NonGrp_Set5_Xception_LRG501_Mul_STD_L2_SGL.hdf5'))

# %%
# model_1.load_weights(os.path.join('checkpoints', 'Cassava_NonGrp_S1_Xception_LRG501_Mul_Pretrained_STD_SGL.hdf5'))
# # model_2.load_weights(os.path.join('checkpoints', 'Cassava_NonGrp_S1_Inception_LRG501_Mul_Pretrained_STD_SGL.hdf5'))
# model_3.load_weights(os.path.join('checkpoints', 'Cassava_NonGrp_S1_IcpResNetV2_LRG501_Mul_Pretrained_STD_SGL.hdf5'))

# %%
# 3 models
# 501
# pre-trainned weight
# get pretrained [-1] layer

from keras.applications import InceptionV3
from keras.applications import Xception
from keras.applications.inception_resnet_v2 import InceptionResNetV2

from keras.preprocessing import image
from keras.models import Model
from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM, LeakyReLU, Dropout
#from keras.applications.inception_v3 import preprocess_input
from keras_applications.imagenet_utils import preprocess_input

f1_mul_x = model_1.layers[-1].output 
f2_mul_x = model_2.layers[-1].output
f3_mul_x = model_3.layers[-1].output

x = concatenate([f1_mul_x, f2_mul_x, f3_mul_x])

x = Dense(4096)(x)
x = LeakyReLU(0.2)(x)
x = Dropout(0.5)(x)
x = Dense(5, activation='softmax')(x)
model_mul = Model(inputs=[model_1.get_input_at(0),model_2.get_input_at(0),model_3.get_input_at(0)],outputs=[x])

print(model_mul.summary())

# %%
for layer in model_mul.layers[:-4]:
    layer.trainable=False
# for layer in model.layers[87:]:
#     layer.trainable=True)
for i,layer in enumerate(model_mul.layers):
    print(i,layer.name,layer.trainable)

# %%
# generators for three inputs
def train_generator_three_img(X1, batch_size):
    gen = ImageDataGenerator(rotation_range=30,
                                   width_shift_range=0.3,
                                   height_shift_range=0.3,
                                   shear_range=0.3,
                                   zoom_range=0.3,
                                   horizontal_flip=True,
                                   fill_mode='nearest')
    genX1 = gen.flow_from_directory(X1, batch_size=batch_size, seed=1, target_size = (501, 501))    
    while True:
        X1i = genX1.next()
        yield [X1i[0], X1i[0], X1i[0]], X1i[1]
        
def valid_generator_three_img(X1, batch_size):
    gen = ImageDataGenerator()

    genX1 = gen.flow_from_directory(X1, batch_size=batch_size, seed=1, target_size = (501, 501))        
    while True:
        X1i = genX1.next()
        yield [X1i[0], X1i[0], X1i[0]], X1i[1]    
    
def test_generator_three_img(X1, batch_size):
    gen = ImageDataGenerator(
#         preprocessing_function=preprocess_input
    )

    genX1 = gen.flow_from_directory(X1, batch_size=batch_size, shuffle=False, target_size = (501, 501))        
    while True:
        X1i_0, X1i_1 = next(genX1)
        yield [X1i_0, X1i_0, X1i_0]

# %%
# !!!!!!!!!!!!!!!
#Non-Groups
#Split training and validation
#Using Expert Data

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil
import multiprocessing

## fix for multi_gpu_model prediction time longer
from keras.layers import Lambda, concatenate
from keras import Model
import tensorflow as tf

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

NUM_GPU = 4
batch_size = 100

training_set = train_datagen.flow_from_directory('train_5',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('valid_5',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cassava_NonGrp_Set5_3M_L1_LRG501_Mul_STD.pkl')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.99, verbose=1)
savecheckpoint = SaveCheckPoint(model_mul, savedfilename)

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('cassava_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('cassava_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    gpus_model_mul = multi_gpu_model(model_mul, gpus=NUM_GPU)

# print('Loading pretrained weights')
# if NUM_GPU != 1:
#     model_mul.load_weights(savedfilename)
# else:
#     model.load_weights(savedfilename)

epochs = 10##!!!
lr = 2*1e-4
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

gpus_model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

step_size_train=ceil(training_set.n/training_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = gpus_model_mul.fit_generator(
    generator = train_generator_three_img('train_5',batch_size=batch_size), 
    steps_per_epoch = step_size_train,
    validation_data = valid_generator_three_img('valid_5',batch_size=batch_size),
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[tb, csv_logger, checkpointer, earlystopping], 
    callbacks=[tb, csv_logger, savecheckpoint, earlystopping], 
    verbose=1)

# %%
#3M
#load model the saved weights
pklfile= os.path.join('checkpoints', 'Cassava_NonGrp_Set5_3M_L1_LRG501_Mul_STD.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

#set the saved weight to mul-gpus model
gpus_model_mul.set_weights(weigh)

# %%
#change test_generator
import numpy as np

# PREDICT ON OFFICIAL TEST
test_datagen1 = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

train_set = train_datagen.flow_from_directory('train_5',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

test_set1 = test_datagen1.flow_from_directory('test',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

if NUM_GPU != 1:
    predict1=gpus_model_mul.predict_generator(test_generator_three_img('test',batch_size), steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
# else:
#     predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
predicted_class_indices=np.argmax(predict1,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions1 = [labels[k] for k in predicted_class_indices]

import pandas as pd

filenames=test_set1.filenames
results=pd.DataFrame({"file_name":filenames,
                      "predicted1":predictions1,
                      })
results.to_csv('Cassava_NonGrp_MulModels501_2708_v11.csv')
results.head(10)

# %%
np.save(os.path.join('pred_npy','Cassava_NonGrp_Set5_M3_L2_LRG501_Mul_STD.npy'), predict1)

# %%
cp Cassava_NonGrp_MulModels501_2708_v11.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels501_2708_v11.csv

# %%
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cassava_NonGrp_Set5_3M_L2_Mul_STD.pkl')

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.99, verbose=1)
savecheckpoint = SaveCheckPoint(model_mul, savedfilename)

epochs = 10##!!!
lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

gpus_model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

result = gpus_model_mul.fit_generator(
    generator = train_generator_three_img('train_5',batch_size=batch_size), 
    steps_per_epoch = step_size_train,
    validation_data = valid_generator_three_img('valid_5',batch_size=batch_size),
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[tb, csv_logger, checkpointer, earlystopping], 
    callbacks=[tb, csv_logger, savecheckpoint, earlystopping], 
    verbose=1)

# %%
#3M
#load model the saved weights
pklfile= os.path.join('checkpoints', 'Cassava_NonGrp_Set5_3M_L2_Mul_STD.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

#set the saved weight to mul-gpus model
gpus_model_mul.set_weights(weigh)

# %%
#change test_generator
import numpy as np

# PREDICT ON OFFICIAL TEST
test_datagen1 = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

train_set = train_datagen.flow_from_directory('train_5',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

test_set1 = test_datagen1.flow_from_directory('test',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

if NUM_GPU != 1:
    predict1=gpus_model_mul.predict_generator(test_generator_three_img('test',batch_size), steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
# else:
#     predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
predicted_class_indices=np.argmax(predict1,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions1 = [labels[k] for k in predicted_class_indices]

import pandas as pd

filenames=test_set1.filenames
results=pd.DataFrame({"file_name":filenames,
                      "predicted1":predictions1,
                      })
results.to_csv('Cassava_NonGrp_MulModels501_2708_v10.csv')
results.head(10)

# %%
cp Cassava_NonGrp_MulModels501_2708_v10.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels501_2708_v10.csv

# %%
# Visualize training history
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy

# list all data in history
# history = result.history
#print(history.history.keys())
# summarize history for accuracy
plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Mul-ResNext - 501 - Noise model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Mul-ResNext - 501 - Noise model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
cp Cassava_NonGrp_MulModels501_2708_v06.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels501_2708_v06.csv

# %%
np.save(os.path.join('pred_npy','Cassava_NonGrp_Set5_3M_LRG501_Mul_STD.npy'), predict1)

# %%
#MULTI GPUS

from keras.preprocessing.image import ImageDataGenerator
from math import ceil
import numpy as np

#Crop-Official Test
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

def crop_generator_three_models(batches, crop_length):
    """Generate random crops from the image batches"""
     
    while True:
        batch_x, _ = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield [batch_crops, batch_crops, batch_crops]

gen = ImageDataGenerator(
#     rescale = 1./255,
#         preprocessing_function=preprocess_input
)

genX1 = gen.flow_from_directory('test',
                                 target_size = (541, 541),
                                 batch_size = batch_size,
                                 class_mode = 'categorical',
                                 shuffle=False,
                                 seed=7,
                              )

#steps
step_size_test_crop = ceil(genX1.n/genX1.batch_size)

#customized generator
test_crops = crop_generator_three_models(genX1, 501)

#number of crops
tta_steps = 3
predictions = []

for i in range(tta_steps):
    print('iteration = %d' %i)
    #reset index
    genX1.reset()
    
    preds=gpus_model_mul.predict_generator(test_crops,steps = step_size_test_crop,verbose=1)  
    predictions.append(preds)

mean_pred = np.mean(predictions, axis=0)

predicted_class_indices_mean=np.argmax(mean_pred,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cassava_NonGrp_MulModels501_2708_v07.csv')
results.head(11)

# %%
cp Cassava_NonGrp_MulModels501_2708_v07.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels501_2708_v07.csv

# %%
import pickle

#use get_weights() command to get your model weights
weigh= model_mul.get_weights()

#now, use pickle to save your model weights, instead of .h5
#for heavy model architectures, .h5 file is unsupported.
pklfile= os.path.join('checkpoints', 'Cassava_NonGrp_S1_LRG501_Mul_Pretrained_STD_09076.pkl')

fpkl= open(pklfile, 'wb') #Python 3
pickle.dump(weigh, fpkl, protocol= pickle.HIGHEST_PROTOCOL)
fpkl.close()

# %%
#use pickle to load model weights

pklfile= os.path.join('checkpoints', 'Cassava_NonGrp_S1_LRG501_Mul_Pretrained_STD_09076.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

gpus_model_mul = multi_gpu_model(model_mul, gpus=NUM_GPU)
#use set_weights to load the modelweights into the model architecture
gpus_model_mul.set_weights(weigh)

# %%
epochs = 50##!!!

result = model_mul.fit_generator(
    generator = train_generator_three_img('train',batch_size=batch_size), 
    steps_per_epoch = step_size_train,
    validation_data = valid_generator_three_img('valid',batch_size=batch_size),
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[tb, csv_logger, checkpointer, earlystopping], 
    callbacks=[tb, csv_logger, earlystopping], 
    verbose=1)

# %%
# Visualize training history
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy

# list all data in history
# history = result.history
#print(history.history.keys())
# summarize history for accuracy
plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Mul-ResNext - 501 - Noise model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Mul-ResNext - 501 - Noise model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#change test_generator
import numpy as np

# PREDICT ON OFFICIAL TEST
test_datagen1 = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

train_set = train_datagen.flow_from_directory('train',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

test_set1 = test_datagen1.flow_from_directory('test',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

if NUM_GPU != 1:
    predict1=model_mul.predict_generator(test_generator_three_img('test',batch_size), steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
# else:
#     predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
predicted_class_indices=np.argmax(predict1,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions1 = [labels[k] for k in predicted_class_indices]

import pandas as pd

filenames=test_set1.filenames
results=pd.DataFrame({"file_name":filenames,
                      "predicted1":predictions1,
                      })
results.to_csv('Cassava_NonGrp_MulModels501_2208_v6.csv')
results.head(10)

# %%
cp Cassava_NonGrp_MulModels501_2208_v6.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels501_2208_v6.csv

# %%
epochs = 10##!!!

lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)
model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.91, verbose=1)

result = model_mul.fit_generator(
    generator = train_generator_three_img('train',batch_size=batch_size), 
    steps_per_epoch = step_size_train,
    validation_data = valid_generator_three_img('valid',batch_size=batch_size),
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[tb, csv_logger, checkpointer, earlystopping], 
    callbacks=[tb, csv_logger, earlystopping], 
    verbose=1)

# %%
#train after reload weight (val_acc: 0.9076)

epochs = 40##!!!

lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)
gpus_model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.913, verbose=1)

result = gpus_model_mul.fit_generator(
    generator = train_generator_three_img('train',batch_size=batch_size), 
    steps_per_epoch = step_size_train,
    validation_data = valid_generator_three_img('valid',batch_size=batch_size),
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[tb, csv_logger, checkpointer, earlystopping], 
    callbacks=[tb, csv_logger, earlystopping], 
    verbose=1)

# %%
#change test_generator
import numpy as np

# PREDICT ON OFFICIAL TEST
test_datagen1 = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

train_set = train_datagen.flow_from_directory('train',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

test_set1 = test_datagen1.flow_from_directory('test',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

if NUM_GPU != 1:
    predict1=gpus_model_mul.predict_generator(test_generator_three_img('test',batch_size), steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
# else:
#     predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
predicted_class_indices=np.argmax(predict1,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions1 = [labels[k] for k in predicted_class_indices]

import pandas as pd

filenames=test_set1.filenames
results=pd.DataFrame({"file_name":filenames,
                      "predicted1":predictions1,
                      })
results.to_csv('Cassava_NonGrp_MulModels501_2208_v8.csv')
results.head(10)

# %%
cp Cassava_NonGrp_MulModels501_2208_v8.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels501_2208_v8.csv

# %%
#MULTI GPUS

from keras.preprocessing.image import ImageDataGenerator
from math import ceil
import numpy as np

#Crop-Official Test
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

def crop_generator_three_models(batches, crop_length):
    """Generate random crops from the image batches"""
     
    while True:
        batch_x, _ = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield [batch_crops, batch_crops, batch_crops]

gen = ImageDataGenerator(
#     rescale = 1./255,
#         preprocessing_function=preprocess_input
)

genX1 = gen.flow_from_directory('test',
                                 target_size = (541, 541),
                                 batch_size = batch_size,
                                 class_mode = 'categorical',
                                 shuffle=False,
                                 seed=7,
                              )

#steps
step_size_test_crop = ceil(genX1.n/genX1.batch_size)

#customized generator
test_crops = crop_generator_three_models(genX1, 501)

#number of crops
tta_steps = 5
predictions = []

for i in range(tta_steps):
    print('iteration = %d / %d' %(i+1,tta_steps))
    #reset index
    genX1.reset()
    
    preds=gpus_model_mul.predict_generator(test_crops,steps = step_size_test_crop,verbose=1)  
    predictions.append(preds)

mean_pred = np.mean(predictions, axis=0)

predicted_class_indices_mean=np.argmax(mean_pred,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cassava_NonGrp_MulModels501_2208_v10.csv')
results.head(11)

# %%
cp Cassava_NonGrp_MulModels501_2208_v10.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels501_2208_v11.csv

# %%
#train after reload weight (val_acc: 0.9076)

epochs = 40##!!!

lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)
gpus_model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.919, verbose=1)

result = gpus_model_mul.fit_generator(
    generator = train_generator_three_img('train',batch_size=batch_size), 
    steps_per_epoch = step_size_train,
    validation_data = valid_generator_three_img('valid',batch_size=batch_size),
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[tb, csv_logger, checkpointer, earlystopping], 
    callbacks=[tb, csv_logger, earlystopping], 
    verbose=1)

# %%
# Visualize training history
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy

# list all data in history
# history = result.history
#print(history.history.keys())
# summarize history for accuracy
plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Mul-ResNext - 501 - Noise model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Mul-ResNext - 501 - Noise model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#change test_generator
import numpy as np

# PREDICT ON OFFICIAL TEST
test_datagen1 = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

train_set = train_datagen.flow_from_directory('train',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

test_set1 = test_datagen1.flow_from_directory('test',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

if NUM_GPU != 1:
    predict1=gpus_model_mul.predict_generator(test_generator_three_img('test',batch_size), steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
# else:
#     predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
predicted_class_indices=np.argmax(predict1,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions1 = [labels[k] for k in predicted_class_indices]

import pandas as pd

filenames=test_set1.filenames
results=pd.DataFrame({"file_name":filenames,
                      "predicted1":predictions1,
                      })
results.to_csv('Cassava_NonGrp_MulModels501_2208_v12.csv')
results.head(10)

# %%
cp Cassava_NonGrp_MulModels501_2208_v12.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels501_2208_v12.csv

# %%
#train after reload weight (val_acc: 0.9076)

epochs = 40##!!!

# lr = 1e-5
# decay = lr/epochs
lr = 1e-6
decay = 0
optimizer = Adam(lr=lr, decay=decay)
gpus_model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.925, verbose=1)

result = gpus_model_mul.fit_generator(
    generator = train_generator_three_img('train',batch_size=batch_size), 
    steps_per_epoch = step_size_train,
    validation_data = valid_generator_three_img('valid',batch_size=batch_size),
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[tb, csv_logger, checkpointer, earlystopping], 
    callbacks=[tb, csv_logger, earlystopping], 
    verbose=1)

# %%
#seresnext50
#Non-Groups
#Split training and validation

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil
import multiprocessing

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

NUM_GPU = 4
batch_size = 20

train_set = train_datagen.flow_from_directory('train',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('valid',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cassava_NonGrp_S1_SEResNext50_LRG501_Mul_Pretrained_STD_L4.hdf5')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('cassava_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('cassava_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

from keras.callbacks import Callback
class EarlyStoppingByAccVal(Callback):
    def __init__(self, monitor='val_acc', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current >= self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping" % epoch)
            self.model.stop_training = True

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.8870, verbose=1)##!!!!!!

#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    model_mul = multi_gpu_model(model_2, gpus=NUM_GPU)

# print('Loading pretrained weights')
# if NUM_GPU != 1:
#     model_mul.load_weights(savedfilename)
# # else:
# #     model.load_weights(savedfilename)

epochs = 30##!!!
lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

step_size_train=ceil(train_set.n/train_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[tb, csv_logger, checkpointer, earlystopping], 
    callbacks=[tb, csv_logger, earlystopping],
    verbose=1)

# %%
#0.8898756673450369
#0.8827708640911651
max(result.history['val_acc'])

# %%
# Visualize training history
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy

# list all data in history
# history = result.history
#print(history.history.keys())
# summarize history for accuracy
plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('SeNet50 - 501 - Noise model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('SeNet50 - 501 - Noise model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model_mul.save_weights(savedfilename)

# %%
model_mul.save_weights(savedfilename)
f2_sgl = model_mul.layers[-2]
f2_sgl.save(os.path.join('checkpoints', 'Cassava_NonGrp_S1_SEResNext50_LRG450_Mul_Pretrained_STD_L3_SGL.hdf5'))

# %%
import numpy as np

# PREDICT ON OFFICIAL TEST
test_datagen1 = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

train_set = train_datagen.flow_from_directory('train',
                                                 target_size = (450, 450),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

test_set1 = test_datagen1.flow_from_directory('test',
                                                 target_size = (450, 450),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

if NUM_GPU != 1:
    predict1=model_mul.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
# else:
#     predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
predicted_class_indices=np.argmax(predict1,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions1 = [labels[k] for k in predicted_class_indices]

import pandas as pd

filenames=test_set1.filenames
results=pd.DataFrame({"file_name":filenames,
                      "predicted1":predictions1,
                      })
results.to_csv('Cassava_NonGrp_MulModels450_2108_v1.csv')
results.head()

# %%
cp Cassava_NonGrp_MulModels450_2108_v1.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels450_2108_v1.csv

# %%
model_2.load_weights(os.path.join('checkpoints', 'Cassava_NonGrp_S1_SEResNext50_LRG450_Mul_Pretrained_STD_L3_SGL.hdf5'))

# %%
from keras.preprocessing.image import ImageDataGenerator
from math import ceil
import numpy as np

batch_size = 20

#Crop-Official Test
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

def crop_generator(batches, crop_length):
    """Generate random crops from the image batches"""
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

test_datagen_crop = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

testing_set_crop = test_datagen_crop.flow_from_directory('test',
                                                 target_size = (500, 500),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="training"
                                              )
#customized generator
test_crops = crop_generator(testing_set_crop, 450)

step_size_test_crop = ceil(testing_set_crop.n/testing_set_crop.batch_size)

tta_steps = 3
predictions = []

# import tensorflow as tf
# with tf.device('/gpu:0'):
for i in range(tta_steps):
    print(i)
    testing_set_crop.reset()
#     if NUM_GPU != 1:
#         preds=mul_model.predict_generator(test_crops, 
#                                            steps = step_size_test_crop,
#                                            max_queue_size=16,
# #                                                use_multiprocessing=True,
#                                            workers=1,
#                                            verbose=1)    
#     else:
#         preds=model.predict_generator(test_crops, 
#                                            steps = step_size_test_crop,
#                                            max_queue_size=16,
# #                                                use_multiprocessing=True,
#                                            workers=1,
#                                            verbose=1)  
    preds=model_2.predict_generator(test_crops,steps = step_size_test_crop,verbose=1)  
    predictions.append(preds)

mean_pred = np.mean(predictions, axis=0)

predicted_class_indices_mean=np.argmax(mean_pred,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cassava_NonGrp_MulModels450_2108_v3.csv')
results.head(10)

# %%
cp Cassava_NonGrp_MulModels450_2108_v3.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels450_2108_v3.csv

# %%
result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)

# %%
from classification_models.keras import Classifiers
from keras.models import Model
# from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM
# from keras.applications.inception_v3 import preprocess_input

from keras.layers import GaussianNoise

nasnet, preprocess_input = Classifiers.get('senet154')

f4_base = nasnet(input_shape=(501,501,3), weights=None, include_top=False)

f4_x = GlobalAveragePooling2D()(f4_base.output)

# # #Regularization with noise
f4_x = GaussianNoise(0.1)(f4_x)

f4_x = Dense(2048, activation='relu')(f4_x)
f4_x = Dense(5, activation='softmax')(f4_x)
model_4 = Model(inputs=[f4_base.input],outputs=[f4_x])

print(model_4.summary())
# # print(f2_base.summary())

# %%
ls -l

# %%
#use pickle to load model weights
import os
import pickle

pklfile= os.path.join('Cassava_NonGrp_S1_SENet154_LRG501_STD.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

# restoredmodel= mymodel()
#use set_weights to load the modelweights into the model architecture
model_4.set_weights(weigh)

# %%
for layer in model_4.layers[:-4]:
    layer.trainable=False
# for layer in model.layers[87:]:
#     layer.trainable=True)
for i,layer in enumerate(model_4.layers):
    print(i,layer.name,layer.trainable)

# %%
#Non-Groups
#Split training and validation
#Using Expert Data

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil
import multiprocessing

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

NUM_GPU = 4
batch_size = 80

train_set = train_datagen.flow_from_directory('train',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('valid',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cassava_NonGrp_S1_SENet154_LRG501_STD.hdf5')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('cassava_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('cassava_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

from keras.callbacks import Callback
class EarlyStoppingByAccVal(Callback):
    def __init__(self, monitor='val_acc', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current >= self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping" % epoch)
            self.model.stop_training = True

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.8850, verbose=1)

#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    model_mul = multi_gpu_model(model_4, gpus=NUM_GPU)

# print('Loading pretrained weights')
# if NUM_GPU != 1:
#     model_mul.load_weights(savedfilename)
# # else:
# #     model.load_weights(savedfilename)

epochs = 30##!!!
lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

step_size_train=ceil(train_set.n/train_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[earlystopping],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)

# %%
# !wget https://github.com/qubvel/classification_models/releases/download/0.0.1/senet154_imagenet_1000_no_top.h5

# %%
mv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_S1_NASNetLarge_LRG501_STD.pkl Cassava_NonGrp_S1_NASNetLarge_LRG501_STD.pkl

# %%
from classification_models.keras import Classifiers
from keras.models import Model
# from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM
# from keras.applications.inception_v3 import preprocess_input

from keras.layers import GaussianNoise

nasnet, preprocess_input = Classifiers.get('nasnetlarge')

f4_base = nasnet(input_shape=(501,501,3), weights=None, include_top=False)

f4_x = GlobalAveragePooling2D()(f4_base.output)

# # #Regularization with noise
f4_x = GaussianNoise(0.1)(f4_x)

f4_x = Dense(2048, activation='relu')(f4_x)
f4_x = Dense(5, activation='softmax')(f4_x)
model_4 = Model(inputs=[f4_base.input],outputs=[f4_x])

print(model_4.summary())
# # print(f2_base.summary())

# %%
#use pickle to load model weights
import os
import pickle

pklfile= os.path.join('Cassava_NonGrp_S1_NASNetLarge_LRG501_STD.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

# restoredmodel= mymodel()
#use set_weights to load the modelweights into the model architecture
model_4.set_weights(weigh)

# %%
#Non-Groups
#Split training and validation
#Using Expert Data

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil
import multiprocessing

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

NUM_GPU = 4
batch_size = 12

train_set = train_datagen.flow_from_directory('train',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('valid',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cassava_NonGrp_S1_NASNetLarge_LRG501_STD.hdf5')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('cassava_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('cassava_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

from keras.callbacks import Callback
class EarlyStoppingByAccVal(Callback):
    def __init__(self, monitor='val_acc', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current >= self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping" % epoch)
            self.model.stop_training = True

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.8850, verbose=1)

#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    model_mul = multi_gpu_model(model_4, gpus=NUM_GPU)

# print('Loading pretrained weights')
# if NUM_GPU != 1:
#     model_mul.load_weights(savedfilename)
# # else:
# #     model.load_weights(savedfilename)

epochs = 30##!!!
lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

step_size_train=ceil(train_set.n/train_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[earlystopping],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)

# %%
#MUL 2 - Inception
#501
import keras

# from keras_applications.resnext import ResNeXt101, preprocess_input
# from keras.applications.resnet50 import ResNet50
# from keras.applications import InceptionV3
# from keras.applications import Xception
# from keras.applications.inception_resnet_v2 import InceptionResNetV2
# from classification_models.senet import SEResNet101, preprocess_input
# from classification_models.keras import Classifiers


from keras.models import Model
from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM
# from keras.applications.inception_v3 import preprocess_input

from keras.layers import GaussianNoise

# ResNext101, preprocess_input = Classifiers.get('resnext101')
# NASNetLarge = preprocess_input = Classifiers.get('nasnetlarge')

# SENet154, preprocess_input = Classifiers.get('senet154')

f2_base = SEInceptionResNetV2(include_top=True,
                        weights=None,
                        input_tensor=None,
                        input_shape=(501,501,3),
                        pooling=None)

# # f2_base = Classifiers.get('nasnetlarge')[0]((501, 501, 3), weights=None)
# f2_base = SENet154((501, 501, 3), weights=None)
# # f2_base = SeNet154((501,501,3), weights = 'imagenet', include_top=False) 
# # f2_base = ResNext101((501,501,3), weights = 'imagenet') 
# # # f2_base = NASNetLarge((501,501,3), weights = 'imagenet')

# # # for layer in f3_base.layers:
# # #     layer.trainable = False 
f2_x = f2_base.layers[-2].output
# # # f2_x = GlobalAveragePooling2D()(f2_x)

# # #Regularization with noise
# f2_x = GaussianNoise(0.1)(f2_x)

f2_x = Dense(2048, activation='relu')(f2_x)
f2_x = Dense(5, activation='softmax')(f2_x)
model_2 = Model(inputs=[f2_base.input],outputs=[f2_x])

print(model_2.summary())
# print(f2_base.summary())

# %%
# !pip install pretrainedmodels

# %%
import pretrainedmodels

# %%
print(pretrainedmodels.model_names)

# %%
from classification_models.keras import Classifiers
from keras.models import Model
# from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM
# from keras.applications.inception_v3 import preprocess_input

from keras.layers import GaussianNoise

senet, preprocess_input = Classifiers.get('seresnext101')

f2_base = senet(input_shape=(501,501,3), weights='imagenet', include_top=False)
f2_x = GlobalAveragePooling2D()(f2_base.output)

# # #Regularization with noise
f2_x = GaussianNoise(0.1)(f2_x)

f2_x = Dense(2048, activation='relu')(f2_x)
f2_x = Dense(5, activation='softmax')(f2_x)
model_2 = Model(inputs=[f2_base.input],outputs=[f2_x])

print(model_2.summary())
# # print(f2_base.summary())

# %%
for layer in model_2.layers[:-3]:
    layer.trainable=False
# for layer in model.layers[87:]:
#     layer.trainable=True)
for i,layer in enumerate(model_2.layers):
    print(i,layer.name,layer.trainable)

# %%
from keras.utils import to_categorical
import numpy as np
import random
import csv
import glob
import os
import os.path

def get_data():
    """Load data from file."""
    with open(os.path.join('cassava_data_senet.csv'), 'r') as fin:
        reader = csv.reader(fin)
        data = list(reader)

    return data

def get_extracted_sequence(sample):
    """Get the extracted features."""
    filename = sample[0] + '_' + sample[1] + '_' + sample[2]
    path = os.path.join('sequences', filename + '.npy')
    #print(path)
    if os.path.isfile(path):
        return np.load(path)
    else:
        return None
    
def get_classes():
    """Extract the classes from data"""
    classes = []
    for item in data:
        if item[1] not in classes:
            classes.append(item[1])

    # Sort them.
    classes = sorted(classes)

    # Return.
    return classes

def get_class_one_hot(class_str):
    """Encode and one-hot classes for training.
    Given a class as a string, return its number in the classes list. """
    # Encode
    label_encoded = classes.index(class_str)

    # One-hot
    label_hot = to_categorical(label_encoded, len(classes))

    assert len(label_hot) == len(classes)

    return label_hot

def get_all_sequences_in_memory(train_test):
    """
    Load everything into memory
    """
    # Get the right dataset.
    train, test = split_train_test()
    data = train if train_test == 'train' else test
    
    print("Loading %d samples into memory for %sing." % (len(data), train_test))
    
    X, y = [], []
    for row in data:
        sequence = get_extracted_sequence(row)
        # modify for single sequence
        sequence = np.expand_dims(sequence, axis=0)

        if sequence is None:
            print("Can't find sequence?")
            raise

        X.append(sequence)
        y.append(get_class_one_hot(row[1]))

    return np.array(X), np.array(y)

def split_train_test():
    """Split the data into train and test sets."""
    train = []
    test = []
    for item in data:
        if item[0] == 'train':
            train.append(item)
        else:
            test.append(item)
    return train, test

# %%
from classification_models.keras import Classifiers
from keras.models import Model
# from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM
# from keras.applications.inception_v3 import preprocess_input

from keras.layers import GaussianNoise

senet, preprocess_input = Classifiers.get('seresnext101')

f3_base = senet(input_shape=(501,501,3), weights='imagenet', include_top=False)
f3_x = GlobalAveragePooling2D()(f3_base.output)

# # # #Regularization with noise
# f2_x = GaussianNoise(0.1)(f2_x)

# f2_x = Dense(2048, activation='relu')(f2_x)
# f2_x = Dense(5, activation='softmax')(f2_x)
model_3 = Model(inputs=[f3_base.input],outputs=[f3_x])

print(model_3.summary())
# # print(f2_base.summary())

# %%
from keras.preprocessing import image as imgload
# from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras.models import Model, load_model
from keras.layers import Input
import numpy as np

class Extractor_SeNet():
    def __init__(self, weights=None):

        # assign model_1 (Xception)
        self.model = model_3
            
    def extract(self, image_path):
        img = imgload.load_img(image_path, target_size=(501, 501)) #input size
        #img = imgload.load_img(image_path, target_size=(224, 224)) #densenet, mobilenet
        x = imgload.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)

        # Get the prediction.
        features = self.model.predict(x)

#         if self.weights is None:
#             # For imagenet/default network:
#             features = features[0]
#         else:
#             # For loaded network:
#             features = features[0]

        return features[0]

# %%
mv sequences sequences_bkp

# %%
rm -r sequences

# %%
mkdir sequences

# %%
# Feature Extraction
#

import numpy as np
import os.path
from tqdm import tqdm
import sys
import os

import csv
import glob
import os
import os.path

# Get model
model = Extractor_SeNet()

# Multiple GPUs
NUM_GPU = 4
model.model = multi_gpu_model(model.model, gpus=NUM_GPU)

# Load weights
# model.model.load_weights(os.path.join('checkpoints', 'Cassava_NonGrp_S1_Xception_LRG501_Mul_Pretrained_STD.hdf5'))

# Get the dataset.
data = get_data()
print(len(data))

# Get the model.
# model = Extractor_InceptionV3()

# Loop through data.
pbar = tqdm(total=len(data))
for images in data:
    feature_path = os.path.join('sequences', images[0] + '_' + images[1] + '_' + images[2])

    # Skip if the file already existed.
    if os.path.isfile(feature_path + '.npy'):
        pbar.update(1)
        continue

    image_path = os.path.join(images[0], images[1], images[2])
    feature = model.extract(image_path)

    # Save the feature.
    np.save(feature_path, feature)
    
    pbar.update(1)

pbar.close()

# %%
from keras.utils import to_categorical
import numpy as np
import random

def get_extracted_sequences_one_model(dir1, sample):
    """Get the extracted features."""
    filename = sample[0] + '_' + sample[1] + '_' + sample[2]
    path1 = os.path.join(dir1, filename + '.npy')
    #print(path)
    if os.path.isfile(path1):
        return np.load(path1)
    else:
        return None
    
def get_all_sequences_one_model_in_memory(dir1, train_test):
    """
    Load everything into memory
    """
    # Get the right dataset.
    train, test = split_train_test()
    data = train if train_test == 'train' else test
    
    print("Loading %d samples into memory for %sing." % (len(data), train_test))
    
    X, y = [], []
    for row in data:
        sequence1 = get_extracted_sequences_one_model(dir1, row)
        
        # add two sequences
#         sequence = np.concatenate(sequence1, axis=0)
        # modify for single sequence
        sequence = np.expand_dims(sequence1, axis=0)

        if sequence is None:
            print("Can't find sequence?")
            raise

        X.append(sequence)
        y.append(get_class_one_hot(row[1]))

    return np.array(X), np.array(y)

# %%
from keras.layers import Dense, Flatten, Dropout, ZeroPadding3D, LeakyReLU
from keras.layers.recurrent import LSTM
from keras.models import Sequential, load_model
from keras.optimizers import Adam, RMSprop
from keras.layers.convolutional import (Conv2D, MaxPooling3D, Conv3D,
    MaxPooling2D)

def base_line_one_model():
    """Build a simple model"""
    # Model.
    model = Sequential()
#     model.add(Dense(32, input_shape=(16,)))
    model.add(Flatten(input_shape=(1,2048)))
#     model.add(Dense(1024, activation='relu'))#inceptionv3
#     model.add(Dense(2048, activation='relu'))
    model.add(Dense(1024))
    model.add(LeakyReLU(0.2))
    model.add(Dropout(0.5))
    model.add(Dense(5, activation='softmax'))

    return model

# %%
senet_model = base_line_one_model()
senet_model.summary()

# %%
# Get the dataset.
data = get_data()
print(len(data))

# Get the classes.
classes = get_classes()
print(classes)

# %%
#3 models
#IcpResNet, Inception, Xception
#501

from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
import time, os

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cassava_NonGrp_S1_TL_SeNet501_Mul_Pretrained_STD.hdf5')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=False)

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('cassava_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('cassava_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

from keras.callbacks import Callback
class EarlyStoppingByAccVal(Callback):
    def __init__(self, monitor='val_acc', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current >= self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping" % epoch)
            self.model.stop_training = True

early_stopper = EarlyStoppingByAccVal(monitor='val_acc', value=0.99, verbose=1)


X_train, y_train = get_all_sequences_one_model_in_memory('sequences','train')
X_valid, y_valid = get_all_sequences_one_model_in_memory('sequences','valid')

from keras.optimizers import Adam

NUM_GPU = 4
batch_size = 60
nb_epoch = 500

lr = 1e-5
decay = lr/nb_epoch
optimizer = Adam(lr=lr, decay=decay)

#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    mul_model = multi_gpu_model(senet_model, gpus=NUM_GPU)

if NUM_GPU != 1:
    mul_model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

result = mul_model.fit(
            X_train,
            y_train,
            batch_size=batch_size,
            validation_data=(X_valid, y_valid),
            verbose=1,
            callbacks=[tb, csv_logger, checkpointer, early_stopper],
            epochs=nb_epoch)

# %%
# Visualize training history
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy

# list all data in history
# history = result.history
#print(history.history.keys())
# summarize history for accuracy
plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Cassava - TL - 3M Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Cassava - TL - 3M Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
