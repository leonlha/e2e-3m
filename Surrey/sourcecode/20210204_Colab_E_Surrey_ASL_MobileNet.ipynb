# %%
ls -l| tail -10
# Out:
# total 2193908
# drwxr-xr-x 2 172318 13010       4096 Feb  7 11:53 dataset5/
# -rw------- 1 root   root  2246539027 Feb  7 11:40 fingerspelling5.tar.bz2
# drwx------ 5 root   root        4096 Feb  7 11:39 gdrive/
# drwxr-xr-x 1 root   root        4096 Feb  4 15:26 sample_data/
# drwxr-xr-x 3 root   root        4096 Feb  7 11:53 surrey/

# %%
#G4
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cp gdrive/My\ Drive/fingerspelling5.tar.bz2 fingerspelling5.tar.bz2

# %%
# rm fingerspelling5.tar.bz2

# %%
# cd /media/datastorage/Phong/
# Out:
# /media/datastorage/Phong

# %%
# !tar xjf fingerspelling5.tar.bz2

# %%
cd dataset5
# Out:
# /content/dataset5

# %%
mkdir surrey

# %%
mkdir surrey/E

# %%
mv dataset5/* surrey/E/

# %%
cd ..
# Out:
# /content

# %%
#remove depth files
import glob
import os
import shutil

# get parts of image's path
def get_image_parts(image_path):
    """Given a full path to an image, return its parts."""
    parts = image_path.split(os.path.sep)
    #print(parts)
    filename = parts[2]
    filename_no_ext = filename.split('.')[0]
    classname = parts[1]
    train_or_test = parts[0]

    return train_or_test, classname, filename_no_ext, filename


#del_folders = ['A','B','C','D','E']  
move_folders_1 = ['A','B','C','D']  
move_folders_2 = ['E']

# look for all images in sub-folders
for folder in move_folders_1:
    class_folders = glob.glob(os.path.join(folder, '*'))
        
    for iid_class in class_folders:
        #move depth files
        class_files = glob.glob(os.path.join(iid_class, 'depth*.png'))
        
        print('copying %d files' %(len(class_files)))
        for idx in range(len(class_files)):        
            src = class_files[idx]
            if "0001" not in src: 
                train_or_test, classname, _, filename = get_image_parts(src)

                dst = os.path.join('train_depth', classname, train_or_test+'_'+ filename)

                # image directory
                img_directory = os.path.join('train_depth', classname)

                # create folder if not existed
                if not os.path.exists(img_directory):
                    os.makedirs(img_directory)

                #copying
                shutil.copy(src, dst)
            else:
                print('ignor: %s' %src)
            
        #move color files    
    for iid_class in class_folders:
        #move depth files
        class_files = glob.glob(os.path.join(iid_class, 'color*.png'))
        
        print('copying %d files' %(len(class_files)))
        for idx in range(len(class_files)):        
            src = class_files[idx]
            train_or_test, classname, _, filename = get_image_parts(src)

            dst = os.path.join('train_color', classname, train_or_test+'_'+ filename)
            
            # image directory
            img_directory = os.path.join('train_color', classname)

            # create folder if not existed
            if not os.path.exists(img_directory):
                os.makedirs(img_directory)
            
            #copying
            shutil.copy(src, dst)
            
# look for all images in sub-folders
for folder in move_folders_2:
    class_folders = glob.glob(os.path.join(folder, '*'))
        
    for iid_class in class_folders:
        #move depth files
        class_files = glob.glob(os.path.join(iid_class, 'depth*.png'))
        
        print('copying %d files' %(len(class_files)))
        for idx in range(len(class_files)):        
            src = class_files[idx]
            if "0001" not in src: 
                train_or_test, classname, _, filename = get_image_parts(src)

                dst = os.path.join('test_depth', classname, train_or_test+'_'+ filename)

                # image directory
                img_directory = os.path.join('test_depth', classname)

                # create folder if not existed
                if not os.path.exists(img_directory):
                    os.makedirs(img_directory)

                #copying
                shutil.copy(src, dst)
            else:
                print('ignor: %s' %src)
            
        #move color files    
    for iid_class in class_folders:
        #move depth files
        class_files = glob.glob(os.path.join(iid_class, 'color*.png'))
        
        print('copying %d files' %(len(class_files)))
        for idx in range(len(class_files)):        
            src = class_files[idx]
            train_or_test, classname, _, filename = get_image_parts(src)

            dst = os.path.join('test_color', classname, train_or_test+'_'+ filename)
            
            # image directory
            img_directory = os.path.join('test_color', classname)

            # create folder if not existed
            if not os.path.exists(img_directory):
                os.makedirs(img_directory)
            
            #copying
            shutil.copy(src, dst)
# Out:
# copying 522 files
# ignor: A/x/depth_23_0001.png
# copying 516 files
# ignor: A/q/depth_16_0001.png
# copying 507 files
# ignor: A/v/depth_21_0001.png
# copying 471 files
# copying 512 files
# ignor: A/o/depth_14_0001.png
# copying 533 files
# ignor: A/y/depth_24_0001.png
# copying 528 files
# ignor: A/g/depth_6_0001.png
# copying 516 files
# ignor: A/l/depth_11_0001.png
# copying 524 files
# ignor: A/t/depth_19_0001.png
# copying 528 files
# ignor: A/a/depth_0_0001.png
# copying 523 files
# ignor: A/h/depth_7_0001.png
# copying 536 files
# ignor: A/d/depth_3_0001.png
# copying 516 files
# ignor: A/b/depth_1_0001.png
# copying 557 files
# ignor: A/c/depth_2_0001.png
# copying 527 files
# ignor: A/m/depth_12_0001.png
# copying 528 files
# ignor: A/r/depth_17_0001.png
# copying 530 files
# ignor: A/n/depth_13_0001.png
# copying 525 files
# ignor: A/w/depth_22_0001.png
# copying 524 files
# ignor: A/u/depth_20_0001.png
# copying 572 files
# ignor: A/p/depth_15_0001.png
# copying 518 files
# ignor: A/k/depth_10_0001.png
# copying 515 files
# ignor: A/i/depth_8_0001.png
# copying 524 files
# ignor: A/e/depth_4_0001.png
# copying 519 files
# ignor: A/f/depth_5_0001.png
# copying 521 files
# copying 515 files
# copying 506 files
# copying 470 files
# copying 511 files
# copying 532 files
# copying 527 files
# copying 515 files
# copying 523 files
# copying 527 files
# copying 522 files
# copying 535 files
# copying 515 files
# copying 556 files
# copying 526 files
# copying 527 files
# copying 529 files
# copying 524 files
# copying 523 files
# copying 571 files
# copying 517 files
# copying 514 files
# copying 523 files
# copying 518 files
# copying 622 files
# ignor: B/x/depth_23_0001.png
# copying 540 files
# ignor: B/q/depth_16_0001.png
# copying 628 files
# ignor: B/v/depth_21_0001.png
# copying 749 files
# ignor: B/s/depth_18_0001.png
# copying 529 files
# ignor: B/o/depth_14_0001.png
# copying 537 files
# ignor: B/y/depth_24_0001.png
# copying 544 files
# ignor: B/g/depth_6_0001.png
# copying 577 files
# ignor: B/l/depth_11_0001.png
# copying 514 files
# ignor: B/t/depth_19_0001.png
# copying 536 files
# ignor: B/a/depth_0_0001.png
# copying 545 files
# ignor: B/h/depth_7_0001.png
# copying 552 files
# ignor: B/d/depth_3_0001.png
# copying 577 files
# ignor: B/b/depth_1_0001.png
# copying 549 files
# ignor: B/c/depth_2_0001.png
# copying 582 files
# ignor: B/m/depth_12_0001.png
# copying 550 files
# ignor: B/r/depth_17_0001.png
# copying 544 files
# ignor: B/n/depth_13_0001.png
# copying 648 files
# ignor: B/w/depth_22_0001.png
# copying 542 files
# ignor: B/u/depth_20_0001.png
# copying 642 files
# ignor: B/p/depth_15_0001.png
# copying 777 files
# ignor: B/k/depth_10_0001.png
# copying 543 files
# ignor: B/i/depth_8_0001.png
# copying 565 files
# ignor: B/e/depth_4_0001.png
# copying 530 files
# ignor: B/f/depth_5_0001.png
# copying 621 files
# copying 539 files
# copying 627 files
# copying 748 files
# copying 528 files
# copying 536 files
# copying 543 files
# copying 576 files
# copying 513 files
# copying 535 files
# copying 544 files
# copying 551 files
# copying 576 files
# copying 548 files
# copying 581 files
# copying 549 files
# copying 543 files
# copying 647 files
# copying 541 files
# copying 641 files
# copying 776 files
# copying 542 files
# copying 564 files
# copying 529 files
# copying 531 files
# ignor: C/x/depth_23_0001.png
# copying 541 files
# ignor: C/q/depth_16_0001.png
# copying 536 files
# ignor: C/v/depth_21_0001.png
# copying 507 files
# ignor: C/s/depth_18_0001.png
# copying 548 files
# ignor: C/o/depth_14_0001.png
# copying 543 files
# ignor: C/y/depth_24_0001.png
# copying 532 files
# ignor: C/g/depth_6_0001.png
# copying 586 files
# ignor: C/l/depth_11_0001.png
# copying 529 files
# ignor: C/t/depth_19_0001.png
# copying 524 files
# ignor: C/a/depth_0_0001.png
# copying 536 files
# ignor: C/h/depth_7_0001.png
# copying 526 files
# ignor: C/d/depth_3_0001.png
# copying 533 files
# ignor: C/b/depth_1_0001.png
# copying 743 files
# ignor: C/c/depth_2_0001.png
# copying 538 files
# ignor: C/m/depth_12_0001.png
# copying 530 files
# ignor: C/r/depth_17_0001.png
# copying 564 files
# ignor: C/n/depth_13_0001.png
# copying 890 files
# ignor: C/w/depth_22_0001.png
# copying 530 files
# ignor: C/u/depth_20_0001.png
# copying 534 files
# ignor: C/p/depth_15_0001.png
# copying 539 files
# ignor: C/k/depth_10_0001.png
# copying 530 files
# ignor: C/i/depth_8_0001.png
# copying 529 files
# ignor: C/e/depth_4_0001.png
# copying 518 files
# ignor: C/f/depth_5_0001.png
# copying 530 files
# copying 540 files
# copying 535 files
# copying 506 files
# copying 547 files
# copying 542 files
# copying 531 files
# copying 585 files
# copying 528 files
# copying 523 files
# copying 535 files
# copying 525 files
# copying 532 files
# copying 742 files
# copying 537 files
# copying 529 files
# copying 563 files
# copying 889 files
# copying 529 files
# copying 533 files
# copying 538 files
# copying 529 files
# copying 528 files
# copying 517 files
# copying 538 files
# ignor: D/x/depth_23_0001.png
# copying 550 files
# ignor: D/q/depth_16_0001.png
# copying 544 files
# ignor: D/v/depth_21_0001.png
# copying 535 files
# ignor: D/s/depth_18_0001.png
# copying 539 files
# ignor: D/o/depth_14_0001.png
# copying 536 files
# ignor: D/y/depth_24_0001.png
# copying 542 files
# ignor: D/g/depth_6_0001.png
# copying 565 files
# ignor: D/l/depth_11_0001.png
# copying 530 files
# ignor: D/t/depth_19_0001.png
# copying 547 files
# ignor: D/a/depth_0_0001.png
# copying 562 files
# ignor: D/h/depth_7_0001.png
# copying 526 files
# ignor: D/d/depth_3_0001.png
# copying 572 files
# ignor: D/b/depth_1_0001.png
# copying 531 files
# ignor: D/c/depth_2_0001.png
# copying 542 files
# ignor: D/m/depth_12_0001.png
# copying 774 files
# ignor: D/r/depth_17_0001.png
# copying 530 files
# ignor: D/n/depth_13_0001.png
# copying 536 files
# ignor: D/w/depth_22_0001.png
# copying 532 files
# ignor: D/u/depth_20_0001.png
# copying 532 files
# ignor: D/p/depth_15_0001.png
# copying 540 files
# ignor: D/k/depth_10_0001.png
# copying 522 files
# ignor: D/i/depth_8_0001.png
# copying 528 files
# ignor: D/e/depth_4_0001.png
# copying 525 files
# ignor: D/f/depth_5_0001.png
# copying 537 files
# copying 549 files
# copying 543 files
# copying 534 files
# copying 538 files
# copying 535 files
# copying 541 files
# copying 564 files
# copying 529 files
# copying 546 files
# copying 561 files
# copying 525 files
# copying 571 files
# copying 530 files
# copying 541 files
# copying 773 files
# copying 529 files
# copying 535 files
# copying 531 files
# copying 531 files
# copying 539 files
# copying 521 files
# copying 527 files
# copying 524 files
# copying 523 files
# ignor: E/x/depth_23_0001.png
# copying 530 files
# ignor: E/q/depth_16_0001.png
# copying 528 files
# ignor: E/v/depth_21_0001.png
# copying 527 files
# ignor: E/s/depth_18_0001.png
# copying 533 files
# ignor: E/o/depth_14_0001.png
# copying 522 files
# ignor: E/y/depth_24_0001.png
# copying 538 files
# ignor: E/g/depth_6_0001.png
# copying 515 files
# ignor: E/l/depth_11_0001.png
# copying 532 files
# ignor: E/t/depth_19_0001.png
# copying 546 files
# ignor: E/a/depth_0_0001.png
# copying 535 files
# ignor: E/h/depth_7_0001.png
# copying 545 files
# ignor: E/d/depth_3_0001.png
# copying 535 files
# ignor: E/b/depth_1_0001.png
# copying 541 files
# ignor: E/c/depth_2_0001.png
# copying 526 files
# ignor: E/m/depth_12_0001.png
# copying 563 files
# ignor: E/r/depth_17_0001.png
# copying 531 files
# ignor: E/n/depth_13_0001.png
# copying 514 files
# ignor: E/w/depth_22_0001.png
# copying 530 files
# ignor: E/u/depth_20_0001.png
# copying 528 files
# ignor: E/p/depth_15_0001.png
# copying 570 files
# ignor: E/k/depth_10_0001.png
# copying 526 files
# ignor: E/i/depth_8_0001.png
# copying 540 files
# ignor: E/e/depth_4_0001.png
# copying 528 files
# ignor: E/f/depth_5_0001.png
# copying 522 files
# copying 529 files
# copying 527 files
# copying 526 files
# copying 532 files
# copying 521 files
# copying 537 files
# copying 514 files
# copying 531 files
# copying 545 files
# copying 534 files
# copying 544 files
# copying 534 files
# copying 540 files
# copying 525 files
# copying 562 files
# copying 530 files
# copying 513 files
# copying 529 files
# copying 527 files
# copying 569 files
# copying 525 files
# copying 539 files
# copying 527 files

# %%
# #/content
# %cd ..
# Out:
# /media/datastorage/Phong

# %%
ls -l

# %%
mkdir surrey/E/checkpoints

# %%
cd surrey/

# %%
#MUL 1 - Inception - ST

from keras.applications import MobileNet
# from keras.applications import InceptionV3
# from keras.applications import Xception
# from keras.applications.inception_resnet_v2 import InceptionResNetV2
from tensorflow.keras.applications import EfficientNetB0

from keras.models import Model
from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, SimpleRNN, LSTM, Flatten, GRU, Reshape

# from keras.applications.inception_v3 import preprocess_input
# from tensorflow.keras.applications.efficientnet import preprocess_input
from keras.applications.mobilenet import preprocess_input

from keras.layers import GaussianNoise

def get_adv_model():
#     f1_base = EfficientNetB0(include_top=False, weights='imagenet', 
#                     input_shape=(299, 299, 3), 
#                     pooling='avg')
#     f1_x = f1_base.output


    f1_base = MobileNet(weights='imagenet', include_top=False, input_shape=(224,224,3))  
    f1_x = f1_base.output
    f1_x = GlobalAveragePooling2D()(f1_x)    

# f1_x = f1_base.layers[-151].output   #layer 5

# f1_x = GlobalAveragePooling2D()(f1_x)
# f1_x = Flatten()(f1_x)

# f1_x = Reshape([1,1280])(f1_x)  
# f1_x = SimpleRNN(2048, 
#             return_sequences=False,                       
# #             dropout=0.8                                     
#             input_shape=[1,1280])(f1_x)
   
    #Regularization with noise
    f1_x = GaussianNoise(0.1)(f1_x)

    f1_x = Dense(1024, activation='relu')(f1_x)
    f1_x = Dense(24, activation='softmax')(f1_x)
    model_1 = Model(inputs=[f1_base.input],outputs=[f1_x])
    model_1.summary()
    
    return model_1

# %%
from keras.callbacks import Callback
import pickle
import sys

#Stop training on val_acc
class EarlyStoppingByAccVal(Callback):
    def __init__(self, monitor='val_acc', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current >= self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping" % epoch)
            self.model.stop_training = True

#Save large model using pickle formate instead of h5            
class SaveCheckPoint(Callback):
    def __init__(self, model, dest_folder):
        super(Callback, self).__init__()
        self.model = model
        self.dest_folder = dest_folder
        
        #initiate
        self.best_val_acc = 0
        self.best_val_loss = sys.maxsize #get max value
          
    def on_epoch_end(self, epoch, logs={}):
        val_acc = logs['val_acc']
        val_loss = logs['val_loss']

        if val_acc > self.best_val_acc:
            self.best_val_acc = val_acc
            
            # Save weights in pickle format instead of h5
            print('\nSaving val_acc %f at %s' %(self.best_val_acc, self.dest_folder))
            weigh= self.model.get_weights()

            #now, use pickle to save your model weights, instead of .h5
            #for heavy model architectures, .h5 file is unsupported.
            fpkl= open(self.dest_folder, 'wb') #Python 3
            pickle.dump(weigh, fpkl, protocol= pickle.HIGHEST_PROTOCOL)
            fpkl.close()
            
#             model.save('tmp.h5')
        elif val_acc == self.best_val_acc:
            if val_loss < self.best_val_loss:
                self.best_val_loss=val_loss
                
                # Save weights in pickle format instead of h5
                print('\nSaving val_acc %f at %s' %(self.best_val_acc, self.dest_folder))
                weigh= self.model.get_weights()

                #now, use pickle to save your model weights, instead of .h5
                #for heavy model architectures, .h5 file is unsupported.
                fpkl= open(self.dest_folder, 'wb') #Python 3
                pickle.dump(weigh, fpkl, protocol= pickle.HIGHEST_PROTOCOL)
                fpkl.close()

# %%
# Training
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam

import time, os
from math import ceil

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
#     horizontal_flip=True,
#     vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    # preprocessing_function=get_cutout_v2(),
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

NUM_GPU = 1
batch_size = 64

train_set = train_datagen.flow_from_directory('surrey/E/train_color/',
                                                 target_size = (224, 224),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('surrey/E/test_color/',
                                                 target_size = (224, 224),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'st'
# Helper: Save the model.
savedfilename = os.path.join('surrey', 'E', 'checkpoints', 'Surrey_MobileNet_E_tmp.hdf5')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_accuracy', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('svhn_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('svhn_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

earlystopping = EarlyStoppingByAccVal(monitor='val_accuracy', value=0.9900, verbose=1)

epochs = 40##!!!
lr = 1e-3
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

# train on multiple-gpus

# Create a MirroredStrategy.
strategy = tf.distribute.MirroredStrategy()
print("Number of GPUs: {}".format(strategy.num_replicas_in_sync))

# Open a strategy scope.
with strategy.scope():
    # Everything that creates variables should be under the strategy scope.
    # In general this is only model construction & `compile()`.
    model_mul = get_adv_model()
    model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

step_size_train=ceil(train_set.n/train_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

# result = model_mul.fit_generator(
#     generator = train_set, 
#     steps_per_epoch = step_size_train,
#     validation_data = valid_set,
#     validation_steps = step_size_valid,
#     shuffle=True,
#     epochs=epochs,
#     callbacks=[checkpointer],
# #     callbacks=[csv_logger, checkpointer, earlystopping],
# #     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
#     verbose=1)
# Out:
# Found 52992 images belonging to 24 classes.
# Found 12782 images belonging to 24 classes.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# Number of GPUs: 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 112, 112, 64)      2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 112, 112, 64)      256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 112, 112, 64)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 113, 113, 64)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 56, 56, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 56, 56, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 56, 56, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 57, 57, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 28, 28, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 28, 28, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 28, 28, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 29, 29, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)       2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 14, 14, 256)       1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 14, 14, 512)       131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 7, 7, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 7, 7, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 7, 7, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 7, 7, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 7, 7, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# gaussian_noise (GaussianNois (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1049600
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                24600
# =================================================================
# Total params: 4,303,064
# Trainable params: 4,281,176
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
# Training
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam

import time, os
from math import ceil

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
#     horizontal_flip=True,
#     vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    # preprocessing_function=get_cutout_v2(),
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

NUM_GPU = 1
batch_size = 64

train_set = train_datagen.flow_from_directory('surrey/E/train_color/',
                                                 target_size = (224, 224),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('surrey/E/test_color/',
                                                 target_size = (224, 224),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'st'
# Helper: Save the model.
savedfilename = os.path.join('gdrive', 'My Drive', 'Surrey_ASL', '4_Surrey_MobileNet_E.hdf5')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_accuracy', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('svhn_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('svhn_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

earlystopping = EarlyStoppingByAccVal(monitor='val_accuracy', value=0.9900, verbose=1)

epochs = 40##!!!
lr = 1e-3
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

# train on multiple-gpus

# Create a MirroredStrategy.
strategy = tf.distribute.MirroredStrategy()
print("Number of GPUs: {}".format(strategy.num_replicas_in_sync))

# Open a strategy scope.
with strategy.scope():
    # Everything that creates variables should be under the strategy scope.
    # In general this is only model construction & `compile()`.
    model_mul = get_adv_model()
    model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

step_size_train=ceil(train_set.n/train_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[checkpointer],
#     callbacks=[csv_logger, checkpointer, earlystopping],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# Found 52992 images belonging to 24 classes.
# Found 12782 images belonging to 24 classes.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# Number of GPUs: 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 112, 112, 64)      2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 112, 112, 64)      256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 112, 112, 64)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 113, 113, 64)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 56, 56, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 56, 56, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 56, 56, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 57, 57, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 28, 28, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 28, 28, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 28, 28, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 29, 29, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)       2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 14, 14, 256)       1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 14, 14, 512)       131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 7, 7, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 7, 7, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 7, 7, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 7, 7, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 7, 7, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# gaussian_noise (GaussianNois (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1049600
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                24600
# =================================================================
# Total params: 4,303,064
# Trainable params: 4,281,176
# Non-trainable params: 21,888
# _________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/40
# 828/828 [==============================] - 722s 858ms/step - loss: 0.6629 - accuracy: 0.8071 - val_loss: 0.7461 - val_accuracy: 0.8534
#
# Epoch 00001: val_accuracy improved from -inf to 0.85339, saving model to gdrive/My Drive/Surrey_ASL/4_Surrey_MobileNet_E.hdf5
# Epoch 2/40
# 828/828 [==============================] - 709s 856ms/step - loss: 0.1014 - accuracy: 0.9685 - val_loss: 0.6600 - val_accuracy: 0.8510
#
# Epoch 00002: val_accuracy did not improve from 0.85339
# Epoch 3/40
# 828/828 [==============================] - 709s 856ms/step - loss: 0.0796 - accuracy: 0.9747 - val_loss: 0.5429 - val_accuracy: 0.9088
#
# Epoch 00003: val_accuracy improved from 0.85339 to 0.90878, saving model to gdrive/My Drive/Surrey_ASL/4_Surrey_MobileNet_E.hdf5
# Epoch 4/40
# 828/828 [==============================] - 708s 855ms/step - loss: 0.0625 - accuracy: 0.9802 - val_loss: 0.5779 - val_accuracy: 0.8980
#
# Epoch 00004: val_accuracy did not improve from 0.90878
# Epoch 5/40
# 828/828 [==============================] - 708s 855ms/step - loss: 0.0501 - accuracy: 0.9850 - val_loss: 0.7018 - val_accuracy: 0.8762
#
# Epoch 00005: val_accuracy did not improve from 0.90878
# Epoch 6/40
# 828/828 [==============================] - 709s 856ms/step - loss: 0.0515 - accuracy: 0.9851 - val_loss: 0.4153 - val_accuracy: 0.8996
#
# Epoch 00006: val_accuracy did not improve from 0.90878
# Epoch 7/40
# 828/828 [==============================] - 706s 853ms/step - loss: 0.0514 - accuracy: 0.9844 - val_loss: 0.9650 - val_accuracy: 0.8453
#
# Epoch 00007: val_accuracy did not improve from 0.90878
# Epoch 8/40
# 828/828 [==============================] - 708s 855ms/step - loss: 0.0422 - accuracy: 0.9875 - val_loss: 0.6608 - val_accuracy: 0.8839
#
# Epoch 00008: val_accuracy did not improve from 0.90878
# Epoch 9/40
# 828/828 [==============================] - 706s 853ms/step - loss: 0.0383 - accuracy: 0.9887 - val_loss: 0.6473 - val_accuracy: 0.8901
#
# Epoch 00009: val_accuracy did not improve from 0.90878
# Epoch 10/40
# 828/828 [==============================] - 707s 854ms/step - loss: 0.0361 - accuracy: 0.9893 - val_loss: 0.6875 - val_accuracy: 0.8843
#
# Epoch 00010: val_accuracy did not improve from 0.90878
# Epoch 11/40
# 828/828 [==============================] - 706s 852ms/step - loss: 0.0352 - accuracy: 0.9891 - val_loss: 1.1725 - val_accuracy: 0.8420
#
# Epoch 00011: val_accuracy did not improve from 0.90878
# Epoch 12/40
# 828/828 [==============================] - 706s 852ms/step - loss: 0.0251 - accuracy: 0.9929 - val_loss: 0.4616 - val_accuracy: 0.9197
#
# Epoch 00012: val_accuracy improved from 0.90878 to 0.91973, saving model to gdrive/My Drive/Surrey_ASL/4_Surrey_MobileNet_E.hdf5
# Epoch 13/40
# 828/828 [==============================] - 707s 854ms/step - loss: 0.0281 - accuracy: 0.9919 - val_loss: 0.9278 - val_accuracy: 0.8970
#
# Epoch 00013: val_accuracy did not improve from 0.91973
# Epoch 14/40
# 828/828 [==============================] - 707s 853ms/step - loss: 0.0264 - accuracy: 0.9924 - val_loss: 0.8065 - val_accuracy: 0.9003
#
# Epoch 00014: val_accuracy did not improve from 0.91973
# Epoch 15/40
# 828/828 [==============================] - 706s 852ms/step - loss: 0.0258 - accuracy: 0.9923 - val_loss: 0.5005 - val_accuracy: 0.9182
#
# Epoch 00015: val_accuracy did not improve from 0.91973
# Epoch 16/40
# 828/828 [==============================] - 709s 856ms/step - loss: 0.0280 - accuracy: 0.9920 - val_loss: 0.6505 - val_accuracy: 0.9039
#
# Epoch 00016: val_accuracy did not improve from 0.91973
# Epoch 17/40
# 828/828 [==============================] - 708s 855ms/step - loss: 0.0246 - accuracy: 0.9924 - val_loss: 0.6671 - val_accuracy: 0.9116
#
# Epoch 00017: val_accuracy did not improve from 0.91973
# Epoch 18/40
# 828/828 [==============================] - 708s 855ms/step - loss: 0.0208 - accuracy: 0.9937 - val_loss: 0.6285 - val_accuracy: 0.9074
#
# Epoch 00018: val_accuracy did not improve from 0.91973
# Epoch 19/40
# 828/828 [==============================] - 708s 855ms/step - loss: 0.0182 - accuracy: 0.9943 - val_loss: 0.5768 - val_accuracy: 0.9121
#
# Epoch 00019: val_accuracy did not improve from 0.91973
# Epoch 20/40
# 828/828 [==============================] - 707s 854ms/step - loss: 0.0216 - accuracy: 0.9932 - val_loss: 0.9838 - val_accuracy: 0.8996
#
# Epoch 00020: val_accuracy did not improve from 0.91973
# Epoch 21/40
# 828/828 [==============================] - 708s 855ms/step - loss: 0.0198 - accuracy: 0.9946 - val_loss: 0.5098 - val_accuracy: 0.9134
#
# Epoch 00021: val_accuracy did not improve from 0.91973
# Epoch 22/40
# 828/828 [==============================] - 708s 855ms/step - loss: 0.0176 - accuracy: 0.9955 - val_loss: 0.6549 - val_accuracy: 0.9073
#
# Epoch 00022: val_accuracy did not improve from 0.91973
# Epoch 23/40
# 828/828 [==============================] - 708s 855ms/step - loss: 0.0132 - accuracy: 0.9959 - val_loss: 0.6774 - val_accuracy: 0.8956
#
# Epoch 00023: val_accuracy did not improve from 0.91973
# Epoch 24/40
# 828/828 [==============================] - 707s 854ms/step - loss: 0.0199 - accuracy: 0.9946 - val_loss: 0.6424 - val_accuracy: 0.9119
#
# Epoch 00024: val_accuracy did not improve from 0.91973
# Epoch 25/40
# 828/828 [==============================] - 709s 856ms/step - loss: 0.0128 - accuracy: 0.9962 - val_loss: 0.5263 - val_accuracy: 0.9136
#
# Epoch 00025: val_accuracy did not improve from 0.91973
# Epoch 26/40
# 828/828 [==============================] - 710s 857ms/step - loss: 0.0131 - accuracy: 0.9956 - val_loss: 0.4730 - val_accuracy: 0.9113
#
# Epoch 00026: val_accuracy did not improve from 0.91973
# Epoch 27/40
# 828/828 [==============================] - 712s 860ms/step - loss: 0.0147 - accuracy: 0.9956 - val_loss: 0.2721 - val_accuracy: 0.9423
#
# Epoch 00027: val_accuracy improved from 0.91973 to 0.94234, saving model to gdrive/My Drive/Surrey_ASL/4_Surrey_MobileNet_E.hdf5
# Epoch 28/40
# 828/828 [==============================] - 712s 859ms/step - loss: 0.0131 - accuracy: 0.9961 - val_loss: 0.4549 - val_accuracy: 0.9144
#
# Epoch 00028: val_accuracy did not improve from 0.94234
# Epoch 29/40
# 828/828 [==============================] - 711s 859ms/step - loss: 0.0132 - accuracy: 0.9959 - val_loss: 0.7806 - val_accuracy: 0.9020
#
# Epoch 00029: val_accuracy did not improve from 0.94234
# Epoch 30/40
# 828/828 [==============================] - 710s 857ms/step - loss: 0.0113 - accuracy: 0.9964 - val_loss: 0.6845 - val_accuracy: 0.8998
#
# Epoch 00030: val_accuracy did not improve from 0.94234
# Epoch 31/40
# 828/828 [==============================] - 710s 857ms/step - loss: 0.0116 - accuracy: 0.9964 - val_loss: 0.3983 - val_accuracy: 0.9269
#
# Epoch 00031: val_accuracy did not improve from 0.94234
# Epoch 32/40
# 828/828 [==============================] - 709s 857ms/step - loss: 0.0115 - accuracy: 0.9966 - val_loss: 0.3015 - val_accuracy: 0.9396
#
# Epoch 00032: val_accuracy did not improve from 0.94234
# Epoch 33/40
# 828/828 [==============================] - 706s 852ms/step - loss: 0.0141 - accuracy: 0.9956 - val_loss: 0.8769 - val_accuracy: 0.9106
#
# Epoch 00033: val_accuracy did not improve from 0.94234
# Epoch 34/40
# 828/828 [==============================] - 716s 864ms/step - loss: 0.0121 - accuracy: 0.9962 - val_loss: 1.0653 - val_accuracy: 0.8896
#
# Epoch 00034: val_accuracy did not improve from 0.94234
# Epoch 35/40
# 828/828 [==============================] - 720s 870ms/step - loss: 0.0121 - accuracy: 0.9967 - val_loss: 0.9238 - val_accuracy: 0.9096
#
# Epoch 00035: val_accuracy did not improve from 0.94234
# Epoch 36/40
# 828/828 [==============================] - 719s 869ms/step - loss: 0.0097 - accuracy: 0.9970 - val_loss: 0.5321 - val_accuracy: 0.9176
#
# Epoch 00036: val_accuracy did not improve from 0.94234
# Epoch 37/40
# 828/828 [==============================] - 711s 858ms/step - loss: 0.0100 - accuracy: 0.9970 - val_loss: 0.6250 - val_accuracy: 0.9020
#
# Epoch 00037: val_accuracy did not improve from 0.94234
# Epoch 38/40
# 828/828 [==============================] - 700s 846ms/step - loss: 0.0102 - accuracy: 0.9967 - val_loss: 0.5469 - val_accuracy: 0.9114
#
# Epoch 00038: val_accuracy did not improve from 0.94234
# Epoch 39/40
# 828/828 [==============================] - 700s 845ms/step - loss: 0.0120 - accuracy: 0.9963 - val_loss: 0.8544 - val_accuracy: 0.8905
#
# Epoch 00039: val_accuracy did not improve from 0.94234
# Epoch 40/40
# 828/828 [==============================] - 704s 850ms/step - loss: 0.0103 - accuracy: 0.9969 - val_loss: 0.7886 - val_accuracy: 0.9020
#
# Epoch 00040: val_accuracy did not improve from 0.94234

# %%
print(savedfilename)
# Out:
# ('gdrive/My Drive/Surrey_ASL/5_Surrey_MobileNet_E.hdf5',)

# %%
ls -l
# Out:
# total 2193908
# drwxr-xr-x 2 172318 13010       4096 Feb  6 23:40 dataset5/
# -rw------- 1 root   root  2246539027 Feb  6 23:30 fingerspelling5.tar.bz2
# drwx------ 5 root   root        4096 Feb  6 23:26 gdrive/
# drwxr-xr-x 1 root   root        4096 Feb  4 15:26 sample_data/
# drwxr-xr-x 3 root   root        4096 Feb  6 23:38 surrey/

# %%
# Open a strategy scope.
with strategy.scope():
    model_mul.load_weights(os.path.join('gdrive', 'My Drive', 'Surrey_ASL', '4_Surrey_MobileNet_E.hdf5'))

# %%
# Helper: Save the model.
savedfilename = os.path.join('gdrive', 'My Drive', 'Surrey_ASL', '4_Surrey_MobileNet_E_L2.hdf5')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_accuracy', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

epochs = 15##!!!
lr = 1e-4
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

# Open a strategy scope.
with strategy.scope():
    model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[checkpointer],
#     callbacks=[csv_logger, checkpointer, earlystopping],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/15
# 828/828 [==============================] - 732s 865ms/step - loss: 0.0103 - accuracy: 0.9968 - val_loss: 0.3256 - val_accuracy: 0.9437
#
# Epoch 00001: val_accuracy improved from -inf to 0.94367, saving model to gdrive/My Drive/Surrey_ASL/4_Surrey_MobileNet_E_L2.hdf5
# Epoch 2/15
# 828/828 [==============================] - 709s 856ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.4053 - val_accuracy: 0.9406
#
# Epoch 00002: val_accuracy did not improve from 0.94367
# Epoch 3/15
# 828/828 [==============================] - 705s 852ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.4023 - val_accuracy: 0.9384
#
# Epoch 00003: val_accuracy did not improve from 0.94367
# Epoch 4/15
# 828/828 [==============================] - 706s 853ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.3570 - val_accuracy: 0.9458
#
# Epoch 00004: val_accuracy improved from 0.94367 to 0.94578, saving model to gdrive/My Drive/Surrey_ASL/4_Surrey_MobileNet_E_L2.hdf5
# Epoch 5/15
# 828/828 [==============================] - 705s 851ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.4062 - val_accuracy: 0.9409
#
# Epoch 00005: val_accuracy did not improve from 0.94578
# Epoch 6/15
# 828/828 [==============================] - 704s 850ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.3931 - val_accuracy: 0.9363
#
# Epoch 00006: val_accuracy did not improve from 0.94578
# Epoch 7/15
# 828/828 [==============================] - 706s 853ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.3904 - val_accuracy: 0.9416
#
# Epoch 00007: val_accuracy did not improve from 0.94578
# Epoch 8/15
# 828/828 [==============================] - 713s 861ms/step - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.4162 - val_accuracy: 0.9389
#
# Epoch 00008: val_accuracy did not improve from 0.94578
# Epoch 9/15
# 828/828 [==============================] - 712s 860ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.4903 - val_accuracy: 0.9314
#
# Epoch 00009: val_accuracy did not improve from 0.94578
# Epoch 10/15
# 828/828 [==============================] - 712s 860ms/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.4218 - val_accuracy: 0.9352
#
# Epoch 00010: val_accuracy did not improve from 0.94578
# Epoch 11/15
# 828/828 [==============================] - 703s 849ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.5272 - val_accuracy: 0.9262
#
# Epoch 00011: val_accuracy did not improve from 0.94578
# Epoch 12/15
# 828/828 [==============================] - 708s 855ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 0.4407 - val_accuracy: 0.9385
#
# Epoch 00012: val_accuracy did not improve from 0.94578
# Epoch 13/15
# 828/828 [==============================] - 708s 855ms/step - loss: 0.0040 - accuracy: 0.9986 - val_loss: 0.4793 - val_accuracy: 0.9325
#
# Epoch 00013: val_accuracy did not improve from 0.94578
# Epoch 14/15
# 828/828 [==============================] - 710s 857ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.5218 - val_accuracy: 0.9299
#
# Epoch 00014: val_accuracy did not improve from 0.94578
# Epoch 15/15
# 828/828 [==============================] - 707s 854ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.6182 - val_accuracy: 0.9226
#
# Epoch 00015: val_accuracy did not improve from 0.94578

# %%
# Open a strategy scope.
with strategy.scope():
    model_mul.load_weights(os.path.join('gdrive', 'My Drive', 'Surrey_ASL', '4_Surrey_MobileNet_E_L2.hdf5'))

# %%
# Helper: Save the model.
savedfilename = os.path.join('gdrive', 'My Drive', 'Surrey_ASL', '4_Surrey_MobileNet_E_L3.hdf5')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_accuracy', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

epochs = 15##!!!
lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

# Open a strategy scope.
with strategy.scope():
    model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[checkpointer],
#     callbacks=[csv_logger, checkpointer, earlystopping],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/15
# 828/828 [==============================] - 731s 869ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.3431 - val_accuracy: 0.9469
#
# Epoch 00001: val_accuracy improved from -inf to 0.94688, saving model to gdrive/My Drive/Surrey_ASL/4_Surrey_MobileNet_E_L3.hdf5
# Epoch 2/15
# 828/828 [==============================] - 721s 870ms/step - loss: 0.0044 - accuracy: 0.9986 - val_loss: 0.3412 - val_accuracy: 0.9465
#
# Epoch 00002: val_accuracy did not improve from 0.94688
# Epoch 3/15
# 828/828 [==============================] - 711s 859ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.3594 - val_accuracy: 0.9443
#
# Epoch 00003: val_accuracy did not improve from 0.94688
# Epoch 4/15
# 828/828 [==============================] - 713s 861ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.3481 - val_accuracy: 0.9463
#
# Epoch 00004: val_accuracy did not improve from 0.94688
# Epoch 5/15
# 828/828 [==============================] - 716s 865ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.3720 - val_accuracy: 0.9437
#
# Epoch 00005: val_accuracy did not improve from 0.94688
# Epoch 6/15
# 828/828 [==============================] - 712s 860ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.3647 - val_accuracy: 0.9442
#
# Epoch 00006: val_accuracy did not improve from 0.94688
# Epoch 7/15
# 828/828 [==============================] - 705s 852ms/step - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.3776 - val_accuracy: 0.9427
#
# Epoch 00007: val_accuracy did not improve from 0.94688
# Epoch 8/15
# 828/828 [==============================] - 706s 852ms/step - loss: 0.0023 - accuracy: 0.9991 - val_loss: 0.3622 - val_accuracy: 0.9447
#
# Epoch 00008: val_accuracy did not improve from 0.94688
# Epoch 9/15
# 828/828 [==============================] - 704s 850ms/step - loss: 0.0026 - accuracy: 0.9991 - val_loss: 0.3545 - val_accuracy: 0.9461
#
# Epoch 00009: val_accuracy did not improve from 0.94688
# Epoch 10/15
# 828/828 [==============================] - 707s 854ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.3463 - val_accuracy: 0.9470
#
# Epoch 00010: val_accuracy improved from 0.94688 to 0.94696, saving model to gdrive/My Drive/Surrey_ASL/4_Surrey_MobileNet_E_L3.hdf5
# Epoch 11/15
# 828/828 [==============================] - 711s 858ms/step - loss: 0.0025 - accuracy: 0.9991 - val_loss: 0.3489 - val_accuracy: 0.9468
#
# Epoch 00011: val_accuracy did not improve from 0.94696
# Epoch 12/15
# 828/828 [==============================] - 707s 854ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.3526 - val_accuracy: 0.9468
#
# Epoch 00012: val_accuracy did not improve from 0.94696
# Epoch 13/15
# 828/828 [==============================] - 712s 859ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.3574 - val_accuracy: 0.9456
#
# Epoch 00013: val_accuracy did not improve from 0.94696
# Epoch 14/15
# 828/828 [==============================] - 713s 861ms/step - loss: 0.0019 - accuracy: 0.9993 - val_loss: 0.3613 - val_accuracy: 0.9452
#
# Epoch 00014: val_accuracy did not improve from 0.94696
# Epoch 15/15
# 828/828 [==============================] - 712s 859ms/step - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.3676 - val_accuracy: 0.9441
#
# Epoch 00015: val_accuracy did not improve from 0.94696

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

test_datagen = ImageDataGenerator(
    rescale = 1./255)

testing_set = test_datagen.flow_from_directory('dataset5/test_color/',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical',
                                                 seed=7,
                                                 shuffle=False
#                                                  subset="validation"
                                             )

y_pred = model.predict_generator(testing_set,steps = testing_set.n//testing_set.batch_size)
y_pred = np.argmax(y_pred, axis=1)

y_true = testing_set.classes

print(confusion_matrix(y_true, y_pred))

# print(model.evaluate_generator(testing_set,
#                                steps = testing_set.n//testing_set.batch_size))
