# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14153314265039406679
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 10935205888
# locality {
#   bus_id: 1
#   links {
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 2
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 3
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 12589400199770238921
# physical_device_desc: "device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1"
# , name: "/device:GPU:1"
# device_type: "GPU"
# memory_limit: 10935205888
# locality {
#   bus_id: 1
#   links {
#     link {
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 2
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 3
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 16239501731080100161
# physical_device_desc: "device: 1, name: GeForce GTX 1080 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1"
# , name: "/device:GPU:2"
# device_type: "GPU"
# memory_limit: 10935205888
# locality {
#   bus_id: 1
#   links {
#     link {
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 3
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 10077358130396405134
# physical_device_desc: "device: 2, name: GeForce GTX 1080 Ti, pci bus id: 0000:03:00.0, compute capability: 6.1"
# , name: "/device:GPU:3"
# device_type: "GPU"
# memory_limit: 10933213594
# locality {
#   bus_id: 1
#   links {
#     link {
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 2
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 16632032935738378784
# physical_device_desc: "device: 3, name: GeForce GTX 1080 Ti, pci bus id: 0000:04:00.0, compute capability: 6.1"
# ]

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0,1,2,3"

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
# !pip3 install kaggle

# %%
import os
os.environ['KAGGLE_USERNAME'] = "paulnh" # username from the json file 
os.environ['KAGGLE_KEY'] = "9e06528f4d63aefff0897e8d0b289fe7" # key from the json file
# !kaggle competitions download -c inaturalist-2019-fgvc6 # api copied from kaggle

# %%
ls -l
# Out:
# total 2711412
# -rw-rw-r--    1 bribeiro bribeiro          0 Ago 20 01:34 cassava_data_senet.csv
# -rw-rw-r--    1 bribeiro bribeiro     912312 Ago 28 09:22 Cassava_MulModels_501_Avg.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    7091492 Ago 25 06:44 Cassava_MulModels_501_Set1.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    7117941 Ago 26 18:22 Cassava_MulModels_501_Set1-re.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    1254358 Ago 28 09:11 Cassava_MulModels_501_Set1_T1.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    7106936 Ago 25 17:30 Cassava_MulModels_501_Set2_copy.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    7107516 Ago 26 16:12 Cassava_MulModels_501_Set2.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    7138085 Ago 26 12:56 Cassava_MulModels_501_Set3.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    1253031 Ago 28 04:55 Cassava_MulModels_501_Set3_T1.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    7073220 Ago 26 11:01 Cassava_MulModels_501_Set4.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    7041555 Ago 27 18:20 Cassava_MulModels_501_Set4_T1.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    7031794 Ago 27 12:22 Cassava_MulModels_501_Set5_T1.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    7278108 Ago 23 21:48 Cassava_MulModels_501_Template.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    3872066 Ago 18 04:22 Cassava_NonGrp_MulModels501-Extended.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    3920008 Ago 17 22:45 Cassava_NonGrp_MulModels501.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    1862717 Ago 20 11:03 Cassava_TL_MulModels-Copy1.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    1854296 Ago 17 22:44 Cassava_TL_Mul_Models.ipynb
# -rw-rw-r--    1 bribeiro bribeiro     822093 Set  4 03:42 Copy_of_Neural_Style_Transfer_with_Eager_Execution.ipynb
# drwxrwxr-x    2 bribeiro bribeiro      16384 Ago 31 05:15 csv/
# -rw-rw-r--    1 bribeiro bribeiro     115999 Set  7 02:57 DogAge_Icp401_PetFinder_STD.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    4004327 Ago  7 18:31 DogAge_Icp501_STD.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    1289338 Set  3 01:32 DogAge_MulModels_450_Set1_T1_ST.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    1485672 Set  3 23:16 DogAge_MulModels_450_Set1_T1_ST-Mixed2.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    1308865 Set  4 02:10 DogAge_MulModels_450_Set1_T1_ST-Mixed5-Copy1.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    1308571 Set  3 15:24 DogAge_MulModels_450_Set1_T1_ST-Mixed.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    2730405 Ago 29 11:17 DogAge_MulModels_500_Set1_T1.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    2710070 Set  1 18:53 DogAge_MulModels_500_Set1_T1_Re-Copy2.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    1440302 Set  5 10:06 DogAge_MulModels_500_Set1_T1_Re-Ext.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    2743775 Set  7 10:23 DogAge_MulModels_500_Set1_T1_Re-Final.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    1412269 Set 11 06:21 DogAge_MulModels_500_Set1_T1_Re_Final_Unbalance.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    2710070 Set  1 18:23 DogAge_MulModels_500_Set1_T1_Re.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    2887687 Ago 30 02:03 DogAge_MulModels_500_Set2_T2.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    1439597 Set  2 17:46 DogAge_MulModels_500_Set2_T2_Re-Ext.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    
# -rw-rw-r--    1 bribeiro bribeiro       7739 Set 10 08:28 DogAge_NonGrp_Set2_T2_Unbalance_IcpResNetV2_MulModels450_1009_v01.csv
# -rw-rw-r--    1 bribeiro bribeiro       7777 Set 10 23:29 DogAge_NonGrp_Set2_T2_Unbalance_MulModels450_1009_v1.csv
# -rw-rw-r--    1 bribeiro bribeiro       7721 Set 11 23:44 DogAge_NonGrp_Set2_T2_Unbalance_MulModels450_1109_v003.csv
# -rw-rw-r--    1 bribeiro bribeiro       7792 Set 10 10:17 DogAge_NonGrp_Set2_T2_Unbalance_MulModels540_1000_v2.csv
# -rw-rw-r--    1 bribeiro bribeiro       7792 Set 10 21:06 DogAge_NonGrp_Set2_T2_Unbalance_MulModels540_1010_v2.csv
# -rw-rw-r--    1 bribeiro bribeiro       7782 Set  5 05:26 DogAge_NonGrp_Set4_T4_MulModels450_SeResNext101_0409.csv
# -rw-rw-r--    1 bribeiro bribeiro     765054 Set  7 12:01 DogAge_NonGrp_Set4_T4_PetFinder_MulModels450_0709_v05.csv
# -rw-rw-r--    1 bribeiro bribeiro     759705 Set  7 05:14 DogAge_NonGrp_Set5_T5_PetFinder_MulModels450_SeResNext101_PetFinder_0709_v01.csv
# -rw-rw-r--    1 bribeiro bribeiro       7783 Set 11 10:35 DogAge_NonGrp_Set5_T5_Unbalance_MulModels450_IcpResNetV2_1109_v1.csv
# -rw-rw-r--    1 bribeiro bribeiro   55180119 Set  3 23:37 DogAge_ST_2.zip
# -rw-rw-r--    1 bribeiro bribeiro   46628047 Set  3 18:44 DogAge_ST_3.zip
# -rw-rw-r--    1 bribeiro bribeiro   53674523 Set  3 23:37 DogAge_ST_4.zip
# -rw-rw-r--    1 bribeiro bribeiro   46949785 Set  3 18:44 DogAge-ST.zip
# -rw-rw-r--    1 bribeiro bribeiro     199974 Set 12 09:16 DogAge_Unbalance_MulModels_450_Avg-Copy1.ipynb
# -rw-rw-r--    1 bribeiro bribeiro   80039411 Set  2 03:40 DogAge.zip
# -rw-rw-r--    1 bribeiro bribeiro  264372855 Ago 29 14:59 Expert_TrainEval.zip
# -rw-rw-r--    1 bribeiro bribeiro       9261 Out 28 15:15 fa_mnist_wrn5.py
# -rw-rw-r--    1 bribeiro bribeiro    5172472 Out 22 03:42 FashionMNIST_InceptionV3_LSTM_T6.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    1271385 Out 26 12:49 FashionMNIST_MulModel_299_RndErs.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    1275688 Out 26 01:21 FashionMNIST_MulModel_450-Copy1.ipynb
# -rw-rw-r--    1 bribeiro bribeiro     952616 Out 28 02:00 FashionMNIST_MulModel_GRU_299.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    3335291 Out 28 16:34 FashionMNIST_MulModel_LSTM_299.ipynb
# -rw-rw-r--    1 bribeiro bribeiro     970865 Out 30 14:59 FashionMNIST_MulModel_LSTM_350.ipynb
# -rw-rw-r--    1 bribeiro bribeiro     925576 Nov  3 13:08 FashionMNIST_MulModel_RNN_299.ipynb
# -rw-rw-r--    1 bribeiro bribeiro     188904 Out 28 01:36 FashionMNIST_MulModels299_AVG_Assembe_2810_1.csv
# -rw-rw-r--    1 bribeiro bribeiro     188904 Out 28 01:42 FashionMNIST_MulModels299_AVG_Assembe_2810_2.csv
# -rw-rw-r--    1 bribeiro bribeiro     188904 Out 25 08:58 FashionMNIST_MulModels299_AVG_Assembe_V2_2510_2.csv
# -rw-rw-r--    1 bribeiro bribeiro     188904 Out 25 08:41 FashionMNIST_MulModels299_AVG_Assembe_V2_2510.csv
# -rw-rw-r--    1 bribeiro bribeiro    1106551 Nov  4 23:35 FashionMNIST_MulModel_STD_299.ipynb
# -rw-rw-r--    1 bribeiro bribeiro     188912 Out 23 14:01 FashionMNIST_SeResNet101_MulModels299_2310_01.csv
# -rw-rw-r--    1 bribeiro bribeiro     188904 Out 23 14:35 FashionMNIST_SeResNet101_MulModels299_2310_tta_3_2.csv
# -rw-rw-r--    1 bribeiro bribeiro     188904 Out 23 14:48 FashionMNIST_SeResNet101_MulModels299_2310_tta_3_3.csv
# -rw-rw-r--    1 bribeiro bribeiro     188904 Out 23 15:09 FashionMNIST_SeResNet101_MulModels299_2310_tta_3_4.csv
# -rw-rw-r--    1 bribeiro bribeiro     188904 Out 23 16:26 FashionMNIST_SeResNet101_MulModels299_2310_tta_3_5.csv
# -rw-rw-r--    1 bribeiro bribeiro     188904 Out 23 14:13 FashionMNIST_SeResNet101_MulModels299_2310_tta_3.csv
# -rw-rw-r--    1 bribeiro bribeiro     420713 Jun  7 19:07 kaggle_sample_submission.csv
# -rw-rw-r--    1 bribeiro bribeiro      12300 Ago 20 22:19 kernel36bbd14953.ipynb
# drwxrwxr-x    3 bribeiro bribeiro       4096 Ago 15 22:27 Nat/
# -rw-rw-r--    1 bribeiro bribeiro   24611621 Ago 15 14:56 nat19_data.csv
# -rw-rw-r--    1 bribeiro bribeiro    4582231 Ago 15 22:16 Nat19_TL_Mul_Models-Copy1.ipynb
# -rw-rw-r--    1 bribeiro bribeiro   46021504 Jun 24 12:48 nat_data_file.csv
# -rw-rw-r--    1 bribeiro bribeiro     641626 Jul 27 22:29 Nat_Grp_S1_Icp_LRG401_STD-Copy1.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    1184152 Jul 31 11:38 Nat_Grp_S1_Icp_LRG401_STD.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    1749312 Ago  6 10:17 Nat_Grp_S1_IcpRes_LRG421_ADV.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    1628765 Ago  3 16:01 Nat_Grp_S1_IcpRes_LRG421_STD.ipynb
# -rw-rw-r--    1 bribeiro bribeiro     920246 Ago  1 13:10 Nat_Grp_S1_XIcp_LRG401_ADV.ipynb
# drwxr-xr-x    3 bribeiro bribeiro       4096 Jun  8 01:28 nat_output/
# -rw-rw-r--    1 bribeiro bribeiro    2862846 Jul 10 17:03 Nat_Rdn_S1_Icp_LRG401_STD_0_1.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    2724827 Jun 28 16:08 Nat_Rdn_S1_IcpRsn-FML.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    2707557 Jun 28 16:33 Nat_Rdn_S1_IcpRsn.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    2836537 Jul 11 13:24 Nat_Rdn_S1_IcpRsn-STD-0_1.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    2734078 Jun 30 18:03 Nat_Rdn_S1_IcpRsn-STD.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    2863085 Nov  4 23:48 Nat_Rdn_S1_MobileNetV1_LRG401_STD_0_1.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    3873689 Jul 25 02:50 Nat_Rdn_S1_SEIcpRes_LRG421_ADV_0_1_L2.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    2949458 Jun 24 10:50 Nat_S2_Lrg.ipynb
# -rw-rw-r--    1 bribeiro bribeiro     258789 Jun 11 08:21 Nat_Sml_v1.ipynb
# -rw-rw-r--    1 bribeiro bribeiro     433644 Set  2 02:20 Neural_Style_Transfer_with_Eager_Execution.ipynb
# drwxrwxr-x    2 bribeiro bribeiro   40148992 Ago 15 18:06 sequences/
# drwxrwxr-x    2 bribeiro bribeiro       4096 Set  2 02:15 ST/
# -rw-rw-r--    1 bribeiro bribeiro    1782704 Ago 31 18:38 STFDG_DogAge_TL_Mul_Models.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    3126967 Ago 31 15:36 STFDG_NonGrp_S1_LRG421_Mul_STD-Copy1.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    2333388 Set  8 13:12 STFDG_NonGrp_S1_LRG421_Mul_STD.ipynb
# -rw-rw-r--    1 bribeiro bribeiro    4415043 Ago 15 14:35 STFDG_TL_Mul_Models.ipynb
# drwxrwxr-x    3 bribeiro bribeiro       4096 Jun 10 14:33 test_2019/
# -rw-rw-r--    1 bribeiro bribeiro    5435872 Jun  7 19:07 test2019.json
# -rw-rw-r--    1 bribeiro bribeiro 1823124616 Set  4 16:10 test_dataset_2.zip
# drwxrwxr-x    3 bribeiro bribeiro       4096 Set  4 03:22 tmp/
# -rw-rw-r--    1 bribeiro bribeiro   59771647 Jun  7 19:07 train2019.json
# drwxrwxr-x    2 bribeiro bribeiro       4096 Set  8 14:39 train_2_extracted/
# drwxrwxr-x 1012 bribeiro bribeiro      36864 Jun  8 01:48 train_edited/
# drwxrwxr-x    2 bribeiro bribeiro       4096 Jun 28 16:04 train_fml/
# drwxrwxr-x 1012 bribeiro bribeiro      40960 Jun 24 12:11 train_rnd/
# drwxrwxr-x    8 bribeiro bribeiro       4096 Mar  8  2019 train_val2019/
# -rw-rw-r--    1 bribeiro bribeiro     178438 Jun 10 08:47 Untitled1.ipynb
# -rw-rw-r--    1 bribeiro bribeiro      28588 Jul 12 00:24 Untitled2.ipynb
# -rw-rw-r--    1 bribeiro bribeiro       5751 Ago  4 03:13 Untitled3.ipynb
# -rw-rw-r--    1 bribeiro bribeiro         72 Ago  5 18:49 Untitled4.ipynb
# -rw-rw-r--    1 bribeiro bribeiro     156889 Ago 16 00:19 Untitled5.ipynb
# -rw-rw-r--    1 bribeiro bribeiro     653643 Ago 16 23:56 Untitled6.ipynb
# -rw-rw-r--    1 bribeiro bribeiro     293117 Jun 13 22:52 Untitled.ipynb
# -rw-rw-r--    1 bribeiro bribeiro     836060 Jun  7 19:07 val2019.json
# drwxrwxr-x 1012 bribeiro bribeiro      40960 Jun  8 01:51 valid_edited/
# drwxrwxr-x 1012 bribeiro bribeiro      40960 Jun 24 12:52 valid_rnd/

# %%
# !tar -zxf train_val2019.tar.gz

# %%
# !tar -zxf test2019.tar.gz

# %%
mkdir test_2019

# %%
mv test2019 test_2019/0

# %% [raw]
# r

# %%
rm train_val2019.tar.gz

# %%
cd test2019

# %%
ls -l|head -20

# %%
cd ..

# %%
# ####=======================
# #### Move back images
# #####

# import csv
# import glob
# import os
# import shutil
# import random

# #move color files  
# #divide 2-2 randomly

# # # get parts of image's path
# def get_image_parts(image_path):
#     """Given a full path to an image, return its parts."""
#     parts = image_path.split(os.path.sep)
#     #print(parts)
#     filename = parts[2]
#     filename_no_ext = filename.split('.')[0]
#     classname = parts[1]
# #     sub_folder = parts[1]
#     train_or_test = parts[0]

#     return train_or_test, classname, filename_no_ext, filename

# move_folders = ['valid_edited']
# dest_folder = 'train_edited'
# data_file = []

# # look for all images in sub-folders
# for folder in move_folders:
#     class_folders = glob.glob(os.path.join(folder, '*'))
#     print('folder %s' %class_folders)
    
# #     for sub_folder in class_folders:
# #         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
# #         print('sub folder %s' %sub_class_folders)
        
#     for iid_class in class_folders:
#         class_files = glob.glob(os.path.join(iid_class, '*.jpg'))

# #             print('moving %d files' %(len(class_files)))

#         #Determize Set# (No Suffle)
#         set = len(class_files)# all images

#         inner = range(0*set, 1*set)

#         print('moving %d files' %(len(inner)))

# #             random_list = random.sample(range(len(class_files)), int(len(class_files))) #All dataset
# #             for idx in range(len(random_list)):

#         for idx in range(len(inner)):
#             src = class_files[inner[idx]]

#             #record paths
# #                 data_file.append(src)

#             train_or_test, classname, _, filename = get_image_parts(src)
#             dst = os.path.join(dest_folder, classname, filename) #

#             # image directory
#             img_directory = os.path.join(dest_folder, classname)

#             # create folder if not existed
#             if not os.path.exists(img_directory):
#                 os.makedirs(img_directory)

#             #moving file
#             shutil.move(src, dst)
# #                 shutil.copy(src, dst)

# # #save recorded paths
# # with open('data_file.csv', 'w') as fout:
# #     writer = csv.writer(fout)
# #     writer.writerows(data_file)

# %%
# ####=======================
# #### Move back images
# #####

# import csv
# import glob
# import os
# import shutil
# import random

# #move color files  
# #divide 2-2 randomly

# # # get parts of image's path
# def get_image_parts(image_path):
#     """Given a full path to an image, return its parts."""
#     parts = image_path.split(os.path.sep)
#     #print(parts)
#     filename = parts[2]
#     filename_no_ext = filename.split('.')[0]
#     classname = parts[1]
# #     sub_folder = parts[1]
#     train_or_test = parts[0]

#     return train_or_test, classname, filename_no_ext, filename

# move_folders = ['train_rnd']
# dest_folder = 'train_edited'
# data_file = []

# # look for all images in sub-folders
# for folder in move_folders:
#     class_folders = glob.glob(os.path.join(folder, '*'))
#     print('folder %s' %class_folders)
    
# #     for sub_folder in class_folders:
# #         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
# #         print('sub folder %s' %sub_class_folders)
        
#     for iid_class in class_folders:
#         class_files = glob.glob(os.path.join(iid_class, '*.jpg'))

# #             print('moving %d files' %(len(class_files)))

#         #Determize Set# (No Suffle)
#         set = len(class_files)# all images

#         inner = range(0*set, 1*set)

#         print('moving %d files' %(len(inner)))

# #             random_list = random.sample(range(len(class_files)), int(len(class_files))) #All dataset
# #             for idx in range(len(random_list)):

#         for idx in range(len(inner)):
#             src = class_files[inner[idx]]

#             #record paths
# #                 data_file.append(src)

#             train_or_test, classname, _, filename = get_image_parts(src)
#             dst = os.path.join(dest_folder, classname, filename) #

#             # image directory
#             img_directory = os.path.join(dest_folder, classname)

#             # create folder if not existed
#             if not os.path.exists(img_directory):
#                 os.makedirs(img_directory)

#             #moving file
#             shutil.move(src, dst)
# #                 shutil.copy(src, dst)

# # #save recorded paths
# # with open('data_file.csv', 'w') as fout:
# #     writer = csv.writer(fout)
# #     writer.writerows(data_file)

# %%
# ####=======================
# import glob
# import os
# import shutil
# import random

# #move color files  
# #divide 2-2 randomly

# # # get parts of image's path
# def get_image_parts(image_path):
#     """Given a full path to an image, return its parts."""
#     parts = image_path.split(os.path.sep)
#     #print(parts)
#     filename = parts[3]
#     filename_no_ext = filename.split('.')[0]
#     classname = parts[2]
#     sub_folder = parts[1]
#     train_or_test = parts[0]

#     return train_or_test, sub_folder, classname, filename_no_ext, filename

# move_folders = ['train_val2019']

# # look for all images in sub-folders
# for folder in move_folders:
#     class_folders = glob.glob(os.path.join(folder, '*'))
#     print('folder %s' %class_folders)
    
#     for sub_folder in class_folders:
#         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
#         print('sub folder %s' %sub_class_folders)
        
#         for iid_class in sub_class_folders:
#             class_files = glob.glob(os.path.join(iid_class, '*.jpg'))

#             print('moving %d files' %(len(class_files)))

# #             random_list = random.sample(range(len(class_files)), int(len(class_files))) #All dataset
#             random_list = range(0,len(class_files)) #All dataset
    
#             for idx in range(len(random_list)):
#                 src = class_files[random_list[idx]]

#                 train_or_test, sub_folder, classname, _, filename = get_image_parts(src)
#                 dst = os.path.join('train_edited', sub_folder+'_'+classname, train_or_test+'_'+ filename)
                
#                 # image directory
#                 img_directory = os.path.join('train_edited', sub_folder+'_'+classname)

#                 # create folder if not existed
#                 if not os.path.exists(img_directory):
#                     os.makedirs(img_directory)

#                 #moving file
#                 shutil.move(src, dst)

# %%
# ####=======================
# import glob
# import os
# import shutil
# import random

# #move color files  
# #divide 2-2 randomly

# # # get parts of image's path
# def get_image_parts(image_path):
#     """Given a full path to an image, return its parts."""
#     parts = image_path.split(os.path.sep)
#     #print(parts)
#     filename = parts[2]
#     filename_no_ext = filename.split('.')[0]
#     classname = parts[1]
# #     sub_folder = parts[1]
#     train_or_test = parts[0]

#     return train_or_test, classname, filename_no_ext, filename

# move_folders = ['train_edited']
# dest_folder = 'valid_edited'
# data_file = []

# # look for all images in sub-folders
# for folder in move_folders:
#     class_folders = glob.glob(os.path.join(folder, '*'))
#     print('folder %s' %class_folders)
    
# #     for sub_folder in class_folders:
# #         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
# #         print('sub folder %s' %sub_class_folders)
        
#     for iid_class in class_folders:
#         class_files = glob.glob(os.path.join(iid_class, '*.jpg'))

# #             print('moving %d files' %(len(class_files)))

#         #Determize Set# (No Suffle)
#         set = len(class_files)//5

#         inner = range(2*set, 3*set) #Set 3

#         print('moving %d files' %(len(inner)))

# #             random_list = random.sample(range(len(class_files)), int(len(class_files))) #All dataset
# #             for idx in range(len(random_list)):

#         for idx in range(len(inner)):
#             src = class_files[inner[idx]]

#             #record paths
# #                 data_file.append(src)

#             train_or_test, classname, _, filename = get_image_parts(src)
#             dst = os.path.join(dest_folder, classname, train_or_test+'_'+ filename)

#             # image directory
#             img_directory = os.path.join(dest_folder, classname)

#             # create folder if not existed
#             if not os.path.exists(img_directory):
#                 os.makedirs(img_directory)

#             #moving file
#             shutil.move(src, dst)
# #                 shutil.copy(src, dst)

# # #save recorded paths
# # with open('data_file.csv', 'w') as fout:
# #     writer = csv.writer(fout)
# #     writer.writerows(data_file)

# %%
# ####=======================
# #### Move files back

# #####======================
# import glob
# import os
# import shutil
# import random

# #move color files  
# #divide 2-2 randomly

# # # get parts of image's path
# def get_image_parts(image_path):
#     """Given a full path to an image, return its parts."""
#     parts = image_path.split(os.path.sep)
#     #print(parts)
#     filename = parts[2]
#     filename_no_ext = filename.split('.')[0]
#     classname = parts[1]
# #     sub_folder = parts[1]
#     train_or_test = parts[0]

#     return train_or_test, classname, filename_no_ext, filename

# move_folders = ['valid_edited']
# dest_folders = 'train_edited'

# data_file = []

# # look for all images in sub-folders
# for folder in move_folders:
#     class_folders = glob.glob(os.path.join(folder, '*'))
#     print('folder %s' %class_folders)
    
# #     for sub_folder in class_folders:
# #         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
# #         print('sub folder %s' %sub_class_folders)
        
#     for iid_class in class_folders:
#         class_files = glob.glob(os.path.join(iid_class, '*.jpg'))

# #             print('moving %d files' %(len(class_files)))

#         #Move all files back
#         set = len(class_files)

#         inner = range(0, set) 

#         print('moving %d files' %(len(inner)))

# #             random_list = random.sample(range(len(class_files)), int(len(class_files))) #All dataset
# #             for idx in range(len(random_list)):

#         for idx in range(len(inner)):
#             src = class_files[inner[idx]]

#             #record paths
# #                 data_file.append(src)

#             train_or_test, classname, _, filename = get_image_parts(src)
#             dst = os.path.join(dest_folders, classname, train_or_test+'_'+ filename)

#             # image directory
#             img_directory = os.path.join(dest_folders, classname)

#             # create folder if not existed
#             if not os.path.exists(img_directory):
#                 os.makedirs(img_directory)

#             #moving file
#             shutil.move(src, dst)
# #                 shutil.copy(src, dst)

# # #save recorded paths
# # with open('data_file.csv', 'w') as fout:
# #     writer = csv.writer(fout)
# #     writer.writerows(data_file)

# %%
mkdir train_rnd

# %%
####=======================


######
import csv
import glob
import os
import shutil
import random

#move color files  

# # get parts of image's path
def get_image_parts(image_path):
    """Given a full path to an image, return its parts."""
    parts = image_path.split(os.path.sep)
    #print(parts)
    filename = parts[2]
    filename_no_ext = filename.split('.')[0]
    classname = parts[1]
#     sub_folder = parts[1]
    train_or_test = parts[0]

    return train_or_test, classname, filename_no_ext, filename

move_folders = ['train_edited']
dest_folder = 'train_rnd'

data_file =[]

# look for all images in sub-folders
for folder in move_folders:
    class_folders = glob.glob(os.path.join(folder, '*'))
#     print('folder %s' %class_folders)
    
#     for sub_folder in class_folders:
#         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
#         print('sub folder %s' %sub_class_folders)
        
    for iid_class in class_folders:
        class_files = glob.glob(os.path.join(iid_class, '*.jpg'))

        print('moving %d files' %(len(class_files)))

#             random_list = random.sample(range(len(class_files)), int(len(class_files))) #All dataset
        random_list = range(0,len(class_files)) #All dataset

        #suffle list
        suffle_list = random.sample(range(len(class_files)), int(len(class_files)))

#         print(len(random_list))
        for idx in range(len(random_list)):
            src = class_files[random_list[idx]]

            train_or_test, classname, _, filename = get_image_parts(src)
            dst = os.path.join(dest_folder, classname, '{:07d}'.format(suffle_list[idx])+'_'+filename)

            # image directory
            img_directory = os.path.join(dest_folder, classname)

            # create folder if not existed
            if not os.path.exists(img_directory):
                os.makedirs(img_directory)

            # moving file
            shutil.move(src, dst) 

            #recording
            data_file.append([src, dst])

with open('nat_data_file.csv', 'w') as fout:
    writer = csv.writer(fout)
    writer.writerows(data_file)

# %%
mkdir valid_rnd

# %%
####=======================
import glob
import os
import shutil
import random

#move color files  
#divide 2-2 randomly

# # get parts of image's path
def get_image_parts(image_path):
    """Given a full path to an image, return its parts."""
    parts = image_path.split(os.path.sep)
    #print(parts)
    filename = parts[2]
    filename_no_ext = filename.split('.')[0]
    classname = parts[1]
#     sub_folder = parts[1]
    train_or_test = parts[0]

    return train_or_test, classname, filename_no_ext, filename

move_folders = ['train_rnd']
dest_folder = 'valid_rnd'
data_file = []

# look for all images in sub-folders
for folder in move_folders:
    class_folders = glob.glob(os.path.join(folder, '*'))
    print('folder %s' %class_folders)
    
#     for sub_folder in class_folders:
#         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
#         print('sub folder %s' %sub_class_folders)
        
    for iid_class in class_folders:
        class_files = glob.glob(os.path.join(iid_class, '*.jpg'))

#             print('moving %d files' %(len(class_files)))

        #Determize Set# (No Suffle)
        set = len(class_files)//5

        inner = range(2*set, 3*set) #Set 3

        print('moving %d files' %(len(inner)))

#             random_list = random.sample(range(len(class_files)), int(len(class_files))) #All dataset
#             for idx in range(len(random_list)):

        for idx in range(len(inner)):
            src = class_files[inner[idx]]

            #record paths
#                 data_file.append(src)

            train_or_test, classname, _, filename = get_image_parts(src)
            dst = os.path.join(dest_folder, classname, train_or_test+'_'+ filename)

            # image directory
            img_directory = os.path.join(dest_folder, classname)

            # create folder if not existed
            if not os.path.exists(img_directory):
                os.makedirs(img_directory)

            #moving file
            shutil.move(src, dst)
#                 shutil.copy(src, dst)

# #save recorded paths
# with open('data_file.csv', 'w') as fout:
#     writer = csv.writer(fout)
#     writer.writerows(data_file)

# %%
####=======================
import glob
import os
import shutil
import random

#move color files  
#divide 2-2 randomly

# # get parts of image's path
def get_image_parts(image_path):
    """Given a full path to an image, return its parts."""
    parts = image_path.split(os.path.sep)
    #print(parts)
    filename = parts[2]
    filename_no_ext = filename.split('.')[0]
    classname = parts[1]
#     sub_folder = parts[1]
    train_or_test = parts[0]

    return train_or_test, classname, filename_no_ext, filename

move_folders = ['valid_rnd']
dest_folder = 'train_rnd'
data_file = []

# look for all images in sub-folders
for folder in move_folders:
    class_folders = glob.glob(os.path.join(folder, '*'))
    print('folder %s' %class_folders)
    
#     for sub_folder in class_folders:
#         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
#         print('sub folder %s' %sub_class_folders)
        
    for iid_class in class_folders:
        class_files = glob.glob(os.path.join(iid_class, '*.jpg'))

#             print('moving %d files' %(len(class_files)))

        #Determize Set# (No Suffle)
        set = len(class_files)//2 #move back 50% (using kfold of 20)

        inner = range(0*set, 1*set) #Set 1

        print('moving %d files' %(len(inner)))

#             random_list = random.sample(range(len(class_files)), int(len(class_files))) #All dataset
#             for idx in range(len(random_list)):

        for idx in range(len(inner)):
            src = class_files[inner[idx]]

            #record paths
#                 data_file.append(src)

            train_or_test, classname, _, filename = get_image_parts(src)
            dst = os.path.join(dest_folder, classname, filename)

            # image directory
            img_directory = os.path.join(dest_folder, classname)

            # create folder if not existed
            if not os.path.exists(img_directory):
                os.makedirs(img_directory)

            #moving file
            shutil.move(src, dst)
#                 shutil.copy(src, dst)

# #save recorded paths
# with open('data_file.csv', 'w') as fout:
#     writer = csv.writer(fout)
#     writer.writerows(data_file)

# %%
cd train_edited/Amphibians_153/

# %%
ls -l|head -30

# %%
cd ../..

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale = 1./255,
#     rotation_range=20,
#     width_shift_range=0.2,
#     height_shift_range=0.2,
#     shear_range=0.2,
#     zoom_range=0.2,
#     horizontal_flip=True,
#     vertical_flip=True,##
# #     brightness_range=[0.5, 1.5],##
#     channel_shift_range=10,##
#     fill_mode='nearest'
)

test_datagen = ImageDataGenerator(
    rescale = 1./255)

training_set = train_datagen.flow_from_directory('train_edited',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('valid_edited',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )
# Out:
# Found 0 images belonging to 1010 classes.
# Found 0 images belonging to 1010 classes.

# %%
import numpy as np
from matplotlib.image import imread
# %matplotlib inline
import matplotlib.pyplot as plt
import glob
import os

# get image parts
def get_image_parts(image_path):
    """Given a full path to an image, return its parts."""
    parts = image_path.split(os.path.sep)
    #print(parts)
    filename = parts[2]
    filename_no_ext = filename.split('.')[0]
    classname = parts[1]
    train_or_test = parts[0]
    
    return train_or_test, classname, filename_no_ext, filename
    
    
sample_images = list(glob.glob(os.path.join('train_rnd/', '*/*'), recursive=True))
np.random.seed(7)
rand_imgs = np.random.choice(sample_images, size=6*7)
fig, axarr = plt.subplots(6, 7, figsize=(20, 25))

for i, rand_img in enumerate(rand_imgs):
    train_or_test, classname, filename_no_ext, filename = get_image_parts(rand_img)
    
    j = i // 7
    k = i % 7
    axarr[j][k].imshow(imread(rand_img))
    axarr[j][k].title.set_text(classname)
    axarr[j][k].grid(False)

# %%
#MUL 1 - Inception - ST

# from keras.applications import InceptionV3
# from keras.applications import Xception
# from keras.applications.inception_resnet_v2 import InceptionResNetV2
from keras.applications import MobileNet

from keras.models import Model
# from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM, Reshape, Concatenate,Bidirectional
from keras.applications.mobilenet import preprocess_input

from keras.layers import GaussianNoise

# f1_base = Xception(weights='imagenet', include_top=False, input_shape=(450,450,3))
# f1_base = InceptionV3(weights='imagenet', include_top=False, input_shape=(299,299,3))
f1_base = MobileNet(weights='imagenet', include_top=False, input_shape=(224,224,3))
f1_x = f1_base.output
f1_x = GlobalAveragePooling2D()(f1_x)

# f1_x = Reshape([1,2048])(f1_x)  

# f1_x = Bidirectional(LSTM(1024, 
#                                  return_sequences=False, 
# #                                  dropout=0.8
#                                 ),
#                             input_shape=[1,2048],
#                             merge_mode='concat')(f1_x)


#Regularization with noise
f1_x = GaussianNoise(0.1)(f1_x)

f1_x = Dense(4096, activation='relu')(f1_x)
f1_x = Dense(1010, activation='softmax')(f1_x)
model_1 = Model(inputs=[f1_base.input],outputs=[f1_x])

print(model_1.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (Activation)      (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# _________________________________________________________________
# conv_dw_1_relu (Activation)  (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 112, 112, 64)      2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 112, 112, 64)      256
# _________________________________________________________________
# conv_pw_1_relu (Activation)  (None, 112, 112, 64)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 56, 56, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (Activation)  (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 56, 56, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (Activation)  (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (Activation)  (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 56, 56, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (Activation)  (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 28, 28, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (Activation)  (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 28, 28, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (Activation)  (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (Activation)  (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 28, 28, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (Activation)  (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)       2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 14, 14, 256)       1024
# _________________________________________________________________
# conv_dw_6_relu (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 14, 14, 512)       131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_6_relu (Activation)  (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_7_relu (Activation)  (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_7_relu (Activation)  (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_8_relu (Activation)  (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_8_relu (Activation)  (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_9_relu (Activation)  (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_9_relu (Activation)  (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_10_relu (Activation) (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_10_relu (Activation) (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_11_relu (Activation) (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_11_relu (Activation) (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 7, 7, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 7, 7, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (Activation) (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 7, 7, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (Activation) (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 7, 7, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (Activation) (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 7, 7, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (Activation) (None, 7, 7, 1024)        0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1024)              0
# _________________________________________________________________
# gaussian_noise_2 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4096)              4198400
# _________________________________________________________________
# dense_4 (Dense)              (None, 1010)              4137970
# =================================================================
# Total params: 11,565,234
# Trainable params: 11,543,346
# Non-trainable params: 21,888
# _________________________________________________________________
# None

# %%
from keras.layers import Lambda, concatenate
from keras import Model
import tensorflow as tf

def multi_gpu_model(model, gpus):
    if isinstance(gpus, (list, tuple)):
        num_gpus = len(gpus)
        target_gpu_ids = gpus
    else:
        num_gpus = gpus
        target_gpu_ids = range(num_gpus)

    def get_slice(data, i, parts):
        shape = tf.shape(data)
        batch_size = shape[:1]
        input_shape = shape[1:]
        step = batch_size // parts
        if i == num_gpus - 1:
            size = batch_size - step * i
        else:
            size = step
        size = tf.concat([size, input_shape], axis=0)
        stride = tf.concat([step, input_shape * 0], axis=0)
        start = stride * i
        return tf.slice(data, start, size)

    all_outputs = []
    for i in range(len(model.outputs)):
        all_outputs.append([])

    # Place a copy of the model on each GPU,
    # each getting a slice of the inputs.
    for i, gpu_id in enumerate(target_gpu_ids):
        with tf.device('/gpu:%d' % gpu_id):
            with tf.name_scope('replica_%d' % gpu_id):
                inputs = []
                # Retrieve a slice of the input.
                for x in model.inputs:
                    input_shape = tuple(x.get_shape().as_list())[1:]
                    slice_i = Lambda(get_slice,
                                   output_shape=input_shape,
                                   arguments={'i': i,
                                              'parts': num_gpus})(x)
                    inputs.append(slice_i)

                # Apply model on slice
                # (creating a model replica on the target device).
                outputs = model(inputs)
                if not isinstance(outputs, list):
                    outputs = [outputs]

                # Save the outputs for merging back together later.
                for o in range(len(outputs)):
                    all_outputs[o].append(outputs[o])

    # Merge outputs on CPU.
    with tf.device('/cpu:0'):
        merged = []
        for name, outputs in zip(model.output_names, all_outputs):
            merged.append(concatenate(outputs,
                                    axis=0, name=name))
        return Model(model.inputs, merged)
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.applications.mobilenet import preprocess_input

import time, os
from math import ceil
import multiprocessing

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

NUM_GPU = 4
batch_size = NUM_GPU * 96

training_set = train_datagen.flow_from_directory('train_rnd',
                                                 target_size = (224, 224),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('valid_rnd',
                                                 target_size = (224, 224),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

# testing_set = test_datagen.flow_from_directory('test_edited',
#                                                  target_size = (224, 224),
#                                                  batch_size = batch_size,
#                                                  class_mode = 'categorical',
#                                                  shuffle=False,
#                                                  seed=7,
# #                                                  subset="validation"
#                                              )

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('Nat', 'Nat_Rdn_S1_MobileNetV1_LRG224_STD_0_1.hdf5')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('nat_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('nat_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

from keras.callbacks import Callback
class EarlyStoppingByAccVal(Callback):
    def __init__(self, monitor='val_acc', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current >= self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping" % epoch)
            self.model.stop_training = True

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.79, verbose=1)

# print('Loading pretrained weights')
# model.load_weights(savedfilename)

if NUM_GPU != 1:
    mul_model = multi_gpu_model(model_1, gpus=NUM_GPU)

epochs = 40##!!!
lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)
if NUM_GPU != 1:
    mul_model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])
else:
    model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

step_size_train=ceil(training_set.n/training_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

if NUM_GPU != 1:
    result = mul_model.fit_generator(training_set,
                              steps_per_epoch = step_size_train,
                              epochs = epochs,
                              validation_data = valid_set,
                              validation_steps = step_size_valid,
                              shuffle=True,
                              verbose=1,
                              callbacks=[tb, csv_logger, checkpointer,earlystopping],
                              max_queue_size=20,
#                               use_multiprocessing=True,
                              workers=10,
                             )
else:    
    result = model.fit_generator(training_set,
                              steps_per_epoch = step_size_train,
                              epochs = epochs,
                              validation_data = valid_set,
                              validation_steps = step_size_valid,
                              shuffle=True,
                              verbose=1,
                              callbacks=[tb, csv_logger, checkpointer,earlystopping],
                              max_queue_size=20,
#                               use_multiprocessing=True,
                              workers=10,
                             )

# loss, acc = model.evaluate_generator(testing_set, steps=step_size_test, verbose=2)
# print('test loss = %f, accuracy: %f' %(loss, acc))
# Out:
# Found 261135 images belonging to 1010 classes.
# Found 7108 images belonging to 1010 classes.
# Epoch 1/40
# 680/681 [============================>.] - ETA: 1s - loss: 6.2834 - acc: 0.0304Epoch 00001: val_acc improved from -inf to 0.08343, saving model to Nat/Nat_Rdn_S1_MobileNetV1_LRG224_STD_0_1.hdf5
# 681/681 [==============================] - 1145s 2s/step - loss: 6.2824 - acc: 0.0305 - val_loss: 5.4390 - val_acc: 0.0834
# Epoch 2/40
# 680/681 [============================>.] - ETA: 1s - loss: 5.0022 - acc: 0.1128Epoch 00002: val_acc improved from 0.08343 to 0.16348, saving model to Nat/Nat_Rdn_S1_MobileNetV1_LRG224_STD_0_1.hdf5
# 681/681 [==============================] - 
40
# 680/681 [============================>.] - ETA: 1s - loss: 2.0271 - acc: 0.4987Epoch 00034: val_acc did not improve
# 681/681 [==============================] - 1363s 2s/step - loss: 2.0268 - acc: 0.4987 - val_loss: 2.0906 - val_acc: 0.4968
# Epoch 35/40
# 680/681 [============================>.] - ETA: 1s - loss: 2.0076 - acc: 0.5039Epoch 00035: val_acc improved from 0.49803 to 0.50141, saving model to Nat/Nat_Rdn_S1_MobileNetV1_LRG224_STD_0_1.hdf5
# 681/681 [==============================] - 1278s 2s/step - loss: 2.0076 - acc: 0.5038 - val_loss: 2.0748 - val_acc: 0.5014
# Epoch 36/40
# 680/681 [============================>.] - ETA: 1s - loss: 1.9929 - acc: 0.5063Epoch 00036: val_acc improved from 0.50141 to 0.50464, saving model to Nat/Nat_Rdn_S1_MobileNetV1_LRG224_STD_0_1.hdf5
# 681/681 [==============================] - 1197s 2s/step - loss: 1.9931 - acc: 0.5062 - val_loss: 2.0660 - val_acc: 0.5046
# Epoch 37/40
# 680/681 [============================>.] - ETA: 1s - loss: 1.9747 - acc: 0.5105Epoch 00037: val_acc improved from 0.50464 to 0.50788, saving model to Nat/Nat_Rdn_S1_MobileNetV1_LRG224_STD_0_1.hdf5
# 681/681 [==============================] - 1145s 2s/step - loss: 1.9745 - acc: 0.5105 - val_loss: 2.0522 - val_acc: 0.5079
# Epoch 38/40
# 680/681 [============================>.] - ETA: 1s - loss: 1.9605 - acc: 0.5127Epoch 00038: val_acc improved from 0.50788 to 0.50971, saving model to Nat/Nat_Rdn_S1_MobileNetV1_LRG224_STD_0_1.hdf5
# 681/681 [==============================] - 1247s 2s/step - loss: 1.9604 - acc: 0.5126 - val_loss: 2.0345 - val_acc: 0.5097
# Epoch 39/40
# 680/681 [============================>.] - ETA: 1s - loss: 1.9433 - acc: 0.5162Epoch 00039: val_acc did not improve
# 681/681 [==============================] - 1204s 2s/step - loss: 1.9433 - acc: 0.5162 - val_loss: 2.0338 - val_acc: 0.5083
# Epoch 40/40
# 680/681 [============================>.] - ETA: 1s - loss: 1.9310 - acc: 0.5188Epoch 00040: val_acc did not improve
# 681/681 [==============================] - 1324s 2s/step - loss: 1.9309 - acc: 0.5189 - val_loss: 2.0246 - val_acc: 0.5083

# %%
checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.75, verbose=1)

# print('Loading pretrained weights')
# model.load_weights(savedfilename)

epochs = 8##!!!

if NUM_GPU != 1:
    result = mul_model.fit_generator(training_set,
                              steps_per_epoch = step_size_train,
                              epochs = epochs,
                              validation_data = valid_set,
                              validation_steps = step_size_valid,
                              shuffle=True,
                              verbose=1,
                              callbacks=[tb, csv_logger, checkpointer, earlystopping],
                              max_queue_size=8,
#                               use_multiprocessing=True,
                              workers=4,
                             )
else:
    result = model.fit_generator(training_set,
                              steps_per_epoch = step_size_train,
                              epochs = epochs,
                              validation_data = valid_set,
                              validation_steps = step_size_valid,
                              shuffle=True,
                              verbose=1,
                              callbacks=[tb, csv_logger, checkpointer,earlystopping],
                              max_queue_size=8,
#                               use_multiprocessing=True,
                              workers=4,
                             )

# %%
from keras.layers import Lambda, concatenate
from keras import Model
import tensorflow as tf

def multi_gpu_model(model, gpus):
    if isinstance(gpus, (list, tuple)):
        num_gpus = len(gpus)
        target_gpu_ids = gpus
    else:
        num_gpus = gpus
        target_gpu_ids = range(num_gpus)

    def get_slice(data, i, parts):
        shape = tf.shape(data)
        batch_size = shape[:1]
        input_shape = shape[1:]
        step = batch_size // parts
        if i == num_gpus - 1:
            size = batch_size - step * i
        else:
            size = step
        size = tf.concat([size, input_shape], axis=0)
        stride = tf.concat([step, input_shape * 0], axis=0)
        start = stride * i
        return tf.slice(data, start, size)

    all_outputs = []
    for i in range(len(model.outputs)):
        all_outputs.append([])

    # Place a copy of the model on each GPU,
    # each getting a slice of the inputs.
    for i, gpu_id in enumerate(target_gpu_ids):
        with tf.device('/gpu:%d' % gpu_id):
            with tf.name_scope('replica_%d' % gpu_id):
                inputs = []
                # Retrieve a slice of the input.
                for x in model.inputs:
                    input_shape = tuple(x.get_shape().as_list())[1:]
                    slice_i = Lambda(get_slice,
                                   output_shape=input_shape,
                                   arguments={'i': i,
                                              'parts': num_gpus})(x)
                    inputs.append(slice_i)

                # Apply model on slice
                # (creating a model replica on the target device).
                outputs = model(inputs)
                if not isinstance(outputs, list):
                    outputs = [outputs]

                # Save the outputs for merging back together later.
                for o in range(len(outputs)):
                    all_outputs[o].append(outputs[o])

    # Merge outputs on CPU.
    with tf.device('/cpu:0'):
        merged = []
        for name, outputs in zip(model.output_names, all_outputs):
            merged.append(concatenate(outputs,
                                    axis=0, name=name))
        return Model(model.inputs, merged)

# %%
# PREDICT ON OFFICIAL TEST
test_datagen1 = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

test_set1 = test_datagen1.flow_from_directory('test_2019',
                                                 target_size = (224, 224),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

if NUM_GPU != 1:
    predict1=mul_model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
else:
    predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
predicted_class_indices=np.argmax(predict1,axis=1)
labels = (training_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions1 = [labels[k] for k in predicted_class_indices]

import pandas as pd

filenames=test_set1.filenames
results=pd.DataFrame({"file_name":filenames,
                      "predicted1":predictions1,
                      })
results.to_csv('Nat_Rdn_S1_MobileNetV1_LRG224_STD_0_1_0511_v1.csv')
results.tail()
# Out:
# Found 35350 images belonging to 1 classes.
# 93/93 [==============================] - 877s 9s/step
#                                     file_name  predicted1
# 35345  0/fff960565176b09dcf2db1c423380727.jpg  Plants_814
# 35346  0/fffa049864300e290dc01260cfe83a18.jpg   Birds_209
# 35347  0/fffa5dd78d09e2d66c268031d3be380e.jpg  Plants_998
# 35348  0/fffbc173860f1ecf28dfc72072a1c552.jpg  Plants_515
# 35349  0/fffcf7648fbccb5e27a4c40e790ebb14.jpg  Plants_446

# %%
print(model.summary())

# %%
base_model = InceptionResNetV2(weights='imagenet',include_top=False,input_shape=(421,421,3))
# x = base_model.output
print(base_model.summary())

# %%
import multiprocessing
print(multiprocessing.cpu_count())

# %%
#Crop-Official Test
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

test_datagen_crop = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

testing_set_crop = test_datagen_crop.flow_from_directory('test_2019',
                                                 target_size = (501, 501),
                                                 batch_size = 1,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="training"
                                              )
#customized generator
test_crops = crop_generator(testing_set_crop, 401)

step_size_test_crop = ceil(testing_set_crop.n/testing_set_crop.batch_size)

tta_steps = 15
predictions = []

# import tensorflow as tf
# with tf.device('/gpu:0'):
for i in range(tta_steps):
    print(i)
    testing_set_crop.reset()
    if NUM_GPU != 1:
        preds=mul_model.predict_generator(test_crops, 
                                           steps = step_size_test_crop,
                                           max_queue_size=16,
#                                                use_multiprocessing=True,
                                           workers=1,
                                           verbose=1)    
    else:
        preds=model.predict_generator(test_crops, 
                                           steps = step_size_test_crop,
                                           max_queue_size=16,
#                                                use_multiprocessing=True,
                                           workers=1,
                                           verbose=1)           
    predictions.append(preds)

mean_pred = np.mean(predictions, axis=0)

predicted_class_indices_mean=np.argmax(mean_pred,axis=1)
labels = (training_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=test_set1.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Nat_Rdn_S1_Icp_LRG401_STD_0_1_0710_v1.csv')
results.tail(20)

# %%
###############Crop-Official Test
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

test_datagen_crop = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

testing_set_crop = test_datagen_crop.flow_from_directory('test_2019',
                                                 target_size = (501, 501),
                                                 batch_size = 2,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="training"
                                              )
#customized generator
test_crops = crop_generator(testing_set_crop, 401)

step_size_test_crop = ceil(testing_set_crop.n/testing_set_crop.batch_size)

tta_steps = 2
# predictions = []

# import tensorflow as tf
# with tf.device('/gpu:0'):
for i in range(tta_steps):
    print(i)
    testing_set_crop.reset()
    if NUM_GPU != 1:
        preds=mul_model.predict_generator(test_crops, 
                                           steps = step_size_test_crop,
                                           max_queue_size=16,
#                                                use_multiprocessing=True,
                                           workers=1,
                                           verbose=1)    
    else:
        preds=model.predict_generator(test_crops, 
                                           steps = step_size_test_crop,
                                           max_queue_size=16,
#                                                use_multiprocessing=True,
                                           workers=1,
                                           verbose=1)           
    predictions.append(preds)

mean_pred = np.mean(predictions, axis=0)

predicted_class_indices_mean=np.argmax(mean_pred,axis=1)
labels = (training_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=test_set1.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Nat_Rdn_S1_Icp_LRG401_STD_0_1_0710_v2.csv')
results.tail(20)

# %%
########## Adding 15 more ##########
#Crop-Official Test
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

test_datagen_crop = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

testing_set_crop = test_datagen_crop.flow_from_directory('test_2019',
                                                 target_size = (501, 501),
                                                 batch_size = 1,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="training"
                                              )
#customized generator
test_crops = crop_generator(testing_set_crop, 401)

step_size_test_crop = ceil(testing_set_crop.n/testing_set_crop.batch_size)

tta_steps = 15
# predictions = []

# import tensorflow as tf
# with tf.device('/gpu:0'):
for i in range(tta_steps):
    print(i)
    testing_set_crop.reset()
    preds=model.predict_generator(test_crops, 
                                           steps = step_size_test_crop,
                                           max_queue_size=16,
#                                                use_multiprocessing=True,
                                           workers=1,
                                           verbose=1)    
    predictions.append(preds)

mean_pred = np.mean(predictions, axis=0)

predicted_class_indices_mean=np.argmax(mean_pred,axis=1)
labels = (training_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=test_set1.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Nat_Rdn_S1_Icp_LRG401_STD_0_1_v4.csv')
results.tail(20)

# %%
saved_modeljson = os.path.join('Nat', 'Nat_Rdn_S1_Icp_LRG421_Adv_0_1_L1_Bkp.json')
saved_modelweights = os.path.join('Nat', 'Nat_Rdn_S1_Icp_LRG421_Adv_0_1_L1_Bkp.h5')

# serialize model to JSON
model_json = mul_model.to_json()
with open(saved_modeljson, "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model_json.save_weights(saved_modelweights)
print("Saved model to disk")
  
# # load json and create model
# json_file = open('model.json', 'r')
# loaded_model_json = json_file.read()
# json_file.close()
# loaded_model = model_from_json(loaded_model_json)
# # load weights into new model
# loaded_model.load_weights("model.h5")
# print("Loaded model from disk")

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.applications.mobilenet import preprocess_input

import time, os
from math import ceil

NUM_GPU = 1
batch_size = NUM_GPU * 16

savedfilename = os.path.join('Nat', 'Nat_Rdn_S1_Icp_LRG421_Adv_0_1_L1.hdf5')

print('Loading pretrained weights')
model.load_weights(savedfilename)

model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

# %%
num_samples = len(predictions[0])
pred_mean = [0]*num_samples

####
# find max prediction/index
# select top-17
# mean of 17

for tx2 in range(num_samples):
    ars_max = []
#     print('=======&%d&=======' %tx2)
    for idx in range(len(predictions)):   
        ars_max.append(numpy.amax(predictions[idx][tx2]))
        ars_max_a = numpy.array(ars_max)
        ars_idx = ars_max_a.argsort()[-17:][::-1]
        
    pred_mean[tx2] = 0                   
    for ind in range(len(ars_idx)):
        pred_mean[tx2] = pred_mean[tx2] + predictions[ars_idx[ind]][tx2]
        
    pred_mean[tx2] = pred_mean[tx2]/len(ars_idx) 

#top-17out of 30
predicted_class_indices_mean=np.argmax(pred_mean,axis=1)
labels = (training_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=test_set1.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Nat_Rdn_S1_Icp_LRG401_STD_0_1_v5.csv')
results.tail(20)

# %%
print('Loading pretrained weights')
model.load_weights(savedfilename)

loss, acc = model.evaluate_generator(valid_set, steps=step_size_valid)
print('test loss = %f, accuracy: %f' %(loss, acc))

# %%
model.save_weights(os.path.join('Nat', '2_Set1_MobileNet_224x224_Global_dense4096x2_E2ETrainingV2.hdf5'))

# %%
# print('Loading pretrained weights')
# model.load_weights(savedfilename)

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.71, verbose=1)

epochs = 10
import tensorflow as tf
with tf.device('/gpu:0'):
    result = model.fit_generator(training_set,
                              steps_per_epoch = step_size_train,
                              epochs = epochs,
                              validation_data = valid_set,
                              validation_steps = step_size_valid,
                              shuffle=True,
                              max_queue_size=16,
#                               use_multiprocessing=True,
                              workers=8,                             
                              verbose=1,
                              callbacks=[tb, csv_logger, checkpointer,earlystopping],
                             )

# %%
# print('Loading pretrained weights')
# model.load_weights(savedfilename)

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.65, verbose=1)

epochs = 40
import tensorflow as tf
with tf.device('/gpu:0'):
    result = model.fit_generator(training_set,
                              steps_per_epoch = step_size_train,
                              epochs = epochs,
                              validation_data = valid_set,
                              validation_steps = step_size_valid,
                              shuffle=True,
                              max_queue_size=16,
#                               use_multiprocessing=True,
                              workers=8,                             
                              verbose=2,
                              callbacks=[tb, csv_logger, checkpointer,earlystopping],
                             )

# %%
# Visualize training history
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy

# list all data in history
# history = result.history
#print(history.history.keys())
# summarize history for accuracy
plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Visualize training history
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy

# list all data in history
# history = result.history
#print(history.history.keys())
# summarize history for accuracy
plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
mkdir Nat

# %%
rm Nat/2_1_Set1_MobileNet_224x224_Global_dense4096x2_E2ETrainingV2.hdf5

# %%
ls -l

# %% [markdown]
# %rm -r train_edited
# %rm -r valid_edited
# %rm -r train_val2019

# %%
rm -r train_edited

# %%
rm -r valid_edited

# %%
rm -r train_val2019
