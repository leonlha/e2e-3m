# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 8524759708388550080
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 10977044071
# locality {
#   bus_id: 1
# }
# incarnation: 16708275092465592086
# physical_device_desc: "device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1"
# , name: "/device:GPU:1"
# device_type: "GPU"
# memory_limit: 10977044071
# locality {
#   bus_id: 1
# }
# incarnation: 13382505377273989821
# physical_device_desc: "device: 1, name: GeForce GTX 1080 Ti, pci bus id: 0000:03:00.0, compute capability: 6.1"
# ]

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0,1"

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
# !pip3 install kaggle

# %%
import os
os.environ['KAGGLE_USERNAME'] = "paulnh" # username from the json file 
os.environ['KAGGLE_KEY'] = "9e06528f4d63aefff0897e8d0b289fe7" # key from the json file
# !kaggle competitions download -c inaturalist-2019-fgvc6 # api copied from kaggle

# %%
ls -l

# %%
# !tar -zxf train_val2019.tar.gz

# %%
# !tar -zxf test2019.tar.gz

# %%
mkdir test_2019

# %%
mv test2019 test_2019/0

# %% [raw]
# r

# %%
rm train_val2019.tar.gz

# %%
cd test2019

# %%
ls -l|head -20

# %%
cd ..

# %%
# ####=======================
# #### Move back images
# #####

# import csv
# import glob
# import os
# import shutil
# import random

# #move color files  
# #divide 2-2 randomly

# # # get parts of image's path
# def get_image_parts(image_path):
#     """Given a full path to an image, return its parts."""
#     parts = image_path.split(os.path.sep)
#     #print(parts)
#     filename = parts[2]
#     filename_no_ext = filename.split('.')[0]
#     classname = parts[1]
# #     sub_folder = parts[1]
#     train_or_test = parts[0]

#     return train_or_test, classname, filename_no_ext, filename

# move_folders = ['valid_edited']
# dest_folder = 'train_edited'
# data_file = []

# # look for all images in sub-folders
# for folder in move_folders:
#     class_folders = glob.glob(os.path.join(folder, '*'))
#     print('folder %s' %class_folders)
    
# #     for sub_folder in class_folders:
# #         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
# #         print('sub folder %s' %sub_class_folders)
        
#     for iid_class in class_folders:
#         class_files = glob.glob(os.path.join(iid_class, '*.jpg'))

# #             print('moving %d files' %(len(class_files)))

#         #Determize Set# (No Suffle)
#         set = len(class_files)# all images

#         inner = range(0*set, 1*set)

#         print('moving %d files' %(len(inner)))

# #             random_list = random.sample(range(len(class_files)), int(len(class_files))) #All dataset
# #             for idx in range(len(random_list)):

#         for idx in range(len(inner)):
#             src = class_files[inner[idx]]

#             #record paths
# #                 data_file.append(src)

#             train_or_test, classname, _, filename = get_image_parts(src)
#             dst = os.path.join(dest_folder, classname, filename) #

#             # image directory
#             img_directory = os.path.join(dest_folder, classname)

#             # create folder if not existed
#             if not os.path.exists(img_directory):
#                 os.makedirs(img_directory)

#             #moving file
#             shutil.move(src, dst)
# #                 shutil.copy(src, dst)

# # #save recorded paths
# # with open('data_file.csv', 'w') as fout:
# #     writer = csv.writer(fout)
# #     writer.writerows(data_file)

# %%
# ####=======================
# #### Move back images
# #####

# import csv
# import glob
# import os
# import shutil
# import random

# #move color files  
# #divide 2-2 randomly

# # # get parts of image's path
# def get_image_parts(image_path):
#     """Given a full path to an image, return its parts."""
#     parts = image_path.split(os.path.sep)
#     #print(parts)
#     filename = parts[2]
#     filename_no_ext = filename.split('.')[0]
#     classname = parts[1]
# #     sub_folder = parts[1]
#     train_or_test = parts[0]

#     return train_or_test, classname, filename_no_ext, filename

# move_folders = ['train_rnd']
# dest_folder = 'train_edited'
# data_file = []

# # look for all images in sub-folders
# for folder in move_folders:
#     class_folders = glob.glob(os.path.join(folder, '*'))
#     print('folder %s' %class_folders)
    
# #     for sub_folder in class_folders:
# #         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
# #         print('sub folder %s' %sub_class_folders)
        
#     for iid_class in class_folders:
#         class_files = glob.glob(os.path.join(iid_class, '*.jpg'))

# #             print('moving %d files' %(len(class_files)))

#         #Determize Set# (No Suffle)
#         set = len(class_files)# all images

#         inner = range(0*set, 1*set)

#         print('moving %d files' %(len(inner)))

# #             random_list = random.sample(range(len(class_files)), int(len(class_files))) #All dataset
# #             for idx in range(len(random_list)):

#         for idx in range(len(inner)):
#             src = class_files[inner[idx]]

#             #record paths
# #                 data_file.append(src)

#             train_or_test, classname, _, filename = get_image_parts(src)
#             dst = os.path.join(dest_folder, classname, filename) #

#             # image directory
#             img_directory = os.path.join(dest_folder, classname)

#             # create folder if not existed
#             if not os.path.exists(img_directory):
#                 os.makedirs(img_directory)

#             #moving file
#             shutil.move(src, dst)
# #                 shutil.copy(src, dst)

# # #save recorded paths
# # with open('data_file.csv', 'w') as fout:
# #     writer = csv.writer(fout)
# #     writer.writerows(data_file)

# %%
# ####=======================
# import glob
# import os
# import shutil
# import random

# #move color files  
# #divide 2-2 randomly

# # # get parts of image's path
# def get_image_parts(image_path):
#     """Given a full path to an image, return its parts."""
#     parts = image_path.split(os.path.sep)
#     #print(parts)
#     filename = parts[3]
#     filename_no_ext = filename.split('.')[0]
#     classname = parts[2]
#     sub_folder = parts[1]
#     train_or_test = parts[0]

#     return train_or_test, sub_folder, classname, filename_no_ext, filename

# move_folders = ['train_val2019']

# # look for all images in sub-folders
# for folder in move_folders:
#     class_folders = glob.glob(os.path.join(folder, '*'))
#     print('folder %s' %class_folders)
    
#     for sub_folder in class_folders:
#         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
#         print('sub folder %s' %sub_class_folders)
        
#         for iid_class in sub_class_folders:
#             class_files = glob.glob(os.path.join(iid_class, '*.jpg'))

#             print('moving %d files' %(len(class_files)))

# #             random_list = random.sample(range(len(class_files)), int(len(class_files))) #All dataset
#             random_list = range(0,len(class_files)) #All dataset
    
#             for idx in range(len(random_list)):
#                 src = class_files[random_list[idx]]

#                 train_or_test, sub_folder, classname, _, filename = get_image_parts(src)
#                 dst = os.path.join('train_edited', sub_folder+'_'+classname, train_or_test+'_'+ filename)
                
#                 # image directory
#                 img_directory = os.path.join('train_edited', sub_folder+'_'+classname)

#                 # create folder if not existed
#                 if not os.path.exists(img_directory):
#                     os.makedirs(img_directory)

#                 #moving file
#                 shutil.move(src, dst)

# %%
# ####=======================
# import glob
# import os
# import shutil
# import random

# #move color files  
# #divide 2-2 randomly

# # # get parts of image's path
# def get_image_parts(image_path):
#     """Given a full path to an image, return its parts."""
#     parts = image_path.split(os.path.sep)
#     #print(parts)
#     filename = parts[2]
#     filename_no_ext = filename.split('.')[0]
#     classname = parts[1]
# #     sub_folder = parts[1]
#     train_or_test = parts[0]

#     return train_or_test, classname, filename_no_ext, filename

# move_folders = ['train_edited']
# dest_folder = 'valid_edited'
# data_file = []

# # look for all images in sub-folders
# for folder in move_folders:
#     class_folders = glob.glob(os.path.join(folder, '*'))
#     print('folder %s' %class_folders)
    
# #     for sub_folder in class_folders:
# #         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
# #         print('sub folder %s' %sub_class_folders)
        
#     for iid_class in class_folders:
#         class_files = glob.glob(os.path.join(iid_class, '*.jpg'))

# #             print('moving %d files' %(len(class_files)))

#         #Determize Set# (No Suffle)
#         set = len(class_files)//5

#         inner = range(2*set, 3*set) #Set 3

#         print('moving %d files' %(len(inner)))

# #             random_list = random.sample(range(len(class_files)), int(len(class_files))) #All dataset
# #             for idx in range(len(random_list)):

#         for idx in range(len(inner)):
#             src = class_files[inner[idx]]

#             #record paths
# #                 data_file.append(src)

#             train_or_test, classname, _, filename = get_image_parts(src)
#             dst = os.path.join(dest_folder, classname, train_or_test+'_'+ filename)

#             # image directory
#             img_directory = os.path.join(dest_folder, classname)

#             # create folder if not existed
#             if not os.path.exists(img_directory):
#                 os.makedirs(img_directory)

#             #moving file
#             shutil.move(src, dst)
# #                 shutil.copy(src, dst)

# # #save recorded paths
# # with open('data_file.csv', 'w') as fout:
# #     writer = csv.writer(fout)
# #     writer.writerows(data_file)

# %%
# ####=======================
# #### Move files back

# #####======================
# import glob
# import os
# import shutil
# import random

# #move color files  
# #divide 2-2 randomly

# # # get parts of image's path
# def get_image_parts(image_path):
#     """Given a full path to an image, return its parts."""
#     parts = image_path.split(os.path.sep)
#     #print(parts)
#     filename = parts[2]
#     filename_no_ext = filename.split('.')[0]
#     classname = parts[1]
# #     sub_folder = parts[1]
#     train_or_test = parts[0]

#     return train_or_test, classname, filename_no_ext, filename

# move_folders = ['valid_edited']
# dest_folders = 'train_edited'

# data_file = []

# # look for all images in sub-folders
# for folder in move_folders:
#     class_folders = glob.glob(os.path.join(folder, '*'))
#     print('folder %s' %class_folders)
    
# #     for sub_folder in class_folders:
# #         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
# #         print('sub folder %s' %sub_class_folders)
        
#     for iid_class in class_folders:
#         class_files = glob.glob(os.path.join(iid_class, '*.jpg'))

# #             print('moving %d files' %(len(class_files)))

#         #Move all files back
#         set = len(class_files)

#         inner = range(0, set) 

#         print('moving %d files' %(len(inner)))

# #             random_list = random.sample(range(len(class_files)), int(len(class_files))) #All dataset
# #             for idx in range(len(random_list)):

#         for idx in range(len(inner)):
#             src = class_files[inner[idx]]

#             #record paths
# #                 data_file.append(src)

#             train_or_test, classname, _, filename = get_image_parts(src)
#             dst = os.path.join(dest_folders, classname, train_or_test+'_'+ filename)

#             # image directory
#             img_directory = os.path.join(dest_folders, classname)

#             # create folder if not existed
#             if not os.path.exists(img_directory):
#                 os.makedirs(img_directory)

#             #moving file
#             shutil.move(src, dst)
# #                 shutil.copy(src, dst)

# # #save recorded paths
# # with open('data_file.csv', 'w') as fout:
# #     writer = csv.writer(fout)
# #     writer.writerows(data_file)

# %%
mkdir train_rnd

# %%
####=======================


######
import csv
import glob
import os
import shutil
import random

#move color files  

# # get parts of image's path
def get_image_parts(image_path):
    """Given a full path to an image, return its parts."""
    parts = image_path.split(os.path.sep)
    #print(parts)
    filename = parts[2]
    filename_no_ext = filename.split('.')[0]
    classname = parts[1]
#     sub_folder = parts[1]
    train_or_test = parts[0]

    return train_or_test, classname, filename_no_ext, filename

move_folders = ['train_edited']
dest_folder = 'train_rnd'

data_file =[]

# look for all images in sub-folders
for folder in move_folders:
    class_folders = glob.glob(os.path.join(folder, '*'))
#     print('folder %s' %class_folders)
    
#     for sub_folder in class_folders:
#         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
#         print('sub folder %s' %sub_class_folders)
        
    for iid_class in class_folders:
        class_files = glob.glob(os.path.join(iid_class, '*.jpg'))

        print('moving %d files' %(len(class_files)))

#             random_list = random.sample(range(len(class_files)), int(len(class_files))) #All dataset
        random_list = range(0,len(class_files)) #All dataset

        #suffle list
        suffle_list = random.sample(range(len(class_files)), int(len(class_files)))

#         print(len(random_list))
        for idx in range(len(random_list)):
            src = class_files[random_list[idx]]

            train_or_test, classname, _, filename = get_image_parts(src)
            dst = os.path.join(dest_folder, classname, '{:07d}'.format(suffle_list[idx])+'_'+filename)

            # image directory
            img_directory = os.path.join(dest_folder, classname)

            # create folder if not existed
            if not os.path.exists(img_directory):
                os.makedirs(img_directory)

            # moving file
            shutil.move(src, dst) 

            #recording
            data_file.append([src, dst])

with open('nat_data_file.csv', 'w') as fout:
    writer = csv.writer(fout)
    writer.writerows(data_file)
# Out:
# moving 56 files
# moving 503 files
# moving 237 files
# moving 278 files
# moving 166 files
# moving 75 files
# moving 114 files
# moving 95 files
# moving 113 files
# moving 198 files
# moving 503 files
# moving 70 files
# moving 503 files
# moving 121 files
# moving 318 files
# moving 75 files
# moving 207 files
# moving 503 files
# moving 53 files
# moving 94 files
# moving 448 files
# moving 503 files
# moving 503 files
# moving 401 files
# moving 362 files
# moving 210 files
# moving 503 files
# moving 103 files
# moving 503 files
# moving 155 files
# moving 503 files
# moving 144 files
# moving 503 files
# moving 317 files
# moving 89 files
# moving 170 files
# moving 503 files
# moving 503 files
# moving 503 files
# moving 122 files
# moving 503 files
# moving 503 files
# moving 126 files
# moving 503 files
# moving 503 files
# moving 205 files
# moving 503 files
# moving 276 files
# moving 503 files
# moving 314 files
# moving 114 files
# moving 138 files
# moving 91 files
# moving 193 files
# moving 162 files
# moving 113 files
# moving 274 files
# moving 90 files
# moving 120 files
# moving 412 files
# moving 223 files
# moving 94 files
# moving 503 files
# moving 174 files
# moving 122 files
# moving 285 files
# moving 503 files
# moving 113 files
# moving 282 files
# moving 213 files
# moving 289 files
# moving 82 files
# moving 91 files
# moving 102 files
# moving 59 files
# moving 139 files
# moving 93 files
# moving 94 files
# moving 503 files
# moving 327 files
# moving 207 files
# moving 503 files
# moving 95 files
# moving 108 files
# moving 75 files
# moving 58 files
# moving 219 files
# moving 65 files
# moving 312 files
# moving 169 files
# moving 105 files
# moving 77 files
# moving 268 files
# moving 318 files
# moving 166 files
# moving 232 files
# moving 64 files
# moving 287 files
# moving 88 files
# moving 339 files
# moving 138 files
# moving 87 files
# moving 241 files
# moving 411 files
# moving 503 files
# moving 111 files
# moving 503 files
# moving 503 files
# moving 116 files
# moving 379 files
# moving 90 files
# moving 42 files
# moving 426 files
# moving 61 files
# moving 64 files
# moving 220 files
# moving 66 files
# moving 124 files
# moving 97 files
# moving 503 files
# moving 503 files
# moving 503 files
# moving 120 files
# moving 50 files
# moving 144 files
# moving 56 files
# moving 152 files
# moving 98 files
# moving 503 files
# moving 97 files
# moving 61 files
# moving 503 files
# moving 116 files
# moving 304 files
# moving 98 files
# moving 139 files
# moving 48 files
# moving 294 files
# moving 147 files
# moving 395 files
# moving 128 files
# moving 264 files
# moving 166 files
# moving 503 files
# moving 163 files
# moving 141 files
# moving 165 files
# moving 89 files
# moving 184 files
# moving 503 files
# moving 61 files
# moving 95 files
# moving 242 files
# moving 49 files
# moving 216 files
# moving 195 files
# moving 503 files
# moving 114 files
# moving 54 files
# moving 146 files
# moving 74 files
# moving 163 files
# moving 151 files
# moving 492 files
# moving 122 files
# moving 289 files
# moving 503 files
# moving 168 files
# moving 166 files
# moving 503 files
# moving 503 files
# moving 114 files
# moving 118 files
# moving 108 files
# moving 73 files
# moving 144 files
# moving 162 files
# moving 313 files
# moving 166 files
# moving 95 files
# moving 155 files
# moving 503 files
# moving 128 files
# moving 282 files
# moving 257 files
# moving 106 files
# moving 373 files
# moving 185 files
# moving 503 files
# moving 98 files
# moving 258 files
# moving 68 files
# moving 503 files
# moving 215 files
# moving 103 files
# moving 149 files
# moving 503 files
# moving 118 files
# moving 142 files
# moving 503 files
# moving 503 files
# moving 83 files
# moving 503 files
# moving 171 files
# moving 456 files
# moving 398 files
# moving 139 files
# moving 48 files
# moving 362 files
# moving 503 files
# moving 257 files
# moving 503 files
# moving 355 files
# moving 55 files
# moving 503 files
# moving 503 files
# moving 72 files
# moving 427 files
# moving 243 files
# moving 375 files
# moving 79 files
# moving 503 files
# moving 296 files
# moving 70 files
# moving 288 files
# moving 277 files
# moving 271 files
# moving 114 files
# moving 392 files
# moving 71 files
# moving 472 files
# moving 276 files
# moving 63 files
# moving 77 files
# moving 290 files
# moving 91 files
# moving 503 files
# moving 97 files
# moving 503 files
# moving 140 files
# moving 37 files
# moving 322 files
# moving 147 files
# moving 150 files
# moving 68 files
# moving 95 files
# moving 212 files
# moving 104 files
# moving 363 files
# moving 503 files
# moving 273 files
# moving 503 files
# moving 503 files
# moving 142 files
# moving 321 files
# moving 503 files
# moving 95 files
# moving 219 files
# moving 62 files
# moving 31 files
# moving 165 files
# moving 33 files
# moving 146 files
# moving 112 files
# moving 101 files
# moving 503 files
# moving 263 files
# moving 503 files
# moving 503 files
# moving 503 files
# moving 133 files
# moving 132 files
# moving 503 files
# moving 208 files
# moving 503 files
# moving 280 files
# moving 361 files
# moving 113 files
# moving 503 files
# moving 503 files
# moving 337 files
# moving 503 files
# moving 503 files
# moving 215 files
# moving 503 files
# moving 503 files
# moving 503 files
# moving 503 files
# moving 122 files
# moving 459 files
# moving 377 files
# moving 305 files
# moving 298 files
# moving 108 files
# moving 29 files
# moving 503 files
# moving 152 files
# moving 503 files
# moving 503 files
# moving 174 files
# moving 503 files
# moving 401 files
# moving 129 files
# moving 360 files
# moving 128 files
# moving 116 files
# moving 167 files
# moving 91 files
# moving 219 files
# moving 503 files
# moving 63 files
# moving 503 files
# moving 503 files
# moving 69 files
# moving 190 files
# moving 333 files
# moving 72 files
# moving 401 files
# moving 171 files
# moving 503 files
# moving 437 files
# moving 503 files
# moving 503 files
# moving 105 files
# moving 503 files
# moving 171 files
# moving 482 files
# moving 330 files
# moving 503 files
# moving 154 files
# moving 503 files
# moving 130 files
# moving 90 files
# moving 503 files
# moving 152 files
# moving 117 files
# moving 503 files
# moving 99 files
# moving 51 files
# moving 128 files
# moving 85 files
# moving 503 files
# moving 503 files
# moving 454 files
# moving 503 files
# moving 503 files
# moving 503 files
# moving 395 files
# moving 503 files
# moving 503 files
# moving 91 files
# moving 491 files
# moving 129 files
# moving 503 files
# moving 337 files
# moving 147 files
# moving 266 files
# moving 201 files
# moving 503 files
# moving 170 files
# moving 503 files
# moving 168 files
# moving 267 files
# moving 219 files
# moving 83 files
# moving 190 files
# moving 503 files
# moving 503 files
# moving 408 files
# moving 190 files
# moving 65 files
# moving 137 files
# moving 308 files
# moving 127 files
# moving 130 files
# moving 56 files
# moving 94 files
# moving 377 files
# moving 67 files
# moving 221 files
# moving 259 files
# moving 503 files
# moving 503 files
# moving 372 files
# moving 72 files
# moving 208 files
# moving 81 files
# moving 503 files
# moving 229 files
# moving 116 files
# moving 151 files
# moving 349 files
# moving 503 files
# moving 156 files
# moving 132 files
# moving 246 files
# moving 503 files
# moving 79 files
# moving 503 files
# moving 128 files
# moving 298 files
# moving 90 files
# moving 73 files
# moving 418 files
# moving 51 files
# moving 243 files
# moving 382 files
# moving 105 files
# moving 352 files
# moving 272 files
# moving 272 files
# moving 503 files
# moving 126 files
# moving 503 files
# moving 343 files
# moving 503 files
# moving 503 files
# moving 105 files
# moving 170 files
# moving 82 files
# moving 503 files
# moving 59 files
# moving 171 files
# moving 207 files
# moving 248 files
# moving 503 files
# moving 222 files
# moving 503 files
# moving 503 files
# moving 61 files
# moving 320 files
# moving 503 files
# moving 459 files
# moving 101 files
# moving 59 files
# moving 65 files
# moving 265 files
# moving 112 files
# moving 180 files
# moving 219 files
# moving 168 files
# moving 503 files
# moving 363 files
# moving 503 files
# moving 205 files
# moving 461 files
# moving 503 files
# moving 503 files
# moving 503 files
# moving 205 files
# moving 143 files
# moving 151 files
# moving 207 files
# moving 115 files
# moving 368 files
# moving 86 files
# moving 160 files
# moving 280 files
# moving 236 files
# moving 503 files
# moving 503 files
# moving 210 files
# moving 160 files
# moving 205 files
# moving 19 files
# moving 326 files
# moving 282 files
# moving 503 files
# moving 120 files
# moving 452 files
# moving 290 files
# moving 118 files
# moving 109 files
# moving 219 files
# moving 99 files
# moving 503 files
# moving 503 files
# moving 503 files
# moving 265 files
# moving 161 files
# moving 299 files
# moving 503 files
# moving 149 files
# moving 241 files
# moving 169 files
# moving 503 files
# moving 442 files
# moving 76 files
# moving 503 files
# moving 363 files
# moving 66 files
# moving 503 files
# moving 241 files
# moving 503 files
# moving 139 files
# moving 198 files
# moving 244 files
# moving 183 files
# moving 162 files
# moving 232 files
# moving 503 files
# moving 140 files
# moving 122 files
# moving 404 files
# moving 503 files
# moving 503 files
# moving 429 files
# moving 342 files
# moving 414 files
# moving 394 files
# moving 340 files
# moving 107 files
# moving 84 files
# moving 503 files
# moving 224 files
# moving 503 files
# moving 340 files
# moving 264 files
# moving 503 files
# moving 108 files
# moving 395 files
# moving 503 files
# moving 503 files
# moving 180 files
# moving 67 files
# moving 337 files
# moving 46 files
# moving 318 files
# moving 88 files
# moving 246 files
# moving 71 files
# moving 185 files
# moving 139 files
# moving 154 files
# moving 252 files
# moving 503 files
# moving 67 files
# moving 371 files
# moving 308 files
# moving 201 files
# moving 27 files
# moving 251 files
# moving 123 files
# moving 198 files
# moving 503 files
# moving 359 files
# moving 187 files
# moving 59 files
# moving 223 files
# moving 503 files
# moving 278 files
# moving 86 files
# moving 271 files
# moving 293 files
# moving 169 files
# moving 274 files
# moving 438 files
# moving 503 files
# moving 503 files
# moving 503 files
# moving 503 files
# moving 503 files
# moving 111 files
# moving 352 files
# moving 125 files
# moving 313 files
# moving 333 files
# moving 81 files
# moving 503 files
# moving 503 files
# moving 89 files
# moving 116 files
# moving 73 files
# moving 95 files
# moving 455 files
# moving 503 files
# moving 142 files
# moving 203 files
# moving 332 files
# moving 503 files
# moving 286 files
# moving 150 files
# moving 111 files
# moving 503 files
# moving 91 files
# moving 503 files
# moving 80 files
# moving 151 files
# moving 122 files
# moving 503 files
# moving 58 files
# moving 174 files
# moving 69 files
# moving 503 files
# moving 418 files
# moving 76 files
# moving 436 files
# moving 74 files
# moving 194 files
# moving 188 files
# moving 121 files
# moving 189 files
# moving 471 files
# moving 494 files
# moving 503 files
# moving 392 files
# moving 80 files
# moving 99 files
# moving 228 files
# moving 107 files
# moving 121 files
# moving 76 files
# moving 30 files
# moving 477 files
# moving 503 files
# moving 235 files
# moving 163 files
# moving 252 files
# moving 503 files
# moving 64 files
# moving 503 files
# moving 117 files
# moving 503 files
# moving 132 files
# moving 66 files
# moving 503 files
# moving 129 files
# moving 143 files
# moving 57 files
# moving 178 files
# moving 503 files
# moving 99 files
# moving 306 files
# moving 503 files
# moving 189 files
# moving 157 files
# moving 99 files
# moving 88 files
# moving 208 files
# moving 98 files
# moving 287 files
# moving 253 files
# moving 76 files
# moving 156 files
# moving 395 files
# moving 207 files
# moving 496 files
# moving 205 files
# moving 282 files
# moving 158 files
# moving 503 files
# moving 113 files
# moving 147 files
# moving 503 files
# moving 183 files
# moving 193 files
# moving 503 files
# moving 503 files
# moving 503 files
# moving 503 files
# moving 78 files
# moving 503 files
# moving 279 files
# moving 59 files
# moving 102 files
# moving 196 files
# moving 96 files
# moving 401 files
# moving 74 files
# moving 363 files
# moving 318 files
# moving 503 files
# moving 503 files
# moving 93 files
# moving 503 files
# moving 503 files
# moving 503 files
# moving 165 files
# moving 450 files
# moving 503 files
# moving 353 files
# moving 25 files
# moving 181 files
# moving 382 files
# moving 208 files
# moving 209 files
# moving 87 files
# moving 92 files
# moving 221 files
# moving 462 files
# moving 124 files
# moving 431 files
# moving 74 files
# moving 137 files
# moving 225 files
# moving 112 files
# moving 86 files
# moving 395 files
# moving 503 files
# moving 57 files
# moving 503 files
# moving 503 files
# moving 215 files
# moving 43 files
# moving 38 files
# moving 466 files
# moving 146 files
# moving 503 files
# moving 86 files
# moving 477 files
# moving 503 files
# moving 503 files
# moving 451 files
# moving 503 files
# moving 317 files
# moving 503 files
# moving 238 files
# moving 183 files
# moving 212 files
# moving 217 files
# moving 381 files
# moving 503 files
# moving 185 files
# moving 470 files
# moving 323 files
# moving 396 files
# moving 146 files
# moving 503 files
# moving 503 files
# moving 244 files
# moving 91 files
# moving 503 files
# moving 137 files
# moving 70 files
# moving 155 files
# moving 154 files
# moving 113 files
# moving 305 files
# moving 45 files
# moving 390 files
# moving 347 files
# moving 503 files
# moving 186 files
# moving 503 files
# moving 66 files
# moving 503 files
# moving 120 files
# moving 104 files
# moving 228 files
# moving 503 files
# moving 503 files
# moving 503 files
# moving 503 files
# moving 274 files
# moving 42 files
# moving 139 files
# moving 189 files
# moving 87 files
# moving 98 files
# moving 84 files
# moving 105 files
# moving 132 files
# moving 200 files
# moving 67 files
# moving 503 files
# moving 225 files
# moving 503 files
# moving 290 files
# moving 81 files
# moving 248 files
# moving 84 files
# moving 194 files
# moving 503 files
# moving 433 files
# moving 91 files
# moving 503 files
# moving 170 files
# moving 235 files
# moving 174 files
# moving 123 files
# moving 77 files
# moving 503 files
# moving 503 files
# moving 224 files
# moving 117 files
# moving 49 files
# moving 503 files
# moving 137 files
# moving 276 files
# moving 163 files
# moving 234 files
# moving 503 files
# moving 158 files
# moving 407 files
# moving 503 files
# moving 136 files
# moving 40 files
# moving 180 files
# moving 134 files
# moving 503 files
# moving 440 files
# moving 221 files
# moving 51 files
# moving 295 files
# moving 101 files
# moving 426 files
# moving 99 files
# moving 503 files
# moving 100 files
# moving 184 files
# moving 40 files
# moving 90 files
# moving 77 files
# moving 338 files
# moving 141 files
# moving 155 files
# moving 214 files
# moving 61 files
# moving 281 files
# moving 35 files
# moving 110 files
# moving 166 files
# moving 220 files
# moving 503 files
# moving 37 files
# moving 104 files
# moving 181 files
# moving 113 files
# moving 55 files
# moving 45 files
# moving 131 files
# moving 503 files
# moving 503 files
# moving 385 files
# moving 161 files
# moving 503 files
# moving 113 files
# moving 123 files
# moving 61 files
# moving 112 files
# moving 352 files
# moving 503 files
# moving 96 files
# moving 503 files
# moving 119 files
# moving 75 files
# moving 503 files
# moving 238 files
# moving 270 files
# moving 149 files
# moving 222 files
# moving 410 files
# moving 169 files
# moving 41 files
# moving 503 files
# moving 140 files
# moving 208 files
# moving 503 files
# moving 321 files
# moving 443 files
# moving 237 files
# moving 503 files
# moving 351 files
# moving 183 files
# moving 503 files
# moving 100 files
# moving 432 files
# moving 503 files
# moving 70 files
# moving 150 files
# moving 299 files
# moving 503 files
# moving 118 files
# moving 70 files
# moving 503 files
# moving 42 files
# moving 102 files
# moving 75 files
# moving 503 files
# moving 211 files
# moving 50 files
# moving 83 files
# moving 437 files
# moving 42 files
# moving 93 files
# moving 55 files
# moving 144 files
# moving 503 files
# moving 137 files
# moving 71 files
# moving 155 files
# moving 160 files
# moving 171 files
# moving 127 files
# moving 97 files
# moving 202 files
# moving 503 files
# moving 503 files
# moving 59 files
# moving 503 files
# moving 125 files
# moving 503 files
# moving 124 files
# moving 390 files
# moving 50 files
# moving 221 files
# moving 83 files
# moving 503 files
# moving 503 files
# moving 56 files
# moving 210 files
# moving 167 files
# moving 53 files
# moving 135 files
# moving 201 files
# moving 372 files
# moving 98 files
# moving 503 files
# moving 127 files
# moving 173 files
# moving 245 files
# moving 100 files
# moving 211 files
# moving 65 files
# moving 221 files
# moving 427 files
# moving 110 files
# moving 503 files
# moving 251 files
# moving 112 files
# moving 163 files
# moving 64 files
# moving 493 files
# moving 108 files
# moving 373 files
# moving 503 files
# moving 262 files
# moving 279 files
# moving 88 files
# moving 95 files
# moving 84 files
# moving 501 files
# moving 112 files
# moving 86 files
# moving 503 files
# moving 176 files
# moving 109 files
# moving 503 files
# moving 503 files
# moving 150 files
# moving 326 files
# moving 503 files
# moving 503 files
# moving 503 files
# moving 68 files
# moving 503 files
# moving 503 files
# moving 129 files
# moving 220 files
# moving 128 files
# moving 503 files
# moving 102 files
# moving 493 files
# moving 503 files
# moving 363 files
# moving 207 files
# moving 503 files
# moving 245 files
# moving 120 files
# moving 279 files
# moving 288 files
# moving 158 files
# moving 497 files
# moving 129 files
# moving 126 files
# moving 503 files
# moving 503 files
# moving 319 files
# moving 159 files
# moving 503 files
# moving 190 files
# moving 120 files
# moving 197 files
# moving 235 files
# moving 26 files
# moving 260 files
# moving 254 files
# moving 503 files
# moving 343 files
# moving 63 files
# moving 376 files
# moving 287 files
# moving 156 files
# moving 287 files
# moving 366 files
# moving 210 files
# moving 89 files
# moving 503 files
# moving 113 files
# moving 438 files
# moving 79 files
# moving 183 files
# moving 164 files
# moving 391 files
# moving 125 files
# moving 115 files
# moving 115 files
# moving 226 files
# moving 106 files
# moving 503 files

# %%
mkdir valid_rnd

# %%
####=======================
import glob
import os
import shutil
import random

#move color files  
#divide 2-2 randomly

# # get parts of image's path
def get_image_parts(image_path):
    """Given a full path to an image, return its parts."""
    parts = image_path.split(os.path.sep)
    #print(parts)
    filename = parts[2]
    filename_no_ext = filename.split('.')[0]
    classname = parts[1]
#     sub_folder = parts[1]
    train_or_test = parts[0]

    return train_or_test, classname, filename_no_ext, filename

move_folders = ['train_rnd']
dest_folder = 'valid_rnd'
data_file = []

# look for all images in sub-folders
for folder in move_folders:
    class_folders = glob.glob(os.path.join(folder, '*'))
    print('folder %s' %class_folders)
    
#     for sub_folder in class_folders:
#         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
#         print('sub folder %s' %sub_class_folders)
        
    for iid_class in class_folders:
        class_files = glob.glob(os.path.join(iid_class, '*.jpg'))

#             print('moving %d files' %(len(class_files)))

        #Determize Set# (No Suffle)
        set = len(class_files)//5

        inner = range(2*set, 3*set) #Set 3

        print('moving %d files' %(len(inner)))

#             random_list = random.sample(range(len(class_files)), int(len(class_files))) #All dataset
#             for idx in range(len(random_list)):

        for idx in range(len(inner)):
            src = class_files[inner[idx]]

            #record paths
#                 data_file.append(src)

            train_or_test, classname, _, filename = get_image_parts(src)
            dst = os.path.join(dest_folder, classname, train_or_test+'_'+ filename)

            # image directory
            img_directory = os.path.join(dest_folder, classname)

            # create folder if not existed
            if not os.path.exists(img_directory):
                os.makedirs(img_directory)

            #moving file
            shutil.move(src, dst)
#                 shutil.copy(src, dst)

# #save recorded paths
# with open('data_file.csv', 'w') as fout:
#     writer = csv.writer(fout)
#     writer.writerows(data_file)
# Out:
# folder ['train_rnd/Plants_636', 'train_rnd/Birds_306', 'train_rnd/Plants_918', 'train_rnd/Reptiles_177', 'train_rnd/Plants_890', 'train_rnd/Plants_946', 'train_rnd/Insects_83', 'train_rnd/Plants_798', 'train_rnd/Plants_972', 'train_rnd/Plants_695', 'train_rnd/Plants_937', 'train_rnd/Insects_148', 'train_rnd/Reptiles_188', 'train_rnd/Plants_469', 'train_rnd/Plants_437', 'train_rnd/Plants_828', 'train_rnd/Plants_753', 'train_rnd/Plants_486', 'train_rnd/Plants_902', 'train_rnd/Insects_18', 'train_rnd/Plants_834', 'train_rnd/Birds_222', 'train_rnd/Insects_144', 'train_rnd/Insects_24', 'train_rnd/Plants_386', 'train_rnd/Amphibians_162', 'train_rnd/Plants_903', 'train_rnd/Insects_61', 'train_rnd/Plants_691', 'train_rnd/Plants_974', 'train_rnd/Birds_321', 'train_rnd/Birds_309', 'train_rnd/Plants_836', 'train_rnd/Insects_13', 'train_rnd/Plants_459', 'train_rnd/Plants_838', 'train_rnd/Plants_578', 'train_rnd/Plants_360', 'train_rnd/Insects_135', 'train_rnd/Plants_963', 'train_rnd/Plants_817', 'train_rnd/Birds_248', 'train_rnd/Amphibians_157', 'train_rnd/Plants_754', 'train_rnd/Plants_392', 'train_rnd/Plants_792', 'train_rnd/Plants_448', 'train_rnd/Plants_521', 'train_rnd/Plants_996', 'train_rnd/Birds_221', 'train_rnd/Plants_931', 'train_rnd/Plants_341', 'train_rnd/Plants_634', 'train_rnd/Plants_775', 'train_rnd/Plants_403', 'train_rnd/Plants_561', 'train_rnd/Insects_58', 'train_rnd/Plants_911', 'train_rnd/Insects_15', 'train_rnd/Insects_150', 'train_rnd/Insects_84', 'train_rnd/Plants_942', 'train_rnd/Amphibians_156', 'train_rnd/Birds_261', 'train_rnd/Plants_839', 'train_rnd/Plants_489', 'train_rnd/Birds_283', 'train_rnd/Plants_809', 'train_rnd/Plants_749', 'train_rnd/Plants_378', 'train_rnd/Plants_987', 'train_rnd/Plants_750', 'train_rnd/Plants_719', 'train_rnd/Plants_581', 'train_rnd/Insects_146', 'train_rnd/Plants_615', 'train_rnd/Plants_613', 'train_rnd/Plants_819', 'train_rnd/Plants_391', 'train_rnd/Plants_603', 'train_rnd/Reptiles_197', 'train_rnd/Reptiles_173', 'train_rnd/Plants_538', 'train_rnd/Plants_501', 'train_rnd/Plants_799', 'train_rnd/Plants_748', 'train_rnd/Birds_223', 'train_rnd/Plants_398', 'train_rnd/Plants_760', 'train_rnd/Plants_913', 'train_rnd/Plants_600', 'train_rnd/Plants_344', 'train_rnd/Plants_328', 'train_rnd/Plants_1005', 'train_rnd/Plants_1001', 'train_rnd/Birds_310', 'train_rnd/Plants_632', 'train_rnd/Plants_508', 'train_rnd/Birds_215', 'train_rnd/Plants_878', 'train_rnd/Birds_317', 'train_rnd/Plants_727', 'train_rnd/Birds_300', 'train_rnd/Insects_34', 'train_rnd/Plants_393', 'train_rnd/Plants_791', 'train_rnd/Plants_811', 'train_rnd/Plants_475', 'train_rnd/Fungi_3', 'train_rnd/Birds_250', 'train_rnd/Plants_907', 'train_rnd/Plants_833', 'train_rnd/Birds_325', 'train_rnd/Insects_130', 'train_rnd/Plants_717', 'train_rnd/Plants_370', 'train_rnd/Plants_332', 'train_rnd/Plants_626', 'train_rnd/Plants_825', 'train_rnd/Plants_434', 'train_rnd/Plants_592', 'train_rnd/Insects_92', 'train_rnd/Plants_793', 'train_rnd/Plants_928', 'train_rnd/Plants_858', 'train_rnd/Insects_60', 'train_rnd/Plants_710', 'train_rnd/Plants_472', 'train_rnd/Birds_311', 'train_rnd/Plants_943', 'train_rnd/Plants_413', 'train_rnd/Plants_474', 'train_rnd/Plants_384', 'train_rnd/Insects_28', 'train_rnd/Plants_975', 'train_rnd/Plants_776', 'train_rnd/Plants_934', 'train_rnd/Reptiles_176', 'train_rnd/Plants_953', 'train_rnd/Birds_265', 'train_rnd/Plants_428', 'train_rnd/Reptiles_198', 'train_rnd/Plants_466', 'train_rnd/Plants_593', 'train_rnd/Plants_694', 'train_rnd/Insects_65', 'train_rnd/Plants_609', 'train_rnd/Plants_794', 'train_rnd/Fungi_2', 'train_rnd/Birds_272', 'train_rnd/Plants_952', 'train_rnd/Birds_230', 'train_rnd/Plants_767', 'train_rnd/Plants_662', 'train_rnd/Plants_823', 'train_rnd/Plants_857', 'train_rnd/Birds_235', 'train_rnd/Insects_151', 'train_rnd/Plants_562', 'train_rnd/Plants_504', 'train_rnd/Plants_614', 'train_rnd/Birds_274', 'train_rnd/Plants_910', 'train_rnd/Plants_533', 'train_rnd/Plants_453', 'train_rnd/Plants_596', 't ...
# moving 11 files
# moving 100 files
# moving 47 files
# moving 55 files
# moving 33 files
# moving 15 files
# moving 22 files
# moving 19 files
# moving 22 files
# moving 39 files
# moving 100 files
# moving 14 files
# moving 100 files
# moving 24 files
# moving 63 files
# moving 15 files
# moving 41 files
# moving 100 files
# moving 10 files
# moving 18 files
# moving 89 files
# moving 100 files
# moving 100 files
# moving 80 files
# moving 72 files
# moving 42 files
# moving 100 files
# moving 20 files
# moving 100 files
# moving 31 files
# moving 100 files
# moving 28 files
# moving 100 files
# moving 63 files
# moving 17 files
# moving 34 files
# moving 100 files
# moving 100 files
# moving 100 files
# moving 24 files
# moving 100 files
# moving 100 files
# moving 25 files
# moving 100 files
# moving 100 files
# moving 41 files
# moving 100 files
# moving 55 files
# moving 100 files
# moving 62 files
# moving 22 files
# moving 27 files
# moving 18 files
# moving 38 files
# moving 32 files
# moving 22 files
# moving 54 files
# moving 18 files
# moving 24 files
# moving 82 files
# moving 44 files
# moving 18 files
# moving 100 files
# moving 34 files
# moving 24 files
# moving 57 files
# moving 100 files
# moving 22 files
# moving 56 files
# moving 42 files
# moving 57 files
# moving 16 files
# moving 18 files
# moving 20 files
# moving 11 files
# moving 27 files
# moving 18 files
# moving 18 files
# moving 100 files
# moving 65 files
# moving 41 files
# moving 100 files
# moving 19 files
# moving 21 files
# moving 15 files
# moving 11 files
# moving 43 files
# moving 13 files
# moving 62 files
# moving 33 files
# moving 21 files
# moving 15 files
# moving 53 files
# moving 63 files
# moving 33 files
# moving 46 files
# moving 12 files
# moving 57 files
# moving 17 files
# moving 67 files
# moving 27 files
# moving 17 files
# moving 48 files
# moving 82 files
# moving 100 files
# moving 22 files
# moving 100 files
# moving 100 files
# moving 23 files
# moving 75 files
# moving 18 files
# moving 8 files
# moving 85 files
# moving 12 files
# moving 12 files
# moving 44 files
# moving 13 files
# moving 24 files
# moving 19 files
# moving 100 files
# moving 100 files
# moving 100 files
# moving 24 files
# moving 10 files
# moving 28 files
# moving 11 files
# moving 30 files
# moving 19 files
# moving 100 files
# moving 19 files
# moving 12 files
# moving 100 files
# moving 23 files
# moving 60 files
# moving 19 files
# moving 27 files
# moving 9 files
# moving 58 files
# moving 29 files
# moving 79 files
# moving 25 files
# moving 52 files
# moving 33 files
# moving 100 files
# moving 32 files
# moving 28 files
# moving 33 files
# moving 17 files
# moving 36 files
# moving 100 files
# moving 12 files
# moving 19 files
# moving 48 files
# moving 9 files
# moving 43 files
# moving 39 files
# moving 100 files
# moving 22 files
# moving 10 files
# moving 29 files
# moving 14 files
# moving 32 files
# moving 30 files
# moving 98 files
# moving 24 files
# moving 57 files
# moving 100 files
# moving 33 files
# moving 33 files
# moving 100 files
# moving 100 files
# moving 22 files
# moving 23 files
# moving 21 files
# moving 14 files
# moving 28 files
# moving 32 files
# moving 62 files
# moving 33 files
# moving 19 files
# moving 31 files
# moving 100 files
# moving 25 files
# moving 56 files
# moving 51 files
# moving 21 files
# moving 74 files
# moving 37 files
# moving 100 files
# moving 19 files
# moving 51 files
# moving 13 files
# moving 100 files
# moving 43 files
# moving 20 files
# moving 29 files
# moving 100 files
# moving 23 files
# moving 28 files
# moving 100 files
# moving 100 files
# moving 16 files
# moving 100 files
# moving 34 files
# moving 91 files
# moving 79 files
# moving 27 files
# moving 9 files
# moving 72 files
# moving 100 files
# moving 51 files
# moving 100 files
# moving 71 files
# moving 11 files
# moving 100 files
# moving 100 files
# moving 14 files
# moving 85 files
# moving 48 files
# moving 75 files
# moving 15 files
# moving 100 files
# moving 59 files
# moving 14 files
# moving 57 files
# moving 55 files
# moving 54 files
# moving 22 files
# moving 78 files
# moving 14 files
# moving 94 files
# moving 55 files
# moving 12 files
# moving 15 files
# moving 58 files
# moving 18 files
# moving 100 files
# moving 19 files
# moving 100 files
# moving 28 files
# moving 7 files
# moving 64 files
# moving 29 files
# moving 30 files
# moving 13 files
# moving 19 files
# moving 42 files
# moving 20 files
# moving 72 files
# moving 100 files
# moving 54 files
# moving 100 files
# moving 100 files
# moving 28 files
# moving 64 files
# moving 100 files
# moving 19 files
# moving 43 files
# moving 12 files
# moving 6 files
# moving 33 files
# moving 6 files
# moving 29 files
# moving 22 files
# moving 20 files
# moving 100 files
# moving 52 files
# moving 100 files
# moving 100 files
# moving 100 files
# moving 26 files
# moving 26 files
# moving 100 files
# moving 41 files
# moving 100 files
# moving 56 files
# moving 72 files
# moving 22 files
# moving 100 files
# moving 100 files
# moving 67 files
# moving 100 files
# moving 100 files
# moving 43 files
# moving 100 files
# moving 100 files
# moving 100 files
# moving 100 files
# moving 24 files
# moving 91 files
# moving 75 files
# moving 61 files
# moving 59 files
# moving 21 files
# moving 5 files
# moving 100 files
# moving 30 files
# moving 100 files
# moving 100 files
# moving 34 files
# moving 100 files
# moving 80 files
# moving 25 files
# moving 72 files
# moving 25 files
# moving 23 files
# moving 33 files
# moving 18 files
# moving 43 files
# moving 100 files
# moving 12 files
# moving 100 files
# moving 100 files
# moving 13 files
# moving 38 files
# moving 66 files
# moving 14 files
# moving 80 files
# moving 34 files
# moving 100 files
# moving 87 files
# moving 100 files
# moving 100 files
# moving 21 files
# moving 100 files
# moving 34 files
# moving 96 files
# moving 66 files
# moving 100 files
# moving 30 files
# moving 100 files
# moving 26 files
# moving 18 files
# moving 100 files
# moving 30 files
# moving 23 files
# moving 100 files
# moving 19 files
# moving 10 files
# moving 25 files
# moving 17 files
# moving 100 files
# moving 100 files
# moving 90 files
# moving 100 files
# moving 100 files
# moving 100 files
# moving 79 files
# moving 100 files
# moving 100 files
# moving 18 files
# moving 98 files
# moving 25 files
# moving 100 files
# moving 67 files
# moving 29 files
# moving 53 files
# moving 40 files
# moving 100 files
# moving 34 files
# moving 100 files
# moving 33 files
# moving 53 files
# moving 43 files
# moving 16 files
# moving 38 files
# moving 100 files
# moving 100 files
# moving 81 files
# moving 38 files
# moving 13 files
# moving 27 files
# moving 61 files
# moving 25 files
# moving 26 files
# moving 11 files
# moving 18 files
# moving 75 files
# moving 13 files
# moving 44 files
# moving 51 files
# moving 100 files
# moving 100 files
# moving 74 files
# moving 14 files
# moving 41 files
# moving 16 files
# moving 100 files
# moving 45 files
# moving 23 files
# moving 30 files
# moving 69 files
# moving 100 files
# moving 31 files
# moving 26 files
# moving 49 files
# moving 100 files
# moving 15 files
# moving 100 files
# moving 25 files
# moving 59 files
# moving 18 files
# moving 14 files
# moving 83 files
# moving 10 files
# moving 48 files
# moving 76 files
# moving 21 files
# moving 70 files
# moving 54 files
# moving 54 files
# moving 100 files
# moving 25 files
# moving 100 files
# moving 68 files
# moving 100 files
# moving 100 files
# moving 21 files
# moving 34 files
# moving 16 files
# moving 100 files
# moving 11 files
# moving 34 files
# moving 41 files
# moving 49 files
# moving 100 files
# moving 44 files
# moving 100 files
# moving 100 files
# moving 12 files
# moving 64 files
# moving 100 files
# moving 91 files
# moving 20 files
# moving 11 files
# moving 13 files
# moving 53 files
# moving 22 files
# moving 36 files
# moving 43 files
# moving 33 files
# moving 100 files
# moving 72 files
# moving 100 files
# moving 41 files
# moving 92 files
# moving 100 files
# moving 100 files
# moving 100 files
# moving 41 files
# moving 28 files
# moving 30 files
# moving 41 files
# moving 23 files
# moving 73 files
# moving 17 files
# moving 32 files
# moving 56 files
# moving 47 files
# moving 100 files
# moving 100 files
# moving 42 files
# moving 32 files
# moving 41 files
# moving 3 files
# moving 65 files
# moving 56 files
# moving 100 files
# moving 24 files
# moving 90 files
# moving 58 files
# moving 23 files
# moving 21 files
# moving 43 files
# moving 19 files
# moving 100 files
# moving 100 files
# moving 100 files
# moving 53 files
# moving 32 files
# moving 59 files
# moving 100 files
# moving 29 files
# moving 48 files
# moving 33 files
# moving 100 files
# moving 88 files
# moving 15 files
# moving 100 files
# moving 72 files
# moving 13 files
# moving 100 files
# moving 48 files
# moving 100 files
# moving 27 files
# moving 39 files
# moving 48 files
# moving 36 files
# moving 32 files
# moving 46 files
# moving 100 files
# moving 28 files
# moving 24 files
# moving 80 files
# moving 100 files
# moving 100 files
# moving 85 files
# moving 68 files
# moving 82 files
# moving 78 files
# moving 68 files
# moving 21 files
# moving 16 files
# moving 100 files
# moving 44 files
# moving 100 files
# moving 68 files
# moving 52 files
# moving 100 files
# moving 21 files
# moving 79 files
# moving 100 files
# moving 100 files
# moving 36 files
# moving 13 files
# moving 67 files
# moving 9 files
# moving 63 files
# moving 17 files
# moving 49 files
# moving 14 files
# moving 37 files
# moving 27 files
# moving 30 files
# moving 50 files
# moving 100 files
# moving 13 files
# moving 74 files
# moving 61 files
# moving 40 files
# moving 5 files
# moving 50 files
# moving 24 files
# moving 39 files
# moving 100 files
# moving 71 files
# moving 37 files
# moving 11 files
# moving 44 files
# moving 100 files
# moving 55 files
# moving 17 files
# moving 54 files
# moving 58 files
# moving 33 files
# moving 54 files
# moving 87 files
# moving 100 files
# moving 100 files
# moving 100 files
# moving 100 files
# moving 100 files
# moving 22 files
# moving 70 files
# moving 25 files
# moving 62 files
# moving 66 files
# moving 16 files
# moving 100 files
# moving 100 files
# moving 17 files
# moving 23 files
# moving 14 files
# moving 19 files
# moving 91 files
# moving 100 files
# moving 28 files
# moving 40 files
# moving 66 files
# moving 100 files
# moving 57 files
# moving 30 files
# moving 22 files
# moving 100 files
# moving 18 files
# moving 100 files
# moving 16 files
# moving 30 files
# moving 24 files
# moving 100 files
# moving 11 files
# moving 34 files
# moving 13 files
# moving 100 files
# moving 83 files
# moving 15 files
# moving 87 files
# moving 14 files
# moving 38 files
# moving 37 files
# moving 24 files
# moving 37 files
# moving 94 files
# moving 98 files
# moving 100 files
# moving 78 files
# moving 16 files
# moving 19 files
# moving 45 files
# moving 21 files
# moving 24 files
# moving 15 files
# moving 6 files
# moving 95 files
# moving 100 files
# moving 47 files
# moving 32 files
# moving 50 files
# moving 100 files
# moving 12 files
# moving 100 files
# moving 23 files
# moving 100 files
# moving 26 files
# moving 13 files
# moving 100 files
# moving 25 files
# moving 28 files
# moving 11 files
# moving 35 files
# moving 100 files
# moving 19 files
# moving 61 files
# moving 100 files
# moving 37 files
# moving 31 files
# moving 19 files
# moving 17 files
# moving 41 files
# moving 19 files
# moving 57 files
# moving 50 files
# moving 15 files
# moving 31 files
# moving 79 files
# moving 41 files
# moving 99 files
# moving 41 files
# moving 56 files
# moving 31 files
# moving 100 files
# moving 22 files
# moving 29 files
# moving 100 files
# moving 36 files
# moving 38 files
# moving 100 files
# moving 100 files
# moving 100 files
# moving 100 files
# moving 15 files
# moving 100 files
# moving 55 files
# moving 11 files
# moving 20 files
# moving 39 files
# moving 19 files
# moving 80 files
# moving 14 files
# moving 72 files
# moving 63 files
# moving 100 files
# moving 100 files
# moving 18 files
# moving 100 files
# moving 100 files
# moving 100 files
# moving 33 files
# moving 90 files
# moving 100 files
# moving 70 files
# moving 5 files
# moving 36 files
# moving 76 files
# moving 41 files
# moving 41 files
# moving 17 files
# moving 18 files
# moving 44 files
# moving 92 files
# moving 24 files
# moving 86 files
# moving 14 files
# moving 27 files
# moving 45 files
# moving 22 files
# moving 17 files
# moving 79 files
# moving 100 files
# moving 11 files
# moving 100 files
# moving 100 files
# moving 43 files
# moving 8 files
# moving 7 files
# moving 93 files
# moving 29 files
# moving 100 files
# moving 17 files
# moving 95 files
# moving 100 files
# moving 100 files
# moving 90 files
# moving 100 files
# moving 63 files
# moving 100 files
# moving 47 files
# moving 36 files
# moving 42 files
# moving 43 files
# moving 76 files
# moving 100 files
# moving 37 files
# moving 94 files
# moving 64 files
# moving 79 files
# moving 29 files
# moving 100 files
# moving 100 files
# moving 48 files
# moving 18 files
# moving 100 files
# moving 27 files
# moving 14 files
# moving 31 files
# moving 30 files
# moving 22 files
# moving 61 files
# moving 9 files
# moving 78 files
# moving 69 files
# moving 100 files
# moving 37 files
# moving 100 files
# moving 13 files
# moving 100 files
# moving 24 files
# moving 20 files
# moving 45 files
# moving 100 files
# moving 100 files
# moving 100 files
# moving 100 files
# moving 54 files
# moving 8 files
# moving 27 files
# moving 37 files
# moving 17 files
# moving 19 files
# moving 16 files
# moving 21 files
# moving 26 files
# moving 40 files
# moving 13 files
# moving 100 files
# moving 45 files
# moving 100 files
# moving 58 files
# moving 16 files
# moving 49 files
# moving 16 files
# moving 38 files
# moving 100 files
# moving 86 files
# moving 18 files
# moving 100 files
# moving 34 files
# moving 47 files
# moving 34 files
# moving 24 files
# moving 15 files
# moving 100 files
# moving 100 files
# moving 44 files
# moving 23 files
# moving 9 files
# moving 100 files
# moving 27 files
# moving 55 files
# moving 32 files
# moving 46 files
# moving 100 files
# moving 31 files
# moving 81 files
# moving 100 files
# moving 27 files
# moving 8 files
# moving 36 files
# moving 26 files
# moving 100 files
# moving 88 files
# moving 44 files
# moving 10 files
# moving 59 files
# moving 20 files
# moving 85 files
# moving 19 files
# moving 100 files
# moving 20 files
# moving 36 files
# moving 8 files
# moving 18 files
# moving 15 files
# moving 67 files
# moving 28 files
# moving 31 files
# moving 42 files
# moving 12 files
# moving 56 files
# moving 7 files
# moving 22 files
# moving 33 files
# moving 44 files
# moving 100 files
# moving 7 files
# moving 20 files
# moving 36 files
# moving 22 files
# moving 11 files
# moving 9 files
# moving 26 files
# moving 100 files
# moving 100 files
# moving 77 files
# moving 32 files
# moving 100 files
# moving 22 files
# moving 24 files
# moving 12 files
# moving 22 files
# moving 70 files
# moving 100 files
# moving 19 files
# moving 100 files
# moving 23 files
# moving 15 files
# moving 100 files
# moving 47 files
# moving 54 files
# moving 29 files
# moving 44 files
# moving 82 files
# moving 33 files
# moving 8 files
# moving 100 files
# moving 28 files
# moving 41 files
# moving 100 files
# moving 64 files
# moving 88 files
# moving 47 files
# moving 100 files
# moving 70 files
# moving 36 files
# moving 100 files
# moving 20 files
# moving 86 files
# moving 100 files
# moving 14 files
# moving 30 files
# moving 59 files
# moving 100 files
# moving 23 files
# moving 14 files
# moving 100 files
# moving 8 files
# moving 20 files
# moving 15 files
# moving 100 files
# moving 42 files
# moving 10 files
# moving 16 files
# moving 87 files
# moving 8 files
# moving 18 files
# moving 11 files
# moving 28 files
# moving 100 files
# moving 27 files
# moving 14 files
# moving 31 files
# moving 32 files
# moving 34 files
# moving 25 files
# moving 19 files
# moving 40 files
# moving 100 files
# moving 100 files
# moving 11 files
# moving 100 files
# moving 25 files
# moving 100 files
# moving 24 files
# moving 78 files
# moving 10 files
# moving 44 files
# moving 16 files
# moving 100 files
# moving 100 files
# moving 11 files
# moving 42 files
# moving 33 files
# moving 10 files
# moving 27 files
# moving 40 files
# moving 74 files
# moving 19 files
# moving 100 files
# moving 25 files
# moving 34 files
# moving 49 files
# moving 20 files
# moving 42 files
# moving 13 files
# moving 44 files
# moving 85 files
# moving 22 files
# moving 100 files
# moving 50 files
# moving 22 files
# moving 32 files
# moving 12 files
# moving 98 files
# moving 21 files
# moving 74 files
# moving 100 files
# moving 52 files
# moving 55 files
# moving 17 files
# moving 19 files
# moving 16 files
# moving 100 files
# moving 22 files
# moving 17 files
# moving 100 files
# moving 35 files
# moving 21 files
# moving 100 files
# moving 100 files
# moving 30 files
# moving 65 files
# moving 100 files
# moving 100 files
# moving 100 files
# moving 13 files
# moving 100 files
# moving 100 files
# moving 25 files
# moving 44 files
# moving 25 files
# moving 100 files
# moving 20 files
# moving 98 files
# moving 100 files
# moving 72 files
# moving 41 files
# moving 100 files
# moving 49 files
# moving 24 files
# moving 55 files
# moving 57 files
# moving 31 files
# moving 99 files
# moving 25 files
# moving 25 files
# moving 100 files
# moving 100 files
# moving 63 files
# moving 31 files
# moving 100 files
# moving 38 files
# moving 24 files
# moving 39 files
# moving 47 files
# moving 5 files
# moving 52 files
# moving 50 files
# moving 100 files
# moving 68 files
# moving 12 files
# moving 75 files
# moving 57 files
# moving 31 files
# moving 57 files
# moving 73 files
# moving 42 files
# moving 17 files
# moving 100 files
# moving 22 files
# moving 87 files
# moving 15 files
# moving 36 files
# moving 32 files
# moving 78 files
# moving 25 files
# moving 23 files
# moving 23 files
# moving 45 files
# moving 21 files
# moving 100 files

# %%
####=======================
import glob
import os
import shutil
import random

#move color files  
#divide 2-2 randomly

# # get parts of image's path
def get_image_parts(image_path):
    """Given a full path to an image, return its parts."""
    parts = image_path.split(os.path.sep)
    #print(parts)
    filename = parts[2]
    filename_no_ext = filename.split('.')[0]
    classname = parts[1]
#     sub_folder = parts[1]
    train_or_test = parts[0]

    return train_or_test, classname, filename_no_ext, filename

move_folders = ['valid_rnd']
dest_folder = 'train_rnd'
data_file = []

# look for all images in sub-folders
for folder in move_folders:
    class_folders = glob.glob(os.path.join(folder, '*'))
    print('folder %s' %class_folders)
    
#     for sub_folder in class_folders:
#         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
#         print('sub folder %s' %sub_class_folders)
        
    for iid_class in class_folders:
        class_files = glob.glob(os.path.join(iid_class, '*.jpg'))

#             print('moving %d files' %(len(class_files)))

        #Determize Set# (No Suffle)
        set = len(class_files)//2 #move back 50% (using kfold of 20)

        inner = range(0*set, 1*set) #Set 1

        print('moving %d files' %(len(inner)))

#             random_list = random.sample(range(len(class_files)), int(len(class_files))) #All dataset
#             for idx in range(len(random_list)):

        for idx in range(len(inner)):
            src = class_files[inner[idx]]

            #record paths
#                 data_file.append(src)

            train_or_test, classname, _, filename = get_image_parts(src)
            dst = os.path.join(dest_folder, classname, filename)

            # image directory
            img_directory = os.path.join(dest_folder, classname)

            # create folder if not existed
            if not os.path.exists(img_directory):
                os.makedirs(img_directory)

            #moving file
            shutil.move(src, dst)
#                 shutil.copy(src, dst)

# #save recorded paths
# with open('data_file.csv', 'w') as fout:
#     writer = csv.writer(fout)
#     writer.writerows(data_file)
# Out:
# folder ['valid_rnd/Plants_636', 'valid_rnd/Birds_306', 'valid_rnd/Plants_918', 'valid_rnd/Reptiles_177', 'valid_rnd/Plants_890', 'valid_rnd/Plants_946', 'valid_rnd/Insects_83', 'valid_rnd/Plants_798', 'valid_rnd/Plants_972', 'valid_rnd/Plants_695', 'valid_rnd/Plants_937', 'valid_rnd/Insects_148', 'valid_rnd/Reptiles_188', 'valid_rnd/Plants_469', 'valid_rnd/Plants_437', 'valid_rnd/Plants_828', 'valid_rnd/Plants_753', 'valid_rnd/Plants_486', 'valid_rnd/Plants_902', 'valid_rnd/Insects_18', 'valid_rnd/Plants_834', 'valid_rnd/Birds_222', 'valid_rnd/Insects_144', 'valid_rnd/Insects_24', 'valid_rnd/Plants_386', 'valid_rnd/Amphibians_162', 'valid_rnd/Plants_903', 'valid_rnd/Insects_61', 'valid_rnd/Plants_691', 'valid_rnd/Plants_974', 'valid_rnd/Birds_321', 'valid_rnd/Birds_309', 'valid_rnd/Plants_836', 'valid_rnd/Insects_13', 'valid_rnd/Plants_459', 'valid_rnd/Plants_838', 'valid_rnd/Plants_578', 'valid_rnd/Plants_360', 'valid_rnd/Insects_135', 'valid_rnd/Plants_963', 'valid_rnd/Plants_817', 'valid_rnd/Birds_248', 'valid_rnd/Amphibians_157', 'valid_rnd/Plants_754', 'valid_rnd/Plants_392', 'valid_rnd/Plants_792', 'valid_rnd/Plants_448', 'valid_rnd/Plants_521', 'valid_rnd/Plants_996', 'valid_rnd/Birds_221', 'valid_rnd/Plants_931', 'valid_rnd/Plants_341', 'valid_rnd/Plants_634', 'valid_rnd/Plants_775', 'valid_rnd/Plants_403', 'valid_rnd/Plants_561', 'valid_rnd/Insects_58', 'valid_rnd/Plants_911', 'valid_rnd/Insects_15', 'valid_rnd/Insects_150', 'valid_rnd/Insects_84', 'valid_rnd/Plants_942', 'valid_rnd/Amphibians_156', 'valid_rnd/Birds_261', 'valid_rnd/Plants_839', 'valid_rnd/Plants_489', 'valid_rnd/Birds_283', 'valid_rnd/Plants_809', 'valid_rnd/Plants_749', 'valid_rnd/Plants_378', 'valid_rnd/Plants_987', 'valid_rnd/Plants_750', 'valid_rnd/Plants_719', 'valid_rnd/Plants_581', 'valid_rnd/Insects_146', 'valid_rnd/Plants_615', 'valid_rnd/Plants_613', 'valid_rnd/Plants_819', 'valid_rnd/Plants_391', 'valid_rnd/Plants_603', 'valid_rnd/Reptiles_197', 'valid_rnd/Reptiles_173', 'valid_rnd/Plants_538', 'valid_rnd/Plants_501', 'valid_rnd/Plants_799', 'valid_rnd/Plants_748', 'valid_rnd/Birds_223', 'valid_rnd/Plants_398', 'valid_rnd/Plants_760', 'valid_rnd/Plants_913', 'valid_rnd/Plants_600', 'valid_rnd/Plants_344', 'valid_rnd/Plants_328', 'valid_rnd/Plants_1005', 'valid_rnd/Plants_1001', 'valid_rnd/Birds_310', 'valid_rnd/Plants_632', 'valid_rnd/Plants_508', 'valid_rnd/Birds_215', 'valid_rnd/Plants_878', 'valid_rnd/Birds_317', 'valid_rnd/Plants_727', 'valid_rnd/Birds_300', 'valid_rnd/Insects_34', 'valid_rnd/Plants_393', 'valid_rnd/Plants_791', 'valid_rnd/Plants_811', 'valid_rnd/Plants_475', 'valid_rnd/Fungi_3', 'valid_rnd/Birds_250', 'valid_rnd/Plants_907', 'valid_rnd/Plants_833', 'valid_rnd/Birds_325', 'valid_rnd/Insects_130', 'valid_rnd/Plants_717', 'valid_rnd/Plants_370', 'valid_rnd/Plants_332', 'valid_rnd/Plants_626', 'valid_rnd/Plants_825', 'valid_rnd/Plants_434', 'valid_rnd/Plants_592', 'valid_rnd/Insects_92', 'valid_rnd/Plants_793', 'valid_rnd/Plants_928', 'valid_rnd/Plants_858', 'valid_rnd/Insects_60', 'valid_rnd/Plants_710', 'valid_rnd/Plants_472', 'valid_rnd/Birds_311', 'valid_rnd/Plants_943', 'valid_rnd/Plants_413', 'valid_rnd/Plants_474', 'valid_rnd/Plants_384', 'valid_rnd/Insects_28', 'valid_rnd/Plants_975', 'valid_rnd/Plants_776', 'valid_rnd/Plants_934', 'valid_rnd/Reptiles_176', 'valid_rnd/Plants_953', 'valid_rnd/Birds_265', 'valid_rnd/Plants_428', 'valid_rnd/Reptiles_198', 'valid_rnd/Plants_466', 'valid_rnd/Plants_593', 'valid_rnd/Plants_694', 'valid_rnd/Insects_65', 'valid_rnd/Plants_609', 'valid_rnd/Plants_794', 'valid_rnd/Fungi_2', 'valid_rnd/Birds_272', 'valid_rnd/Plants_952', 'valid_rnd/Birds_230', 'valid_rnd/Plants_767', 'valid_rnd/Plants_662', 'valid_rnd/Plants_823', 'valid_rnd/Plants_857', 'valid_rnd/Birds_235', 'valid_rnd/Insects_151', 'valid_rnd/Plants_562', 'valid_rnd/Plants_504', 'valid_rnd/Plants_614', 'valid_rnd/Birds_274', 'valid_rnd/Plants_910', 'valid_rnd/Plants_533', 'valid_rnd/Plants_453', 'valid_rnd/Plants_596', 'v ...
# moving 3 files
# moving 25 files
# moving 12 files
# moving 14 files
# moving 8 files
# moving 4 files
# moving 5 files
# moving 5 files
# moving 5 files
# moving 10 files
# moving 25 files
# moving 3 files
# moving 25 files
# moving 6 files
# moving 16 files
# moving 4 files
# moving 10 files
# moving 25 files
# moving 2 files
# moving 4 files
# moving 22 files
# moving 25 files
# moving 25 files
# moving 20 files
# moving 18 files
# moving 10 files
# moving 25 files
# moving 5 files
# moving 25 files
# moving 8 files
# moving 25 files
# moving 7 files
# moving 25 files
# moving 16 files
# moving 4 files
# moving 8 files
# moving 25 files
# moving 25 files
# moving 25 files
# moving 6 files
# moving 25 files
# moving 25 files
# moving 6 files
# moving 25 files
# moving 25 files
# moving 10 files
# moving 25 files
# moving 14 files
# moving 25 files
# moving 15 files
# moving 5 files
# moving 7 files
# moving 4 files
# moving 9 files
# moving 8 files
# moving 5 files
# moving 13 files
# moving 4 files
# moving 6 files
# moving 20 files
# moving 11 files
# moving 4 files
# moving 25 files
# moving 8 files
# moving 6 files
# moving 14 files
# moving 25 files
# moving 5 files
# moving 14 files
# moving 10 files
# moving 14 files
# moving 4 files
# moving 4 files
# moving 5 files
# moving 3 files
# moving 7 files
# moving 4 files
# moving 4 files
# moving 25 files
# moving 16 files
# moving 10 files
# moving 25 files
# moving 5 files
# moving 5 files
# moving 4 files
# moving 3 files
# moving 11 files
# moving 3 files
# moving 15 files
# moving 8 files
# moving 5 files
# moving 4 files
# moving 13 files
# moving 16 files
# moving 8 files
# moving 11 files
# moving 3 files
# moving 14 files
# moving 4 files
# moving 17 files
# moving 7 files
# moving 4 files
# moving 12 files
# moving 20 files
# moving 25 files
# moving 5 files
# moving 25 files
# moving 25 files
# moving 6 files
# moving 19 files
# moving 4 files
# moving 2 files
# moving 21 files
# moving 3 files
# moving 3 files
# moving 11 files
# moving 3 files
# moving 6 files
# moving 5 files
# moving 25 files
# moving 25 files
# moving 25 files
# moving 6 files
# moving 2 files
# moving 7 files
# moving 3 files
# moving 7 files
# moving 5 files
# moving 25 files
# moving 5 files
# moving 3 files
# moving 25 files
# moving 6 files
# moving 15 files
# moving 5 files
# moving 7 files
# moving 2 files
# moving 14 files
# moving 7 files
# moving 20 files
# moving 6 files
# moving 13 files
# moving 8 files
# moving 25 files
# moving 8 files
# moving 7 files
# moving 8 files
# moving 4 files
# moving 9 files
# moving 25 files
# moving 3 files
# moving 5 files
# moving 12 files
# moving 2 files
# moving 11 files
# moving 10 files
# moving 25 files
# moving 5 files
# moving 2 files
# moving 7 files
# moving 3 files
# moving 8 files
# moving 7 files
# moving 24 files
# moving 6 files
# moving 14 files
# moving 25 files
# moving 8 files
# moving 8 files
# moving 25 files
# moving 25 files
# moving 5 files
# moving 6 files
# moving 5 files
# moving 3 files
# moving 7 files
# moving 8 files
# moving 15 files
# moving 8 files
# moving 5 files
# moving 8 files
# moving 25 files
# moving 6 files
# moving 14 files
# moving 13 files
# moving 5 files
# moving 18 files
# moving 9 files
# moving 25 files
# moving 5 files
# moving 13 files
# moving 3 files
# moving 25 files
# moving 11 files
# moving 5 files
# moving 7 files
# moving 25 files
# moving 6 files
# moving 7 files
# moving 25 files
# moving 25 files
# moving 4 files
# moving 25 files
# moving 8 files
# moving 23 files
# moving 20 files
# moving 7 files
# moving 2 files
# moving 18 files
# moving 25 files
# moving 13 files
# moving 25 files
# moving 18 files
# moving 3 files
# moving 25 files
# moving 25 files
# moving 3 files
# moving 21 files
# moving 12 files
# moving 19 files
# moving 4 files
# moving 25 files
# moving 15 files
# moving 3 files
# moving 14 files
# moving 14 files
# moving 13 files
# moving 5 files
# moving 19 files
# moving 3 files
# moving 23 files
# moving 14 files
# moving 3 files
# moving 4 files
# moving 14 files
# moving 4 files
# moving 25 files
# moving 5 files
# moving 25 files
# moving 7 files
# moving 2 files
# moving 16 files
# moving 7 files
# moving 7 files
# moving 3 files
# moving 5 files
# moving 10 files
# moving 5 files
# moving 18 files
# moving 25 files
# moving 13 files
# moving 25 files
# moving 25 files
# moving 7 files
# moving 16 files
# moving 25 files
# moving 5 files
# moving 11 files
# moving 3 files
# moving 1 files
# moving 8 files
# moving 1 files
# moving 7 files
# moving 5 files
# moving 5 files
# moving 25 files
# moving 13 files
# moving 25 files
# moving 25 files
# moving 25 files
# moving 6 files
# moving 6 files
# moving 25 files
# moving 10 files
# moving 25 files
# moving 14 files
# moving 18 files
# moving 5 files
# moving 25 files
# moving 25 files
# moving 17 files
# moving 25 files
# moving 25 files
# moving 11 files
# moving 25 files
# moving 25 files
# moving 25 files
# moving 25 files
# moving 6 files
# moving 23 files
# moving 19 files
# moving 15 files
# moving 15 files
# moving 5 files
# moving 1 files
# moving 25 files
# moving 7 files
# moving 25 files
# moving 25 files
# moving 8 files
# moving 25 files
# moving 20 files
# moving 6 files
# moving 18 files
# moving 6 files
# moving 6 files
# moving 8 files
# moving 4 files
# moving 11 files
# moving 25 files
# moving 3 files
# moving 25 files
# moving 25 files
# moving 3 files
# moving 9 files
# moving 16 files
# moving 3 files
# moving 20 files
# moving 8 files
# moving 25 files
# moving 22 files
# moving 25 files
# moving 25 files
# moving 5 files
# moving 25 files
# moving 8 files
# moving 24 files
# moving 16 files
# moving 25 files
# moving 7 files
# moving 25 files
# moving 6 files
# moving 4 files
# moving 25 files
# moving 7 files
# moving 6 files
# moving 25 files
# moving 5 files
# moving 2 files
# moving 6 files
# moving 4 files
# moving 25 files
# moving 25 files
# moving 22 files
# moving 25 files
# moving 25 files
# moving 25 files
# moving 20 files
# moving 25 files
# moving 25 files
# moving 4 files
# moving 24 files
# moving 6 files
# moving 25 files
# moving 17 files
# moving 7 files
# moving 13 files
# moving 10 files
# moving 25 files
# moving 8 files
# moving 25 files
# moving 8 files
# moving 13 files
# moving 11 files
# moving 4 files
# moving 9 files
# moving 25 files
# moving 25 files
# moving 20 files
# moving 9 files
# moving 3 files
# moving 7 files
# moving 15 files
# moving 6 files
# moving 6 files
# moving 3 files
# moving 4 files
# moving 19 files
# moving 3 files
# moving 11 files
# moving 13 files
# moving 25 files
# moving 25 files
# moving 18 files
# moving 3 files
# moving 10 files
# moving 4 files
# moving 25 files
# moving 11 files
# moving 6 files
# moving 7 files
# moving 17 files
# moving 25 files
# moving 8 files
# moving 6 files
# moving 12 files
# moving 25 files
# moving 4 files
# moving 25 files
# moving 6 files
# moving 15 files
# moving 4 files
# moving 3 files
# moving 21 files
# moving 2 files
# moving 12 files
# moving 19 files
# moving 5 files
# moving 17 files
# moving 13 files
# moving 13 files
# moving 25 files
# moving 6 files
# moving 25 files
# moving 17 files
# moving 25 files
# moving 25 files
# moving 5 files
# moving 8 files
# moving 4 files
# moving 25 files
# moving 3 files
# moving 8 files
# moving 10 files
# moving 12 files
# moving 25 files
# moving 11 files
# moving 25 files
# moving 25 files
# moving 3 files
# moving 16 files
# moving 25 files
# moving 23 files
# moving 5 files
# moving 3 files
# moving 3 files
# moving 13 files
# moving 5 files
# moving 9 files
# moving 11 files
# moving 8 files
# moving 25 files
# moving 18 files
# moving 25 files
# moving 10 files
# moving 23 files
# moving 25 files
# moving 25 files
# moving 25 files
# moving 10 files
# moving 7 files
# moving 7 files
# moving 10 files
# moving 6 files
# moving 18 files
# moving 4 files
# moving 8 files
# moving 14 files
# moving 12 files
# moving 25 files
# moving 25 files
# moving 10 files
# moving 8 files
# moving 10 files
# moving 1 files
# moving 16 files
# moving 14 files
# moving 25 files
# moving 6 files
# moving 22 files
# moving 14 files
# moving 6 files
# moving 5 files
# moving 11 files
# moving 5 files
# moving 25 files
# moving 25 files
# moving 25 files
# moving 13 files
# moving 8 files
# moving 15 files
# moving 25 files
# moving 7 files
# moving 12 files
# moving 8 files
# moving 25 files
# moving 22 files
# moving 4 files
# moving 25 files
# moving 18 files
# moving 3 files
# moving 25 files
# moving 12 files
# moving 25 files
# moving 7 files
# moving 10 files
# moving 12 files
# moving 9 files
# moving 8 files
# moving 11 files
# moving 25 files
# moving 7 files
# moving 6 files
# moving 20 files
# moving 25 files
# moving 25 files
# moving 21 files
# moving 17 files
# moving 20 files
# moving 19 files
# moving 17 files
# moving 5 files
# moving 4 files
# moving 25 files
# moving 11 files
# moving 25 files
# moving 17 files
# moving 13 files
# moving 25 files
# moving 5 files
# moving 20 files
# moving 25 files
# moving 25 files
# moving 9 files
# moving 3 files
# moving 17 files
# moving 2 files
# moving 16 files
# moving 4 files
# moving 12 files
# moving 3 files
# moving 9 files
# moving 7 files
# moving 7 files
# moving 12 files
# moving 25 files
# moving 3 files
# moving 18 files
# moving 15 files
# moving 10 files
# moving 1 files
# moving 12 files
# moving 6 files
# moving 10 files
# moving 25 files
# moving 18 files
# moving 9 files
# moving 3 files
# moving 11 files
# moving 25 files
# moving 14 files
# moving 4 files
# moving 13 files
# moving 14 files
# moving 8 files
# moving 13 files
# moving 22 files
# moving 25 files
# moving 25 files
# moving 25 files
# moving 25 files
# moving 25 files
# moving 5 files
# moving 17 files
# moving 6 files
# moving 15 files
# moving 16 files
# moving 4 files
# moving 25 files
# moving 25 files
# moving 4 files
# moving 6 files
# moving 3 files
# moving 5 files
# moving 23 files
# moving 25 files
# moving 7 files
# moving 10 files
# moving 16 files
# moving 25 files
# moving 14 files
# moving 7 files
# moving 5 files
# moving 25 files
# moving 4 files
# moving 25 files
# moving 4 files
# moving 7 files
# moving 6 files
# moving 25 files
# moving 3 files
# moving 8 files
# moving 3 files
# moving 25 files
# moving 21 files
# moving 4 files
# moving 22 files
# moving 3 files
# moving 9 files
# moving 9 files
# moving 6 files
# moving 9 files
# moving 23 files
# moving 24 files
# moving 25 files
# moving 19 files
# moving 4 files
# moving 5 files
# moving 11 files
# moving 5 files
# moving 6 files
# moving 4 files
# moving 1 files
# moving 24 files
# moving 25 files
# moving 12 files
# moving 8 files
# moving 12 files
# moving 25 files
# moving 3 files
# moving 25 files
# moving 6 files
# moving 25 files
# moving 6 files
# moving 3 files
# moving 25 files
# moving 6 files
# moving 7 files
# moving 3 files
# moving 9 files
# moving 25 files
# moving 5 files
# moving 15 files
# moving 25 files
# moving 9 files
# moving 8 files
# moving 5 files
# moving 4 files
# moving 10 files
# moving 5 files
# moving 14 files
# moving 12 files
# moving 4 files
# moving 8 files
# moving 20 files
# moving 10 files
# moving 25 files
# moving 10 files
# moving 14 files
# moving 8 files
# moving 25 files
# moving 5 files
# moving 7 files
# moving 25 files
# moving 9 files
# moving 9 files
# moving 25 files
# moving 25 files
# moving 25 files
# moving 25 files
# moving 4 files
# moving 25 files
# moving 14 files
# moving 3 files
# moving 5 files
# moving 10 files
# moving 5 files
# moving 20 files
# moving 3 files
# moving 18 files
# moving 16 files
# moving 25 files
# moving 25 files
# moving 4 files
# moving 25 files
# moving 25 files
# moving 25 files
# moving 8 files
# moving 22 files
# moving 25 files
# moving 17 files
# moving 1 files
# moving 9 files
# moving 19 files
# moving 10 files
# moving 10 files
# moving 4 files
# moving 4 files
# moving 11 files
# moving 23 files
# moving 6 files
# moving 21 files
# moving 3 files
# moving 7 files
# moving 11 files
# moving 5 files
# moving 4 files
# moving 20 files
# moving 25 files
# moving 3 files
# moving 25 files
# moving 25 files
# moving 11 files
# moving 2 files
# moving 2 files
# moving 23 files
# moving 7 files
# moving 25 files
# moving 4 files
# moving 24 files
# moving 25 files
# moving 25 files
# moving 22 files
# moving 25 files
# moving 16 files
# moving 25 files
# moving 12 files
# moving 9 files
# moving 10 files
# moving 11 files
# moving 19 files
# moving 25 files
# moving 9 files
# moving 23 files
# moving 16 files
# moving 20 files
# moving 7 files
# moving 25 files
# moving 25 files
# moving 12 files
# moving 4 files
# moving 25 files
# moving 7 files
# moving 3 files
# moving 8 files
# moving 7 files
# moving 5 files
# moving 15 files
# moving 2 files
# moving 19 files
# moving 17 files
# moving 25 files
# moving 9 files
# moving 25 files
# moving 3 files
# moving 25 files
# moving 6 files
# moving 5 files
# moving 11 files
# moving 25 files
# moving 25 files
# moving 25 files
# moving 25 files
# moving 13 files
# moving 2 files
# moving 7 files
# moving 9 files
# moving 4 files
# moving 5 files
# moving 4 files
# moving 5 files
# moving 6 files
# moving 10 files
# moving 3 files
# moving 25 files
# moving 11 files
# moving 25 files
# moving 14 files
# moving 4 files
# moving 12 files
# moving 4 files
# moving 9 files
# moving 25 files
# moving 21 files
# moving 4 files
# moving 25 files
# moving 8 files
# moving 12 files
# moving 8 files
# moving 6 files
# moving 4 files
# moving 25 files
# moving 25 files
# moving 11 files
# moving 6 files
# moving 2 files
# moving 25 files
# moving 7 files
# moving 14 files
# moving 8 files
# moving 11 files
# moving 25 files
# moving 8 files
# moving 20 files
# moving 25 files
# moving 7 files
# moving 2 files
# moving 9 files
# moving 6 files
# moving 25 files
# moving 22 files
# moving 11 files
# moving 2 files
# moving 15 files
# moving 5 files
# moving 21 files
# moving 5 files
# moving 25 files
# moving 5 files
# moving 9 files
# moving 2 files
# moving 4 files
# moving 4 files
# moving 17 files
# moving 7 files
# moving 8 files
# moving 10 files
# moving 3 files
# moving 14 files
# moving 2 files
# moving 5 files
# moving 8 files
# moving 11 files
# moving 25 files
# moving 2 files
# moving 5 files
# moving 9 files
# moving 5 files
# moving 3 files
# moving 2 files
# moving 6 files
# moving 25 files
# moving 25 files
# moving 19 files
# moving 8 files
# moving 25 files
# moving 5 files
# moving 6 files
# moving 3 files
# moving 5 files
# moving 17 files
# moving 25 files
# moving 5 files
# moving 25 files
# moving 6 files
# moving 4 files
# moving 25 files
# moving 12 files
# moving 13 files
# moving 7 files
# moving 11 files
# moving 20 files
# moving 8 files
# moving 2 files
# moving 25 files
# moving 7 files
# moving 10 files
# moving 25 files
# moving 16 files
# moving 22 files
# moving 12 files
# moving 25 files
# moving 17 files
# moving 9 files
# moving 25 files
# moving 5 files
# moving 21 files
# moving 25 files
# moving 3 files
# moving 7 files
# moving 15 files
# moving 25 files
# moving 6 files
# moving 3 files
# moving 25 files
# moving 2 files
# moving 5 files
# moving 4 files
# moving 25 files
# moving 10 files
# moving 2 files
# moving 4 files
# moving 22 files
# moving 2 files
# moving 4 files
# moving 3 files
# moving 7 files
# moving 25 files
# moving 7 files
# moving 3 files
# moving 8 files
# moving 8 files
# moving 8 files
# moving 6 files
# moving 5 files
# moving 10 files
# moving 25 files
# moving 25 files
# moving 3 files
# moving 25 files
# moving 6 files
# moving 25 files
# moving 6 files
# moving 19 files
# moving 2 files
# moving 11 files
# moving 4 files
# moving 25 files
# moving 25 files
# moving 3 files
# moving 10 files
# moving 8 files
# moving 2 files
# moving 7 files
# moving 10 files
# moving 18 files
# moving 5 files
# moving 25 files
# moving 6 files
# moving 8 files
# moving 12 files
# moving 5 files
# moving 10 files
# moving 3 files
# moving 11 files
# moving 21 files
# moving 5 files
# moving 25 files
# moving 12 files
# moving 5 files
# moving 8 files
# moving 3 files
# moving 24 files
# moving 5 files
# moving 18 files
# moving 25 files
# moving 13 files
# moving 14 files
# moving 4 files
# moving 5 files
# moving 4 files
# moving 25 files
# moving 5 files
# moving 4 files
# moving 25 files
# moving 9 files
# moving 5 files
# moving 25 files
# moving 25 files
# moving 7 files
# moving 16 files
# moving 25 files
# moving 25 files
# moving 25 files
# moving 3 files
# moving 25 files
# moving 25 files
# moving 6 files
# moving 11 files
# moving 6 files
# moving 25 files
# moving 5 files
# moving 24 files
# moving 25 files
# moving 18 files
# moving 10 files
# moving 25 files
# moving 12 files
# moving 6 files
# moving 14 files
# moving 14 files
# moving 8 files
# moving 25 files
# moving 6 files
# moving 6 files
# moving 25 files
# moving 25 files
# moving 16 files
# moving 8 files
# moving 25 files
# moving 9 files
# moving 6 files
# moving 10 files
# moving 12 files
# moving 1 files
# moving 13 files
# moving 12 files
# moving 25 files
# moving 17 files
# moving 3 files
# moving 19 files
# moving 14 files
# moving 8 files
# moving 14 files
# moving 18 files
# moving 10 files
# moving 4 files
# moving 25 files
# moving 5 files
# moving 22 files
# moving 4 files
# moving 9 files
# moving 8 files
# moving 19 files
# moving 6 files
# moving 6 files
# moving 6 files
# moving 11 files
# moving 5 files
# moving 25 files

# %%
cd train_edited/Amphibians_153/

# %%
ls -l|head -30

# %%
cd ../..

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale = 1./255,
#     rotation_range=20,
#     width_shift_range=0.2,
#     height_shift_range=0.2,
#     shear_range=0.2,
#     zoom_range=0.2,
#     horizontal_flip=True,
#     vertical_flip=True,##
# #     brightness_range=[0.5, 1.5],##
#     channel_shift_range=10,##
#     fill_mode='nearest'
)

test_datagen = ImageDataGenerator(
    rescale = 1./255)

training_set = train_datagen.flow_from_directory('train_rnd',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('valid_rnd',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )
# Out:
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Found 241451 images belonging to 1010 classes.
# Found 26792 images belonging to 1010 classes.

# %%
import numpy as np
from matplotlib.image import imread
# %matplotlib inline
import matplotlib.pyplot as plt

# get image parts
def get_image_parts(image_path):
    """Given a full path to an image, return its parts."""
    parts = image_path.split(os.path.sep)
    #print(parts)
    filename = parts[2]
    filename_no_ext = filename.split('.')[0]
    classname = parts[1]
    train_or_test = parts[0]
    
    return train_or_test, classname, filename_no_ext, filename
    
    
sample_images = list(glob.glob(os.path.join('train_rnd/', '*/*'), recursive=True))
np.random.seed(42)
rand_imgs = np.random.choice(sample_images, size=5*5)
fig, axarr = plt.subplots(5, 5, figsize=(20, 20))

for i, rand_img in enumerate(rand_imgs):
    train_or_test, classname, filename_no_ext, filename = get_image_parts(rand_img)
    
    j = i // 5
    k = i % 5
    axarr[j][k].imshow(imread(rand_img))
    axarr[j][k].title.set_text(classname)
    axarr[j][k].grid(False)

# %%
# Out:
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 421, 421, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 210, 210, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 210, 210, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 210, 210, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 208, 208, 32) 9216        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 208, 208, 32) 96          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 208, 208, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 208, 208, 64) 18432       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 208, 208, 64) 192         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 208, 208, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 103, 103, 64) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 103, 103, 80) 5120        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 103, 103, 80) 240         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 103, 103, 80) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 101, 101, 192 138240      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 101, 101, 192 576         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 101, 101, 192 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 50, 50, 192)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 50, 50, 64)   12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 50, 50, 64)   192         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 50, 50, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 50, 50, 48)   9216        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 50, 50, 96)   55296       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 50, 50, 48)   144         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 50, 50, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 50, 50, 48)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 50, 50, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 50, 50, 192)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 50, 50, 64)   12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 50, 50, 64)   76800       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 50, 50, 96)   82944       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 50, 50, 32)   6144        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 50, 50, 64)   192         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 50, 50, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 50, 50, 96)   288         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 50, 50, 32)   96          conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 50, 50, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 50, 50, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 50, 50, 96)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 50, 50, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 50, 50, 256)  0           activation_6[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 50, 50, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 50, 50, 64)   192         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 50, 50, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 50, 50, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 50, 50, 96)   55296       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 50, 50, 48)   144         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 50, 50, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 50, 50, 48)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 50, 50, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 50, 50, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 50, 50, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 50, 50, 64)   76800       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 50, 50, 96)   82944       activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 50, 50, 64)   16384       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 50, 50, 64)   192         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 50, 50, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 50, 50, 96)   288         conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 50, 50, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 50, 50, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 50, 50, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 50, 50, 96)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 50, 50, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 50, 50, 288)  0           activation_13[0][0]
#                                                                  activation_15[0][0]
#                                                                  activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 50, 50, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 50, 50, 64)   192         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 50, 50, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 50, 50, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 50, 50, 96)   55296       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 50, 50, 48)   144         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 50, 50, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 50, 50, 48)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 50, 50, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 50, 50, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 50, 50, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 50, 50, 64)   76800       activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 50, 50, 96)   82944       activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 50, 50, 64)   18432       average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 50, 50, 64)   192         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 50, 50, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 50, 50, 96)   288         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 50, 50, 64)   192         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 50, 50, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 50, 50, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 50, 50, 96)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 50, 50, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 50, 50, 288)  0           activation_20[0][0]
#                                                                  activation_22[0][0]
#                                                                  activation_25[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 50, 50, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 50, 50, 64)   192         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 50, 50, 64)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 50, 50, 96)   55296       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 50, 50, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 50, 50, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 24, 24, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 24, 24, 96)   82944       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 24, 24, 384)  1152        conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 24, 24, 96)   288         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 24, 24, 384)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 24, 24, 96)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 24, 24, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 24, 24, 768)  0           activation_27[0][0]
#                                                                  activation_30[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 24, 24, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 24, 24, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 24, 24, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 24, 24, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 24, 24, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 24, 24, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 24, 24, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 24, 24, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 24, 24, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 24, 24, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 24, 24, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 24, 24, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 24, 24, 128)  114688      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 24, 24, 128)  114688      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 24, 24, 128)  384         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 24, 24, 128)  384         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 24, 24, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 24, 24, 128)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 24, 24, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 24, 24, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 24, 24, 192)  172032      activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 24, 24, 192)  172032      activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 24, 24, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 24, 24, 192)  576         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 24, 24, 192)  576         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 24, 24, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 24, 24, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 24, 24, 192)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 24, 24, 192)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 24, 24, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 24, 24, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 24, 24, 768)  0           activation_31[0][0]
#                                                                  activation_34[0][0]
#                                                                  activation_39[0][0]
#                                                                  activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 24, 24, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 24, 24, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 24, 24, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 24, 24, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 24, 24, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 24, 24, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 24, 24, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 24, 24, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 24, 24, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 24, 24, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 24, 24, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 24, 24, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 24, 24, 160)  179200      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 24, 24, 160)  179200      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 24, 24, 160)  480         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 24, 24, 160)  480         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 24, 24, 160)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 24, 24, 160)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 24, 24, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 24, 24, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 24, 24, 192)  215040      activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 24, 24, 192)  215040      activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 24, 24, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 24, 24, 192)  576         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 24, 24, 192)  576         conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 24, 24, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 24, 24, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 24, 24, 192)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 24, 24, 192)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 24, 24, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 24, 24, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 24, 24, 768)  0           activation_41[0][0]
#                                                                  activation_44[0][0]
#                                                                  activation_49[0][0]
#                                                                  activation_50[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 24, 24, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 24, 24, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 24, 24, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 24, 24, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 24, 24, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 24, 24, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 24, 24, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 24, 24, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 24, 24, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 24, 24, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 24, 24, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 24, 24, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 24, 24, 160)  179200      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 24, 24, 160)  179200      activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 24, 24, 160)  480         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 24, 24, 160)  480         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 24, 24, 160)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 24, 24, 160)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 24, 24, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 24, 24, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 24, 24, 192)  215040      activation_53[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 24, 24, 192)  215040      activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 24, 24, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 24, 24, 192)  576         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 24, 24, 192)  576         conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 24, 24, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 24, 24, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 24, 24, 192)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 24, 24, 192)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 24, 24, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 24, 24, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 24, 24, 768)  0           activation_51[0][0]
#                                                                  activation_54[0][0]
#                                                                  activation_59[0][0]
#                                                                  activation_60[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 24, 24, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 24, 24, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 24, 24, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 24, 24, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 24, 24, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 24, 24, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 24, 24, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 24, 24, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 24, 24, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 24, 24, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 24, 24, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 24, 24, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 24, 24, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 24, 24, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 24, 24, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 24, 24, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 24, 24, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 24, 24, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 24, 24, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 24, 24, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 24, 24, 192)  258048      activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 24, 24, 192)  258048      activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 24, 24, 192)  147456      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 24, 24, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 24, 24, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 24, 24, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 24, 24, 192)  576         conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 24, 24, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 24, 24, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 24, 24, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 24, 24, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 24, 24, 768)  0           activation_61[0][0]
#                                                                  activation_64[0][0]
# ...
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 11, 11, 320)  0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 11, 11, 192)  0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 11, 11, 768)  0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 11, 11, 1280) 0           activation_72[0][0]
#                                                                  activation_76[0][0]
#                                                                  max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 11, 11, 448)  573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 11, 11, 448)  1344        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 11, 11, 448)  0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 11, 11, 384)  491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 11, 11, 384)  1548288     activation_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 11, 11, 384)  1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 11, 11, 384)  1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 11, 11, 384)  0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 11, 11, 384)  0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 11, 11, 384)  442368      activation_78[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 11, 11, 384)  442368      activation_78[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 11, 11, 384)  442368      activation_82[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 11, 11, 384)  442368      activation_82[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 11, 11, 1280) 0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 11, 11, 320)  409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 11, 11, 384)  1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 11, 11, 384)  1152        conv2d_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 11, 11, 384)  1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 11, 11, 384)  1152        conv2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 11, 11, 192)  245760      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 11, 11, 320)  960         conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 11, 11, 384)  0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 11, 11, 384)  0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 11, 11, 384)  0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 11, 11, 384)  0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 11, 11, 192)  576         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 11, 11, 320)  0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 11, 11, 768)  0           activation_79[0][0]
#                                                                  activation_80[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 11, 11, 768)  0           activation_83[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 11, 11, 192)  0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 11, 11, 2048) 0           activation_77[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_85[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 11, 11, 448)  917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 11, 11, 448)  1344        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 11, 11, 448)  0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 11, 11, 384)  786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 11, 11, 384)  1548288     activation_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 11, 11, 384)  1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 11, 11, 384)  1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 11, 11, 384)  0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 11, 11, 384)  0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 11, 11, 384)  442368      activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 11, 11, 384)  442368      activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 11, 11, 384)  442368      activation_91[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 11, 11, 384)  442368      activation_91[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 11, 11, 2048) 0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 11, 11, 320)  655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 11, 11, 384)  1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 11, 11, 384)  1152        conv2d_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 11, 11, 384)  1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 11, 11, 384)  1152        conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 11, 11, 192)  393216      average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 11, 11, 320)  960         conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 11, 11, 384)  0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 11, 11, 384)  0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 11, 11, 384)  0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 11, 11, 384)  0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 11, 11, 192)  576         conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 11, 11, 320)  0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 11, 11, 768)  0           activation_88[0][0]
#                                                                  activation_89[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 11, 11, 768)  0           activation_92[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 11, 11, 192)  0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 11, 11, 2048) 0           activation_86[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_2[0][0]
#                                                                  activation_94[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2048)         0           mixed10[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 2048)      0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 4096)         67125248    reshape_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 4096)         16781312    bidirectional_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 4096)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 4096)         0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1010)         4137970     dropout_1[0][0]
# ==================================================================================================
# Total params: 109,847,314
# Trainable params: 109,812,882
# Non-trainable params: 34,432
# __________________________________________________________________________________________________
# None

# %%
from keras.layers import Lambda, concatenate
from keras import Model
import tensorflow as tf

def multi_gpu_model(model, gpus):
    if isinstance(gpus, (list, tuple)):
        num_gpus = len(gpus)
        target_gpu_ids = gpus
    else:
        num_gpus = gpus
        target_gpu_ids = range(num_gpus)

    def get_slice(data, i, parts):
        shape = tf.shape(data)
        batch_size = shape[:1]
        input_shape = shape[1:]
        step = batch_size // parts
        if i == num_gpus - 1:
            size = batch_size - step * i
        else:
            size = step
        size = tf.concat([size, input_shape], axis=0)
        stride = tf.concat([step, input_shape * 0], axis=0)
        start = stride * i
        return tf.slice(data, start, size)

    all_outputs = []
    for i in range(len(model.outputs)):
        all_outputs.append([])

    # Place a copy of the model on each GPU,
    # each getting a slice of the inputs.
    for i, gpu_id in enumerate(target_gpu_ids):
        with tf.device('/gpu:%d' % gpu_id):
            with tf.name_scope('replica_%d' % gpu_id):
                inputs = []
                # Retrieve a slice of the input.
                for x in model.inputs:
                    input_shape = tuple(x.get_shape().as_list())[1:]
                    slice_i = Lambda(get_slice,
                                   output_shape=input_shape,
                                   arguments={'i': i,
                                              'parts': num_gpus})(x)
                    inputs.append(slice_i)

                # Apply model on slice
                # (creating a model replica on the target device).
                outputs = model(inputs)
                if not isinstance(outputs, list):
                    outputs = [outputs]

                # Save the outputs for merging back together later.
                for o in range(len(outputs)):
                    all_outputs[o].append(outputs[o])

    # Merge outputs on CPU.
    with tf.device('/cpu:0'):
        merged = []
        for name, outputs in zip(model.output_names, all_outputs):
            merged.append(concatenate(outputs,
                                    axis=0, name=name))
        return Model(model.inputs, merged)

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.applications.mobilenet import preprocess_input

import time, os
from math import ceil
import multiprocessing

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

NUM_GPU = 4
batch_size = NUM_GPU * 16

training_set = train_datagen.flow_from_directory('train_rnd',
                                                 target_size = (401, 401),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('valid_rnd',
                                                 target_size = (401, 401),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

# testing_set = test_datagen.flow_from_directory('test_edited',
#                                                  target_size = (224, 224),
#                                                  batch_size = batch_size,
#                                                  class_mode = 'categorical',
#                                                  shuffle=False,
#                                                  seed=7,
# #                                                  subset="validation"
#                                              )

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('Nat', 'Nat_Rdn_S1_Icp_LRG541_Adv_0_1_L1.hdf5')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('nat_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('nat_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

from keras.callbacks import Callback
class EarlyStoppingByAccVal(Callback):
    def __init__(self, monitor='val_acc', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current >= self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping" % epoch)
            self.model.stop_training = True

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.79, verbose=1)

# print('Loading pretrained weights')
# model.load_weights(savedfilename)

if NUM_GPU != 1:
    mul_model = multi_gpu_model(model, gpus=NUM_GPU)

epochs = 25##!!!
lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)
if NUM_GPU != 1:
    mul_model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])
else:
    model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

step_size_train=ceil(training_set.n/training_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

if NUM_GPU != 1:
    result = mul_model.fit_generator(training_set,
                              steps_per_epoch = step_size_train,
                              epochs = epochs,
                              validation_data = valid_set,
                              validation_steps = step_size_valid,
                              shuffle=True,
                              verbose=1,
                              callbacks=[tb, csv_logger, checkpointer,earlystopping],
                              max_queue_size=20,
#                               use_multiprocessing=True,
                              workers=10,
                             )
else:    
    result = model.fit_generator(training_set,
                              steps_per_epoch = step_size_train,
                              epochs = epochs,
                              validation_data = valid_set,
                              validation_steps = step_size_valid,
                              shuffle=True,
                              verbose=1,
                              callbacks=[tb, csv_logger, checkpointer,earlystopping],
                              max_queue_size=20,
#                               use_multiprocessing=True,
                              workers=10,
                             )

# loss, acc = model.evaluate_generator(testing_set, steps=step_size_test, verbose=2)
# print('test loss = %f, accuracy: %f' %(loss, acc))

# %%
checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.75, verbose=1)

# print('Loading pretrained weights')
# model.load_weights(savedfilename)

epochs = 8##!!!

if NUM_GPU != 1:
    result = mul_model.fit_generator(training_set,
                              steps_per_epoch = step_size_train,
                              epochs = epochs,
                              validation_data = valid_set,
                              validation_steps = step_size_valid,
                              shuffle=True,
                              verbose=1,
                              callbacks=[tb, csv_logger, checkpointer, earlystopping],
                              max_queue_size=8,
#                               use_multiprocessing=True,
                              workers=4,
                             )
else:
    result = model.fit_generator(training_set,
                              steps_per_epoch = step_size_train,
                              epochs = epochs,
                              validation_data = valid_set,
                              validation_steps = step_size_valid,
                              shuffle=True,
                              verbose=1,
                              callbacks=[tb, csv_logger, checkpointer,earlystopping],
                              max_queue_size=8,
#                               use_multiprocessing=True,
                              workers=4,
                             )
# Out:
# Epoch 1/8
# 7957/7958 [============================>.] - ETA: 0s - loss: 0.6131 - acc: 0.8180Epoch 00001: val_acc improved from -inf to 0.73754, saving model to Nat/Nat_Rdn_S1_Icp_LRG421_Adv_0_1_L1.hdf5
# 7958/7958 [==============================] - 4795s 602ms/step - loss: 0.6131 - acc: 0.8180 - val_loss: 1.1224 - val_acc: 0.7375
# Epoch 2/8
# 7957/7958 [============================>.] - ETA: 0s - loss: 0.6005 - acc: 0.8212Epoch 00002: val_acc improved from 0.73754 to 0.74130, saving model to Nat/Nat_Rdn_S1_Icp_LRG421_Adv_0_1_L1.hdf5
# 7958/7958 [==============================] - 4814s 605ms/step - loss: 0.6005 - acc: 0.8212 - val_loss: 1.1145 - val_acc: 0.7413
# Epoch 3/8
# 7957/7958 [============================>.] - ETA: 0s - loss: 0.5819 - acc: 0.8253Epoch 00003: val_acc did not improve
# 7958/7958 [==============================] - 4806s 604ms/step - loss: 0.5820 - acc: 0.8253 - val_loss: 1.1317 - val_acc: 0.7357
# Epoch 4/8
# 7957/7958 [============================>.] - ETA: 0s - loss: 0.5697 - acc: 0.8303Epoch 00004: val_acc did not improve
# 7958/7958 [==============================] - 4800s 603ms/step - loss: 0.5697 - acc: 0.8303 - val_loss: 1.1329 - val_acc: 0.7367
# Epoch 5/8
# 7957/7958 [============================>.] - ETA: 0s - loss: 0.5564 - acc: 0.8323Epoch 00005: val_acc did not improve
# 7958/7958 [==============================] - 4800s 603ms/step - loss: 0.5564 - acc: 0.8323 - val_loss: 1.1487 - val_acc: 0.7385
# Epoch 6/8
# 7957/7958 [============================>.] - ETA: 0s - loss: 0.5438 - acc: 0.8363Epoch 00006: val_acc did not improve
# 7958/7958 [==============================] - 4795s 603ms/step - loss: 0.5438 - acc: 0.8363 - val_loss: 1.1295 - val_acc: 0.7370
# Epoch 7/8
# 7957/7958 [============================>.] - ETA: 0s - loss: 0.5325 - acc: 0.8403Epoch 00007: val_acc did not improve
# 7958/7958 [==============================] - 4761s 598ms/step - loss: 0.5325 - acc: 0.8403 - val_loss: 1.1609 - val_acc: 0.7340
# Epoch 8/8
# 7957/7958 [============================>.] - ETA: 0s - loss: 0.5179 - acc: 0.8443Epoch 00008: val_acc did not improve
# 7958/7958 [==============================] - 4763s 598ms/step - loss: 0.5179 - acc: 0.8443 - val_loss: 1.1618 - val_acc: 0.7395

# %%
from keras.layers import Lambda, concatenate
from keras import Model
import tensorflow as tf

def multi_gpu_model(model, gpus):
    if isinstance(gpus, (list, tuple)):
        num_gpus = len(gpus)
        target_gpu_ids = gpus
    else:
        num_gpus = gpus
        target_gpu_ids = range(num_gpus)

    def get_slice(data, i, parts):
        shape = tf.shape(data)
        batch_size = shape[:1]
        input_shape = shape[1:]
        step = batch_size // parts
        if i == num_gpus - 1:
            size = batch_size - step * i
        else:
            size = step
        size = tf.concat([size, input_shape], axis=0)
        stride = tf.concat([step, input_shape * 0], axis=0)
        start = stride * i
        return tf.slice(data, start, size)

    all_outputs = []
    for i in range(len(model.outputs)):
        all_outputs.append([])

    # Place a copy of the model on each GPU,
    # each getting a slice of the inputs.
    for i, gpu_id in enumerate(target_gpu_ids):
        with tf.device('/gpu:%d' % gpu_id):
            with tf.name_scope('replica_%d' % gpu_id):
                inputs = []
                # Retrieve a slice of the input.
                for x in model.inputs:
                    input_shape = tuple(x.get_shape().as_list())[1:]
                    slice_i = Lambda(get_slice,
                                   output_shape=input_shape,
                                   arguments={'i': i,
                                              'parts': num_gpus})(x)
                    inputs.append(slice_i)

                # Apply model on slice
                # (creating a model replica on the target device).
                outputs = model(inputs)
                if not isinstance(outputs, list):
                    outputs = [outputs]

                # Save the outputs for merging back together later.
                for o in range(len(outputs)):
                    all_outputs[o].append(outputs[o])

    # Merge outputs on CPU.
    with tf.device('/cpu:0'):
        merged = []
        for name, outputs in zip(model.output_names, all_outputs):
            merged.append(concatenate(outputs,
                                    axis=0, name=name))
        return Model(model.inputs, merged)

# %%
# PREDICT ON OFFICIAL TEST
test_datagen1 = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

test_set1 = test_datagen1.flow_from_directory('test_2019',
                                                 target_size = (421, 421),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

if NUM_GPU != 1:
    predict1=mul_model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
else:
    predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
predicted_class_indices=np.argmax(predict1,axis=1)
labels = (training_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions1 = [labels[k] for k in predicted_class_indices]

import pandas as pd

filenames=test_set1.filenames
results=pd.DataFrame({"file_name":filenames,
                      "predicted1":predictions1,
                      })
results.to_csv('Nat_Rdn_S1_Icp_LRG401_STD_0_1_0710_v3.csv')
results.tail()
# Out:
# Found 35350 images belonging to 1 classes.
#  51/553 [=>............................] - ETA: 12:41

# %%
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 401, 401, 3)  0
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 401, 401, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 401, 401, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# model_2 (Model)                 (None, 1010)         109847314   lambda_3[0][0]
#                                                                  lambda_4[0][0]
# __________________________________________________________________________________________________
# dense_2 (Concatenate)           (None, 1010)         0           model_2[1][0]
#                                                                  model_2[2][0]
# ==================================================================================================
# Total params: 109,847,314
# Trainable params: 109,812,882
# Non-trainable params: 34,432
# __________________________________________________________________________________________________
# None

# %%
base_model = InceptionResNetV2(weights='imagenet',include_top=False,input_shape=(421,421,3))
# x = base_model.output
print(base_model.summary())

# %%
import multiprocessing
print(multiprocessing.cpu_count())
# Out:
# 12

# %%
#Crop-Official Test
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

test_datagen_crop = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

testing_set_crop = test_datagen_crop.flow_from_directory('test_2019',
                                                 target_size = (501, 501),
                                                 batch_size = 1,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="training"
                                              )
#customized generator
test_crops = crop_generator(testing_set_crop, 401)

step_size_test_crop = ceil(testing_set_crop.n/testing_set_crop.batch_size)

tta_steps = 15
predictions = []

# import tensorflow as tf
# with tf.device('/gpu:0'):
for i in range(tta_steps):
    print(i)
    testing_set_crop.reset()
    if NUM_GPU != 1:
        preds=mul_model.predict_generator(test_crops, 
                                           steps = step_size_test_crop,
                                           max_queue_size=16,
#                                                use_multiprocessing=True,
                                           workers=1,
                                           verbose=1)    
    else:
        preds=model.predict_generator(test_crops, 
                                           steps = step_size_test_crop,
                                           max_queue_size=16,
#                                                use_multiprocessing=True,
                                           workers=1,
                                           verbose=1)           
    predictions.append(preds)

mean_pred = np.mean(predictions, axis=0)

predicted_class_indices_mean=np.argmax(mean_pred,axis=1)
labels = (training_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=test_set1.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Nat_Rdn_S1_Icp_LRG401_STD_0_1_0710_v1.csv')
results.tail(20)

# %%
###############Crop-Official Test
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

test_datagen_crop = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

testing_set_crop = test_datagen_crop.flow_from_directory('test_2019',
                                                 target_size = (501, 501),
                                                 batch_size = 2,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="training"
                                              )
#customized generator
test_crops = crop_generator(testing_set_crop, 401)

step_size_test_crop = ceil(testing_set_crop.n/testing_set_crop.batch_size)

tta_steps = 2
# predictions = []

# import tensorflow as tf
# with tf.device('/gpu:0'):
for i in range(tta_steps):
    print(i)
    testing_set_crop.reset()
    if NUM_GPU != 1:
        preds=mul_model.predict_generator(test_crops, 
                                           steps = step_size_test_crop,
                                           max_queue_size=16,
#                                                use_multiprocessing=True,
                                           workers=1,
                                           verbose=1)    
    else:
        preds=model.predict_generator(test_crops, 
                                           steps = step_size_test_crop,
                                           max_queue_size=16,
#                                                use_multiprocessing=True,
                                           workers=1,
                                           verbose=1)           
    predictions.append(preds)

mean_pred = np.mean(predictions, axis=0)

predicted_class_indices_mean=np.argmax(mean_pred,axis=1)
labels = (training_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=test_set1.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Nat_Rdn_S1_Icp_LRG401_STD_0_1_0710_v2.csv')
results.tail(20)
# Out:
# Found 35350 images belonging to 1 classes.
# 0
#  4136/17675 [======>.......................] - ETA: 22:58
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 17675/17675 [==============================] - 1799s 102ms/step
# 1
# 17675/17675 [==============================] - 1801s 102ms/step
#                                            id    predicted
# 35330  0/ffd53b1d22768bdcb13b3f7f20f6b0c8.jpg   Plants_749
# 35331  0/ffd9c770fd57d3674dd7f38259d55b1f.jpg   Plants_397
# 35332  0/ffdad754f2345442b6066daeef2cbc6c.jpg   Plants_863
# 35333  0/ffdb7768a1d68703d12880c9233ac6c5.jpg   Plants_841
# 35334  0/ffdc6ea51b91df0ac1323bffd3d43141.jpg   Plants_699
# 35335  0/ffded51f5fcd84a0d17a84d39bcfafdb.jpg   Plants_415
# 35336  0/ffe0d6426d390b8d20858d07ffe77627.jpg   Plants_502
# 35337  0/ffe1f68fc501efbbcef0526626116095.jpg   Plants_942
# 35338  0/ffe471230c18cf058b5a260a38e7776a.jpg   Plants_917
# 35339  0/ffe628497422756ec27663f764d54bc4.jpg   Plants_578
# 35340  0/ffec87eea81ff3f017bae498552b0b8c.jpg   Plants_882
# 35341  0/fff1dcbe0b5dfd85be7d521d8f49300b.jpg   Plants_550
# 35342  0/fff2e2b0c52e6bca6062c668014bc332.jpg   Insects_21
# 35343  0/fff6c90fc1183979fc52ff5a096ff5f6.jpg   Plants_785
# 35344  0/fff87a0bf91fc87633a60bb9ac34c882.jpg   Plants_454
# 35345  0/fff960565176b09dcf2db1c423380727.jpg   Plants_814
# 35346  0/fffa049864300e290dc01260cfe83a18.jpg    Birds_202
# 35347  0/fffa5dd78d09e2d66c268031d3be380e.jpg  Plants_1008
# 35348  0/fffbc173860f1ecf28dfc72072a1c552.jpg   Plants_515
# 35349  0/fffcf7648fbccb5e27a4c40e790ebb14.jpg   Plants_696

# %%
########## Adding 15 more ##########
#Crop-Official Test
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

test_datagen_crop = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

testing_set_crop = test_datagen_crop.flow_from_directory('test_2019',
                                                 target_size = (501, 501),
                                                 batch_size = 1,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="training"
                                              )
#customized generator
test_crops = crop_generator(testing_set_crop, 401)

step_size_test_crop = ceil(testing_set_crop.n/testing_set_crop.batch_size)

tta_steps = 15
# predictions = []

# import tensorflow as tf
# with tf.device('/gpu:0'):
for i in range(tta_steps):
    print(i)
    testing_set_crop.reset()
    preds=model.predict_generator(test_crops, 
                                           steps = step_size_test_crop,
                                           max_queue_size=16,
#                                                use_multiprocessing=True,
                                           workers=1,
                                           verbose=1)    
    predictions.append(preds)

mean_pred = np.mean(predictions, axis=0)

predicted_class_indices_mean=np.argmax(mean_pred,axis=1)
labels = (training_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=test_set1.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Nat_Rdn_S1_Icp_LRG401_STD_0_1_v4.csv')
results.tail(20)
# Out:
# Found 35350 images belonging to 1 classes.
# 0
# 14687/35350 [===========>..................] - ETA: 8:01
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 35075/35350 [============================>.] - ETA: 6s
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 20278/35350 [================>.............] - ETA: 5:51
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 35350/35350 [==============================] - 826s 23ms/step
# 2
# 35350/35350 [==============================] - 827s 23ms/step
# 3
# 35350/35350 [==============================] - 827s 23ms/step
# 4
# 35350/35350 [==============================] - 824s 23ms/step
# 5
# 35350/35350 [==============================] - 827s 23ms/step
# 6
# 35350/35350 [==============================] - 828s 23ms/step
# 7
# 35350/35350 [==============================] - 826s 23ms/step
# 8
# 35350/35350 [==============================] - 825s 23ms/step
# 9
# 35350/35350 [==============================] - 831s 23ms/step
# 10
# 35350/35350 [==============================] - 828s 23ms/step
# 11
# 29300/35350 [=======================>......] - ETA: 2:21
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 16901/35350 [=============>................] - ETA: 7:12
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 35350/35350 [==============================] - 828s 23ms/step
# 13
#  4577/35350 [==>...........................] - ETA: 12:03
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 28532/35350 [=======================>......] - ETA: 2:39
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 15521/35350 [============>.................] - ETA: 7:45
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 35350/35350 [==============================] - 829s 23ms/step
#                                            id    predicted
# 35330  0/ffd53b1d22768bdcb13b3f7f20f6b0c8.jpg   Plants_749
# 35331  0/ffd9c770fd57d3674dd7f38259d55b1f.jpg   Plants_397
# 35332  0/ffdad754f2345442b6066daeef2cbc6c.jpg   Plants_863
# 35333  0/ffdb7768a1d68703d12880c9233ac6c5.jpg   Plants_841
# 35334  0/ffdc6ea51b91df0ac1323bffd3d43141.jpg   Plants_699
# 35335  0/ffded51f5fcd84a0d17a84d39bcfafdb.jpg   Plants_415
# 35336  0/ffe0d6426d390b8d20858d07ffe77627.jpg   Plants_502
# 35337  0/ffe1f68fc501efbbcef0526626116095.jpg   Plants_942
# 35338  0/ffe471230c18cf058b5a260a38e7776a.jpg   Plants_917
# 35339  0/ffe628497422756ec27663f764d54bc4.jpg   Plants_578
# 35340  0/ffec87eea81ff3f017bae498552b0b8c.jpg   Plants_882
# 35341  0/fff1dcbe0b5dfd85be7d521d8f49300b.jpg   Plants_950
# 35342  0/fff2e2b0c52e6bca6062c668014bc332.jpg   Insects_21
# 35343  0/fff6c90fc1183979fc52ff5a096ff5f6.jpg   Plants_785
# 35344  0/fff87a0bf91fc87633a60bb9ac34c882.jpg   Plants_454
# 35345  0/fff960565176b09dcf2db1c423380727.jpg   Plants_814
# 35346  0/fffa049864300e290dc01260cfe83a18.jpg    Birds_202
# 35347  0/fffa5dd78d09e2d66c268031d3be380e.jpg  Plants_1008
# 35348  0/fffbc173860f1ecf28dfc72072a1c552.jpg   Plants_515
# 35349  0/fffcf7648fbccb5e27a4c40e790ebb14.jpg   Plants_695

# %%
saved_modeljson = os.path.join('Nat', 'Nat_Rdn_S1_Icp_LRG421_Adv_0_1_L1_Bkp.json')
saved_modelweights = os.path.join('Nat', 'Nat_Rdn_S1_Icp_LRG421_Adv_0_1_L1_Bkp.h5')

# serialize model to JSON
model_json = mul_model.to_json()
with open(saved_modeljson, "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model_json.save_weights(saved_modelweights)
print("Saved model to disk")
  
# # load json and create model
# json_file = open('model.json', 'r')
# loaded_model_json = json_file.read()
# json_file.close()
# loaded_model = model_from_json(loaded_model_json)
# # load weights into new model
# loaded_model.load_weights("model.h5")
# print("Loaded model from disk")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-e4872898a697> in <module>
#       3
#       4 # serialize model to JSON
# ----> 5 model_json = mul_model.to_json()
#       6 with open(saved_modeljson, "w") as json_file:
#       7     json_file.write(model_json)
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/keras/engine/topology.py in to_json(self, **kwargs)
#    2666             raise TypeError('Not JSON Serializable:', obj)
#    2667
# -> 2668         model_config = self._updated_config()
#    2669         return json.dumps(model_config, default=get_json_type, **kwargs)
#    2670
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/keras/engine/topology.py in _updated_config(self)
#    2633         from .. import __version__ as keras_version
#    2634
# -> 2635         config = self.get_config()
#    2636         model_config = {
#    2637             'class_name': self.__class__.__name__,
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/keras/engine/topology.py in get_config(self)
#    2395             model_outputs.append([layer.name, new_node_index, tensor_index])
#    2396         config['output_layers'] = model_outputs
# -> 2397         return copy.deepcopy(config)
#    2398
#    2399     @classmethod
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in _deepcopy_dict(x, memo)
#     241     memo[id(x)] = y
#     242     for key, value in x.items():
# --> 243         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     244     return y
#     245 d[dict] = _deepcopy_dict
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in _deepcopy_list(x, memo)
#     216     memo[id(x)] = y
#     217     for a in x:
# --> 218         y.append(deepcopy(a, memo))
#     219     return y
#     220 d[list] = _deepcopy_list
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in _deepcopy_dict(x, memo)
#     241     memo[id(x)] = y
#     242     for key, value in x.items():
# --> 243         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     244     return y
#     245 d[dict] = _deepcopy_dict
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in _deepcopy_dict(x, memo)
#     241     memo[id(x)] = y
#     242     for key, value in x.items():
# --> 243         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     244     return y
#     245 d[dict] = _deepcopy_dict
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in _deepcopy_tuple(x, memo)
#     221
#     222 def _deepcopy_tuple(x, memo):
# --> 223     y = [deepcopy(a, memo) for a in x]
#     224     # We're not going to put the tuple in the memo, but it's still important we
#     225     # check for it, in case the tuple contains recursive mutable structures.
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in <listcomp>(.0)
#     221
#     222 def _deepcopy_tuple(x, memo):
# --> 223     y = [deepcopy(a, memo) for a in x]
#     224     # We're not going to put the tuple in the memo, but it's still important we
#     225     # check for it, in case the tuple contains recursive mutable structures.
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in _deepcopy_tuple(x, memo)
#     221
#     222 def _deepcopy_tuple(x, memo):
# --> 223     y = [deepcopy(a, memo) for a in x]
#     224     # We're not going to put the tuple in the memo, but it's still important we
#     225     # check for it, in case the tuple contains recursive mutable structures.
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in <listcomp>(.0)
#     221
#     222 def _deepcopy_tuple(x, memo):
# --> 223     y = [deepcopy(a, memo) for a in x]
#     224     # We're not going to put the tuple in the memo, but it's still important we
#     225     # check for it, in case the tuple contains recursive mutable structures.
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     180                             raise Error(
#     181                                 "un(deep)copyable object of type %s" % cls)
# --> 182                 y = _reconstruct(x, rv, 1, memo)
#     183
#     184     # If is its own copy, don't memoize.
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in _reconstruct(x, info, deep, memo)
#     295     if state is not None:
#     296         if deep:
# --> 297             state = deepcopy(state, memo)
#     298         if hasattr(y, '__setstate__'):
#     299             y.__setstate__(state)
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in _deepcopy_dict(x, memo)
#     241     memo[id(x)] = y
#     242     for key, value in x.items():
# --> 243         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     244     return y
#     245 d[dict] = _deepcopy_dict
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     180                             raise Error(
#     181                                 "un(deep)copyable object of type %s" % cls)
# --> 182                 y = _reconstruct(x, rv, 1, memo)
#     183
#     184     # If is its own copy, don't memoize.
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in _reconstruct(x, info, deep, memo)
#     295     if state is not None:
#     296         if deep:
# --> 297             state = deepcopy(state, memo)
#     298         if hasattr(y, '__setstate__'):
#     299             y.__setstate__(state)
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in _deepcopy_dict(x, memo)
#     241     memo[id(x)] = y
#     242     for key, value in x.items():
# --> 243         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     244     return y
#     245 d[dict] = _deepcopy_dict
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in _deepcopy_dict(x, memo)
#     241     memo[id(x)] = y
#     242     for key, value in x.items():
# --> 243         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     244     return y
#     245 d[dict] = _deepcopy_dict
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in _deepcopy_method(x, memo)
#     248
#     249 def _deepcopy_method(x, memo): # Copy instance methods
# --> 250     return type(x)(x.__func__, deepcopy(x.__self__, memo))
#     251 _deepcopy_dispatch[types.MethodType] = _deepcopy_method
#     252
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     180                             raise Error(
#     181                                 "un(deep)copyable object of type %s" % cls)
# --> 182                 y = _reconstruct(x, rv, 1, memo)
#     183
#     184     # If is its own copy, don't memoize.
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in _reconstruct(x, info, deep, memo)
#     295     if state is not None:
#     296         if deep:
# --> 297             state = deepcopy(state, memo)
#     298         if hasattr(y, '__setstate__'):
#     299             y.__setstate__(state)
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in _deepcopy_dict(x, memo)
#     241     memo[id(x)] = y
#     242     for key, value in x.items():
# --> 243         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     244     return y
#     245 d[dict] = _deepcopy_dict
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in _deepcopy_list(x, memo)
#     216     memo[id(x)] = y
#     217     for a in x:
# --> 218         y.append(deepcopy(a, memo))
#     219     return y
#     220 d[list] = _deepcopy_list
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     180                             raise Error(
#     181                                 "un(deep)copyable object of type %s" % cls)
# --> 182                 y = _reconstruct(x, rv, 1, memo)
#     183
#     184     # If is its own copy, don't memoize.
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in _reconstruct(x, info, deep, memo)
#     295     if state is not None:
#     296         if deep:
# --> 297             state = deepcopy(state, memo)
#     298         if hasattr(y, '__setstate__'):
#     299             y.__setstate__(state)
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in _deepcopy_dict(x, memo)
#     241     memo[id(x)] = y
#     242     for key, value in x.items():
# --> 243         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     244     return y
#     245 d[dict] = _deepcopy_dict
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     172                     reductor = getattr(x, "__reduce_ex__", None)
#     173                     if reductor:
# --> 174                         rv = reductor(4)
#     175                     else:
#     176                         reductor = getattr(x, "__reduce__", None)
#
# TypeError: can't pickle _thread.lock objects

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.applications.mobilenet import preprocess_input

import time, os
from math import ceil

NUM_GPU = 1
batch_size = NUM_GPU * 16

savedfilename = os.path.join('Nat', 'Nat_Rdn_S1_Icp_LRG421_Adv_0_1_L1.hdf5')

print('Loading pretrained weights')
model.load_weights(savedfilename)

model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# Loading pretrained weights
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-7ce410848740> in <module>
#      13
#      14 print('Loading pretrained weights')
# ---> 15 model.load_weights(savedfilename)
#      16
#      17 model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/keras/engine/topology.py in load_weights(self, filepath, by_name)
#    2620             load_weights_from_hdf5_group_by_name(f, self.layers)
#    2621         else:
# -> 2622             load_weights_from_hdf5_group(f, self.layers)
#    2623
#    2624         if hasattr(f, 'close'):
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/keras/engine/topology.py in load_weights_from_hdf5_group(f, layers)
#    3114                          'containing ' + str(len(layer_names)) +
#    3115                          ' layers into a model with ' +
# -> 3116                          str(len(filtered_layers)) + ' layers.')
#    3117
#    3118     # We batch weight value assignments in a single backend call
#
# ValueError: You are trying to load a weight file containing 1 layers into a model with 191 layers.

# %%
# Out:
# 1.0

# %%
# Out:
# 18

# %%
num_samples = len(predictions[0])
pred_mean = [0]*num_samples

####
# find max prediction/index
# select top-17
# mean of 17

for tx2 in range(num_samples):
    ars_max = []
#     print('=======&%d&=======' %tx2)
    for idx in range(len(predictions)):   
        ars_max.append(numpy.amax(predictions[idx][tx2]))
        ars_max_a = numpy.array(ars_max)
        ars_idx = ars_max_a.argsort()[-17:][::-1]
        
    pred_mean[tx2] = 0                   
    for ind in range(len(ars_idx)):
        pred_mean[tx2] = pred_mean[tx2] + predictions[ars_idx[ind]][tx2]
        
    pred_mean[tx2] = pred_mean[tx2]/len(ars_idx) 

#top-17out of 30
predicted_class_indices_mean=np.argmax(pred_mean,axis=1)
labels = (training_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=test_set1.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Nat_Rdn_S1_Icp_LRG401_STD_0_1_v5.csv')
results.tail(20)
# Out:
#                                            id    predicted
# 35330  0/ffd53b1d22768bdcb13b3f7f20f6b0c8.jpg   Plants_749
# 35331  0/ffd9c770fd57d3674dd7f38259d55b1f.jpg   Plants_397
# 35332  0/ffdad754f2345442b6066daeef2cbc6c.jpg   Plants_863
# 35333  0/ffdb7768a1d68703d12880c9233ac6c5.jpg   Plants_841
# 35334  0/ffdc6ea51b91df0ac1323bffd3d43141.jpg   Plants_699
# 35335  0/ffded51f5fcd84a0d17a84d39bcfafdb.jpg   Plants_415
# 35336  0/ffe0d6426d390b8d20858d07ffe77627.jpg   Plants_502
# 35337  0/ffe1f68fc501efbbcef0526626116095.jpg   Plants_942
# 35338  0/ffe471230c18cf058b5a260a38e7776a.jpg   Plants_917
# 35339  0/ffe628497422756ec27663f764d54bc4.jpg   Plants_578
# 35340  0/ffec87eea81ff3f017bae498552b0b8c.jpg   Plants_882
# 35341  0/fff1dcbe0b5dfd85be7d521d8f49300b.jpg   Plants_950
# 35342  0/fff2e2b0c52e6bca6062c668014bc332.jpg   Insects_21
# 35343  0/fff6c90fc1183979fc52ff5a096ff5f6.jpg   Plants_785
# 35344  0/fff87a0bf91fc87633a60bb9ac34c882.jpg   Plants_454
# 35345  0/fff960565176b09dcf2db1c423380727.jpg   Plants_814
# 35346  0/fffa049864300e290dc01260cfe83a18.jpg    Birds_202
# 35347  0/fffa5dd78d09e2d66c268031d3be380e.jpg  Plants_1008
# 35348  0/fffbc173860f1ecf28dfc72072a1c552.jpg   Plants_515
# 35349  0/fffcf7648fbccb5e27a4c40e790ebb14.jpg   Plants_695

# %%
# Out:
#                                            id    predicted
# 35330  0/ffd53b1d22768bdcb13b3f7f20f6b0c8.jpg   Plants_749
# 35331  0/ffd9c770fd57d3674dd7f38259d55b1f.jpg   Plants_398
# 35332  0/ffdad754f2345442b6066daeef2cbc6c.jpg   Plants_892
# 35333  0/ffdb7768a1d68703d12880c9233ac6c5.jpg   Plants_841
# 35334  0/ffdc6ea51b91df0ac1323bffd3d43141.jpg   Plants_699
# 35335  0/ffded51f5fcd84a0d17a84d39bcfafdb.jpg   Plants_415
# 35336  0/ffe0d6426d390b8d20858d07ffe77627.jpg   Plants_502
# 35337  0/ffe1f68fc501efbbcef0526626116095.jpg   Plants_942
# 35338  0/ffe471230c18cf058b5a260a38e7776a.jpg   Plants_917
# 35339  0/ffe628497422756ec27663f764d54bc4.jpg   Plants_578
# 35340  0/ffec87eea81ff3f017bae498552b0b8c.jpg   Plants_882
# 35341  0/fff1dcbe0b5dfd85be7d521d8f49300b.jpg   Plants_950
# 35342  0/fff2e2b0c52e6bca6062c668014bc332.jpg   Insects_21
# 35343  0/fff6c90fc1183979fc52ff5a096ff5f6.jpg   Plants_785
# 35344  0/fff87a0bf91fc87633a60bb9ac34c882.jpg   Plants_454
# 35345  0/fff960565176b09dcf2db1c423380727.jpg   Plants_814
# 35346  0/fffa049864300e290dc01260cfe83a18.jpg    Birds_204
# 35347  0/fffa5dd78d09e2d66c268031d3be380e.jpg  Plants_1008
# 35348  0/fffbc173860f1ecf28dfc72072a1c552.jpg   Plants_515
# 35349  0/fffcf7648fbccb5e27a4c40e790ebb14.jpg   Plants_695

# %%
print('Loading pretrained weights')
model.load_weights(savedfilename)

loss, acc = model.evaluate_generator(valid_set, steps=step_size_valid)
print('test loss = %f, accuracy: %f' %(loss, acc))
# Out:
# Loading pretrained weights
# test loss = 1.641238, accuracy: 0.614552

# %%
model.save_weights(os.path.join('Nat', '2_Set1_MobileNet_224x224_Global_dense4096x2_E2ETrainingV2.hdf5'))

# %%
# print('Loading pretrained weights')
# model.load_weights(savedfilename)

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.71, verbose=1)

epochs = 10
import tensorflow as tf
with tf.device('/gpu:0'):
    result = model.fit_generator(training_set,
                              steps_per_epoch = step_size_train,
                              epochs = epochs,
                              validation_data = valid_set,
                              validation_steps = step_size_valid,
                              shuffle=True,
                              max_queue_size=16,
#                               use_multiprocessing=True,
                              workers=8,                             
                              verbose=1,
                              callbacks=[tb, csv_logger, checkpointer,earlystopping],
                             )
# Out:
# Epoch 1/10
# 6982/7958 [=========================>....] - ETA: 12:20 - loss: 1.3656 - acc: 0.6265
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 7957/7958 [============================>.] - ETA: 0s - loss: 1.2984 - acc: 0.6425Epoch 00002: val_acc improved from 0.66409 to 0.66939, saving model to Nat/Nat_Rdn_S1_Icp_LRG501_STD_0_1_L1.hdf5
# 7958/7958 [==============================] - 6144s 772ms/step - loss: 1.2984 - acc: 0.6425 - val_loss: 1.2000 - val_acc: 0.6694
# Epoch 3/10
# 2047/7958 [======>.......................] - ETA: 1:14:41 - loss: 1.2389 - acc: 0.6579
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 7957/7958 [============================>.] - ETA: 0s - loss: 1.2422 - acc: 0.6564Epoch 00003: val_acc improved from 0.66939 to 0.67778, saving model to Nat/Nat_Rdn_S1_Icp_LRG501_STD_0_1_L1.hdf5
# 7958/7958 [==============================] - 6142s 772ms/step - loss: 1.2422 - acc: 0.6564 - val_loss: 1.1846 - val_acc: 0.6778
# Epoch 4/10
#  783/7958 [=>............................] - ETA: 1:30:43 - loss: 1.1784 - acc: 0.6706
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 7095/7958 [=========================>....] - ETA: 10:54 - loss: 1.1901 - acc: 0.6685
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 7957/7958 [============================>.] - ETA: 0s - loss: 1.1898 - acc: 0.6686Epoch 00004: val_acc improved from 0.67778 to 0.68602, saving model to Nat/Nat_Rdn_S1_Icp_LRG501_STD_0_1_L1.hdf5
# 7958/7958 [==============================] - 6144s 772ms/step - loss: 1.1898 - acc: 0.6686 - val_loss: 1.1506 - val_acc: 0.6860
# Epoch 5/10
# 7957/7958 [============================>.] - ETA: 0s - loss: 1.1456 - acc: 0.6802Epoch 00005: val_acc improved from 0.68602 to 0.69103, saving model to Nat/Nat_Rdn_S1_Icp_LRG501_STD_0_1_L1.hdf5
# 7958/7958 [==============================] - 6147s 772ms/step - loss: 1.1456 - acc: 0.6802 - val_loss: 1.1285 - val_acc: 0.6910
# Epoch 6/10
# 7957/7958 [============================>.] - ETA: 0s - loss: 1.1016 - acc: 0.6902Epoch 00006: val_acc improved from 0.69103 to 0.69441, saving model to Nat/Nat_Rdn_S1_Icp_LRG501_STD_0_1_L1.hdf5
# 7958/7958 [==============================] - 6148s 773ms/step - loss: 1.1015 - acc: 0.6902 - val_loss: 1.1184 - val_acc: 0.6944
# Epoch 7/10
# 1146/7958 [===>..........................] - ETA: 1:26:07 - loss: 1.0598 - acc: 0.7020
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 7957/7958 [============================>.] - ETA: 0s - loss: 1.0627 - acc: 0.7006Epoch 00007: val_acc improved from 0.69441 to 0.69979, saving model to Nat/Nat_Rdn_S1_Icp_LRG501_STD_0_1_L1.hdf5
# 7958/7958 [==============================] - 6147s 772ms/step - loss: 1.0627 - acc: 0.7006 - val_loss: 1.1025 - val_acc: 0.6998
# Epoch 8/10
# 4264/7958 [===============>..............] - ETA: 46:41 - loss: 1.0260 - acc: 0.7096
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 7957/7958 [============================>.] - ETA: 0s - loss: 1.0290 - acc: 0.7090Epoch 00008: val_acc improved from 0.69979 to 0.70339, saving model to Nat/Nat_Rdn_S1_Icp_LRG501_STD_0_1_L1.hdf5
# 7958/7958 [==============================] - 6147s 772ms/step - loss: 1.0290 - acc: 0.7090 - val_loss: 1.0941 - val_acc: 0.7034
# Epoch 9/10
# 3919/7958 [=============>................] - ETA: 51:03 - loss: 0.9824 - acc: 0.7204
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 7957/7958 [============================>.] - ETA: 0s - loss: 0.9911 - acc: 0.7182Epoch 00009: val_acc improved from 0.70339 to 0.71009, saving model to Nat/Nat_Rdn_S1_Icp_LRG501_STD_0_1_L1.hdf5
# Epoch 00008: early stopping
# 7958/7958 [==============================] - 6147s 772ms/step - loss: 0.9911 - acc: 0.7182 - val_loss: 1.0803 - val_acc: 0.7101

# %%
# Out:
# Epoch 1/10
# Epoch 00001: val_acc improved from 0.60100 to 0.60376, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1796s - loss: 0.8207 - acc: 0.7591 - val_loss: 1.7491 - val_acc: 0.6038
# Epoch 2/10
# Epoch 00002: val_acc did not improve
#  - 1792s - loss: 0.7996 - acc: 0.7643 - val_loss: 1.7718 - val_acc: 0.6011
# Epoch 3/10
# Epoch 00003: val_acc did not improve
#  - 1790s - loss: 0.7893 - acc: 0.7675 - val_loss: 1.7884 - val_acc: 0.5968
# Epoch 4/10
# Epoch 00004: val_acc did not improve
#  - 1789s - loss: 0.7756 - acc: 0.7712 - val_loss: 1.8104 - val_acc: 0.5955
# Epoch 5/10
# Epoch 00005: val_acc did not improve
#  - 1794s - loss: 0.7645 - acc: 0.7747 - val_loss: 1.8033 - val_acc: 0.5971
# Epoch 6/10
# Epoch 00006: val_acc did not improve
#  - 1788s - loss: 0.7480 - acc: 0.7788 - val_loss: 1.8290 - val_acc: 0.5965
# Epoch 7/10
# Epoch 00007: val_acc did not improve
#  - 1786s - loss: 0.7345 - acc: 0.7804 - val_loss: 1.8282 - val_acc: 0.5969
# Epoch 8/10
# Epoch 00008: val_acc did not improve
#  - 1784s - loss: 0.7210 - acc: 0.7851 - val_loss: 1.8320 - val_acc: 0.5978
# Epoch 9/10
# Epoch 00009: val_acc did not improve
#  - 1786s - loss: 0.7092 - acc: 0.7890 - val_loss: 1.8523 - val_acc: 0.5954
# Epoch 10/10
# Epoch 00010: val_acc did not improve
#  - 1787s - loss: 0.6988 - acc: 0.7923 - val_loss: 1.8652 - val_acc: 0.5977

# %%
# print('Loading pretrained weights')
# model.load_weights(savedfilename)

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.65, verbose=1)

epochs = 40
import tensorflow as tf
with tf.device('/gpu:0'):
    result = model.fit_generator(training_set,
                              steps_per_epoch = step_size_train,
                              epochs = epochs,
                              validation_data = valid_set,
                              validation_steps = step_size_valid,
                              shuffle=True,
                              max_queue_size=16,
#                               use_multiprocessing=True,
                              workers=8,                             
                              verbose=2,
                              callbacks=[tb, csv_logger, checkpointer,earlystopping],
                             )
# Out:
# Epoch 1/40
# Epoch 00001: val_acc improved from 0.54751 to 0.55281, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1747s - loss: 1.7712 - acc: 0.5333 - val_loss: 1.7294 - val_acc: 0.5528
# Epoch 2/40
# Epoch 00002: val_acc improved from 0.55281 to 0.55630, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1746s - loss: 1.7313 - acc: 0.5424 - val_loss: 1.7128 - val_acc: 0.5563
# Epoch 3/40
# Epoch 00003: val_acc improved from 0.55630 to 0.56196, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1753s - loss: 1.6882 - acc: 0.5510 - val_loss: 1.7025 - val_acc: 0.5620
# Epoch 4/40
# Epoch 00004: val_acc improved from 0.56196 to 0.56574, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1749s - loss: 1.6552 - acc: 0.5577 - val_loss: 1.6892 - val_acc: 0.5657
# Epoch 5/40
# Epoch 00005: val_acc improved from 0.56574 to 0.56694, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1756s - loss: 1.6177 - acc: 0.5667 - val_loss: 1.6767 - val_acc: 0.5669
# Epoch 6/40
# Epoch 00006: val_acc improved from 0.56694 to 0.56837, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1756s - loss: 1.5875 - acc: 0.5746 - val_loss: 1.6746 - val_acc: 0.5684
# Epoch 7/40
# Epoch 00007: val_acc improved from 0.56837 to 0.57064, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1749s - loss: 1.5512 - acc: 0.5822 - val_loss: 1.6652 - val_acc: 0.5706
# Epoch 8/40
# Epoch 00008: val_acc improved from 0.57064 to 0.57611, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1753s - loss: 1.5174 - acc: 0.5892 - val_loss: 1.6444 - val_acc: 0.5761
# Epoch 9/40
# Epoch 00009: val_acc improved from 0.57611 to 0.57743, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1748s - loss: 1.4888 - acc: 0.5966 - val_loss: 1.6394 - val_acc: 0.5774
# Epoch 10/40
# Epoch 00010: val_acc did not improve
#  - 1745s - loss: 1.4566 - acc: 0.6039 - val_loss: 1.6528 - val_acc: 0.5774
# Epoch 11/40
# Epoch 00011: val_acc improved from 0.57743 to 0.58375, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1756s - loss: 1.4295 - acc: 0.6092 - val_loss: 1.6309 - val_acc: 0.5837
# Epoch 12/40
# Epoch 00012: val_acc improved from 0.58375 to 0.58459, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1746s - loss: 1.4033 - acc: 0.6159 - val_loss: 1.6305 - val_acc: 0.5846
# Epoch 13/40
# Epoch 00013: val_acc improved from 0.58459 to 0.58623, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1747s - loss: 1.3768 - acc: 0.6230 - val_loss: 1.6329 - val_acc: 0.5862
# Epoch 14/40
# Epoch 00014: val_acc improved from 0.58623 to 0.58709, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1754s - loss: 1.3490 - acc: 0.6291 - val_loss: 1.6227 - val_acc: 0.5871
# Epoch 15/40
# Epoch 00015: val_acc improved from 0.58709 to 0.58814, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1754s - loss: 1.3198 - acc: 0.6359 - val_loss: 1.6245 - val_acc: 0.5881
# Epoch 16/40
# Epoch 00016: val_acc improved from 0.58814 to 0.58835, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1754s - loss: 1.2962 - acc: 0.6404 - val_loss: 1.6293 - val_acc: 0.5884
# Epoch 17/40
# Epoch 00017: val_acc improved from 0.58835 to 0.58921, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1754s - loss: 1.2726 - acc: 0.6469 - val_loss: 1.6371 - val_acc: 0.5892
# Epoch 18/40
# Epoch 00018: val_acc improved from 0.58921 to 0.59177, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1753s - loss: 1.2496 - acc: 0.6522 - val_loss: 1.6225 - val_acc: 0.5918
# Epoch 19/40
# Epoch 00019: val_acc improved from 0.59177 to 0.59307, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1755s - loss: 1.2233 - acc: 0.6593 - val_loss: 1.6243 - val_acc: 0.5931
# Epoch 20/40
# Epoch 00020: val_acc improved from 0.59307 to 0.59348, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1781s - loss: 1.2054 - acc: 0.6630 - val_loss: 1.6267 - val_acc: 0.5935
# Epoch 21/40
# Epoch 00021: val_acc did not improve
#  - 1791s - loss: 1.1827 - acc: 0.6686 - val_loss: 1.6326 - val_acc: 0.5930
# Epoch 22/40
# Epoch 00022: val_acc did not improve
#  - 1793s - loss: 1.1598 - acc: 0.6731 - val_loss: 1.6485 - val_acc: 0.5927
# Epoch 23/40
# Epoch 00023: val_acc improved from 0.59348 to 0.59570, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1787s - loss: 1.1399 - acc: 0.6780 - val_loss: 1.6425 - val_acc: 0.5957
# Epoch 24/40
# Epoch 00024: val_acc improved from 0.59570 to 0.59593, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1787s - loss: 1.1171 - acc: 0.6840 - val_loss: 1.6458 - val_acc: 0.5959
# Epoch 25/40
# Epoch 00025: val_acc improved from 0.59593 to 0.59749, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1788s - loss: 1.0958 - acc: 0.6891 - val_loss: 1.6494 - val_acc: 0.5975
# Epoch 26/40
# Epoch 00026: val_acc did not improve
#  - 1788s - loss: 1.0733 - acc: 0.6939 - val_loss: 1.6583 - val_acc: 0.5954
# Epoch 27/40
# Epoch 00027: val_acc improved from 0.59749 to 0.59978, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1793s - loss: 1.0569 - acc: 0.6995 - val_loss: 1.6495 - val_acc: 0.5998
# Epoch 28/40
# Epoch 00028: val_acc improved from 0.59978 to 0.59998, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1791s - loss: 1.0402 - acc: 0.7026 - val_loss: 1.6565 - val_acc: 0.6000
# Epoch 29/40
# Epoch 00029: val_acc did not improve
#  - 1792s - loss: 1.0194 - acc: 0.7074 - val_loss: 1.6696 - val_acc: 0.5977
# Epoch 30/40
# Epoch 00030: val_acc did not improve
#  - 1789s - loss: 0.9990 - acc: 0.7124 - val_loss: 1.6716 - val_acc: 0.5997
# Epoch 31/40
# Epoch 00031: val_acc improved from 0.59998 to 0.60085, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1792s - loss: 0.9833 - acc: 0.7176 - val_loss: 1.6717 - val_acc: 0.6008
# Epoch 32/40
# Epoch 00032: val_acc did not improve
#  - 1787s - loss: 0.9664 - acc: 0.7223 - val_loss: 1.7008 - val_acc: 0.5969
# Epoch 33/40
# Epoch 00033: val_acc did not improve
#  - 1781s - loss: 0.9499 - acc: 0.7267 - val_loss: 1.6994 - val_acc: 0.5992
# Epoch 34/40
# Epoch 00034: val_acc did not improve
#  - 1782s - loss: 0.9304 - acc: 0.7312 - val_loss: 1.7046 - val_acc: 0.5981
# Epoch 35/40
# Epoch 00035: val_acc did not improve
#  - 1787s - loss: 0.9113 - acc: 0.7346 - val_loss: 1.7067 - val_acc: 0.5993
# Epoch 36/40
# Epoch 00036: val_acc did not improve
#  - 1791s - loss: 0.8992 - acc: 0.7380 - val_loss: 1.7099 - val_acc: 0.6008
# Epoch 37/40
# Epoch 00037: val_acc did not improve
#  - 1784s - loss: 0.8824 - acc: 0.7435 - val_loss: 1.7345 - val_acc: 0.5986
# Epoch 38/40
# Epoch 00038: val_acc did not improve
#  - 1780s - loss: 0.8662 - acc: 0.7471 - val_loss: 1.7359 - val_acc: 0.5985
# Epoch 39/40
# Epoch 00039: val_acc improved from 0.60085 to 0.60100, saving model to Nat/Rnd_Set3_InceptionV3.hdf5
#  - 1791s - loss: 0.8528 - acc: 0.7505 - val_loss: 1.7414 - val_acc: 0.6010
# Epoch 40/40
# Epoch 00040: val_acc did not improve
#  - 1789s - loss: 0.8299 - acc: 0.7565 - val_loss: 1.7575 - val_acc: 0.5997

# %%
# Visualize training history
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy

# list all data in history
# history = result.history
#print(history.history.keys())
# summarize history for accuracy
plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Visualize training history
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy

# list all data in history
# history = result.history
#print(history.history.keys())
# summarize history for accuracy
plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
mkdir Nat

# %%
rm Nat/2_1_Set1_MobileNet_224x224_Global_dense4096x2_E2ETrainingV2.hdf5

# %%
ls -l

# %% [markdown]
# %rm -r train_edited
# %rm -r valid_edited
# %rm -r train_val2019

# %%
rm -r train_edited

# %%
rm -r valid_edited

# %%
rm -r train_val2019
