# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14440224274965397889
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 10977044071
# locality {
#   bus_id: 1
# }
# incarnation: 15383274536765165145
# physical_device_desc: "device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1"
# , name: "/device:GPU:1"
# device_type: "GPU"
# memory_limit: 10977044071
# locality {
#   bus_id: 1
# }
# incarnation: 17480295693993697196
# physical_device_desc: "device: 1, name: GeForce GTX 1080 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1"
# , name: "/device:GPU:2"
# device_type: "GPU"
# memory_limit: 10977044071
# locality {
#   bus_id: 1
# }
# incarnation: 809811683650813496
# physical_device_desc: "device: 2, name: GeForce GTX 1080 Ti, pci bus id: 0000:03:00.0, compute capability: 6.1"
# , name: "/device:GPU:3"
# device_type: "GPU"
# memory_limit: 10975051776
# locality {
#   bus_id: 1
# }
# incarnation: 4829663557809879439
# physical_device_desc: "device: 3, name: GeForce GTX 1080 Ti, pci bus id: 0000:04:00.0, compute capability: 6.1"
# ]

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0,1,2,3"

# %%
cd /media/datastorage/Phong/cifar10/cifar-10-batches-py/
# Out:
# /media/datastorage/Phong/cifar10/cifar-10-batches-py

# %%
#Images/n02105855-Shetland_sheepdog/n02105855_9415.jpg

import glob
import os

import numpy as np
from matplotlib.image import imread
# %matplotlib inline
import matplotlib.pyplot as plt

# get image parts
def get_image_parts(image_path):
    """Given a full path to an image, return its parts."""
    parts = image_path.split(os.path.sep)
    #print(parts)
    filename = parts[2]
    filename_no_ext = filename.split('.')[0]
    classname = parts[1]
    train_or_test = parts[0]
    
    return train_or_test, classname, filename_no_ext, filename
    
    
sample_images = list(glob.glob(os.path.join('train_resized_299/', '*/*'), recursive=True))
np.random.seed(42)
rand_imgs = np.random.choice(sample_images, size=5*5)
fig, axarr = plt.subplots(5, 5, figsize=(20, 20))

for i, rand_img in enumerate(rand_imgs):
    train_or_test, classname, filename_no_ext, filename = get_image_parts(rand_img)
    
    classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

    j = i // 5
    k = i % 5
    axarr[j][k].imshow(imread(rand_img))
    axarr[j][k].title.set_text(classes[classname])
    axarr[j][k].grid(False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-2483eb91ffbc> in <module>
#      36     k = i % 5
#      37     axarr[j][k].imshow(imread(rand_img))
# ---> 38     axarr[j][k].title.set_text(classes[classname])
#      39     axarr[j][k].grid(False)
#
# TypeError: tuple indices must be integers or slices, not str

# %%
# from PIL import Image
# import numpy

# def convert_img_square(im_pth='', dest_path='', desired_size=224):
# #     print(im_pth)
    
#     im = Image.open(im_pth)
#     old_size = im.size  # (width, height) format

#     ratio = float(desired_size)/max(old_size)
#     new_size = tuple([int(x*ratio) for x in old_size])

# #     new_im = im.resize(new_size, Image.ANTIALIAS)
#     new_im = im.resize(new_size)
    
#     new_im = new_im.convert('RGB')
    
#     new_im.save(dest_path)

#     return True

# %%
# ####=======================
# import glob
# import os
# import shutil
# import random

# #move class folder from classname_# to classname/#

# def get_image_parts(image_path):
#     """Given a full path to an image, return its parts."""
#     parts = image_path.split(os.path.sep)
#     #print(parts)
#     filename = parts[2]
#     filename_no_ext = filename.split('.')[0]
#     classname = parts[1]
#     train_or_test = parts[0]
    
#     return train_or_test, classname, filename_no_ext, filename

# move_folders = ['fashion_mnist_train_resized_299']
# dest_folder = 'fashion_mnist_train_resized_350'
# data_file = []

# # look for all images in sub-folders
# for folder in move_folders:
#     class_folders = glob.glob(os.path.join(folder, '*'))
#     print('folder %s' %class_folders)
    
# #     for sub_folder in class_folders:
# #         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
# #         print('sub folder %s' %sub_class_folders)
        
#     for iid_class in class_folders:
#         print(iid_class)
        
#         class_files = glob.glob(os.path.join(iid_class, '*.png'))
        
# #         #Determize Set# (No Suffle)
#         set = len(class_files)
#         inner = range(0*set, 1*set) #all

#         print('moving %d files' %(len(inner)))

# #         random_list = random.sample(range(len(class_files)), int(len(class_files)/5)) #1/5 dataset
# #         for idx in range(len(random_list)):

#         for idx in range(len(inner)):
#             src = class_files[inner[idx]]

#             train_or_test, classname, filename_no_ext, filename = get_image_parts(src)
#             dst = os.path.join(dest_folder, classname, filename)

#             # image directory
#             img_directory = os.path.join(dest_folder, classname)

#             # create folder if not existed
#             if not os.path.exists(img_directory):
#                 os.makedirs(img_directory)
                
#             # convert image
#             convert_img_square(src, dst, 350)
# #             #moving file
# #             shutil.move(src, dst)
# # #                 shutil.copy(src, dst)

# %%
# ####=======================
# import glob
# import os
# import shutil
# import random

# #move class folder from classname_# to classname/#

# def get_image_parts(image_path):
#     """Given a full path to an image, return its parts."""
#     parts = image_path.split(os.path.sep)
#     #print(parts)
#     filename = parts[2]
#     filename_no_ext = filename.split('.')[0]
#     classname = parts[1]
#     train_or_test = parts[0]
    
#     return train_or_test, classname, filename_no_ext, filename

# move_folders = ['fashion_mnist_test_resized_299']
# dest_folder = 'fashion_mnist_test_resized_350'
# data_file = []

# # look for all images in sub-folders
# for folder in move_folders:
#     class_folders = glob.glob(os.path.join(folder, '*'))
#     print('folder %s' %class_folders)
    
# #     for sub_folder in class_folders:
# #         sub_class_folders = glob.glob(os.path.join(sub_folder, '*'))    
# #         print('sub folder %s' %sub_class_folders)
        
#     for iid_class in class_folders:
#         print(iid_class)
        
#         class_files = glob.glob(os.path.join(iid_class, '*.png'))
        
# #         #Determize Set# (No Suffle)
#         set = len(class_files)
#         inner = range(0*set, 1*set) #all

#         print('moving %d files' %(len(inner)))

# #         random_list = random.sample(range(len(class_files)), int(len(class_files)/5)) #1/5 dataset
# #         for idx in range(len(random_list)):

#         for idx in range(len(inner)):
#             src = class_files[inner[idx]]

#             train_or_test, classname, filename_no_ext, filename = get_image_parts(src)
#             dst = os.path.join(dest_folder, classname, filename)

#             # image directory
#             img_directory = os.path.join(dest_folder, classname)

#             # create folder if not existed
#             if not os.path.exists(img_directory):
#                 os.makedirs(img_directory)
                
#             # convert image
#             convert_img_square(src, dst, 299)
# #             #moving file
# #             shutil.move(src, dst)
# # #                 shutil.copy(src, dst)

# %%
## fix for multi_gpu_model prediction time longer
from keras.layers import Lambda, concatenate
from keras import Model
import tensorflow as tf

def multi_gpu_model(model, gpus):
    if isinstance(gpus, (list, tuple)):
        num_gpus = len(gpus)
        target_gpu_ids = gpus
    else:
        num_gpus = gpus
        target_gpu_ids = range(num_gpus)

    def get_slice(data, i, parts):
        shape = tf.shape(data)
        batch_size = shape[:1]
        input_shape = shape[1:]
        step = batch_size // parts
        if i == num_gpus - 1:
            size = batch_size - step * i
        else:
            size = step
        size = tf.concat([size, input_shape], axis=0)
        stride = tf.concat([step, input_shape * 0], axis=0)
        start = stride * i
        return tf.slice(data, start, size)

    all_outputs = []
    for i in range(len(model.outputs)):
        all_outputs.append([])

    # Place a copy of the model on each GPU,
    # each getting a slice of the inputs.
    for i, gpu_id in enumerate(target_gpu_ids):
        with tf.device('/gpu:%d' % gpu_id):
            with tf.name_scope('replica_%d' % gpu_id):
                inputs = []
                # Retrieve a slice of the input.
                for x in model.inputs:
                    input_shape = tuple(x.get_shape().as_list())[1:]
                    slice_i = Lambda(get_slice,
                                   output_shape=input_shape,
                                   arguments={'i': i,
                                              'parts': num_gpus})(x)
                    inputs.append(slice_i)

                # Apply model on slice
                # (creating a model replica on the target device).
                outputs = model(inputs)
                if not isinstance(outputs, list):
                    outputs = [outputs]

                # Save the outputs for merging back together later.
                for o in range(len(outputs)):
                    all_outputs[o].append(outputs[o])

    # Merge outputs on CPU.
    with tf.device('/cpu:0'):
        merged = []
        for name, outputs in zip(model.output_names, all_outputs):
            merged.append(concatenate(outputs,
                                    axis=0, name=name))
        return Model(model.inputs, merged)
# Out:
# Using TensorFlow backend.

# %%
from keras.callbacks import Callback
import pickle
import sys

#Stop training on val_acc
class EarlyStoppingByAccVal(Callback):
    def __init__(self, monitor='val_acc', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current >= self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping" % epoch)
            self.model.stop_training = True

#Save large model using pickle formate instead of h5            
class SaveCheckPoint(Callback):
    def __init__(self, model, dest_folder):
        super(Callback, self).__init__()
        self.model = model
        self.dest_folder = dest_folder
        
        #initiate
        self.best_val_acc = 0
        self.best_val_loss = sys.maxsize #get max value
          
    def on_epoch_end(self, epoch, logs={}):
        val_acc = logs['val_acc']
        val_loss = logs['val_loss']

        if val_acc > self.best_val_acc:
            self.best_val_acc = val_acc
            
            # Save weights in pickle format instead of h5
            print('\nSaving val_acc %f at %s' %(self.best_val_acc, self.dest_folder))
            weigh= self.model.get_weights()

            #now, use pickle to save your model weights, instead of .h5
            #for heavy model architectures, .h5 file is unsupported.
            fpkl= open(self.dest_folder, 'wb') #Python 3
            pickle.dump(weigh, fpkl, protocol= pickle.HIGHEST_PROTOCOL)
            fpkl.close()
            
#             model.save('tmp.h5')
        elif val_acc == self.best_val_acc:
            if val_loss < self.best_val_loss:
                self.best_val_loss=val_loss
                
                # Save weights in pickle format instead of h5
                print('\nSaving val_acc %f at %s' %(self.best_val_acc, self.dest_folder))
                weigh= self.model.get_weights()

                #now, use pickle to save your model weights, instead of .h5
                #for heavy model architectures, .h5 file is unsupported.
                fpkl= open(self.dest_folder, 'wb') #Python 3
                pickle.dump(weigh, fpkl, protocol= pickle.HIGHEST_PROTOCOL)
                fpkl.close()

# %%
#SET 1

from classification_models.keras import Classifiers
from keras.models import Model
# from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM, SimpleRNN, Reshape, Concatenate,Bidirectional
# from keras.applications.inception_v3 import preprocess_input

from keras.layers import GaussianNoise

senet, preprocess_input = Classifiers.get('seresnext101')

f2_base = senet(input_shape=(299,299,3), weights='imagenet', include_top=False)
f2_x = GlobalAveragePooling2D()(f2_base.output)

#ADV Model
# f2_x = Reshape([1,2048])(f2_x)  
# f2_x = SimpleRNN(2048, 
#             return_sequences=False,                       
# #             dropout=0.8                                     
#             input_shape=[1,2048])(f2_x)

#Regularization with noise
f2_x = GaussianNoise(0.1)(f2_x)

f2_x = Dense(2048, activation='relu')(f2_x)
f2_x = Dense(10, activation='softmax')(f2_x)
model_2 = Model(inputs=[f2_base.input],outputs=[f2_x])

print(model_2.summary())
# # print(f2_base.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 305, 305, 3)  0           input[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 150, 150, 64) 9408        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 150, 150, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 150, 150, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 152, 152, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 75, 75, 64)   0           zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 75, 75, 128)  8192        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 75, 75, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 75, 75, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 77, 77, 128)  0           activation_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 75, 75, 4)    144         lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 75, 75, 4)    144         lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 75, 75, 4)    144         lambda_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 75, 75, 4)    144         lambda_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 75, 75, 4)    144         lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 75, 75, 4)    144         lambda_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 75, 75, 4)    144         lambda_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 75, 75, 4)    144         lambda_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 75, 75, 4)    144         lambda_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 75, 75, 4)    144         lambda_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 75, 75, 4)    144         lambda_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 75, 75, 4)    144         lambda_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 75, 75, 4)    144         lambda_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 75, 75, 4)    144         lambda_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 75, 75, 4)    144         lambda_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 75, 75, 4)    144         lambda_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 75, 75, 4)    144         lambda_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 75, 75, 4)    144         lambda_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 75, 75, 4)    144         lambda_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 75, 75, 4)    144         lambda_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 75, 75, 4)    144         lambda_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 75, 75, 4)    144         lambda_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 75, 75, 4)    144         lambda_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 75, 75, 4)    144         lambda_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 75, 75, 4)    144         lambda_25[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 75, 75, 4)    144         lambda_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 75, 75, 4)    144         lambda_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 75, 75, 4)    144         lambda_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 75, 75, 4)    144         lambda_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 75, 75, 4)    144         lambda_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 75, 75, 4)    144         lambda_31[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 75, 75, 4)    144         lambda_32[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 75, 75, 128)  0           conv2d_3[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
#                                                                  conv2d_9[0][0]
#                                                                  conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
#                                                                  conv2d_15[0][0]
#                                                                  conv2d_16[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_18[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
#                                                                  conv2d_21[0][0]
#                                                                  conv2d_22[0][0]
#                                                                  conv2d_23[0][0]
#                                                                  conv2d_24[0][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_27[0][0]
#                                                                  conv2d_28[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_30[0][0]
#                                                                  conv2d_31[0][0]
#                                                                  conv2d_32[0][0]
#                                                                  conv2d_33[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 75, 75, 128)  512         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 75, 75, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 75, 75, 256)  32768       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 75, 75, 256)  1024        conv2d_35[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 256)          0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 1, 1, 256)    0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 1, 1, 16)     4112        lambda_33[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1, 1, 16)     0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 1, 1, 256)    4352        activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 1, 1, 256)    0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 75, 75, 256)  16384       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 75, 75, 256)  0           batch_normalization_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 75, 75, 256)  1024        conv2d_36[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 75, 75, 256)  0           multiply_1[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 75, 75, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 75, 75, 128)  32768       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 75, 75, 128)  512         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 75, 75, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 77, 77, 128)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_52 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_53 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_54 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_55 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_56 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_57 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_58 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_59 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_60 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_61 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_62 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_63 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_64 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_65 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 75, 75, 4)    144         lambda_34[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 75, 75, 4)    144         lambda_35[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 75, 75, 4)    144         lambda_36[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 75, 75, 4)    144         lambda_37[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 75, 75, 4)    144         lambda_38[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 75, 75, 4)    144         lambda_39[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 75, 75, 4)    144         lambda_40[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 75, 75, 4)    144         lambda_41[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 75, 75, 4)    144         lambda_42[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 75, 75, 4)    144         lambda_43[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 75, 75, 4)    144         lambda_44[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 75, 75, 4)    144         lambda_45[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 75, 75, 4)    144         lambda_46[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 75, 75, 4)    144         lambda_47[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 75, 75, 4)    144         lambda_48[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 75, 75, 4)    144         lambda_49[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 75, 75, 4)    144         lambda_50[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 75, 75, 4)    144         lambda_51[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 75, 75, 4)    144         lambda_52[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 75, 75, 4)    144         lambda_53[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 75, 75, 4)    144         lambda_54[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 75, 75, 4)    144         lambda_55[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 75, 75, 4)    144         lambda_56[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 75, 75, 4)    144         lambda_57[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 75, 75, 4)    144         lambda_58[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 75, 75, 4)    144         lambda_59[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 75, 75, 4)    144         lambda_60[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 75, 75, 4)    144         lambda_61[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 75, 75, 4)    144         lambda_62[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 75, 75, 4)    144         lambda_63[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 75, 75, 4)    144         lambda_64[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 75, 75, 4)    144         lambda_65[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 75, 75, 128)  0           conv2d_40[0][0]
#                                                                  conv2d_41[0][0]
#                                                                  conv2d_42[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
#                                                                  conv2d_45[0][0]
#                                                                  conv2d_46[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_48[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_50[0][0]
#                                                                  conv2d_51[0][0]
#                                                                  conv2d_52[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_54[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_56[0][0]
#                                                                  conv2d_57[0][0]
#                                                                  conv2d_58[0][0]
#                                                                  conv2d_59[0][0]
#                                                                  conv2d_60[0][0]
#                                                                  conv2d_61[0][0]
#                                                                  conv2d_62[0][0]
#                                                                  conv2d_63[0][0]
#                                                                  conv2d_64[0][0]
#                                                                  conv2d_65[0][0]
#                                                                  conv2d_66[0][0]
#                                                                  conv2d_67[0][0]
#                                                                  conv2d_68[0][0]
#                                                                  conv2d_69[0][0]
#                                                                  conv2d_70[0][0]
#                                                                  conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 75, 75, 128)  512         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 75, 75, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 75, 75, 256)  32768       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 75, 75, 256)  1024        conv2d_72[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 256)          0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# lambda_66 (Lambda)              (None, 1, 1, 256)    0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 1, 1, 16)     4112        lambda_66[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 1, 1, 16)     0           conv2d_73[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 1, 1, 256)    4352        activation_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 1, 1, 256)    0           conv2d_74[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 75, 75, 256)  0           batch_normalization_8[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 75, 75, 256)  0           multiply_2[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 75, 75, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 75, 75, 128)  32768       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 75, 75, 128)  512         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 75, 75, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 77, 77, 128)  0           activation_12[0][0]
# __________________________________________________________________________________________________
# lambda_67 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_68 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_69 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_70 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_71 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_72 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_73 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_74 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_75 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_76 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_77 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_78 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_79 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_80 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_81 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_82 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_83 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_84 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_85 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_86 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_87 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_88 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_89 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_90 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_91 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_92 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_93 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_94 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_95 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_96 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_97 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# ...
# lambda_1076 (Lambda)            (None, 12, 12, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1077 (Lambda)            (None, 12, 12, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1078 (Lambda)            (None, 12, 12, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1079 (Lambda)            (None, 12, 12, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1080 (Lambda)            (None, 12, 12, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1081 (Lambda)            (None, 12, 12, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1082 (Lambda)            (None, 12, 12, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1083 (Lambda)            (None, 12, 12, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1084 (Lambda)            (None, 12, 12, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1085 (Lambda)            (None, 12, 12, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1086 (Lambda)            (None, 12, 12, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1087 (Lambda)            (None, 12, 12, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# lambda_1088 (Lambda)            (None, 12, 12, 32)   0           zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_1159 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1057[0][0]
# __________________________________________________________________________________________________
# conv2d_1160 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1058[0][0]
# __________________________________________________________________________________________________
# conv2d_1161 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1059[0][0]
# __________________________________________________________________________________________________
# conv2d_1162 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1060[0][0]
# __________________________________________________________________________________________________
# conv2d_1163 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1061[0][0]
# __________________________________________________________________________________________________
# conv2d_1164 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1062[0][0]
# __________________________________________________________________________________________________
# conv2d_1165 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1063[0][0]
# __________________________________________________________________________________________________
# conv2d_1166 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1064[0][0]
# __________________________________________________________________________________________________
# conv2d_1167 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1065[0][0]
# __________________________________________________________________________________________________
# conv2d_1168 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1066[0][0]
# __________________________________________________________________________________________________
# conv2d_1169 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1067[0][0]
# __________________________________________________________________________________________________
# conv2d_1170 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1068[0][0]
# __________________________________________________________________________________________________
# conv2d_1171 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1069[0][0]
# __________________________________________________________________________________________________
# conv2d_1172 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1070[0][0]
# __________________________________________________________________________________________________
# conv2d_1173 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1071[0][0]
# __________________________________________________________________________________________________
# conv2d_1174 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1072[0][0]
# __________________________________________________________________________________________________
# conv2d_1175 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1073[0][0]
# __________________________________________________________________________________________________
# conv2d_1176 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1074[0][0]
# __________________________________________________________________________________________________
# conv2d_1177 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1075[0][0]
# __________________________________________________________________________________________________
# conv2d_1178 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1076[0][0]
# __________________________________________________________________________________________________
# conv2d_1179 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1077[0][0]
# __________________________________________________________________________________________________
# conv2d_1180 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1078[0][0]
# __________________________________________________________________________________________________
# conv2d_1181 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1079[0][0]
# __________________________________________________________________________________________________
# conv2d_1182 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1080[0][0]
# __________________________________________________________________________________________________
# conv2d_1183 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1081[0][0]
# __________________________________________________________________________________________________
# conv2d_1184 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1082[0][0]
# __________________________________________________________________________________________________
# conv2d_1185 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1083[0][0]
# __________________________________________________________________________________________________
# conv2d_1186 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1084[0][0]
# __________________________________________________________________________________________________
# conv2d_1187 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1085[0][0]
# __________________________________________________________________________________________________
# conv2d_1188 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1086[0][0]
# __________________________________________________________________________________________________
# conv2d_1189 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1087[0][0]
# __________________________________________________________________________________________________
# conv2d_1190 (Conv2D)            (None, 10, 10, 32)   9216        lambda_1088[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 10, 10, 1024) 0           conv2d_1159[0][0]
#                                                                  conv2d_1160[0][0]
#                                                                  conv2d_1161[0][0]
#                                                                  conv2d_1162[0][0]
#                                                                  conv2d_1163[0][0]
#                                                                  conv2d_1164[0][0]
#                                                                  conv2d_1165[0][0]
#                                                                  conv2d_1166[0][0]
#                                                                  conv2d_1167[0][0]
#                                                                  conv2d_1168[0][0]
#                                                                  conv2d_1169[0][0]
#                                                                  conv2d_1170[0][0]
#                                                                  conv2d_1171[0][0]
#                                                                  conv2d_1172[0][0]
#                                                                  conv2d_1173[0][0]
#                                                                  conv2d_1174[0][0]
#                                                                  conv2d_1175[0][0]
#                                                                  conv2d_1176[0][0]
#                                                                  conv2d_1177[0][0]
#                                                                  conv2d_1178[0][0]
#                                                                  conv2d_1179[0][0]
#                                                                  conv2d_1180[0][0]
#                                                                  conv2d_1181[0][0]
#                                                                  conv2d_1182[0][0]
#                                                                  conv2d_1183[0][0]
#                                                                  conv2d_1184[0][0]
#                                                                  conv2d_1185[0][0]
#                                                                  conv2d_1186[0][0]
#                                                                  conv2d_1187[0][0]
#                                                                  conv2d_1188[0][0]
#                                                                  conv2d_1189[0][0]
#                                                                  conv2d_1190[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 10, 10, 1024) 4096        concatenate_33[0][0]
# __________________________________________________________________________________________________
# activation_163 (Activation)     (None, 10, 10, 1024) 0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_1191 (Conv2D)            (None, 10, 10, 2048) 2097152     activation_163[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 10, 10, 2048) 8192        conv2d_1191[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_33 (Gl (None, 2048)         0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# lambda_1089 (Lambda)            (None, 1, 1, 2048)   0           global_average_pooling2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_1192 (Conv2D)            (None, 1, 1, 128)    262272      lambda_1089[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, 1, 1, 128)    0           conv2d_1192[0][0]
# __________________________________________________________________________________________________
# conv2d_1193 (Conv2D)            (None, 1, 1, 2048)   264192      activation_164[0][0]
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, 1, 1, 2048)   0           conv2d_1193[0][0]
# __________________________________________________________________________________________________
# multiply_33 (Multiply)          (None, 10, 10, 2048) 0           batch_normalization_104[0][0]
#                                                                  activation_165[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 10, 10, 2048) 0           multiply_33[0][0]
#                                                                  activation_161[0][0]
# __________________________________________________________________________________________________
# activation_166 (Activation)     (None, 10, 10, 2048) 0           add_33[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_34 (Gl (None, 2048)         0           activation_166[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_1 (GaussianNoise (None, 2048)         0           global_average_pooling2d_34[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2048)         4196352     gaussian_noise_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           20490       dense_1[0][0]
# ==================================================================================================
# Total params: 51,261,114
# Trainable params: 51,123,258
# Non-trainable params: 137,856
# __________________________________________________________________________________________________
# None

# %%
# %mv train_resized train_resized_299
# %mv test_resized test_resized_299

# %%
#Non-Groups
#Split training and validation
#Using Expert Data

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil
import multiprocessing

NUM_GPU = 4
batch_size = 40
#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    model_mul = multi_gpu_model(model_2, gpus=NUM_GPU)

epochs = 40##!!!
lr = 1e-4
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

if NUM_GPU != 1:
    model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

train_set = train_datagen.flow_from_directory('train_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('test_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cifar10_SEResNext101_LRG299_Mul_STD.pkl')

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.99, verbose=1)
savecheckpoint = SaveCheckPoint(model_2, savedfilename)

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('cifar10_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('cifar10_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

# number of steps each epoch
step_size_train=ceil(train_set.n/train_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[earlystopping, savecheckpoint],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# Found 50000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Epoch 1/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.7063 - acc: 0.7543
# Saving val_acc 0.911200 at checkpoints/Cifar10_SEResNext101_LRG299_Mul_STD.pkl
# 1250/1250 [==============================] - 1336s 1s/step - loss: 0.7062 - acc: 0.7543 - val_loss: 0.2530 - val_acc: 0.9112
# Epoch 2/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.3984 - acc: 0.8621
# Saving val_acc 0.934800 at checkpoints/Cifar10_SEResNext101_LRG299_Mul_STD.pkl
# 1250/1250 [==============================] - 1267s 1s/step - loss: 0.3984 - acc: 0.8620 - val_loss: 0.1929 - val_acc: 0.9348
# Epoch 3/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.3210 - acc: 0.8895
# Saving val_acc 0.944500 at checkpoints/Cifar10_SEResNext101_LRG299_Mul_STD.pkl
# 1250/1250 [==============================] - 1269s 1s/step - loss: 0.3210 - acc: 0.8895 - val_loss: 0.1659 - val_acc: 0.9445
# Epoch 4/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2775 - acc: 0.9032
# Saving val_acc 0.947700 at checkpoints/Cifar10_SEResNext101_LRG299_Mul_STD.pkl
# 1250/1250 [==============================] - 1269s 1s/step - loss: 0.2775 - acc: 0.9032 - val_loss: 0.1645 - val_acc: 0.9477
# Epoch 5/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2475 - acc: 0.9155
# Saving val_acc 0.953000 at checkpoints/Cifar10_SEResNext101_LRG299_Mul_STD.pkl
# 1250/1250 [==============================] - 1270s 1s/step - loss: 0.2476 - acc: 0.9155 - val_loss: 0.1425 - val_acc: 0.9530
# Epoch 6/40
# 1250/1250 [==============================] - 1269s 1s/step - loss: 0.2225 - acc: 0.9227 - val_loss: 0.1731 - val_acc: 0.9442
# Epoch 7/40
# 1250/1250 [==============================] - 1266s 1s/step - loss: 0.2088 - acc: 0.9288 - val_loss: 0.1674 - val_acc: 0.9491
# Epoch 8/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.1911 - acc: 0.9350
# Saving val_acc 0.953000 at checkpoints/Cifar10_SEResNext101_LRG299_Mul_STD.pkl
# 1250/1250 [==============================] - 1269s 1s/step - loss: 0.1910 - acc: 0.9350 - val_loss: 0.1603 - val_acc: 0.9530
# Epoch 9/40
# 1250/1250 [==============================] - 1266s 1s/step - loss: 0.1775 - acc: 0.9395 - val_loss: 0.1657 - val_acc: 0.9501
# Epoch 10/40
# 1250/1250 [==============================] - 1268s 1s/step - loss: 0.1691 - acc: 0.9418 - val_loss: 0.1654 - val_acc: 0.9522
# Epoch 11/40
# 1250/1250 [==============================] - 1268s 1s/step - loss: 0.1578 - acc: 0.9455 - val_loss: 0.1797 - val_acc: 0.9478
# Epoch 12/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.1488 - acc: 0.9492
# Saving val_acc 0.953800 at checkpoints/Cifar10_SEResNext101_LRG299_Mul_STD.pkl
# 1250/1250 [==============================] - 1269s 1s/step - loss: 0.1488 - acc: 0.9492 - val_loss: 0.1521 - val_acc: 0.9538
# Epoch 13/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.1415 - acc: 0.9510
# Saving val_acc 0.960200 at checkpoints/Cifar10_SEResNext101_LRG299_Mul_STD.pkl
# 1250/1250 [==============================] - 1269s 1s/step - loss: 0.1414 - acc: 0.9510 - val_loss: 0.1255 - val_acc: 0.9602
# Epoch 14/40
# 1250/1250 [==============================] - 1267s 1s/step - loss: 0.1345 - acc: 0.9535 - val_loss: 0.1419 - val_acc: 0.9590
# Epoch 15/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.1262 - acc: 0.9566
# Saving val_acc 0.960700 at checkpoints/Cifar10_SEResNext101_LRG299_Mul_STD.pkl
# 1250/1250 [==============================] - 1270s 1s/step - loss: 0.1261 - acc: 0.9566 - val_loss: 0.1396 - val_acc: 0.9607
# Epoch 16/40
# 1250/1250 [==============================] - 1269s 1s/step - loss: 0.1215 - acc: 0.9567 - val_loss: 0.1584 - val_acc: 0.9549
# Epoch 17/40
# 1250/1250 [==============================] - 1270s 1s/step - loss: 0.1167 - acc: 0.9598 - val_loss: 0.1457 - val_acc: 0.9575
# Epoch 18/40
# 1250/1250 [==============================] - 1269s 1s/step - loss: 0.1109 - acc: 0.9623 - val_loss: 0.1546 - val_acc: 0.9557
# Epoch 19/40
# 1250/1250 [==============================] - 1268s 1s/step - loss: 0.1073 - acc: 0.9629 - val_loss: 0.1595 - val_acc: 0.9561
# Epoch 20/40
# 1250/1250 [==============================] - 1268s 1s/step - loss: 0.1054 - acc: 0.9645 - val_loss: 0.1477 - val_acc: 0.9592
# Epoch 21/40
# 1250/1250 [==============================] - 1268s 1s/step - loss: 0.0982 - acc: 0.9655 - val_loss: 0.1625 - val_acc: 0.9573
# Epoch 22/40
# 1250/1250 [==============================] - 1269s 1s/step - loss: 0.0978 - acc: 0.9663 - val_loss: 0.1560 - val_acc: 0.9581
# Epoch 23/40
# 1250/1250 [==============================] - 1269s 1s/step - loss: 0.0933 - acc: 0.9678 - val_loss: 0.1598 - val_acc: 0.9577
# Epoch 24/40
# 1250/1250 [==============================] - 1268s 1s/step - loss: 0.0892 - acc: 0.9690 - val_loss: 0.1572 - val_acc: 0.9593
# Epoch 25/40
# 1250/1250 [==============================] - 1270s 1s/step - loss: 0.0872 - acc: 0.9702 - val_loss: 0.1697 - val_acc: 0.9573
# Epoch 26/40
# 1250/1250 [==============================] - 1268s 1s/step - loss: 0.0904 - acc: 0.9693 - val_loss: 0.1552 - val_acc: 0.9595
# Epoch 27/40
# 1250/1250 [==============================] - 1270s 1s/step - loss: 0.0844 - acc: 0.9707 - val_loss: 0.1668 - val_acc: 0.9555
# Epoch 28/40
# 1250/1250 [==============================] - 1268s 1s/step - loss: 0.0788 - acc: 0.9724 - val_loss: 0.1835 - val_acc: 0.9548
# Epoch 29/40
# 1250/1250 [==============================] - 1267s 1s/step - loss: 0.0786 - acc: 0.9733 - val_loss: 0.1557 - val_acc: 0.9584
# Epoch 30/40
# 1250/1250 [==============================] - 1269s 1s/step - loss: 0.0772 - acc: 0.9736 - val_loss: 0.1614 - val_acc: 0.9565
# Epoch 31/40
# 1250/1250 [==============================] - 1268s 1s/step - loss: 0.0727 - acc: 0.9749 - val_loss: 0.1748 - val_acc: 0.9562
# Epoch 32/40
# 1250/1250 [==============================] - 1269s 1s/step - loss: 0.0745 - acc: 0.9747 - val_loss: 0.1663 - val_acc: 0.9592
# Epoch 33/40
# 1250/1250 [==============================] - 1268s 1s/step - loss: 0.0722 - acc: 0.9753 - val_loss: 0.1782 - val_acc: 0.9572
# Epoch 34/40
# 1250/1250 [==============================] - 1270s 1s/step - loss: 0.0730 - acc: 0.9748 - val_loss: 0.1538 - val_acc: 0.9605
# Epoch 35/40
# 1250/1250 [==============================] - 1268s 1s/step - loss: 0.0704 - acc: 0.9758 - val_loss: 0.1645 - val_acc: 0.9599
# Epoch 36/40
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0648 - acc: 0.9773
# Saving val_acc 0.963200 at checkpoints/Cifar10_SEResNext101_LRG299_Mul_STD.pkl
# 1250/1250 [==============================] - 1271s 1s/step - loss: 0.0648 - acc: 0.9773 - val_loss: 0.1537 - val_acc: 0.9632
# Epoch 37/40
# 1250/1250 [==============================] - 1269s 1s/step - loss: 0.0675 - acc: 0.9761 - val_loss: 0.1789 - val_acc: 0.9585
# Epoch 38/40
# 1250/1250 [==============================] - 1269s 1s/step - loss: 0.0649 - acc: 0.9774 - val_loss: 0.1763 - val_acc: 0.9580
# Epoch 39/40
# 1250/1250 [==============================] - 1270s 1s/step - loss: 0.0643 - acc: 0.9782 - val_loss: 0.1543 - val_acc: 0.9604
# Epoch 40/40
# 1250/1250 [==============================] - 1272s 1s/step - loss: 0.0625 - acc: 0.9791 - val_loss: 0.1614 - val_acc: 0.9603

# %%
#use pickle to load model weights
import os
import pickle

pklfile= os.path.join('checkpoints', 'Cifar10_SEResNext101_LRG299_Mul_STD.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

# #use set_weights to load the modelweights into the model architecture
# NUM_GPU = 4
# #Using multiple models if more than 1 GPU
# if NUM_GPU != 1:
#     model_mul = multi_gpu_model(model_2, gpus=NUM_GPU)

model_mul.set_weights(weigh)

# %%
mkdir checkpoints

# %%
# Change LR=1e-5

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

epochs = 15##!!!
lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

if NUM_GPU != 1:
    model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

savedfilename = os.path.join('checkpoints', 'Cifar10_SEResNext101_LRG299_Mul_STD_L2.pkl')
savecheckpoint = SaveCheckPoint(model_2, savedfilename)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[earlystopping, savecheckpoint],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# Epoch 1/15
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0455 - acc: 0.9842
# Saving val_acc 0.966100 at checkpoints/Cifar10_SEResNext101_LRG299_Mul_STD_L2.pkl
# 1250/1250 [==============================] - 1334s 1s/step - loss: 0.0456 - acc: 0.9842 - val_loss: 0.1409 - val_acc: 0.9661
# Epoch 2/15
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0357 - acc: 0.9878
# Saving val_acc 0.969200 at checkpoints/Cifar10_SEResNext101_LRG299_Mul_STD_L2.pkl
# 1250/1250 [==============================] - 1267s 1s/step - loss: 0.0357 - acc: 0.9878 - val_loss: 0.1380 - val_acc: 0.9692
# Epoch 3/15
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0300 - acc: 0.9897
# Saving val_acc 0.970100 at checkpoints/Cifar10_SEResNext101_LRG299_Mul_STD_L2.pkl
# 1250/1250 [==============================] - 1268s 1s/step - loss: 0.0301 - acc: 0.9897 - val_loss: 0.1386 - val_acc: 0.9701
# Epoch 4/15
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0273 - acc: 0.9907
# Saving val_acc 0.970700 at checkpoints/Cifar10_SEResNext101_LRG299_Mul_STD_L2.pkl
# 1250/1250 [==============================] - 1268s 1s/step - loss: 0.0274 - acc: 0.9906 - val_loss: 0.1327 - val_acc: 0.9707
# Epoch 5/15
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0269 - acc: 0.9906
# Saving val_acc 0.971500 at checkpoints/Cifar10_SEResNext101_LRG299_Mul_STD_L2.pkl
# 1250/1250 [==============================] - 1269s 1s/step - loss: 0.0269 - acc: 0.9906 - val_loss: 0.1360 - val_acc: 0.9715
# Epoch 6/15
# 1250/1250 [==============================] - 1267s 1s/step - loss: 0.0256 - acc: 0.9914 - val_loss: 0.1371 - val_acc: 0.9712
# Epoch 7/15
# 1250/1250 [==============================] - 1265s 1s/step - loss: 0.0251 - acc: 0.9918 - val_loss: 0.1401 - val_acc: 0.9708
# Epoch 8/15
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.0229 - acc: 0.9922
# Saving val_acc 0.972700 at checkpoints/Cifar10_SEResNext101_LRG299_Mul_STD_L2.pkl
# 1250/1250 [==============================] - 1268s 1s/step - loss: 0.0229 - acc: 0.9922 - val_loss: 0.1358 - val_acc: 0.9727
# Epoch 9/15
# 1250/1250 [==============================] - 1267s 1s/step - loss: 0.0224 - acc: 0.9921 - val_loss: 0.1373 - val_acc: 0.9713
# Epoch 10/15
# 1250/1250 [==============================] - 1268s 1s/step - loss: 0.0214 - acc: 0.9928 - val_loss: 0.1450 - val_acc: 0.9704
# Epoch 11/15
# 1250/1250 [==============================] - 1267s 1s/step - loss: 0.0215 - acc: 0.9924 - val_loss: 0.1444 - val_acc: 0.9697
# Epoch 12/15
# 1250/1250 [==============================] - 1269s 1s/step - loss: 0.0206 - acc: 0.9931 - val_loss: 0.1425 - val_acc: 0.9700
# Epoch 13/15
# 1250/1250 [==============================] - 1267s 1s/step - loss: 0.0193 - acc: 0.9936 - val_loss: 0.1401 - val_acc: 0.9719
# Epoch 14/15
# 1250/1250 [==============================] - 1269s 1s/step - loss: 0.0181 - acc: 0.9942 - val_loss: 0.1389 - val_acc: 0.9707
# Epoch 15/15
# 1250/1250 [==============================] - 1266s 1s/step - loss: 0.0189 - acc: 0.9938 - val_loss: 0.1431 - val_acc: 0.9719

# %%
max(result.history['val_acc']),min(result.history['val_acc'])
# Out:
# (0.9727000055313111, 0.9661000044345855)

# %%
# Visualize training history
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy

# list all data in history
# history = result.history
#print(history.history.keys())
# summarize history for accuracy
plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('SeNet - 501 - Noise model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('SeNet - 501 - Noise model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#use pickle to load model weights
import os
import pickle

pklfile= os.path.join('checkpoints', 'Cifar10_SEResNext101_LRG299_Mul_STD_L2.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

# #use set_weights to load the modelweights into the model architecture
# NUM_GPU = 4
# #Using multiple models if more than 1 GPU
# if NUM_GPU != 1:
#     model_mul = multi_gpu_model(model_2, gpus=NUM_GPU)

model_mul.set_weights(weigh)

# %%
# Change LR=1e-6

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

epochs = 15##!!!
lr = 1e-6
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

if NUM_GPU != 1:
    model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

savedfilename = os.path.join('checkpoints', 'Cifar10_SEResNext101_LRG299_Mul_STD_L3.pkl')
savecheckpoint = SaveCheckPoint(model_2, savedfilename)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[earlystopping, savecheckpoint],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# Epoch 1/15
# 1249/1250 [============================>.] - ETA: 1s - loss: 0.0230 - acc: 0.9924
# Saving val_acc 0.973100 at checkpoints/Cifar10_SEResNext101_LRG299_Mul_STD_L3.pkl
# 1250/1250 [==============================] - 1357s 1s/step - loss: 0.0230 - acc: 0.9924 - val_loss: 0.1348 - val_acc: 0.9731
# Epoch 2/15
# 1250/1250 [==============================] - 1278s 1s/step - loss: 0.0203 - acc: 0.9932 - val_loss: 0.1349 - val_acc: 0.9724
# Epoch 3/15
# 1250/1250 [==============================] - 1277s 1s/step - loss: 0.0221 - acc: 0.9926 - val_loss: 0.1367 - val_acc: 0.9721
# Epoch 4/15
# 1250/1250 [==============================] - 1279s 1s/step - loss: 0.0208 - acc: 0.9930 - val_loss: 0.1363 - val_acc: 0.9723
# Epoch 5/15
# 1250/1250 [==============================] - 1277s 1s/step - loss: 0.0206 - acc: 0.9929 - val_loss: 0.1357 - val_acc: 0.9728
# Epoch 6/15
# 1250/1250 [==============================] - 1278s 1s/step - loss: 0.0230 - acc: 0.9925 - val_loss: 0.1366 - val_acc: 0.9724
# Epoch 7/15
# 1250/1250 [==============================] - 1278s 1s/step - loss: 0.0189 - acc: 0.9937 - val_loss: 0.1367 - val_acc: 0.9721
# Epoch 8/15
# 1250/1250 [==============================] - 1276s 1s/step - loss: 0.0220 - acc: 0.9929 - val_loss: 0.1362 - val_acc: 0.9724
# Epoch 9/15
# 1250/1250 [==============================] - 1278s 1s/step - loss: 0.0204 - acc: 0.9933 - val_loss: 0.1364 - val_acc: 0.9723
# Epoch 10/15
# 1250/1250 [==============================] - 1275s 1s/step - loss: 0.0197 - acc: 0.9933 - val_loss: 0.1376 - val_acc: 0.9726
# Epoch 11/15
# 1250/1250 [==============================] - 1278s 1s/step - loss: 0.0199 - acc: 0.9931 - val_loss: 0.1358 - val_acc: 0.9726
# Epoch 12/15
# 1250/1250 [==============================] - 1277s 1s/step - loss: 0.0203 - acc: 0.9932 - val_loss: 0.1373 - val_acc: 0.9723
# Epoch 13/15
# 1250/1250 [==============================] - 1276s 1s/step - loss: 0.0194 - acc: 0.9931 - val_loss: 0.1358 - val_acc: 0.9722
# Epoch 14/15
# 1250/1250 [==============================] - 1278s 1s/step - loss: 0.0182 - acc: 0.9939 - val_loss: 0.1365 - val_acc: 0.9725
# Epoch 15/15
# 1250/1250 [==============================] - 1276s 1s/step - loss: 0.0223 - acc: 0.9927 - val_loss: 0.1346 - val_acc: 0.9728

# %%
# import tensorflow as tf
# import keras.backend as K

# run_meta = tf.RunMetadata()
# with tf.Session(graph=tf.Graph()) as sess:
#     K.set_session(sess)
#     net = senet(input_tensor=tf.placeholder('float32', shape=(1,421,421,3)))

#     opts = tf.profiler.ProfileOptionBuilder.float_operation()    
#     flops = tf.profiler.profile(sess.graph, run_meta=run_meta, cmd='op', options=opts)

#     opts = tf.profiler.ProfileOptionBuilder.trainable_variables_parameter()    
#     params = tf.profiler.profile(sess.graph, run_meta=run_meta, cmd='op', options=opts)

#     print("{:,} --- {:,}".format(flops.total_float_ops, params.total_parameters))
# Out:
# 59,914,782,602 --- 49,093,272

# %%
#use pickle to load model weights
import os
import pickle

pklfile= os.path.join('checkpoints', 'Cifar10_SEResNext101_LRG299_Mul_STD_L3.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

#use set_weights to load the modelweights into the model architecture
NUM_GPU = 4
#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    model_mul = multi_gpu_model(model_2, gpus=NUM_GPU)

model_mul.set_weights(weigh)

# %%
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
import time, os
from math import ceil

# PREDICT ON OFFICIAL TEST
train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

test_datagen1 = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

batch_size = 40

train_set = train_datagen.flow_from_directory('train_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

test_set1 = test_datagen1.flow_from_directory('test_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

if NUM_GPU != 1:
    predict1=model_mul.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
# else:
#     predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
predicted_class_indices=np.argmax(predict1,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions1 = [labels[k] for k in predicted_class_indices]

import pandas as pd

filenames=test_set1.filenames
results=pd.DataFrame({"file_name":filenames,
                      "predicted1":predictions1,
                      })
results.to_csv('Cifar10_SeResNet101_MulModels299_STD_0711_v1.csv')
results.head()
# Out:
# Found 50000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# 250/250 [==============================] - 95s 379ms/step
#                   file_name predicted1
# 0  0/aeroplane_s_000002.png          0
# 1  0/aeroplane_s_000040.png          0
# 2  0/aeroplane_s_000045.png          0
# 3  0/aeroplane_s_000063.png          0
# 4     0/airbus_s_000009.png          0

# %%
results.tail()

# %%
cp FashionMNIST_SeResNet101_MulModels299_2310_01.csv /home/bribeiro/Phong/Nat19/FashionMNIST_SeResNet101_MulModels299_2310_01.csv

# %%
np.save(os.path.join('pred_npy','FashionMNIST_SEResNext101_LRG299_Mul.npy'), predict1)

# %%
from keras.preprocessing.image import ImageDataGenerator
from math import ceil
import numpy as np

batch_size = 40

#Crop-Official Test
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

def crop_generator(batches, crop_length):
    """Generate random crops from the image batches"""
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

test_datagen_crop = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

testing_set_crop = test_datagen_crop.flow_from_directory('test_resized_299',
                                                 target_size = (320, 320),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="training"
                                              )
#customized generator
test_crops = crop_generator(testing_set_crop, 299)

step_size_test_crop = ceil(testing_set_crop.n/testing_set_crop.batch_size)

tta_steps = 21
predictions = []

# import tensorflow as tf
# with tf.device('/gpu:0'):
for i in range(tta_steps):
    print(i)
    testing_set_crop.reset()
    if NUM_GPU != 1:
        preds=model_mul.predict_generator(test_crops, 
                                           steps = step_size_test_crop,
#                                            max_queue_size=16,
#                                                use_multiprocessing=True,
#                                            workers=1,
                                           verbose=1)    
#     else:
#         preds=model.predict_generator(test_crops, 
#                                            steps = step_size_test_crop,
#                                            max_queue_size=16,
# #                                                use_multiprocessing=True,
#                                            workers=1,
#                                            verbose=1)  
#     preds=model_2.predict_generator(test_crops,steps = step_size_test_crop,verbose=1)  
    predictions.append(preds)

mean_pred = np.mean(predictions, axis=0)

predicted_class_indices_mean=np.argmax(mean_pred,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar10_SeResNet101_MulModels299_STD_tta_21_0715_v5.csv')
results.head(10)
# Out:
# Found 10000 images belonging to 10 classes.
# 0
# 250/250 [==============================] - 91s 365ms/step
# 1
# 250/250 [==============================] - 92s 368ms/step
# 2
# 250/250 [==============================] - 92s 367ms/step
# 3
# 250/250 [==============================] - 92s 368ms/step
# 4
# 250/250 [==============================] - 92s 369ms/step
# 5
# 250/250 [==============================] - 92s 368ms/step
# 6
# 250/250 [==============================] - 92s 368ms/step
# 7
# 250/250 [==============================] - 92s 368ms/step
# 8
# 250/250 [==============================] - 92s 367ms/step
# 9
# 250/250 [==============================] - 92s 368ms/step
# 10
# 250/250 [==============================] - 92s 368ms/step
# 11
# 250/250 [==============================] - 92s 368ms/step
# 12
# 250/250 [==============================] - 92s 368ms/step
# 13
# 250/250 [==============================] - 92s 368ms/step
# 14
# 250/250 [==============================] - 92s 368ms/step
# 15
# 250/250 [==============================] - 92s 370ms/step
# 16
# 250/250 [==============================] - 92s 370ms/step
# 17
# 250/250 [==============================] - 93s 370ms/step
# 18
# 250/250 [==============================] - 92s 369ms/step
# 19
# 250/250 [==============================] - 92s 369ms/step
# 20
# 250/250 [==============================] - 92s 369ms/step
#                          id predicted
# 0  0/aeroplane_s_000002.png         0
# 1  0/aeroplane_s_000040.png         0
# 2  0/aeroplane_s_000045.png         0
# 3  0/aeroplane_s_000063.png         0
# 4     0/airbus_s_000009.png         0
# 5     0/airbus_s_000030.png         0
# 6     0/airbus_s_000049.png         0
# 7     0/airbus_s_000099.png         0
# 8     0/airbus_s_000108.png         0
# 9     0/airbus_s_000131.png         0

# %%
cp Cifar10_SeResNet101_MulModels299_STD_tta_3_0711_v1.csv /home/bribeiro/Phong/Nat19/Cifar10_SeResNet101_MulModels299_STD_tta_3_0711_v1.csv

# %%
cp Cifar10_SeResNet101_MulModels299_STD_tta_21_0715_v5.csv /home/bribeiro/Phong/Nat19/Cifar10_SeResNet101_MulModels299_STD_tta_21_0715_v5.csv

# %%
# # Save weights in pickle format instead of h5
# import pickle

# #use get_weights() command to get your model weights
# weigh= model_2.get_weights()

# #now, use pickle to save your model weights, instead of .h5
# #for heavy model architectures, .h5 file is unsupported.
# pklfile= os.path.join('checkpoints', 'FashionMNIST_SEResNext101_LRG501_Mul_STD.pkl')

# fpkl= open(pklfile, 'wb') #Python 3
# pickle.dump(weigh, fpkl, protocol= pickle.HIGHEST_PROTOCOL)
# fpkl.close()

# %%
os.listdir("checkpoints")

# %%
# #use pickle to load model weights
# import os
# import pickle

# pklfile= os.path.join('checkpoints', 'FashionMNIST_SEResNext101_LRG299_Mul_LSTM_L3.pkl')

# f= open(pklfile, 'rb')     #Python 3                 
# weigh= pickle.load(f);                
# f.close();

# #use set_weights to load the modelweights into the model architecture
# NUM_GPU = 4
# #Using multiple models if more than 1 GPU
# if NUM_GPU != 1:
#     model_mul = multi_gpu_model(model_2, gpus=NUM_GPU)

# model_mul.set_weights(weigh)

# %%
# model 2 - SeResNext101
#use pickle to load model weights
import os
import pickle

# load to multi gpu
NUM_GPU = 4
model_mul = multi_gpu_model(model_2, gpus=NUM_GPU)

#load model the saved weights
pklfile= os.path.join('checkpoints', 'Cifar10_SEResNext101_LRG299_Mul_STD_L3.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

#set the saved weight to mul-gpus model
model_mul.set_weights(weigh)

f2_sgl = model_mul.layers[-2]

#get weight from single gpu
weigh= f2_sgl.get_weights()

#now, use pickle to save model weights, instead of .h5
#for heavy model architectures, .h5 file is unsupported.
pklfile= os.path.join('checkpoints', 'Cifar10_SEResNext101_LRG299_Mul_STD_L3_SGL.pkl')

fpkl= open(pklfile, 'wb') #Python 3
pickle.dump(weigh, fpkl, protocol= pickle.HIGHEST_PROTOCOL)
fpkl.close()

# %%
#model 2 - SEResNext101
#load model the saved weights
pklfile= os.path.join('checkpoints', 'Cifar10_SEResNext101_LRG299_Mul_STD_L3_SGL.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

#set the saved weight to mul-gpus model
model_2.set_weights(weigh)

# %%
# # load to multi gpu
# NUM_GPU = 4
# model_mul = multi_gpu_model(model_2, gpus=NUM_GPU)

# #get weight from mul gpu
# weigh= model_mul.get_weights()

# #now, use pickle to save model weights, instead of .h5
# #for heavy model architectures, .h5 file is unsupported.
# pklfile= os.path.join('checkpoints', 'FashionMNIST_SEResNext101_LRG299_Mul_LSTM_L3_SGL.pkl')

# fpkl= open(pklfile, 'wb') #Python 3
# pickle.dump(weigh, fpkl, protocol= pickle.HIGHEST_PROTOCOL)
# fpkl.close()

# %%
#Set 1
#MUL 1 - Xception

# from keras.applications import InceptionV3
from keras.applications import Xception
# from keras.applications.inception_resnet_v2 import InceptionResNetV2

from keras.models import Model
from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM, Reshape, Bidirectional
# from keras.applications.inception_v3 import preprocess_input
from keras.applications.xception import preprocess_input

from keras.layers import GaussianNoise

f1_base = Xception(weights='imagenet', include_top=False, input_shape=(299,299,3))  
f1_x = f1_base.output
f1_x = GlobalAveragePooling2D()(f1_x)

# f1_x = Reshape([1,2048])(f1_x)  
# f1_x = Bidirectional(LSTM(1024, 
#                                  return_sequences=False, 
# #                                  dropout=0.8
#                                 ),
#                             input_shape=[1,2048],
#                             merge_mode='concat')(f1_x)

#Regularization with noise
f1_x = GaussianNoise(0.1)(f1_x)

f1_x = Dense(2048, activation='relu')(f1_x)
f1_x = Dense(10, activation='softmax')(f1_x)
model_1 = Model(inputs=[f1_base.input],outputs=[f1_x])

print(model_1.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 149, 149, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 149, 149, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 147, 147, 64) 18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 147, 147, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 147, 147, 64) 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 147, 147, 128 8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 147, 147, 128 0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 147, 147, 128 17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1194 (Conv2D)            (None, 74, 74, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 74, 74, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 74, 74, 128)  512         conv2d_1194[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 74, 74, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 74, 74, 128)  0           add_34[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 74, 74, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 74, 74, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 74, 74, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1195 (Conv2D)            (None, 37, 37, 256)  32768       add_34[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 37, 37, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 37, 37, 256)  1024        conv2d_1195[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 37, 37, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 37, 37, 256)  0           add_35[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 37, 37, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 37, 37, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 37, 37, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1196 (Conv2D)            (None, 19, 19, 728)  186368      add_35[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 19, 19, 728)  0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 19, 19, 728)  2912        conv2d_1196[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 19, 19, 728)  0           block4_pool[0][0]
#                                                                  batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 19, 19, 728)  0           add_36[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 19, 19, 728)  0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 19, 19, 728)  0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 19, 19, 728)  0           block5_sepconv3_bn[0][0]
#                                                                  add_36[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 19, 19, 728)  0           add_37[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 19, 19, 728)  0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 19, 19, 728)  0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 19, 19, 728)  0           block6_sepconv3_bn[0][0]
#                                                                  add_37[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 19, 19, 728)  0           add_38[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 19, 19, 728)  0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 19, 19, 728)  0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 19, 19, 728)  0           block7_sepconv3_bn[0][0]
#                                                                  add_38[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 19, 19, 728)  0           add_39[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 19, 19, 728)  0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 19, 19, 728)  0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 19, 19, 728)  0           block8_sepconv3_bn[0][0]
#                                                                  add_39[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 19, 19, 728)  0           add_40[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 19, 19, 728)  0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 19, 19, 728)  0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 19, 19, 728)  0           block9_sepconv3_bn[0][0]
#                                                                  add_40[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_41[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 19, 19, 728)  0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 19, 19, 728)  0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 19, 19, 728)  0           block10_sepconv3_bn[0][0]
#                                                                  add_41[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_42[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 19, 19, 728)  0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 19, 19, 728)  0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 19, 19, 728)  0           block11_sepconv3_bn[0][0]
#                                                                  add_42[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_43[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 19, 19, 728)  0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 19, 19, 728)  0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 19, 19, 728)  0           block12_sepconv3_bn[0][0]
#                                                                  add_43[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_44[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 19, 19, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 19, 19, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 19, 19, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1197 (Conv2D)            (None, 10, 10, 1024) 745472      add_44[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 10, 10, 1024) 0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 10, 10, 1024) 4096        conv2d_1197[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 10, 10, 1024) 0           block13_pool[0][0]
#                                                                  batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 10, 10, 1536) 1582080     add_45[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 10, 10, 1536) 6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 10, 10, 1536) 0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 10, 10, 2048) 3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 10, 10, 2048) 8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 10, 10, 2048) 0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_35 (Gl (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_2 (GaussianNoise (None, 2048)         0           global_average_pooling2d_35[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2048)         4196352     gaussian_noise_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 10)           20490       dense_3[0][0]
# ==================================================================================================
# Total params: 25,078,322
# Trainable params: 25,023,794
# Non-trainable params: 54,528
# __________________________________________________________________________________________________
# None

# %%
#Non-Groups
#Split training and validation
#Using Expert Data

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil
import multiprocessing

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

NUM_GPU = 4
batch_size = 100

train_set = train_datagen.flow_from_directory('train_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('test_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cifar10_Xception_LRG299_Mul_STD.hdf5')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('cassava_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('cassava_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.9900, verbose=1)

#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    model_mul = multi_gpu_model(model_1, gpus=NUM_GPU)

# print('Loading pretrained weights')
# if NUM_GPU != 1:
#     model_mul.load_weights(savedfilename)
# # else:
# #     model.load_weights(savedfilename)

epochs = 40##!!!
lr = 1e-4
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

step_size_train=ceil(train_set.n/train_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[earlystopping, checkpointer],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# Found 50000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Epoch 1/40
# 499/500 [============================>.] - ETA: 1s - loss: 0.8587 - acc: 0.6974Epoch 00001: val_acc improved from -inf to 0.91000, saving model to checkpoints/Cifar10_Xception_LRG299_Mul_STD.hdf5
# 500/500 [==============================] - 601s 1s/step - loss: 0.8581 - acc: 0.6976 - val_loss: 0.2616 - val_acc: 0.9100
# Epoch 2/40
# 499/500 [============================>.] - ETA: 1s - loss: 0.4582 - acc: 0.8405Epoch 00002: val_acc improved from 0.91000 to 0.92800, saving model to checkpoints/Cifar10_Xception_LRG299_Mul_STD.hdf5
# 500/500 [==============================] - 586s 1s/step - loss: 0.4583 - acc: 0.8405 - val_loss: 0.2135 - val_acc: 0.9280
# Epoch 3/40
# 499/500 [============================>.] - ETA: 1s - loss: 0.3707 - acc: 0.8717Epoch 00003: val_acc improved from 0.92800 to 0.93680, saving model to checkpoints/Cifar10_Xception_LRG299_Mul_STD.hdf5
# 500/500 [==============================] - 587s 1s/step - loss: 0.3705 - acc: 0.8718 - val_loss: 0.1893 - val_acc: 0.9368
# Epoch 4/40
# 499/500 [============================>.] - ETA: 1s - loss: 0.3137 - acc: 0.8908Epoch 00004: val_acc improved from 0.93680 to 0.94850, saving model to checkpoints/Cifar10_Xception_LRG299_Mul_STD.hdf5
# 500/500 [==============================] - 587s 1s/step - loss: 0.3137 - acc: 0.8908 - val_loss: 0.1547 - val_acc: 0.9485
# Epoch 5/40
# 499/500 [============================>.] - ETA: 1s - loss: 0.2802 - acc: 0.9033Epoch 00005: val_acc improved from 0.94850 to 0.95110, saving model to checkpoints/Cifar10_Xception_LRG299_Mul_STD.hdf5
# 500/500 [==============================] - 586s 1s/step - loss: 0.2804 - acc: 0.9033 - val_loss: 0.1427 - val_acc: 0.9511
# Epoch 6/40
# 499/500 [============================>.] - ETA: 1s - loss: 0
40
# 499/500 [============================>.] - ETA: 1s - loss: 0.0634 - acc: 0.9786Epoch 00039: val_acc did not improve
# 500/500 [==============================] - 590s 1s/step - loss: 0.0634 - acc: 0.9786 - val_loss: 0.1542 - val_acc: 0.9640
# Epoch 40/40
# 499/500 [============================>.] - ETA: 1s - loss: 0.0627 - acc: 0.9784Epoch 00040: val_acc did not improve
# 500/500 [==============================] - 591s 1s/step - loss: 0.0627 - acc: 0.9784 - val_loss: 0.1582 - val_acc: 0.9628

# %%
max(result.history['val_acc']),min(result.history['val_acc'])
# Out:
# (0.9702000069618225, 0.9672000068426132)

# %%
import matplotlib.pyplot as plt
history = result
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model_mul.load_weights(os.path.join('checkpoints', 'Cifar10_Xception_LRG299_Mul_STD.hdf5'))

# %%
#Non-Groups
#Split training and validation
#Using Expert Data

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil
import multiprocessing

savedfilename = os.path.join('checkpoints', 'Cifar10_Xception_LRG299_Mul_STD_L2.hdf5')
checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

epochs = 15##!!!
lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[earlystopping, checkpointer],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# Epoch 1/15
# 499/500 [============================>.] - ETA: 1s - loss: 0.0509 - acc: 0.9831Epoch 00001: val_acc improved from -inf to 0.96730, saving model to checkpoints/Cifar10_Xception_LRG299_Mul_STD_L2.hdf5
# 500/500 [==============================] - 628s 1s/step - loss: 0.0508 - acc: 0.9831 - val_loss: 0.1317 - val_acc: 0.9673
# Epoch 2/15
# 499/500 [============================>.] - ETA: 1s - loss: 0.0445 - acc: 0.9855Epoch 00002: val_acc improved from 0.96730 to 0.96830, saving model to checkpoints/Cifar10_Xception_LRG299_Mul_STD_L2.hdf5
# 500/500 [==============================] - 586s 1s/step - loss: 0.0445 - acc: 0.9855 - val_loss: 0.1298 - val_acc: 0.9683
# Epoch 3/15
# 499/500 [============================>.] - ETA: 1s - loss: 0.0420 - acc: 0.9854Epoch 00003: val_acc improved from 0.96830 to 0.96830, saving model to checkpoints/Cifar10_Xception_LRG299_Mul_STD_L2.hdf5
# 500/500 [==============================] - 586s 1s/step - loss: 0.0419 - acc: 0.9854 - val_loss: 0.1302 - val_acc: 0.9683
# Epoch 4/15
# 499/500 [============================>.] - ETA: 1s - loss: 0.0410 - acc: 0.9861Epoch 00004: val_acc did not improve
# 500/500 [==============================] - 587s 1s/step - loss: 0.0410 - acc: 0.9860 - val_loss: 0.1351 - val_acc: 0.9672
# Epoch 5/15
# 499/500 [============================>.] - ETA: 1s - loss: 0.0391 - acc: 0.9870Epoch 00005: val_acc did not improve
# 500/500 [==============================] - 589s 1s/step - loss: 0.0391 - acc: 0.9870 - val_loss: 0.1334 - val_acc: 0.9675
# Epoch 6/15
# 499/500 [============================>.] - ETA: 1s - loss: 0.0373 - acc: 0.9878Epoch 00006: val_acc improved from 0.96830 to 0.96870, saving model to checkpoints/Cifar10_Xception_LRG299_Mul_STD_L2.hdf5
# 500/500 [==============================] - 590s 1s/step - loss: 0.0372 - acc: 0.9879 - val_loss: 0.1379 - val_acc: 0.9687
# Epoch 7/15
# 499/500 [============================>.] - ETA: 1s - loss: 0.0402 - acc: 0.9865Epoch 00007: val_acc improved from 0.96870 to 0.96880, saving model to checkpoints/Cifar10_Xception_LRG299_Mul_STD_L2.hdf5
# 500/500 [==============================] - 587s 1s/step - loss: 0.0401 - acc: 0.9865 - val_loss: 0.1298 - val_acc: 0.9688
# Epoch 8/15
# 499/500 [============================>.] - ETA: 1s - loss: 0.0349 - acc: 0.9886Epoch 00008: val_acc improved from 0.96880 to 0.96890, saving model to checkpoints/Cifar10_Xception_LRG299_Mul_STD_L2.hdf5
# 500/500 [==============================] - 585s 1s/step - loss: 0.0350 - acc: 0.9886 - val_loss: 0.1367 - val_acc: 0.9689
# Epoch 9/15
# 499/500 [============================>.] - ETA: 1s - loss: 0.0348 - acc: 0.9881Epoch 00009: val_acc did not improve
# 500/500 [==============================] - 587s 1s/step - loss: 0.0349 - acc: 0.9880 - val_loss: 0.1370 - val_acc: 0.9687
# Epoch 10/15
# 499/500 [============================>.] - ETA: 1s - loss: 0.0330 - acc: 0.9883Epoch 00010: val_acc improved from 0.96890 to 0.97020, saving model to checkpoints/Cifar10_Xception_LRG299_Mul_STD_L2.hdf5
# 500/500 [==============================] - 587s 1s/step - loss: 0.0330 - acc: 0.9883 - val_loss: 0.1365 - val_acc: 0.9702
# Epoch 11/15
# 499/500 [============================>.] - ETA: 1s - loss: 0.0311 - acc: 0.9896Epoch 00011: val_acc did not improve
# 500/500 [==============================] - 586s 1s/step - loss: 0.0311 - acc: 0.9897 - val_loss: 0.1416 - val_acc: 0.9679
# Epoch 12/15
# 499/500 [============================>.] - ETA: 1s - loss: 0.
15
# 499/500 [============================>.] - ETA: 1s - loss: 0.0317 - acc: 0.9895Epoch 00011: val_acc did not improve
# 500/500 [==============================] - 588s 1s/step - loss: 0.0317 - acc: 0.9895 - val_loss: 0.1346 - val_acc: 0.9699
# Epoch 12/15
# 499/500 [============================>.] - ETA: 1s - loss: 0.0304 - acc: 0.9898Epoch 00012: val_acc did not improve
# 500/500 [==============================] - 589s 1s/step - loss: 0.0306 - acc: 0.9897 - val_loss: 0.1343 - val_acc: 0.9695
# Epoch 13/15
# 499/500 [============================>.] - ETA: 1s - loss: 0.0314 - acc: 0.9897Epoch 00013: val_acc did not improve
# 500/500 [==============================] - 588s 1s/step - loss: 0.0314 - acc: 0.9897 - val_loss: 0.1347 - val_acc: 0.9696
# Epoch 14/15
# 499/500 [============================>.] - ETA: 1s - loss: 0.0329 - acc: 0.9888Epoch 00014: val_acc did not improve
# 500/500 [==============================] - 588s 1s/step - loss: 0.0330 - acc: 0.9888 - val_loss: 0.1333 - val_acc: 0.9692
# Epoch 15/15
# 499/500 [============================>.] - ETA: 1s - loss: 0.0299 - acc: 0.9900Epoch 00015: val_acc did not improve
# 500/500 [==============================] - 587s 1s/step - loss: 0.0300 - acc: 0.9899 - val_loss: 0.1341 - val_acc: 0.9694

# %% [markdown]
# # import numpy as np
#
# print(result.history['val_acc'])
# print(np.mean(result.history['val_acc']))
# print(np.max(result.history['val_acc']))
#
# print(result.history['acc'])
# print(np.mean(result.history['acc']))
# print(np.max(result.history['acc']))

# %%
#Using multiple models if more than 1 GPU
NUM_GPU = 4
if NUM_GPU != 1:
    model_mul = multi_gpu_model(model_1, gpus=NUM_GPU)

model_mul.load_weights(os.path.join('checkpoints', 'FashionMNIST_Xception_LRG299_Mul_L3.hdf5'))

# %%
import numpy as np

# PREDICT ON OFFICIAL TEST
test_datagen1 = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

train_set = train_datagen.flow_from_directory('fashion_mnist_train_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

test_set1 = test_datagen1.flow_from_directory('fashion_mnist_test_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

if NUM_GPU != 1:
    predict1=model_mul.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
# else:
#     predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
predicted_class_indices=np.argmax(predict1,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions1 = [labels[k] for k in predicted_class_indices]

import pandas as pd

filenames=test_set1.filenames
results=pd.DataFrame({"file_name":filenames,
                      "predicted1":predictions1,
                      })
results.to_csv('FashionMNIST_SeResNet101_MulModels299_2410_01.csv')
results.head()

# %%
mkdir pred_npy

# %%
np.save(os.path.join('pred_npy','FashionMNIST_Xception_LRG299_Mul.npy'), predict1)

# %%
#model 1 - Xception
# load to multi gpu

#use hdf5
NUM_GPU = 4
model_mul = multi_gpu_model(model_1, gpus=NUM_GPU)

hdf5file= os.path.join('checkpoints', 'Cifar10_Xception_LRG299_Mul_STD_L2.hdf5')
model_mul.load_weights(hdf5file)

f1_sgl = model_mul.layers[-2]
f1_sgl.save(os.path.join('checkpoints', 'Cifar10_Xception_LRG299_Mul_STD_L3_SGL.hdf5'))

# %%
model_1.load_weights(os.path.join('checkpoints', 'Cifar10_Xception_LRG299_Mul_STD_L3_SGL.hdf5'))

# %%
mkdir checkpoints

# %%
#501
#MUL 3 InceptionResNetV2
# from keras.applications import InceptionV3
# from keras.applications import Xception
from keras.applications.inception_resnet_v2 import InceptionResNetV2

from keras.preprocessing import image
from keras.models import Model
from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM
from keras.applications.inception_v3 import preprocess_input

from keras.layers import GaussianNoise

f3_base = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(299,299,3))  
# for layer in f3_base.layers:
#     layer.trainable = False 
f3_x = f3_base.output
f3_x = GlobalAveragePooling2D()(f3_x)

#Regularization with noise
f3_x = GaussianNoise(0.1)(f3_x)

f3_x = Dense(2048, activation='relu')(f3_x)
f3_x = Dense(10, activation='softmax')(f3_x)
model_3 = Model(inputs=[f3_base.input],outputs=[f3_x])

print(model_3.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv2d_1198 (Conv2D)            (None, 149, 149, 32) 864         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 149, 149, 32) 96          conv2d_1198[0][0]
# __________________________________________________________________________________________________
# activation_167 (Activation)     (None, 149, 149, 32) 0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_1199 (Conv2D)            (None, 147, 147, 32) 9216        activation_167[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None,
           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# activation_214 (Activation)     (None, 35, 35, 64)   0           batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# block35_6_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_209[0][0]
#                                                                  activation_211[0][0]
#                                                                  activation_214[0][0]
# __________________________________________________________________________________________________
# block35_6_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_6_mixed[0][0]
# __________________________________________________________________________________________________
# block35_6 (Lambda)              (None, 35, 35, 320)  0           block35_5_ac[0][0]
#                                                                  block35_6_conv[0][0]
# __________________________________________________________________________________________________
# block35_6_ac (Activation)       (None, 35, 35, 320)  0           block35_6[0][0]
# __________________________________________________________________________________________________
# conv2d_1249 (Conv2D)            (None, 35, 35, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_160 (BatchN (None, 35, 35, 32)   96          conv2d_1249[0][0]
# __________________________________________________________________________________________________
# activation_218 (Activation)     (None, 35, 35, 32)   0           batch_normalization_160[0][0]
# __________________________________________________________________________________________________
# conv2d_1247 (Conv2D)            (None, 35, 35, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1250 (Conv2D)            (None, 35, 35, 48)   13824       activation_218[0][0]
# __________________________________________________________________________________________________
# batch_normalization_158 (BatchN (None, 35, 35, 32)   96          conv2d_1247[0][0]
# __________________________________________________________________________________________________
# batch_normalization_161 (BatchN (None, 35, 35, 48)   144         conv2d_1250[0][0]
# __________________________________________________________________________________________________
# activation_216 (Activation)     (None, 35, 35, 32)   0           batch_normalization_158[0][0]
# __________________________________________________________________________________________________
# activation_219 (Activation)     (None, 35, 35, 48)   0           batch_normalization_161[0][0]
# __________________________________________________________________________________________________
# conv2d_1246 (Conv2D)            (None, 35, 35, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1248 (Conv2D)            (None, 35, 35, 32)   9216        activation_216[0][0]
# __________________________________________________________________________________________________
# conv2d_1251 (Conv2D)            (None, 35, 35, 64)   27648       activation_219[0][0]
# __________________________________________________________________________________________________
# batch_normalization_157 (BatchN (None, 35, 35, 32)   96          conv2d_1246[0][0]
# __________________________________________________________________________________________________
# batch_normalization_159 (BatchN (None, 35, 35, 32)   96          conv2d_1248[0][0]
# __________________________________________________________________________________________________
# batch_normalization_162 (BatchN (None, 35, 35, 64)   192         conv2d_1251[0][0]
# __________________________________________________________________________________________________
# activation_215 (Activation)     (None, 35, 35, 32)   0           batch_normalization_157[0][0]
# __________________________________________________________________________________________________
# activation_217 (Activation)     (None, 35, 35, 32)   0           batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# activation_220 (Activation)     (None, 35, 35, 64)   0           batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# block35_7_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_215[0][0]
#                                                                  activation_217[0][0]
#                                                                  activation_220[0][0]
# __________________________________________________________________________________________________
# block35_7_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_7_mixed[0][0]
# __________________________________________________________________________________________________
# block35_7 (Lambda)              (None, 35, 35, 320)  0           block35_6_ac[0][0]
#                                                                  block35_7_conv[0][0]
# __________________________________________________________________________________________________
# block35_7_ac (Activation)       (None, 35, 35, 320)  0           block35_7[0][0]
# __________________________________________________________________________________________________
# conv2d_1255 (Conv2D)            (None, 35, 35, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_166 (BatchN (None, 35, 35, 32)   96          conv2d_1255[0][0]
# __________________________________________________________________________________________________
# activation_224 (Activation)     (None, 35, 35, 32)   0           batch_normalization_166[0][0]
# __________________________________________________________________________________________________
# conv2d_1253 (Conv2D)            (None, 35, 35, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1256 (Conv2D)            (None, 35, 35, 48)   13824       activation_224[0][0]
# __________________________________________________________________________________________________
# batch_normalization_164 (BatchN (None, 35, 35, 32)   96          conv2d_1253[0][0]
# __________________________________________________________________________________________________
# batch_normalization_167 (BatchN (None, 35, 35, 48)   144         conv2d_1256[0][0]
# __________________________________________________________________________________________________
# activation_222 (Activation)     (None, 35, 35, 32)   0           batch_normalization_164[0][0]
# __________________________________________________________________________________________________
# activation_225 (Activation)     (None, 35, 35, 48)   0           batch_normalization_167[0][0]
# __________________________________________________________________________________________________
# conv2d_1252 (Conv2D)            (None, 35, 35, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1254 (Conv2D)            (None, 35, 35, 32)   9216        activation_222[0][0]
# __________________________________________________________________________________________________
# conv2d_1257 (Conv2D)            (None, 35, 35, 64)   27648       activation_225[0][0]
# __________________________________________________________________________________________________
# batch_normalization_163 (BatchN (None, 35, 35, 32)   96          conv2d_1252[0][0]
# __________________________________________________________________________________________________
# batch_normalization_165 (BatchN (None, 35, 35, 32)   96          conv2d_1254[0][0]
# __________________________________________________________________________________________________
# batch_normalization_168 (BatchN (None, 35, 35, 64)   192         conv2d_1257[0][0]
# __________________________________________________________________________________________________
# activation_221 (Activation)     (None, 35, 35, 32)   0           batch_normalization_163[0][0]
# __________________________________________________________________________________________________
# activation_223 (Activation)     (None, 35, 35, 32)   0           batch_normalization_165[0][0]
# __________________________________________________________________________________________________
# activation_226 (Activation)     (None, 35, 35, 64)   0           batch_normalization_168[0][0]
# __________________________________________________________________________________________________
# block35_8_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_221[0][0]
#                                                                  activation_223[0][0]
#                                                                  activation_226[0][0]
# __________________________________________________________________________________________________
# block35_8_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_8_mixed[0][0]
# __________________________________________________________________________________________________
# block35_8 (Lambda)              (None, 35, 35, 320)  0           block35_7_ac[0][0]
#                                                                  block35_8_conv[0][0]
# __________________________________________________________________________________________________
# block35_8_ac (Activation)       (None, 35, 35, 320)  0           block35_8[0][0]
# __________________________________________________________________________________________________
# conv2d_1261 (Conv2D)            (None, 35, 35, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_172 (BatchN (None, 35, 35, 32)   96          conv2d_1261[0][0]
# __________________________________________________________________________________________________
# activation_230 (Activation)     (None, 35, 35, 32)   0           batch_normalization_172[0][0]
# __________________________________________________________________________________________________
# conv2d_1259 (Conv2D)            (None, 35, 35, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1262 (Conv2D)            (None, 35, 35, 48)   13824       activation_230[0][0]
# __________________________________________________________________________________________________
# batch_normalization_170 (BatchN (None, 35, 35, 32)   96          conv2d_1259[0][0]
# __________________________________________________________________________________________________
# batch_normalization_173 (BatchN (None, 35, 35, 48)   144         conv2d_1262[0][0]
# __________________________________________________________________________________________________
# activation_228 (Activation)     (None, 35, 35, 32)   0           batch_normalization_170[0][0]
# __________________________________________________________________________________________________
# activation_231 (Activation)     (None, 35, 35, 48)   0           batch_normalization_173[0][0]
# __________________________________________________________________________________________________
# conv2d_1258 (Conv2D)            (None, 35, 35, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# block8_6_mixed (Concatenate)    (None, 8, 8, 448)    0           activation_350[0][0]
#                                                                  activation_353[0][0]
# __________________________________________________________________________________________________
# block8_6_conv (Conv2D)          (None, 8, 8, 2080)   933920      block8_6_mixed[0][0]
# __________________________________________________________________________________________________
# block8_6 (Lambda)               (None, 8, 8, 2080)   0           block8_5_ac[0][0]
#                                                                  block8_6_conv[0][0]
# __________________________________________________________________________________________________
# block8_6_ac (Activation)        (None, 8, 8, 2080)   0           block8_6[0][0]
# __________________________________________________________________________________________________
# conv2d_1386 (Conv2D)            (None, 8, 8, 192)    399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_297 (BatchN (None, 8, 8, 192)    576         conv2d_1386[0][0]
# __________________________________________________________________________________________________
# activation_355 (Activation)     (None, 8, 8, 192)    0           batch_normalization_297[0][0]
# __________________________________________________________________________________________________
# conv2d_1387 (Conv2D)            (None, 8, 8, 224)    129024      activation_355[0][0]
# __________________________________________________________________________________________________
# batch_normalization_298 (BatchN (None, 8, 8, 224)    672         conv2d_1387[0][0]
# __________________________________________________________________________________________________
# activation_356 (Activation)     (None, 8, 8, 224)    0           batch_normalization_298[0][0]
# __________________________________________________________________________________________________
# conv2d_1385 (Conv2D)            (None, 8, 8, 192)    399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1388 (Conv2D)            (None, 8, 8, 256)    172032      activation_356[0][0]
# __________________________________________________________________________________________________
# batch_normalization_296 (BatchN (None, 8, 8, 192)    576         conv2d_1385[0][0]
# __________________________________________________________________________________________________
# batch_normalization_299 (BatchN (None, 8, 8, 256)    768         conv2d_1388[0][0]
# __________________________________________________________________________________________________
# activation_354 (Activation)     (None, 8, 8, 192)    0           batch_normalization_296[0][0]
# __________________________________________________________________________________________________
# activation_357 (Activation)     (None, 8, 8, 256)    0           batch_normalization_299[0][0]
# __________________________________________________________________________________________________
# block8_7_mixed (Concatenate)    (None, 8, 8, 448)    0           activation_354[0][0]
#                                                                  activation_357[0][0]
# __________________________________________________________________________________________________
# block8_7_conv (Conv2D)          (None, 8, 8, 2080)   933920      block8_7_mixed[0][0]
# __________________________________________________________________________________________________
# block8_7 (Lambda)               (None, 8, 8, 2080)   0           block8_6_ac[0][0]
#                                                                  block8_7_conv[0][0]
# __________________________________________________________________________________________________
# block8_7_ac (Activation)        (None, 8, 8, 2080)   0           block8_7[0][0]
# __________________________________________________________________________________________________
# conv2d_1390 (Conv2D)            (None, 8, 8, 192)    399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_301 (BatchN (None, 8, 8, 192)    576         conv2d_1390[0][0]
# __________________________________________________________________________________________________
# activation_359 (Activation)     (None, 8, 8, 192)    0           batch_normalization_301[0][0]
# __________________________________________________________________________________________________
# conv2d_1391 (Conv2D)            (None, 8, 8, 224)    129024      activation_359[0][0]
# __________________________________________________________________________________________________
# batch_normalization_302 (BatchN (None, 8, 8, 224)    672         conv2d_1391[0][0]
# __________________________________________________________________________________________________
# activation_360 (Activation)     (None, 8, 8, 224)    0           batch_normalization_302[0][0]
# __________________________________________________________________________________________________
# conv2d_1389 (Conv2D)            (None, 8, 8, 192)    399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1392 (Conv2D)            (None, 8, 8, 256)    172032      activation_360[0][0]
# __________________________________________________________________________________________________
# batch_normalization_300 (BatchN (None, 8, 8, 192)    576         conv2d_1389[0][0]
# __________________________________________________________________________________________________
# batch_normalization_303 (BatchN (None, 8, 8, 256)    768         conv2d_1392[0][0]
# __________________________________________________________________________________________________
# activation_358 (Activation)     (None, 8, 8, 192)    0           batch_normalization_300[0][0]
# __________________________________________________________________________________________________
# activation_361 (Activation)     (None, 8, 8, 256)    0           batch_normalization_303[0][0]
# __________________________________________________________________________________________________
# block8_8_mixed (Concatenate)    (None, 8, 8, 448)    0           activation_358[0][0]
#                                                                  activation_361[0][0]
# __________________________________________________________________________________________________
# block8_8_conv (Conv2D)          (None, 8, 8, 2080)   933920      block8_8_mixed[0][0]
# __________________________________________________________________________________________________
# block8_8 (Lambda)               (None, 8, 8, 2080)   0           block8_7_ac[0][0]
#                                                                  block8_8_conv[0][0]
# __________________________________________________________________________________________________
# block8_8_ac (Activation)        (None, 8, 8, 2080)   0           block8_8[0][0]
# __________________________________________________________________________________________________
# conv2d_1394 (Conv2D)            (None, 8, 8, 192)    399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_305 (BatchN (None, 8, 8, 192)    576         conv2d_1394[0][0]
# __________________________________________________________________________________________________
# activation_363 (Activation)     (None, 8, 8, 192)    0           batch_normalization_305[0][0]
# __________________________________________________________________________________________________
# conv2d_1395 (Conv2D)            (None, 8, 8, 224)    129024      activation_363[0][0]
# __________________________________________________________________________________________________
# batch_normalization_306 (BatchN (None, 8, 8, 224)    672         conv2d_1395[0][0]
# __________________________________________________________________________________________________
# activation_364 (Activation)     (None, 8, 8, 224)    0           batch_normalization_306[0][0]
# __________________________________________________________________________________________________
# conv2d_1393 (Conv2D)            (None, 8, 8, 192)    399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1396 (Conv2D)            (None, 8, 8, 256)    172032      activation_364[0][0]
# __________________________________________________________________________________________________
# batch_normalization_304 (BatchN (None, 8, 8, 192)    576         conv2d_1393[0][0]
# __________________________________________________________________________________________________
# batch_normalization_307 (BatchN (None, 8, 8, 256)    768         conv2d_1396[0][0]
# __________________________________________________________________________________________________
# activation_362 (Activation)     (None, 8, 8, 192)    0           batch_normalization_304[0][0]
# __________________________________________________________________________________________________
# activation_365 (Activation)     (None, 8, 8, 256)    0           batch_normalization_307[0][0]
# __________________________________________________________________________________________________
# block8_9_mixed (Concatenate)    (None, 8, 8, 448)    0           activation_362[0][0]
#                                                                  activation_365[0][0]
# __________________________________________________________________________________________________
# block8_9_conv (Conv2D)          (None, 8, 8, 2080)   933920      block8_9_mixed[0][0]
# __________________________________________________________________________________________________
# block8_9 (Lambda)               (None, 8, 8, 2080)   0           block8_8_ac[0][0]
#                                                                  block8_9_conv[0][0]
# __________________________________________________________________________________________________
# block8_9_ac (Activation)        (None, 8, 8, 2080)   0           block8_9[0][0]
# __________________________________________________________________________________________________
# conv2d_1398 (Conv2D)            (None, 8, 8, 192)    399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_309 (BatchN (None, 8, 8, 192)    576         conv2d_1398[0][0]
# __________________________________________________________________________________________________
# activation_367 (Activation)     (None, 8, 8, 192)    0           batch_normalization_309[0][0]
# __________________________________________________________________________________________________
# conv2d_1399 (Conv2D)            (None, 8, 8, 224)    129024      activation_367[0][0]
# __________________________________________________________________________________________________
# batch_normalization_310 (BatchN (None, 8, 8, 224)    672         conv2d_1399[0][0]
# __________________________________________________________________________________________________
# activation_368 (Activation)     (None, 8, 8, 224)    0           batch_normalization_310[0][0]
# __________________________________________________________________________________________________
# conv2d_1397 (Conv2D)            (None, 8, 8, 192)    399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1400 (Conv2D)            (None, 8, 8, 256)    172032      activation_368[0][0]
# __________________________________________________________________________________________________
# batch_normalization_308 (BatchN (None, 8, 8, 192)    576         conv2d_1397[0][0]
# __________________________________________________________________________________________________
# batch_normalization_311 (BatchN (None, 8, 8, 256)    768         conv2d_1400[0][0]
# __________________________________________________________________________________________________
# activation_366 (Activation)     (None, 8, 8, 192)    0           batch_normalization_308[0][0]
# __________________________________________________________________________________________________
# activation_369 (Activation)     (None, 8, 8, 256)    0           batch_normalization_311[0][0]
# __________________________________________________________________________________________________
# block8_10_mixed (Concatenate)   (None, 8, 8, 448)    0           activation_366[0][0]
#                                                                  activation_369[0][0]
# __________________________________________________________________________________________________
# block8_10_conv (Conv2D)         (None, 8, 8, 2080)   933920      block8_10_mixed[0][0]
# __________________________________________________________________________________________________
# block8_10 (Lambda)              (None, 8, 8, 2080)   0           block8_9_ac[0][0]
#                                                                  block8_10_conv[0][0]
# __________________________________________________________________________________________________
# conv_7b (Conv2D)                (None, 8, 8, 1536)   3194880     block8_10[0][0]
# __________________________________________________________________________________________________
# conv_7b_bn (BatchNormalization) (None, 8, 8, 1536)   4608        conv_7b[0][0]
# __________________________________________________________________________________________________
# conv_7b_ac (Activation)         (None, 8, 8, 1536)   0           conv_7b_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_36 (Gl (None, 1536)         0           conv_7b_ac[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_3 (GaussianNoise (None, 1536)         0           global_average_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 2048)         3147776     gaussian_noise_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 10)           20490       dense_5[0][0]
# ==================================================================================================
# Total params: 57,505,002
# Trainable params: 57,444,458
# Non-trainable params: 60,544
# __________________________________________________________________________________________________
# None

# %%
from keras.callbacks import Callback
import pickle
import sys

#Stop training on val_acc
class EarlyStoppingByAccVal(Callback):
    def __init__(self, monitor='val_acc', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current >= self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping" % epoch)
            self.model.stop_training = True

#Save large model using pickle formate instead of h5            
class SaveCheckPoint(Callback):
    def __init__(self, model, dest_folder):
        super(Callback, self).__init__()
        self.model = model
        self.dest_folder = dest_folder
        
        #initiate
        self.best_val_acc = 0
        self.best_val_loss = sys.maxsize #get max value
          
    def on_epoch_end(self, epoch, logs={}):
        val_acc = logs['val_acc']
        val_loss = logs['val_loss']

        if val_acc > self.best_val_acc:
            self.best_val_acc = val_acc
            
            # Save weights in pickle format instead of h5
            print('\nSaving val_acc %f at %s' %(self.best_val_acc, self.dest_folder))
            weigh= self.model.get_weights()

            #now, use pickle to save your model weights, instead of .h5
            #for heavy model architectures, .h5 file is unsupported.
            fpkl= open(self.dest_folder, 'wb') #Python 3
            pickle.dump(weigh, fpkl, protocol= pickle.HIGHEST_PROTOCOL)
            fpkl.close()
            
#             model.save('tmp.h5')
        elif val_acc == self.best_val_acc:
            if val_loss < self.best_val_loss:
                self.best_val_loss=val_loss
                
                # Save weights in pickle format instead of h5
                print('\nSaving val_acc %f at %s' %(self.best_val_acc, self.dest_folder))
                weigh= self.model.get_weights()

                #now, use pickle to save your model weights, instead of .h5
                #for heavy model architectures, .h5 file is unsupported.
                fpkl= open(self.dest_folder, 'wb') #Python 3
                pickle.dump(weigh, fpkl, protocol= pickle.HIGHEST_PROTOCOL)
                fpkl.close()

# %%
#Non-Groups
#Split training and validation
#Using Expert Data

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil
import multiprocessing

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

NUM_GPU = 4
batch_size = 120

train_set = train_datagen.flow_from_directory('train_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('test_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cifar10_IcpResNetV2_LRG299_Mul_STD.hdf5')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('cassava_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('cassava_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.9900, verbose=1)

#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    model_mul = multi_gpu_model(model_3, gpus=NUM_GPU)

# print('Loading pretrained weights')
# if NUM_GPU != 1:
#     model_mul.load_weights(savedfilename)
# # else:
# #     model.load_weights(savedfilename)

epochs = 40##!!!
lr = 1e-4
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

step_size_train=ceil(train_set.n/train_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[earlystopping, checkpointer],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# Found 50000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Epoch 1/40
# 416/417 [============================>.] - ETA: 1s - loss: 0.7376 - acc: 0.7413Epoch 00001: val_acc improved from -inf to 0.92780, saving model to checkpoints/Cifar10_IcpResNetV2_LRG299_Mul_STD.hdf5
# 417/417 [==============================] - 684s 2s/step - loss: 0.7370 - acc: 0.7416 - val_loss: 0.2091 - val_acc: 0.9278
# Epoch 2/40
# 416/417 [============================>.] - ETA: 1s - loss: 0.3942 - acc: 0.8628Epoch 00002: val_acc improved from 0.92780 to 0.94070, saving model to checkpoints/Cifar10_IcpResNetV2_LRG299_Mul_STD.hdf5
# 417/417 [==============================] - 651s 2s/step - loss: 0.3944 - acc: 0.8628 - val_loss: 0.1755 - val_acc: 0.9407
# Epoch 3/40
# 416/417 [============================>.] - ETA: 1s - loss: 0.3181 - acc: 0.8901Epoch 00003: val_acc improved from 0.94070 to 0.94110, saving model to checkpoints/Cifar10_IcpResNetV2_LRG299_Mul_STD.hdf5
# 417/417 [==============================] - 651s 2s/step - loss: 0.3183 - acc: 0.8900 - val_loss: 0.1760 - val_acc: 0.9411
# Epoch 4/40
# 416/417 [============================>.] - ETA: 1s - loss: 0.2669 - acc: 0.9085Epoch 00004: val_acc improved from 0.94110 to 0.94230, saving model to checkpoints/Cifar10_IcpResNetV2_LRG299_Mul_STD.hdf5
# 417/417 [==============================] - 651s 2s/step - loss: 0.2670 - acc: 0.9085 - val_loss: 0.1855 - val_acc: 0.9423
# Epoch 5/40
# 416/417 [============================>.] - ETA: 1s - loss: 0.2443 - acc: 0.9168Epoch 00005: val_acc improved from 0.94230 to 0.94490, saving model to checkpoints/Cifar10_IcpResNetV2_LRG299_Mul_STD.hdf5
# 417/417 [==============================] - 651s 2s/step - loss: 0.2444 - acc: 0.9168 - val_loss: 0.1676 - val_acc: 0.9449
# Epoch 6/40
# 416/417 [============================>.] - ETA: 1s - loss: 0.2242 - acc: 0.9224Epoch 00006: val_acc improved from 0.94490 to 0.95270, saving model to checkpoints/Cifar10_IcpResNetV2_LRG299_Mul_STD.hdf5
# 417/417 [==============================] - 655s 2s/step - loss: 0.2242 - acc: 0.9224 - val_loss: 0.1403 - val_acc: 0.9527
# Epoch 7/40
# 416/417 [============================>.] - ETA: 1s - loss: 0.2030 - acc: 0.9299Epoch 00007: val_acc improved from 0.95270 to 0.95410, saving model to checkpoints/Cifar10_IcpResNetV2_LRG299_Mul_STD.hdf5
# 417/417 [==============================] - 651s 2s/step - loss: 0.2032 - acc: 0.9298 - val_loss: 0.1392 - val_acc: 0.9541
# Epoch 8/40
# 416/417 [============================>.] - ETA: 1s - loss: 0.1893 - acc: 0.9356Epoch 00008: val_acc improved from 0.95410 to 0.95420, saving model to checkpoints/Cifar10_IcpResNetV2_LRG299_Mul_STD.hdf5
# 417/417 [==============================] - 650s 2s/step - loss: 0.1895 - acc: 0.9355 - val_loss: 0.1475 - val_acc: 0.9542
# Epoch 9/40
# 416/417 [============================>.] - ETA: 1s - loss: 0.1748 - acc: 0.9401Epoch 00009: val_acc improved from 0.95420 to 0.95490, saving model to checkpoints/Cifar10_IcpResNetV2_LRG299_Mul_STD.hdf5
# 417/417 [==============================] - 656s 2s/step - loss: 0.1750 - acc: 0.9400 - val_loss: 0.1408 - val_acc: 0.9549
# Epoch 10/40
# 416/417 [============================>.] - ETA: 1s - loss: 0.
model_mul.load_weights(os.path.join('checkpoints', 'Cifar10_IcpResNetV2_LRG299_Mul_STD_L2.hdf5'))

# %%
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cifar10_IcpResNetV2_LRG299_Mul_STD_L3.hdf5')
checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########
epochs = 15##!!!
lr = 1e-6
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[earlystopping, checkpointer],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# Epoch 1/15
# 416/417 [============================>.] - ETA: 1s - loss: 0.0254 - acc: 0.9912Epoch 00001: val_acc improved from -inf to 0.97520, saving model to checkpoints/Cifar10_IcpResNetV2_LRG299_Mul_STD_L3.hdf5
# 417/417 [==============================] - 722s 2s/step - loss: 0.0254 - acc: 0.9913 - val_loss: 0.1174 - val_acc: 0.9752
# Epoch 2/15
# 416/417 [============================>.] - ETA: 1s - loss: 0.0257 - acc: 0.9915Epoch 00002: val_acc did not improve
# 417/417 [==============================] - 659s 2s/step - loss: 0.0257 - acc: 0.9915 - val_loss: 0.1169 - val_acc: 0.9752
# Epoch 3/15
# 416/417 [============================>.] - ETA: 1s - loss: 0.0250 - acc: 0.9914Epoch 00003: val_acc improved from 0.97520 to 0.97550, saving model to checkpoints/Cifar10_IcpResNetV2_LRG299_Mul_STD_L3.hdf5
# 417/417 [==============================] - 656s 2s/step - loss: 0.0249 - acc: 0.9914 - val_loss: 0.1175 - val_acc: 0.9755
# Epoch 4/15
# 416/417 [============================>.] - ETA: 1s - loss: 0.0245 - acc: 0.9918Epoch 00004: val_acc improved from 0.97550 to 0.97560, saving model to checkpoints/Cifar10_IcpResNetV2_LRG299_Mul_STD_L3.hdf5
# 417/417 [==============================] - 657s 2s/step - loss: 0.0245 - acc: 0.9918 - val_loss: 0.1173 - val_acc: 0.9756
# Epoch 5/15
# 416/417 [============================>.] - ETA: 1s - loss: 0.0241 - acc: 0.9914Epoch 00005: val_acc did not improve
# 417/417 [==============================] - 659s 2s/step - loss: 0.0240 - acc: 0.9914 - val_loss: 0.1175 - val_acc: 0.9752
# Epoch 6/15
# 416/417 [============================>.] - ETA: 1s - loss: 0.0244 - acc: 0.9918Epoch 00006: val_acc did not improve
# 417/417 [==============================] - 656s 2s/step - loss: 0.0245 - acc: 0.9918 - val_loss: 0.1169 - val_acc: 0.9755
# Epoch 7/15
# 416/417 [============================>.] - ETA: 1s - loss: 0.0241 - acc: 0.9919Epoch 00007: val_acc improved from 0.97560 to 0.97580, saving model to checkpoints/Cifar10_IcpResNetV2_LRG299_Mul_STD_L3.hdf5
# 417/417 [==============================] - 657s 2s/step - loss: 0.0241 - acc: 0.9919 - val_loss: 0.1178 - val_acc: 0.9758
# Epoch 8/15
# 416/417 [============================>.] - ETA: 1s - loss: 0.0257 - acc: 0.9914Epoch 00008: val_acc did not improve
# 417/417 [==============================] - 658s 2s/step - loss: 0.0257 - acc: 0.9913 - val_loss: 0.1174 - val_acc: 0.9756
# Epoch 9/15
# 416/417 [============================>.] - ETA: 1s - loss: 0.0227 - acc: 0.9922Epoch 00009: val_acc did not improve
# 417/417 [==============================] - 657s 2s/step - loss: 0.0226 - acc: 0.9922 - val_loss: 0.1170 - val_acc: 0.9756
# Epoch 10/15
# 416/417 [============================>.] - ETA: 1s - loss: 0.0240 - acc: 0.9917Epoch 00010: val_acc did not improve
# 417/417 [==============================] - 656s 2s/step - loss: 0.0240 - acc: 0.9917 - val_loss: 0.1182 - val_acc: 0.9754
# Epoch 11/15
# 138/417 [========>.....................] - ETA: 6:33 - loss: 0.0232 - acc: 0.9923
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2146                                                sample_weight=sample_weight,
# -> 2147                                                class_weight=class_weight)
#    2148
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1838         self._make_train_function()
# -> 1839         outputs = self.train_function(ins)
#    1840         if len(outputs) == 1:
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2356         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2357                               **self.session_kwargs)
#    2358         return updated[:len(self.outputs)]
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-2725c1e99d0c> in <module>
#      20     callbacks=[earlystopping, checkpointer],
#      21 #     callbacks=[tb, csv_logger, checkpointer, earlystopping],
# ---> 22     verbose=1)
#      23
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2192         finally:
#    2193             if enqueuer is not None:
# -> 2194                 enqueuer.stop()
#    2195
#    2196         callbacks.on_train_end()
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/keras/utils/data_utils.py in stop(self, timeout)
#     582             self.queue.unfinished_tasks = 0
#     583             self.queue.not_full.notify()
# --> 584         self._close_pool()
#     585         self.run_thread.join(timeout)
#     586         _SHARED_SEQUENCES[self.uid] = None
#
# /home/cdv/.virtualenvs/cv3/lib/python3.5/site-packages/keras/utils/data_utils.py in _close_pool(self)
#     588     def _close_pool(self):
#     589         self.executor.close()
# --> 590         self.executor.join()
#     591
#     592
#
# /usr/lib/python3.5/multiprocessing/pool.py in join(self)
#     508         util.debug('joining pool')
#     509         assert self._state in (CLOSE, TERMINATE)
# --> 510         self._worker_handler.join()
#     511         self._task_handler.join()
#     512         self._result_handler.join()
#
# /usr/lib/python3.5/threading.py in join(self, timeout)
#    1052
#    1053         if timeout is None:
# -> 1054             self._wait_for_tstate_lock()
#    1055         else:
#    1056             # the behavior of a negative timeout isn't documented, but
#
# /usr/lib/python3.5/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1068         if lock is None:  # already determined that the C code is done
#    1069             assert self._is_stopped
# -> 1070         elif lock.acquire(block, timeout):
#    1071             lock.release()
#    1072             self._stop()
#
# KeyboardInterrupt:

# %%
#Using multiple models if more than 1 GPU
import os

# NUM_GPU = 4
# if NUM_GPU != 1:
#     model_mul = multi_gpu_model(model_3, gpus=NUM_GPU)

model_mul.load_weights(os.path.join('checkpoints', 'Cifar10_IcpResNetV2_LRG299_Mul_STD_L2.hdf5'))

# %%
#model 1 - InceptionResNetV2
# load to multi gpu

#use hdf5
NUM_GPU = 4
model_mul = multi_gpu_model(model_3, gpus=NUM_GPU)

hdf5file= os.path.join('checkpoints', 'Cifar10_IcpResNetV2_LRG299_Mul_STD_L2.hdf5')
model_mul.load_weights(hdf5file)

f1_sgl = model_mul.layers[-2]
f1_sgl.save(os.path.join('checkpoints', 'Cifar10_IcpResNetV2_LRG299_Mul_STD_L2_SGL.hdf5'))

# %%
model_3.load_weights(os.path.join('checkpoints', 'Cifar10_IcpResNetV2_LRG299_Mul_STD_L2_SGL.hdf5'))

# %%
#Net 4 - SEResNext-50

from classification_models.keras import Classifiers
from keras.models import Model
# from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM, SimpleRNN, Reshape, Concatenate,Bidirectional
# from keras.applications.inception_v3 import preprocess_input

from keras.layers import GaussianNoise

senet, preprocess_input = Classifiers.get('seresnext50')

f4_base = senet(input_shape=(299,299,3), weights='imagenet', include_top=False)
f4_x = GlobalAveragePooling2D()(f4_base.output)

# #ADV Model
# f2_x = Reshape([1,2048])(f2_x)  
# f2_x = SimpleRNN(2048, 
#             return_sequences=False,                       
# #             dropout=0.8                                     
#             input_shape=[1,2048])(f2_x)

#Regularization with noise
f4_x = GaussianNoise(0.1)(f4_x)

f4_x = Dense(2048, activation='relu')(f4_x)
f4_x = Dense(10, activation='softmax')(f4_x)
model_4 = Model(inputs=[f4_base.input],outputs=[f4_x])

print(model_4.summary())
# # print(f2_base.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 305, 305, 3)  0           input[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 150, 150, 64) 9408        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 150, 150, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 150, 150, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 152, 152, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 75, 75, 64)   0           zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 75, 75, 128)  8192        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 75, 75, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 75, 75, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 77, 77, 128)  0           activation_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 75, 75, 4)    144         lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 75, 75, 4)    144         lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 75, 75, 4)    144         lambda_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 75, 75, 4)    144         lambda_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 75, 75, 4)    144         lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 75, 75, 4)    144         lambda_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 75, 75, 4)    144         lambda_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 75, 75, 4)    144         lambda_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 75, 75, 4)    144         lambda_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 75, 75, 4)    144         lambda_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 75, 75, 4)    144         lambda_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 75, 75, 4)    144         lambda_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 75, 75, 4)    144         lambda_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 75, 75, 4)    144         lambda_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 75, 75, 4)    144         lambda_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None,
(Lambda)             (None, 12, 12, 32)   0           zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_547 (Conv2D)             (None, 10, 10, 32)   9216        lambda_496[0][0]
# __________________________________________________________________________________________________
# conv2d_548 (Conv2D)             (None, 10, 10, 32)   9216        lambda_497[0][0]
# __________________________________________________________________________________________________
# conv2d_549 (Conv2D)             (None, 10, 10, 32)   9216        lambda_498[0][0]
# __________________________________________________________________________________________________
# conv2d_550 (Conv2D)             (None, 10, 10, 32)   9216        lambda_499[0][0]
# __________________________________________________________________________________________________
# conv2d_551 (Conv2D)             (None, 10, 10, 32)   9216        lambda_500[0][0]
# __________________________________________________________________________________________________
# conv2d_552 (Conv2D)             (None, 10, 10, 32)   9216        lambda_501[0][0]
# __________________________________________________________________________________________________
# conv2d_553 (Conv2D)             (None, 10, 10, 32)   9216        lambda_502[0][0]
# __________________________________________________________________________________________________
# conv2d_554 (Conv2D)             (None, 10, 10, 32)   9216        lambda_503[0][0]
# __________________________________________________________________________________________________
# conv2d_555 (Conv2D)             (None, 10, 10, 32)   9216        lambda_504[0][0]
# __________________________________________________________________________________________________
# conv2d_556 (Conv2D)             (None, 10, 10, 32)   9216        lambda_505[0][0]
# __________________________________________________________________________________________________
# conv2d_557 (Conv2D)             (None, 10, 10, 32)   9216        lambda_506[0][0]
# __________________________________________________________________________________________________
# conv2d_558 (Conv2D)             (None, 10, 10, 32)   9216        lambda_507[0][0]
# __________________________________________________________________________________________________
# conv2d_559 (Conv2D)             (None, 10, 10, 32)   9216        lambda_508[0][0]
# __________________________________________________________________________________________________
# conv2d_560 (Conv2D)             (None, 10, 10, 32)   9216        lambda_509[0][0]
# __________________________________________________________________________________________________
# conv2d_561 (Conv2D)             (None, 10, 10, 32)   9216        lambda_510[0][0]
# __________________________________________________________________________________________________
# conv2d_562 (Conv2D)             (None, 10, 10, 32)   9216        lambda_511[0][0]
# __________________________________________________________________________________________________
# conv2d_563 (Conv2D)             (None, 10, 10, 32)   9216        lambda_512[0][0]
# __________________________________________________________________________________________________
# conv2d_564 (Conv2D)             (None, 10, 10, 32)   9216        lambda_513[0][0]
# __________________________________________________________________________________________________
# conv2d_565 (Conv2D)             (None, 10, 10, 32)   9216        lambda_514[0][0]
# __________________________________________________________________________________________________
# conv2d_566 (Conv2D)             (None, 10, 10, 32)   9216        lambda_515[0][0]
# __________________________________________________________________________________________________
# conv2d_567 (Conv2D)             (None, 10, 10, 32)   9216        lambda_516[0][0]
# __________________________________________________________________________________________________
# conv2d_568 (Conv2D)             (None, 10, 10, 32)   9216        lambda_517[0][0]
# __________________________________________________________________________________________________
# conv2d_569 (Conv2D)             (None, 10, 10, 32)   9216        lambda_518[0][0]
# __________________________________________________________________________________________________
# conv2d_570 (Conv2D)             (None, 10, 10, 32)   9216        lambda_519[0][0]
# __________________________________________________________________________________________________
# conv2d_571 (Conv2D)             (None, 10, 10, 32)   9216        lambda_520[0][0]
# __________________________________________________________________________________________________
# conv2d_572 (Conv2D)             (None, 10, 10, 32)   9216        lambda_521[0][0]
# __________________________________________________________________________________________________
# conv2d_573 (Conv2D)             (None, 10, 10, 32)   9216        lambda_522[0][0]
# __________________________________________________________________________________________________
# conv2d_574 (Conv2D)             (None, 10, 10, 32)   9216        lambda_523[0][0]
# __________________________________________________________________________________________________
# conv2d_575 (Conv2D)             (None, 10, 10, 32)   9216        lambda_524[0][0]
# __________________________________________________________________________________________________
# conv2d_576 (Conv2D)             (None, 10, 10, 32)   9216        lambda_525[0][0]
# __________________________________________________________________________________________________
# conv2d_577 (Conv2D)             (None, 10, 10, 32)   9216        lambda_526[0][0]
# __________________________________________________________________________________________________
# conv2d_578 (Conv2D)             (None, 10, 10, 32)   9216        lambda_527[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 10, 10, 1024) 0           conv2d_547[0][0]
#                                                                  conv2d_548[0][0]
#                                                                  conv2d_549[0][0]
#                                                                  conv2d_550[0][0]
#                                                                  conv2d_551[0][0]
#                                                                  conv2d_552[0][0]
#                                                                  conv2d_553[0][0]
#                                                                  conv2d_554[0][0]
#                                                                  conv2d_555[0][0]
#                                                                  conv2d_556[0][0]
#                                                                  conv2d_557[0][0]
#                                                                  conv2d_558[0][0]
#                                                                  conv2d_559[0][0]
#                                                                  conv2d_560[0][0]
#                                                                  conv2d_561[0][0]
#                                                                  conv2d_562[0][0]
#                                                                  conv2d_563[0][0]
#                                                                  conv2d_564[0][0]
#                                                                  conv2d_565[0][0]
#                                                                  conv2d_566[0][0]
#                                                                  conv2d_567[0][0]
#                                                                  conv2d_568[0][0]
#                                                                  conv2d_569[0][0]
#                                                                  conv2d_570[0][0]
#                                                                  conv2d_571[0][0]
#                                                                  conv2d_572[0][0]
#                                                                  conv2d_573[0][0]
#                                                                  conv2d_574[0][0]
#                                                                  conv2d_575[0][0]
#                                                                  conv2d_576[0][0]
#                                                                  conv2d_577[0][0]
#                                                                  conv2d_578[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 10, 10, 1024) 4096        concatenate_16[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 10, 10, 1024) 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_579 (Conv2D)             (None, 10, 10, 2048) 2097152     activation_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 10, 10, 2048) 8192        conv2d_579[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_16 (Gl (None, 2048)         0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# lambda_528 (Lambda)             (None, 1, 1, 2048)   0           global_average_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_580 (Conv2D)             (None, 1, 1, 128)    262272      lambda_528[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 1, 1, 128)    0           conv2d_580[0][0]
# __________________________________________________________________________________________________
# conv2d_581 (Conv2D)             (None, 1, 1, 2048)   264192      activation_79[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 1, 1, 2048)   0           conv2d_581[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 10, 10, 2048) 0           batch_normalization_53[0][0]
#                                                                  activation_80[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 10, 10, 2048) 0           multiply_16[0][0]
#                                                                  activation_76[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 10, 10, 2048) 0           add_16[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_17 (Gl (None, 2048)         0           activation_81[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_1 (GaussianNoise (None, 2048)         0           global_average_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2048)         4196352     gaussian_noise_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           20490       dense_1[0][0]
# ==================================================================================================
# Total params: 29,795,962
# Trainable params: 29,727,738
# Non-trainable params: 68,224
# __________________________________________________________________________________________________
# None

# %%
#Non-Groups
#Split training and validation
#Using Expert Data

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil
import multiprocessing

NUM_GPU = 4
batch_size = 80
#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    model_mul = multi_gpu_model(model_4, gpus=NUM_GPU)

epochs = 40##!!!
lr = 1e-4
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

if NUM_GPU != 1:
    model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

train_set = train_datagen.flow_from_directory('train_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('test_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cifar10_SEResNext50_LRG299_Mul_STD.pkl')

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.99, verbose=1)
savecheckpoint = SaveCheckPoint(model_4, savedfilename)

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('cifar10_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('cifar10_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

# number of steps each epoch
step_size_train=ceil(train_set.n/train_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[earlystopping, savecheckpoint],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# Found 50000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
#
40
# 624/625 [============================>.] - ETA: 0s - loss: 0.0957 - acc: 0.9666
# Saving val_acc 0.956300 at checkpoints/Cifar10_SEResNext50_LRG299_Mul_STD.pkl
# 625/625 [==============================] - 655s 1s/step - loss: 0.0958 - acc: 0.9666 - val_loss: 0.1598 - val_acc: 0.9563
# Epoch 22/40
# 625/625 [==============================] - 655s 1s/step - loss: 0.0900 - acc: 0.9689 - val_loss: 0.1869 - val_acc: 0.9514
# Epoch 23/40
# 625/625 [==============================] - 655s 1s/step - loss: 0.0914 - acc: 0.9687 - val_loss: 0.1746 - val_acc: 0.9549
# Epoch 24/40
# 625/625 [==============================] - 655s 1s/step - loss: 0.0870 - acc: 0.9696 - val_loss: 0.1807 - val_acc: 0.9549
# Epoch 25/40
# 625/625 [==============================] - 656s 1s/step - loss: 0.0836 - acc: 0.9708 - val_loss: 0.1984 - val_acc: 0.9511
# Epoch 26/40
# 625/625 [==============================] - 655s 1s/step - loss: 0.0836 - acc: 0.9716 - val_loss: 0.2011 - val_acc: 0.9525
# Epoch 27/40
# 625/625 [==============================] - 656s 1s/step - loss: 0.0817 - acc: 0.9719 - val_loss: 0.1903 - val_acc: 0.9532
# Epoch 28/40
# 625/625 [==============================] - 655s 1s/step - loss: 0.0815 - acc: 0.9720 - val_loss: 0.1891 - val_acc: 0.9560
# Epoch 29/40
# 625/625 [==============================] - 655s 1s/step - loss: 0.0751 - acc: 0.9740 - val_loss: 0.1765 - val_acc: 0.9558
# Epoch 30/40
# 625/625 [==============================] - 656s 1s/step - loss: 0.0733 - acc: 0.9748 - val_loss: 0.2066 - val_acc: 0.9522
# Epoch 31/40
# 625/625 [==============================] - 655s 1s/step - loss: 0.0707 - acc: 0.9759 - val_loss: 0.1847 - val_acc: 0.9533
# Epoch 32/40
# 625/625 [==============================] - 656s 1s/step - loss: 0.0707 - acc: 0.9761 - val_loss: 0.1787 - val_acc: 0.9554
# Epoch 33/40
# 625/625 [==============================] - 656s 1s/step - loss: 0.0682 - acc: 0.9762 - val_loss: 0.2087 - val_acc: 0.9506
# Epoch 34/40
# 625/625 [==============================] - 656s 1s/step - loss: 0.0686 - acc: 0.9769 - val_loss: 0.1995 - val_acc: 0.9505
# Epoch 35/40
# 625/625 [==============================] - 654s 1s/step - loss: 0.0647 - acc: 0.9779 - val_loss: 0.1940 - val_acc: 0.9509
# Epoch 36/40
# 625/625 [==============================] - 656s 1s/step - loss: 0.0641 - acc: 0.9781 - val_loss: 0.1792 - val_acc: 0.9529
# Epoch 37/40
# 625/625 [==============================] - 657s 1s/step - loss: 0.0644 - acc: 0.9780 - val_loss: 0.2197 - val_acc: 0.9506
# Epoch 38/40
# 625/625 [==============================] - 657s 1s/step - loss: 0.0639 - acc: 0.9784 - val_loss: 0.1922 - val_acc: 0.9553
# Epoch 39/40
# 625/625 [==============================] - 655s 1s/step - loss: 0.0616 - acc: 0.9797 - val_loss: 0.1962 - val_acc: 0.9524
# Epoch 40/40
# 625/625 [==============================] - 655s 1s/step - loss: 0.0576 - acc: 0.9798 - val_loss: 0.2188 - val_acc: 0.9489

# %%
#Net 4 - ResNext-50

from classification_models.keras import Classifiers
from keras.models import Model
# from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM, SimpleRNN, Reshape, Concatenate,Bidirectional
# from keras.applications.inception_v3 import preprocess_input

from keras.layers import GaussianNoise

senet, preprocess_input = Classifiers.get('resnext50')

f5_base = senet(input_shape=(299,299,3), weights='imagenet', include_top=False)
f5_x = GlobalAveragePooling2D()(f5_base.output)

# #ADV Model
# f2_x = Reshape([1,2048])(f2_x)  
# f2_x = SimpleRNN(2048, 
#             return_sequences=False,                       
# #             dropout=0.8                                     
#             input_shape=[1,2048])(f2_x)

#Regularization with noise
f5_x = GaussianNoise(0.1)(f5_x)

f5_x = Dense(2048, activation='relu')(f5_x)
f5_x = Dense(10, activation='softmax')(f5_x)
model_5 = Model(inputs=[f5_base.input],outputs=[f5_x])

print(model_5.summary())
# # print(f2_base.summary())
# Out:
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnext50_imagenet_1000_no_top.h5
# 94429184/94428600 [==============================] - 44s 0us/step
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# bn_data (BatchNormalization)    (None, 299, 299, 3)  9           data[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 305, 305, 3)  0           bn_data[0][0]
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, 150, 150, 64) 9408        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, 150, 150, 64) 256         conv0[0][0]
# __________________________________________________________________________________________________
# relu0 (Activation)              (None, 150, 150, 64) 0           bn0[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 152, 152, 64) 0           relu0[0][0]
# __________________________________________________________________________________________________
# pooling0 (MaxPooling2D)         (None, 75, 75, 64)   0           zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv1 (Conv2D)     (None, 75, 75, 128)  8192        pooling0[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn1 (BatchNormaliz (None, 75, 75, 128)  512         stage1_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu1 (Activation) (None, 75, 75, 128)  0           stage1_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 77, 77, 128)  0           stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 75, 75, 4)    144         lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 75, 75, 4)    144         lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 75, 75, 4)    144         lambda_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 75, 75, 4)    144         lambda_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 75, 75, 4)    144         lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 75, 75, 4)    144         lambda_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 75, 75, 4)    144         lambda_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 75, 75, 4)    144         lambda_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 75, 75, 4)    144         lambda_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 75, 75, 4)    144         lambda_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 75, 75, 4)    144         lambda_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 75, 75, 4)    144         lambda_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 75, 75, 4)    144         lambda_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 75, 75, 4)    144         lambda_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 75, 75, 4)    144         lambda_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 75, 75, 4)    144         lambda_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 75, 75, 4)    144         lambda_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 75, 75, 4)    144         lambda_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 75, 75, 4)    144         lambda_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 75, 75, 4)    144         lambda_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 75, 75, 4)    144         lambda_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 75, 75, 4)    144         lambda_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 75, 75, 4)    144         lambda_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 75, 75, 4)    144         lambda_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 75, 75, 4)    144         lambda_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 75, 75, 4)    144         lambda_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 75, 75, 4)    144         lambda_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 75, 75, 4)    144         lambda_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 75, 75, 4)    144         lambda_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 75, 75, 4)    144         lambda_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 75, 75, 4)    144         lambda_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 75, 75, 4)    144         lambda_32[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 75, 75, 128)  0           conv2d_1[0][0]
#                                                                  conv2d_2[0][0]
#                                                                  conv2d_3[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
#                                                                  conv2d_9[0][0]
#                                                                  conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
#                                                                  conv2d_15[0][0]
#                                                                  conv2d_16[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_18[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
#                                                                  conv2d_21[0][0]
#                                                                  conv2d_22[0][0]
#                                                                  conv2d_23[0][0]
#                                                                  conv2d_24[0][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_27[0][0]
#                                                                  conv2d_28[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_30[0][0]
#                                                                  conv2d_31[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn2 (BatchNormaliz (None, 75, 75, 128)  512         concatenate_1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu2 (Activation) (None, 75, 75, 128)  0           stage1_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv3 (Conv2D)     (None, 75, 75, 256)  32768       stage1_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_sc (Conv2D)        (None, 75, 75, 256)  16384       pooling0[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn3 (BatchNormaliz (None, 75, 75, 256)  1024        stage1_unit1_conv3[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_sc_bn (BatchNormal (None, 75, 75, 256)  1024        stage1_unit1_sc[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 75, 75, 256)  0           stage1_unit1_bn3[0][0]
#                                                                  stage1_unit1_sc_bn[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu (Activation)  (None, 75, 75, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv1 (Conv2D)     (None, 75, 75, 128)  32768       stage1_unit1_relu[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn1 (BatchNormaliz (None, 75, 75, 128)  512         stage1_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu1 (Activation) (None, 75, 75, 128)  0           stage1_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 77, 77, 128)  0           stage1_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_52 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_53 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_54 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_55 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_56 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_57 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_58 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_59 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_60 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_61 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_62 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_63 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_64 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 75, 75, 4)    144         lambda_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 75, 75, 4)    144         lambda_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 75, 75, 4)    144         lambda_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 75, 75, 4)    144         lambda_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 75, 75, 4)    144         lambda_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 75, 75, 4)    144         lambda_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 75, 75, 4)    144         lambda_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 75, 75, 4)    144         lambda_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 75, 75, 4)    144         lambda_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 75, 75, 4)    144         lambda_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 75, 75, 4)    144         lambda_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 75, 75, 4)    144         lambda_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 75, 75, 4)    144         lambda_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 75, 75, 4)    144         lambda_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 75, 75, 4)    144         lambda_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 75, 75, 4)    144         lambda_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 75, 75, 4)    144         lambda_49[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 75, 75, 4)    144         lambda_50[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 75, 75, 4)    144         lambda_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 75, 75, 4)    144         lambda_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 75, 75, 4)    144         lambda_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 75, 75, 4)    144         lambda_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 75, 75, 4)    144         lambda_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 75, 75, 4)    144         lambda_56[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 75, 75, 4)    144         lambda_57[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 75, 75, 4)    144         lambda_58[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 75, 75, 4)    144         lambda_59[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 75, 75, 4)    144         lambda_60[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 75, 75, 4)    144         lambda_61[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 75, 75, 4)    144         lambda_62[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 75, 75, 4)    144         lambda_63[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 75, 75, 4)    144         lambda_64[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 75, 75, 128)  0           conv2d_33[0][0]
#                                                                  conv2d_34[0][0]
#                                                                  conv2d_35[0][0]
#                                                                  conv2d_36[0][0]
#                                                                  conv2d_37[0][0]
#                                                                  conv2d_38[0][0]
#                                                                  conv2d_39[0][0]
#                                                                  conv2d_40[0][0]
#                                                                  conv2d_41[0][0]
#                                                                  conv2d_42[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
#                                                                  conv2d_45[0][0]
#                                                                  conv2d_46[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_48[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_50[0][0]
#                                                                  conv2d_51[0][0]
#                                                                  conv2d_52[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_54[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_56[0][0]
#                                                                  conv2d_57[0][0]
#                                                                  conv2d_58[0][0]
#                                                                  conv2d_59[0][0]
#                                                                  conv2d_60[0][0]
#                                                                  conv2d_61[0][0]
#                                                                  conv2d_62[0][0]
#                                                                  conv2d_63[0][0]
#                                                                  conv2d_64[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn2 (BatchNormaliz (None, 75, 75, 128)  512         concatenate_2[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu2 (Activation) (None, 75, 75, 128)  0           stage1_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv3 (Conv2D)     (None, 75, 75, 256)  32768       stage1_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn3 (BatchNormaliz (None, 75, 75, 256)  1024        stage1_unit2_conv3[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 75, 75, 256)  0           stage1_unit2_bn3[0][0]
#                                                                  stage1_unit1_relu[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu (Activation)  (None, 75, 75, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv1 (Conv2D)     (None, 75, 75, 128)  32768       stage1_unit2_relu[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn1 (BatchNormaliz (None, 75, 75, 128)  512         stage1_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu1 (Activation) (None, 75, 75, 128)  0           stage1_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 77, 77, 128)  0           stage1_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# lambda_65 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_66 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_67 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_68 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_69 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_70 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_71 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_72 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_73 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_74 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_75 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_76 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_77 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_78 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_79 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_80 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_81 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_82 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_83 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_84 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_85 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_86 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_87 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_88 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_89 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_90 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_91 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_92 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_93 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_94 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_95 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_96 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 75, 75, 4)    144         lambda_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 75, 75, 4)    144         lambda_66[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 75, 75, 4)    144         lambda_67[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 75, 75, 4)    144         lambda_68[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 75, 75, 4)    144         lambda_69[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 75, 75, 4)    144         lambda_70[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 75, 75, 4)    144         lambda_71[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 75, 75, 4)    144         lambda_72[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 75, 75, 4)    144         lambda_73[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 75, 75, 4)    144         lambda_74[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 75, 75, 4)    144         lambda_75[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 75, 75, 4)    144         lambda_76[0][0]
# ...
# __________________________________________________________________________________________________
# lambda_493 (Lambda)             (None, 12, 12, 32)   0           zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# lambda_494 (Lambda)             (None, 12, 12, 32)   0           zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# lambda_495 (Lambda)             (None, 12, 12, 32)   0           zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# lambda_496 (Lambda)             (None, 12, 12, 32)   0           zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# lambda_497 (Lambda)             (None, 12, 12, 32)   0           zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# lambda_498 (Lambda)             (None, 12, 12, 32)   0           zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# lambda_499 (Lambda)             (None, 12, 12, 32)   0           zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# lambda_500 (Lambda)             (None, 12, 12, 32)   0           zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# lambda_501 (Lambda)             (None, 12, 12, 32)   0           zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# lambda_502 (Lambda)             (None, 12, 12, 32)   0           zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# lambda_503 (Lambda)             (None, 12, 12, 32)   0           zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# lambda_504 (Lambda)             (None, 12, 12, 32)   0           zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# lambda_505 (Lambda)             (None, 12, 12, 32)   0           zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# lambda_506 (Lambda)             (None, 12, 12, 32)   0           zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# lambda_507 (Lambda)             (None, 12, 12, 32)   0           zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# lambda_508 (Lambda)             (None, 12, 12, 32)   0           zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# lambda_509 (Lambda)             (None, 12, 12, 32)   0           zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# lambda_510 (Lambda)             (None, 12, 12, 32)   0           zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# lambda_511 (Lambda)             (None, 12, 12, 32)   0           zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# lambda_512 (Lambda)             (None, 12, 12, 32)   0           zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_481 (Conv2D)             (None, 10, 10, 32)   9216        lambda_481[0][0]
# __________________________________________________________________________________________________
# conv2d_482 (Conv2D)             (None, 10, 10, 32)   9216        lambda_482[0][0]
# __________________________________________________________________________________________________
# conv2d_483 (Conv2D)             (None, 10, 10, 32)   9216        lambda_483[0][0]
# __________________________________________________________________________________________________
# conv2d_484 (Conv2D)             (None, 10, 10, 32)   9216        lambda_484[0][0]
# __________________________________________________________________________________________________
# conv2d_485 (Conv2D)             (None, 10, 10, 32)   9216        lambda_485[0][0]
# __________________________________________________________________________________________________
# conv2d_486 (Conv2D)             (None, 10, 10, 32)   9216        lambda_486[0][0]
# __________________________________________________________________________________________________
# conv2d_487 (Conv2D)             (None, 10, 10, 32)   9216        lambda_487[0][0]
# __________________________________________________________________________________________________
# conv2d_488 (Conv2D)             (None, 10, 10, 32)   9216        lambda_488[0][0]
# __________________________________________________________________________________________________
# conv2d_489 (Conv2D)             (None, 10, 10, 32)   9216        lambda_489[0][0]
# __________________________________________________________________________________________________
# conv2d_490 (Conv2D)             (None, 10, 10, 32)   9216        lambda_490[0][0]
# __________________________________________________________________________________________________
# conv2d_491 (Conv2D)             (None, 10, 10, 32)   9216        lambda_491[0][0]
# __________________________________________________________________________________________________
# conv2d_492 (Conv2D)             (None, 10, 10, 32)   9216        lambda_492[0][0]
# __________________________________________________________________________________________________
# conv2d_493 (Conv2D)             (None, 10, 10, 32)   9216        lambda_493[0][0]
# __________________________________________________________________________________________________
# conv2d_494 (Conv2D)             (None, 10, 10, 32)   9216        lambda_494[0][0]
# __________________________________________________________________________________________________
# conv2d_495 (Conv2D)             (None, 10, 10, 32)   9216        lambda_495[0][0]
# __________________________________________________________________________________________________
# conv2d_496 (Conv2D)             (None, 10, 10, 32)   9216        lambda_496[0][0]
# __________________________________________________________________________________________________
# conv2d_497 (Conv2D)             (None, 10, 10, 32)   9216        lambda_497[0][0]
# __________________________________________________________________________________________________
# conv2d_498 (Conv2D)             (None, 10, 10, 32)   9216        lambda_498[0][0]
# __________________________________________________________________________________________________
# conv2d_499 (Conv2D)             (None, 10, 10, 32)   9216        lambda_499[0][0]
# __________________________________________________________________________________________________
# conv2d_500 (Conv2D)             (None, 10, 10, 32)   9216        lambda_500[0][0]
# __________________________________________________________________________________________________
# conv2d_501 (Conv2D)             (None, 10, 10, 32)   9216        lambda_501[0][0]
# __________________________________________________________________________________________________
# conv2d_502 (Conv2D)             (None, 10, 10, 32)   9216        lambda_502[0][0]
# __________________________________________________________________________________________________
# conv2d_503 (Conv2D)             (None, 10, 10, 32)   9216        lambda_503[0][0]
# __________________________________________________________________________________________________
# conv2d_504 (Conv2D)             (None, 10, 10, 32)   9216        lambda_504[0][0]
# __________________________________________________________________________________________________
# conv2d_505 (Conv2D)             (None, 10, 10, 32)   9216        lambda_505[0][0]
# __________________________________________________________________________________________________
# conv2d_506 (Conv2D)             (None, 10, 10, 32)   9216        lambda_506[0][0]
# __________________________________________________________________________________________________
# conv2d_507 (Conv2D)             (None, 10, 10, 32)   9216        lambda_507[0][0]
# __________________________________________________________________________________________________
# conv2d_508 (Conv2D)             (None, 10, 10, 32)   9216        lambda_508[0][0]
# __________________________________________________________________________________________________
# conv2d_509 (Conv2D)             (None, 10, 10, 32)   9216        lambda_509[0][0]
# __________________________________________________________________________________________________
# conv2d_510 (Conv2D)             (None, 10, 10, 32)   9216        lambda_510[0][0]
# __________________________________________________________________________________________________
# conv2d_511 (Conv2D)             (None, 10, 10, 32)   9216        lambda_511[0][0]
# __________________________________________________________________________________________________
# conv2d_512 (Conv2D)             (None, 10, 10, 32)   9216        lambda_512[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 10, 10, 1024) 0           conv2d_481[0][0]
#                                                                  conv2d_482[0][0]
#                                                                  conv2d_483[0][0]
#                                                                  conv2d_484[0][0]
#                                                                  conv2d_485[0][0]
#                                                                  conv2d_486[0][0]
#                                                                  conv2d_487[0][0]
#                                                                  conv2d_488[0][0]
#                                                                  conv2d_489[0][0]
#                                                                  conv2d_490[0][0]
#                                                                  conv2d_491[0][0]
#                                                                  conv2d_492[0][0]
#                                                                  conv2d_493[0][0]
#                                                                  conv2d_494[0][0]
#                                                                  conv2d_495[0][0]
#                                                                  conv2d_496[0][0]
#                                                                  conv2d_497[0][0]
#                                                                  conv2d_498[0][0]
#                                                                  conv2d_499[0][0]
#                                                                  conv2d_500[0][0]
#                                                                  conv2d_501[0][0]
#                                                                  conv2d_502[0][0]
#                                                                  conv2d_503[0][0]
#                                                                  conv2d_504[0][0]
#                                                                  conv2d_505[0][0]
#                                                                  conv2d_506[0][0]
#                                                                  conv2d_507[0][0]
#                                                                  conv2d_508[0][0]
#                                                                  conv2d_509[0][0]
#                                                                  conv2d_510[0][0]
#                                                                  conv2d_511[0][0]
#                                                                  conv2d_512[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn2 (BatchNormaliz (None, 10, 10, 1024) 4096        concatenate_16[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu2 (Activation) (None, 10, 10, 1024) 0           stage4_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv3 (Conv2D)     (None, 10, 10, 2048) 2097152     stage4_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn3 (BatchNormaliz (None, 10, 10, 2048) 8192        stage4_unit3_conv3[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 10, 10, 2048) 0           stage4_unit3_bn3[0][0]
#                                                                  stage4_unit2_relu[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu (Activation)  (None, 10, 10, 2048) 0           add_16[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2048)         0           stage4_unit3_relu[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_1 (GaussianNoise (None, 2048)         0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2048)         4196352     gaussian_noise_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           20490       dense_1[0][0]
# ==================================================================================================
# Total params: 27,264,979
# Trainable params: 27,196,749
# Non-trainable params: 68,230
# __________________________________________________________________________________________________
# None

# %%
#Non-Groups
#Split training and validation
#Using Expert Data

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil
import multiprocessing

NUM_GPU = 4
batch_size = 80
#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    model_mul = multi_gpu_model(model_5, gpus=NUM_GPU)

epochs = 40##!!!
lr = 1e-4
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

if NUM_GPU != 1:
    model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

train_set = train_datagen.flow_from_directory('train_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('test_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cifar10_ResNext50_LRG299_Mul_STD.pkl')

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.99, verbose=1)
savecheckpoint = SaveCheckPoint(model_5, savedfilename)

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('cifar10_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('cifar10_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

# number of steps each epoch
step_size_train=ceil(train_set.n/train_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[earlystopping, savecheckpoint],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)
# Out:
# Found 50000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Epoch 1/40
# 624/625 [============================>.] - ETA: 1s - loss: 0.9106 - acc: 0.6803
# Saving val_acc 0.869700 at checkpoints/Cifar10_ResNext50_LRG299_Mul_STD.pkl
# 625/625 [==============================] - 689s 1s/step - loss: 0.9101 - acc: 0.6805 - val_loss: 0.3974 - val_acc: 0.8697
# Epoch 2/40
# 624/625 [============================>.] - ETA: 0s - loss: 0.5525 - acc: 0.8085
# Saving val_acc 0.893200 at checkpoints/Cifar10_ResNext50_LRG299_Mul_STD.pkl
# 625/625 [==============================] - 638s 1s/step - loss: 0.5524 - acc: 0.8085 - val_loss: 0.3172 - val_acc: 0.8932
# Epoch 3/40
# 624/625 [============================>.] - ETA: 0s - loss: 0.4568 - acc: 0.8422
# Saving val_acc 0.906200 at checkpoints/Cifar10_ResNext50_LRG299_Mul_STD.pkl
# 625/625 [==============================] - 639s 1s/step - loss: 0.4571 - acc: 0.8421 - val_loss: 0.2932 - val_acc: 0.9062
# Epoch 4/40
# 624/625 [============================>.] - ETA: 0s - loss: 0.3950 - acc: 0.8634
# Saving val_acc 0.917400 at checkpoints/Cifar10_ResNext50_LRG299_Mul_STD.pkl
# 625/625 [==============================] - 637s 1s/step - loss: 0.3951 - acc: 0.8634 - val_loss: 0.2488 - val_acc: 0.9174
# Epoch 5/40
# 625/625 [==============================] - 641s 1s/step - loss: 0.3510 - acc: 0.8789 - val_loss: 0.2830 - val_acc: 0.9103
# Epoch 6/40
# 624/625 [============================>.] - ETA: 0s - loss: 0.3292 - acc: 0.8865
# Saving val_acc 0.921300 at checkpoints/Cifar10_ResNext50_LRG299_Mul_STD.pkl
# 625/625 [==============================] - 639s 1s/step - loss: 0.3291 - acc: 0.8865 - val_loss: 0.2498 - val_acc: 0.9213
# Epoch 7/40
# 624/625 [============================>.] - ETA: 0s - loss: 0.3054 - acc: 0.8945
# Saving val_acc 0.923000 at checkpoints/Cifar10_ResNext50_LRG299_Mul_STD.pkl
# 625/625 [==============================] - 639s 1s/step - loss: 0.3055 - acc: 0.8945 - val_loss: 0.2395 - val_acc: 0.9230
# Epoch 8/40
# 624/625 [============================>.] - ETA: 0s - loss: 0.2809 - acc: 0.9040
# Saving val_acc 0.931100 at checkpoints/Cifar10_ResNext50_LRG299_Mul_STD.pkl
# 625/625 [==============================] - 640s 1s/step - loss: 0.2811 - acc: 0.9039 - val_loss: 0.2174 - val_acc: 0.9311
# Epoch 9/40
# 624/625 [============================>.] - ETA: 0s - loss: 0.2628 - acc: 0.9093
# Saving val_acc 0.931300 at checkpoints/Cifar10_ResNext50_LRG299_Mul_STD.pkl
# 625/625 [==============================] -
# Epoch 34/40
# 625/625 [==============================] - 636s 1s/step - loss: 0.1082 - acc: 0.9620 - val_loss: 0.2452 - val_acc: 0.9368
# Epoch 35/40
# 625/625 [==============================] - 638s 1s/step - loss: 0.1026 - acc: 0.9634 - val_loss: 0.2507 - val_acc: 0.9396
# Epoch 36/40
# 625/625 [==============================] - 637s 1s/step - loss: 0.1060 - acc: 0.9631 - val_loss: 0.2250 - val_acc: 0.9425
# Epoch 37/40
# 625/625 [==============================] - 637s 1s/step - loss: 0.0971 - acc: 0.9669 - val_loss: 0.2154 - val_acc: 0.9452
# Epoch 38/40
# 625/625 [==============================] - 639s 1s/step - loss: 0.0978 - acc: 0.9666 - val_loss: 0.2184 - val_acc: 0.9436
# Epoch 39/40
# 625/625 [==============================] - 640s 1s/step - loss: 0.0925 - acc: 0.9685 - val_loss: 0.2257 - val_acc: 0.9447
# Epoch 40/40
# 625/625 [==============================] - 640s 1s/step - loss: 0.0910 - acc: 0.9685 - val_loss: 0.2462 - val_acc: 0.9385

# %%
# import numpy as np
# from keras.preprocessing.image import ImageDataGenerator
# from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
# from keras.optimizers import Adam
# # from keras.utils import multi_gpu_model

# import time, os
# from math import ceil
# import multiprocessing

# train_datagen = ImageDataGenerator(
# #     rescale = 1./255,
#     rotation_range=30,
#     width_shift_range=0.3,
#     height_shift_range=0.3,
#     shear_range=0.3,
#     zoom_range=0.3,
#     horizontal_flip=True,
#     vertical_flip=True,##
# #     brightness_range=[0.5, 1.5],##
#     channel_shift_range=10,##
#     fill_mode='nearest',
#     preprocessing_function=preprocess_input,
# )

# test_datagen = ImageDataGenerator(
# #     rescale = 1./255
#     preprocessing_function=preprocess_input
# )

# # PREDICT ON OFFICIAL TEST
# test_datagen1 = ImageDataGenerator(
# #     rescale = 1./255,
#     preprocessing_function=preprocess_input
# )

# batch_size = 120

# train_set = train_datagen.flow_from_directory('fashion_mnist_train_resized_299',
#                                                  target_size = (299, 299),
#                                                  batch_size = batch_size,
#                                                  class_mode = 'categorical',
#                                                  shuffle=True,
#                                                  seed=7,
# #                                                  subset="training"
#                                               )

# test_set1 = test_datagen1.flow_from_directory('fashion_mnist_test_resized_299',
#                                                  target_size = (299, 299),
#                                                  batch_size = batch_size,
#                                                  class_mode = 'categorical',
#                                                  shuffle=False,
#                                                  seed=7,
# #                                                  subset="validation"
#                                              )

# if NUM_GPU != 1:
#     predict1=model_mul.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
# # else:
# #     predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
# predicted_class_indices=np.argmax(predict1,axis=1)
# labels = (train_set.class_indices)
# labels = dict((v,k) for k,v in labels.items())
# predictions1 = [labels[k] for k in predicted_class_indices]

# import pandas as pd
# #
# filenames=test_set1.filenames
# results=pd.DataFrame({"file_name":filenames,
#                       "predicted1":predictions1,
#                       })
# results.to_csv('FashionMNIST_IcpResNetV2_MulModels299_2510_01.csv')
# results.head()

# %%
np.save(os.path.join('pred_npy','FashionMNIST_IcpResNetV2_LRG299_Mul.npy'), predict1)

# %%
mean_pred3_1 = np.load(os.path.join('pred_npy','FashionMNIST_SEResNext101_LRG299_Mul.npy'))
mean_pred3_2 = np.load(os.path.join('pred_npy','FashionMNIST_Xception_LRG299_Mul.npy'))
mean_pred3_3 = np.load(os.path.join('pred_npy','FashionMNIST_IcpResNetV2_LRG299_Mul.npy'))
mean_pred3 = (mean_pred3_1+mean_pred3_2+mean_pred3_3)/3
print(mean_pred3[0:9])

# %%
from keras.preprocessing.image import ImageDataGenerator
from math import ceil
import numpy as np

batch_size = 20

#Crop-Official Test
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

def crop_generator(batches, crop_length):
    """Generate random crops from the image batches"""
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

train_datagen = ImageDataGenerator(

)

train_set = train_datagen.flow_from_directory('fashion_mnist_train_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )
        
test_datagen_crop = ImageDataGenerator(
)

testing_set_crop = test_datagen_crop.flow_from_directory('fashion_mnist_test_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="training"
                                              )
#customized generator
test_crops = crop_generator(testing_set_crop, 299)

step_size_test_crop = ceil(testing_set_crop.n/testing_set_crop.batch_size)

predicted_class_indices_mean=np.argmax(mean_pred3,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('FashionMNIST_MulModels299_AVG_Assembe_V2_2510_2.csv')
results.head(20)

# %%
cp FashionMNIST_MulModels299_AVG_Assembe_V2_2510_2.csv /home/bribeiro/Phong/Nat19/FashionMNIST_MulModels299_AVG_Assembe_V2_2510_2.csv

# %%
# model_1.load_weights(os.path.join('checkpoints', 'Cassava_NonGrp_S1_Xception_LRG501_Mul_Pretrained_STD_SGL.hdf5'))
# # model_2.load_weights(os.path.join('checkpoints', 'Cassava_NonGrp_S1_Inception_LRG501_Mul_Pretrained_STD_SGL.hdf5'))
# model_3.load_weights(os.path.join('checkpoints', 'Cassava_NonGrp_S1_IcpResNetV2_LRG501_Mul_Pretrained_STD_SGL.hdf5'))

# %%
# 3 models
# 501
# pre-trainned weight
# get pretrained [-1] layer

from keras.applications import InceptionV3
from keras.applications import Xception
from keras.applications.inception_resnet_v2 import InceptionResNetV2

from keras.preprocessing import image
from keras.models import Model
from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM, LeakyReLU, Dropout
#from keras.applications.inception_v3 import preprocess_input
from keras_applications.imagenet_utils import preprocess_input

f1_mul_x = model_1.layers[-1].output 
f2_mul_x = model_2.layers[-1].output
f3_mul_x = model_3.layers[-1].output

x = concatenate([f1_mul_x, f2_mul_x, f3_mul_x])

x = Dense(4096)(x)
x = LeakyReLU(0.2)(x)
x = Dropout(0.5)(x)
x = Dense(10, activation='softmax')(x)
model_mul = Model(inputs=[model_1.get_input_at(0),model_2.get_input_at(0),model_3.get_input_at(0)],outputs=[x])

print(model_mul.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 305, 305, 3)  0           input[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 150, 150, 64) 9408        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 150, 150, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 150, 150, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 152, 152, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 75, 75, 64)   0           zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 75, 75, 128)  8192        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 75, 75, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 75, 75, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 77, 77, 128)  0           activation_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 75, 75, 4)    144         lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 75, 75, 4)    144         lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 75, 75, 4)    144         lambda_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 75, 75, 4)    144         lambda_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 75, 75, 4)    144         lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 75, 75, 4)    144         lambda_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 75, 75, 4)    144         lambda_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 75, 75, 4)    144         lambda_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 75, 75, 4)    144         lambda_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 75, 75, 4)    144         lambda_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 75, 75, 4)    144         lambda_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 75, 75, 4)    144         lambda_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 75, 75, 4)    144         lambda_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 75, 75, 4)    144         lambda_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 75, 75, 4)    144         lambda_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 75, 75, 4)    144         lambda_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 75, 75, 4)    144         lambda_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 75, 75, 4)    144         lambda_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 75, 75, 4)    144         lambda_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 75, 75, 4)    144         lambda_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 75, 75, 4)    144         lambda_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 75, 75, 4)    144         lambda_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 75, 75, 4)    144         lambda_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 75, 75, 4)    144         lambda_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 75, 75, 4)    144         lambda_25[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 75, 75, 4)    144         lambda_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 75, 75, 4)    144         lambda_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 75, 75, 4)    144         lambda_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None,
#                                                                  conv2d_1180[0][0]
#                                                                  conv2d_1181[0][0]
#                                                                  conv2d_1182[0][0]
#                                                                  conv2d_1183[0][0]
#                                                                  conv2d_1184[0][0]
#                                                                  conv2d_1185[0][0]
#                                                                  conv2d_1186[0][0]
#                                                                  conv2d_1187[0][0]
#                                                                  conv2d_1188[0][0]
#                                                                  conv2d_1189[0][0]
#                                                                  conv2d_1190[0][0]
# __________________________________________________________________________________________________
# batch_normalization_309 (BatchN (None, 8, 8, 192)    576         conv2d_1398[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 10, 10, 1024) 4096        concatenate_33[0][0]
# __________________________________________________________________________________________________
# activation_367 (Activation)     (None, 8, 8, 192)    0           batch_normalization_309[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# activation_163 (Activation)     (None, 10, 10, 1024) 0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_1399 (Conv2D)            (None, 8, 8, 224)    129024      activation_367[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 19, 19, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# conv2d_1191 (Conv2D)            (None, 10, 10, 2048) 2097152     activation_163[0][0]
# __________________________________________________________________________________________________
# batch_normalization_310 (BatchN (None, 8, 8, 224)    672         conv2d_1399[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 19, 19, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 10, 10, 2048) 8192        conv2d_1191[0][0]
# __________________________________________________________________________________________________
# activation_368 (Activation)     (None, 8, 8, 224)    0           batch_normalization_310[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 19, 19, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1197 (Conv2D)            (None, 10, 10, 1024) 745472      add_44[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_33 (Gl (None, 2048)         0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv2d_1397 (Conv2D)            (None, 8, 8, 192)    399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1400 (Conv2D)            (None, 8, 8, 256)    172032      activation_368[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 10, 10, 1024) 0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 10, 10, 1024) 4096        conv2d_1197[0][0]
# __________________________________________________________________________________________________
# lambda_1089 (Lambda)            (None, 1, 1, 2048)   0           global_average_pooling2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_308 (BatchN (None, 8, 8, 192)    576         conv2d_1397[0][0]
# __________________________________________________________________________________________________
# batch_normalization_311 (BatchN (None, 8, 8, 256)    768         conv2d_1400[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 10, 10, 1024) 0           block13_pool[0][0]
#                                                                  batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_1192 (Conv2D)            (None, 1, 1, 128)    262272      lambda_1089[0][0]
# __________________________________________________________________________________________________
# activation_366 (Activation)     (None, 8, 8, 192)    0           batch_normalization_308[0][0]
# __________________________________________________________________________________________________
# activation_369 (Activation)     (None, 8, 8, 256)    0           batch_normalization_311[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 10, 10, 1536) 1582080     add_45[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, 1, 1, 128)    0           conv2d_1192[0][0]
# __________________________________________________________________________________________________
# block8_10_mixed (Concatenate)   (None, 8, 8, 448)    0           activation_366[0][0]
#                                                                  activation_369[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 10, 10, 1536) 6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# conv2d_1193 (Conv2D)            (None, 1, 1, 2048)   264192      activation_164[0][0]
# __________________________________________________________________________________________________
# block8_10_conv (Conv2D)         (None, 8, 8, 2080)   933920      block8_10_mixed[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 10, 10, 1536) 0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, 1, 1, 2048)   0           conv2d_1193[0][0]
# __________________________________________________________________________________________________
# block8_10 (Lambda)              (None, 8, 8, 2080)   0           block8_9_ac[0][0]
#                                                                  block8_10_conv[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 10, 10, 2048) 3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# multiply_33 (Multiply)          (None, 10, 10, 2048) 0           batch_normalization_104[0][0]
#                                                                  activation_165[0][0]
# __________________________________________________________________________________________________
# conv_7b (Conv2D)                (None, 8, 8, 1536)   3194880     block8_10[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 10, 10, 2048) 8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 10, 10, 2048) 0           multiply_33[0][0]
#                                                                  activation_161[0][0]
# __________________________________________________________________________________________________
# conv_7b_bn (BatchNormalization) (None, 8, 8, 1536)   4608        conv_7b[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 10, 10, 2048) 0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# activation_166 (Activation)     (None, 10, 10, 2048) 0           add_33[0][0]
# __________________________________________________________________________________________________
# conv_7b_ac (Activation)         (None, 8, 8, 1536)   0           conv_7b_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_35 (Gl (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_34 (Gl (None, 2048)         0           activation_166[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_36 (Gl (None, 1536)         0           conv_7b_ac[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_2 (GaussianNoise (None, 2048)         0           global_average_pooling2d_35[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_1 (GaussianNoise (None, 2048)         0           global_average_pooling2d_34[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_3 (GaussianNoise (None, 1536)         0           global_average_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2048)         4196352     gaussian_noise_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2048)         4196352     gaussian_noise_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 2048)         3147776     gaussian_noise_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 10)           20490       dense_3[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           20490       dense_1[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 10)           20490       dense_5[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 30)           0           dense_4[0][0]
#                                                                  dense_2[0][0]
#                                                                  dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 4096)         126976      concatenate_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 4096)         0           dense_7[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 4096)         0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 10)           40970       dropout_1[0][0]
# ==================================================================================================
# Total params: 134,012,384
# Trainable params: 133,759,456
# Non-trainable params: 252,928
# __________________________________________________________________________________________________
# None

# %%
# 3 models v2 (3 FCs)
# 299
# pre-trainned weight
# get pretrained [-1] layer

from keras.applications import InceptionV3
from keras.applications import Xception
from keras.applications.inception_resnet_v2 import InceptionResNetV2

from keras.preprocessing import image
from keras.models import Model
from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM, LeakyReLU, Dropout
#from keras.applications.inception_v3 import preprocess_input
from keras_applications.imagenet_utils import preprocess_input

f1_mul_x = model_1.layers[-1].output 
f2_mul_x = model_2.layers[-1].output
f3_mul_x = model_3.layers[-1].output

x = concatenate([f1_mul_x, f2_mul_x, f3_mul_x])

x = Dense(4096)(x)
x = LeakyReLU(0.2)(x)
x = Dropout(0.5)(x)

# x = Dense(3072)(x)
# x = LeakyReLU(0.1)(x)
# x = Dropout(0.2)(x)

x = Dense(10, activation='softmax')(x)
model_mul = Model(inputs=[model_1.get_input_at(0),model_2.get_input_at(0),model_3.get_input_at(0)],outputs=[x])

print(model_mul.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 305, 305, 3)  0           input[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 150, 150, 64) 9408        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 150, 150, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 150, 150, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 152, 152, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 75, 75, 64)   0           zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 75, 75, 128)  8192        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 75, 75, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 75, 75, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 77, 77, 128)  0           activation_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 75, 75, 4)    144         lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 75, 75, 4)    144         lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 75, 75, 4)    144         lambda_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 75, 75, 4)    144         lambda_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 75, 75, 4)    144         lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 75, 75, 4)    144         lambda_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 75, 75, 4)    144         lambda_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 75, 75, 4)    144         lambda_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 75, 75, 4)    144         lambda_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 75, 75, 4)    144         lambda_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 75, 75, 4)    144         lambda_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 75, 75, 4)    144         lambda_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 75, 75, 4)    144         lambda_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 75, 75, 4)    144         lambda_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 75, 75, 4)    144         lambda_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 75, 75, 4)    144         lambda_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 75, 75, 4)    144         lambda_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 75, 75, 4)    144         lambda_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 75, 75, 4)    144         lambda_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 75, 75, 4)    144         lambda_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 75, 75, 4)    144         lambda_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 75, 75, 4)    144         lambda_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 75, 75, 4)    144         lambda_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 75, 75, 4)    144         lambda_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 75, 75, 4)    144         lambda_25[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 75, 75, 4)    144         lambda_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 75, 75, 4)    144         lambda_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 75, 75, 4)    144         lambda_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 75, 75, 4)    144         lambda_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 75, 75, 4)    144         lambda_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 75, 75, 4)    144         lambda_31[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 75, 75, 4)    144         lambda_32[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 75, 75, 128)  0           conv2d_3[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
#                                                                  conv2d_9[0][0]
#                                                                  conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
#                                                                  conv2d_15[0][0]
#                                                                  conv2d_16[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_18[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
#                                                                  conv2d_21[0][0]
#                                                                  conv2d_22[0][0]
#                                                                  conv2d_23[0][0]
#                                                                  conv2d_24[0][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_27[0][0]
#                                                                  conv2d_28[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_30[0][0]
#                                                                  conv2d_31[0][0]
#                                                                  conv2d_32[0][0]
#                                                                  conv2d_33[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 75, 75, 128)  512         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 75, 75, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 75, 75, 256)  32768       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 75, 75, 256)  1024        conv2d_35[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 256)          0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 1, 1, 256)    0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 1, 1, 16)     4112        lambda_33[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1, 1, 16)     0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 1, 1, 256)    4352        activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 1, 1, 256)    0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 75, 75, 256)  16384       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 75, 75, 256)  0           batch_normalization_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 75, 75, 256)  1024        conv2d_36[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 75, 75, 256)  0           multiply_1[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 75, 75, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 75, 75, 128)  32768       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 75, 75, 128)  512         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 75, 75, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 77, 77, 128)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_52 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_53 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_54 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_55 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_56 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_57 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_58 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_59 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_60 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_61 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_62 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_63 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_64 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_65 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 75, 75, 4)    144         lambda_34[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 75, 75, 4)    144         lambda_35[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 75, 75, 4)    144         lambda_36[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 75, 75, 4)    144         lambda_37[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 75, 75, 4)    144         lambda_38[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 75, 75, 4)    144         lambda_39[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 75, 75, 4)    144         lambda_40[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 75, 75, 4)    144         lambda_41[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 75, 75, 4)    144         lambda_42[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 75, 75, 4)    144         lambda_43[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 75, 75, 4)    144         lambda_44[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 75, 75, 4)    144         lambda_45[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 75, 75, 4)    144         lambda_46[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 75, 75, 4)    144         lambda_47[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 75, 75, 4)    144         lambda_48[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 75, 75, 4)    144         lambda_49[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 75, 75, 4)    144         lambda_50[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 75, 75, 4)    144         lambda_51[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 75, 75, 4)    144         lambda_52[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 75, 75, 4)    144         lambda_53[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 75, 75, 4)    144         lambda_54[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 75, 75, 4)    144         lambda_55[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 75, 75, 4)    144         lambda_56[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 75, 75, 4)    144         lambda_57[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 75, 75, 4)    144         lambda_58[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 75, 75, 4)    144         lambda_59[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 75, 75, 4)    144         lambda_60[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 75, 75, 4)    144         lambda_61[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 75, 75, 4)    144         lambda_62[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 75, 75, 4)    144         lambda_63[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 75, 75, 4)    144         lambda_64[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 75, 75, 4)    144         lambda_65[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 75, 75, 128)  0           conv2d_40[0][0]
#                                                                  conv2d_41[0][0]
#                                                                  conv2d_42[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
#                                                                  conv2d_45[0][0]
#                                                                  conv2d_46[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_48[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_50[0][0]
#                                                                  conv2d_51[0][0]
#                                                                  conv2d_52[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_54[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_56[0][0]
#                                                                  conv2d_57[0][0]
#                                                                  conv2d_58[0][0]
#                                                                  conv2d_59[0][0]
#                                                                  conv2d_60[0][0]
#                                                                  conv2d_61[0][0]
#                                                                  conv2d_62[0][0]
#                                                                  conv2d_63[0][0]
#                                                                  conv2d_64[0][0]
#                                                                  conv2d_65[0][0]
#                                                                  conv2d_66[0][0]
#                                                                  conv2d_67[0][0]
#                                                                  conv2d_68[0][0]
#                                                                  conv2d_69[0][0]
#                                                                  conv2d_70[0][0]
#                                                                  conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 75, 75, 128)  512         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 75, 75, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 75, 75, 256)  32768       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 75, 75, 256)  1024        conv2d_72[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 256)          0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# lambda_66 (Lambda)              (None, 1, 1, 256)    0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 1, 1, 16)     4112        lambda_66[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 1, 1, 16)     0           conv2d_73[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 1, 1, 256)    4352        activation_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 1, 1, 256)    0           conv2d_74[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 75, 75, 256)  0           batch_normalization_8[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 75, 75, 256)  0           multiply_2[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 75, 75, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 75, 75, 128)  32768       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 75, 75, 128)  512         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 75, 75, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 77, 77, 128)  0           activation_12[0][0]
# __________________________________________________________________________________________________
# lambda_67 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_68 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_69 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_70 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_71 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_72 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_73 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_74 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_75 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_76 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_77 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_78 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_79 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_80 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_81 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_82 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_83 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_84 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_85 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_86 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_87 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_88 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_89 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_90 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_91 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_92 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_93 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_94 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_95 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_96 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_97 (Lambda)              (None, 77, 77, 4)    0           zero_padding2d_5[0][0]
# ...
#                                                                  conv2d_1164[0][0]
#                                                                  conv2d_1165[0][0]
#                                                                  conv2d_1166[0][0]
#                                                                  conv2d_1167[0][0]
#                                                                  conv2d_1168[0][0]
#                                                                  conv2d_1169[0][0]
#                                                                  conv2d_1170[0][0]
#                                                                  conv2d_1171[0][0]
#                                                                  conv2d_1172[0][0]
#                                                                  conv2d_1173[0][0]
#                                                                  conv2d_1174[0][0]
#                                                                  conv2d_1175[0][0]
#                                                                  conv2d_1176[0][0]
#                                                                  conv2d_1177[0][0]
#                                                                  conv2d_1178[0][0]
#                                                                  conv2d_1179[0][0]
#                                                                  conv2d_1180[0][0]
#                                                                  conv2d_1181[0][0]
#                                                                  conv2d_1182[0][0]
#                                                                  conv2d_1183[0][0]
#                                                                  conv2d_1184[0][0]
#                                                                  conv2d_1185[0][0]
#                                                                  conv2d_1186[0][0]
#                                                                  conv2d_1187[0][0]
#                                                                  conv2d_1188[0][0]
#                                                                  conv2d_1189[0][0]
#                                                                  conv2d_1190[0][0]
# __________________________________________________________________________________________________
# batch_normalization_309 (BatchN (None, 8, 8, 192)    576         conv2d_1398[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 10, 10, 1024) 4096        concatenate_33[0][0]
# __________________________________________________________________________________________________
# activation_367 (Activation)     (None, 8, 8, 192)    0           batch_normalization_309[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# activation_163 (Activation)     (None, 10, 10, 1024) 0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_1399 (Conv2D)            (None, 8, 8, 224)    129024      activation_367[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 19, 19, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# conv2d_1191 (Conv2D)            (None, 10, 10, 2048) 2097152     activation_163[0][0]
# __________________________________________________________________________________________________
# batch_normalization_310 (BatchN (None, 8, 8, 224)    672         conv2d_1399[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 19, 19, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 10, 10, 2048) 8192        conv2d_1191[0][0]
# __________________________________________________________________________________________________
# activation_368 (Activation)     (None, 8, 8, 224)    0           batch_normalization_310[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 19, 19, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1197 (Conv2D)            (None, 10, 10, 1024) 745472      add_44[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_33 (Gl (None, 2048)         0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv2d_1397 (Conv2D)            (None, 8, 8, 192)    399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1400 (Conv2D)            (None, 8, 8, 256)    172032      activation_368[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 10, 10, 1024) 0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 10, 10, 1024) 4096        conv2d_1197[0][0]
# __________________________________________________________________________________________________
# lambda_1089 (Lambda)            (None, 1, 1, 2048)   0           global_average_pooling2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_308 (BatchN (None, 8, 8, 192)    576         conv2d_1397[0][0]
# __________________________________________________________________________________________________
# batch_normalization_311 (BatchN (None, 8, 8, 256)    768         conv2d_1400[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 10, 10, 1024) 0           block13_pool[0][0]
#                                                                  batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_1192 (Conv2D)            (None, 1, 1, 128)    262272      lambda_1089[0][0]
# __________________________________________________________________________________________________
# activation_366 (Activation)     (None, 8, 8, 192)    0           batch_normalization_308[0][0]
# __________________________________________________________________________________________________
# activation_369 (Activation)     (None, 8, 8, 256)    0           batch_normalization_311[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 10, 10, 1536) 1582080     add_45[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, 1, 1, 128)    0           conv2d_1192[0][0]
# __________________________________________________________________________________________________
# block8_10_mixed (Concatenate)   (None, 8, 8, 448)    0           activation_366[0][0]
#                                                                  activation_369[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 10, 10, 1536) 6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# conv2d_1193 (Conv2D)            (None, 1, 1, 2048)   264192      activation_164[0][0]
# __________________________________________________________________________________________________
# block8_10_conv (Conv2D)         (None, 8, 8, 2080)   933920      block8_10_mixed[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 10, 10, 1536) 0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, 1, 1, 2048)   0           conv2d_1193[0][0]
# __________________________________________________________________________________________________
# block8_10 (Lambda)              (None, 8, 8, 2080)   0           block8_9_ac[0][0]
#                                                                  block8_10_conv[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 10, 10, 2048) 3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# multiply_33 (Multiply)          (None, 10, 10, 2048) 0           batch_normalization_104[0][0]
#                                                                  activation_165[0][0]
# __________________________________________________________________________________________________
# conv_7b (Conv2D)                (None, 8, 8, 1536)   3194880     block8_10[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 10, 10, 2048) 8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 10, 10, 2048) 0           multiply_33[0][0]
#                                                                  activation_161[0][0]
# __________________________________________________________________________________________________
# conv_7b_bn (BatchNormalization) (None, 8, 8, 1536)   4608        conv_7b[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 10, 10, 2048) 0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# activation_166 (Activation)     (None, 10, 10, 2048) 0           add_33[0][0]
# __________________________________________________________________________________________________
# conv_7b_ac (Activation)         (None, 8, 8, 1536)   0           conv_7b_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_35 (Gl (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_34 (Gl (None, 2048)         0           activation_166[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_36 (Gl (None, 1536)         0           conv_7b_ac[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_2 (GaussianNoise (None, 2048)         0           global_average_pooling2d_35[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_1 (GaussianNoise (None, 2048)         0           global_average_pooling2d_34[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_3 (GaussianNoise (None, 1536)         0           global_average_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2048)         4196352     gaussian_noise_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2048)         4196352     gaussian_noise_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 2048)         3147776     gaussian_noise_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 10)           20490       dense_3[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           20490       dense_1[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 10)           20490       dense_5[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 30)           0           dense_4[0][0]
#                                                                  dense_2[0][0]
#                                                                  dense_6[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 4096)         126976      concatenate_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 4096)         0           dense_13[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 4096)         0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 10)           40970       dropout_4[0][0]
# ==================================================================================================
# Total params: 134,012,384
# Trainable params: 167,946
# Non-trainable params: 133,844,438
# __________________________________________________________________________________________________
# None

# %%
for layer in model_mul.layers[:-4]:
    layer.trainable=False
# for layer in model.layers[87:]:
#     layer.trainable=True)
for i,layer in enumerate(model_mul.layers):
    print(i,layer.name,layer.trainable)
# Out:
# 0 input False
# 1 zero_padding2d_1 False
# 2 conv2d_1 False
# 3 batch_normalization_1 False
# 4 activation_1 False
# 5 zero_padding2d_2 False
# 6 max_pooling2d_1 False
# 7 conv2d_2 False
# 8 batch_normalization_2 False
# 9 activation_2 False
# 10 zero_padding2d_3 False
# 11 lambda_1 False
# 12 lambda_2 False
# 13 lambda_3 False
# 14 lambda_4 False
# 15 lambda_5 False
# 16 lambda_6 False
# 17 lambda_7 False
# 18 lambda_8 False
# 19 lambda_9 False
# 20 lambda_10 False
# 21 lambda_11 False
# 22 lambda_12 False
# 23 lambda_13 False
# 24 lambda_14 False
# 25 lambda_15 False
# 26 lambda_16 False
# 27 lambda_17 False
# 28 lambda_18 False
# 29 lambda_19 False
# 30 lambda_20 False
# 31 lambda_21 False
# 32 lambda_22 False
# 33 lambda_23 False
# 34 lambda_24 False
# 35 lambda_25 False
# 36 lambda_26 False
# 37 lambda_27 False
# 38 lambda_28 False
# 39 lambda_29 False
# 40 lambda_30 False
# 41 lambda_31 False
# 42 lambda_32 False
# 43 conv2d_3 False
# 44 conv2d_4 False
# 45 conv2d_5 False
# 46 conv2d_6 False
# 47 conv2d_7 False
# 48 conv2d_8 False
# 49 conv2d_9 False
# 50 conv2d_10 False
# 51 conv2d_11 False
# 52 conv2d_12 False
# 53 conv2d_13 False
# 54 conv2d_14 False
# 55 conv2d_15 False
# 56 conv2d_16 False
# 57 conv2d_17 False
# 58 conv2d_18 False
# 59 conv2d_19 False
# 60 conv2d_20 False
# 61 conv2d_21 False
# 62 conv2d_22 False
# 63 conv2d_23 False
# 64 conv2d_24 False
# 65 conv2d_25 False
# 66 conv2d_26 False
# 67 conv2d_27 False
# 68 conv2d_28 False
# 69 conv2d_29 False
# 70 conv2d_30 False
# 71 conv2d_31 False
# 72 conv2d_32 False
# 73 conv2d_33 False
# 74 conv2d_34 False
# 75 concatenate_1 False
# 76 batch_normalization_3 False
# 77 activation_3 False
# 78 conv2d_35 False
# 79 batch_normalization_4 False
# 80 global_average_pooling2d_1 False
# 81 lambda_33 False
# 82 conv2d_37 False
# 83 activation_4 False
# 84 conv2d_38 False
# 85 activation_5 False
# 86 conv2d_36 False
# 87 multiply_1 False
# 88 batch_normalization_5 False
# 89 add_1 False
# 90 activation_6 False
# 91 conv2d_39 False
# 92 batch_normalization_6 False
# 93 activation_7 False
# 94 zero_padding2d_4 False
# 95 lambda_34 False
# 96 lambda_35 False
# 97 lambda_36 False
# 98 lambda_37 False
# 99 lambda_38 False
# 100 lambda_39 False
# 101 lambda_40 False
# 102 lambda_41 False
# 103 lambda_42 False
# 104 lambda_43 False
# 105 lambda_44 False
# 106 lambda_45 False
# 107 lambda_46 False
# 108 lambda_47 False
# 109 lambda_48 False
# 110 lambda_49 False
# 111 lambda_50 False
# 112 lambda_51 False
# 113 lambda_52 False
# 114 lambda_53 False
# 115 lambda_54 False
# 116 lambda_55 False
# 117 lambda_56 False
# 118 lambda_57 False
# 119 lambda_58 False
# 120 lambda_59 False
# 121 lambda_60 False
# 122 lambda_61 False
# 123 lambda_62 False
# 124 lambda_63 False
# 125 lambda_64 False
# 126 lambda_65 False
# 127 conv2d_40 False
# 128 conv2d_41 False
# 129 conv2d_42 False
# 130 conv2d_43 False
# 131 conv2d_44 False
# 132 conv2d_45 False
# 133 conv2d_46 False
# 134 conv2d_47 False
# 135 conv2d_48 False
# 136 conv2d_49 False
# 137 conv2d_50 False
# 138 conv2d_51 False
# 139 conv2d_52 False
# 140 conv2d_53 False
# 141 conv2d_54 False
# 142 conv2d_55 False
# 143 conv2d_56 False
# 144 conv2d_57 False
# 145 conv2d_58 False
# 146 conv2d_59 False
# 147 conv2d_60 False
# 148 conv2d_61 False
# 149 conv2d_62 False
# 150 conv2d_63 False
# 151 conv2d_64 False
# 152 conv2d_65 False
# 153 conv2d_66 False
# 154 conv2d_67 False
# 155 conv2d_68 False
# 156 conv2d_69 False
# 157 conv2d_70 False
# 158 conv2d_71 False
# 159 concatenate_2 False
# 160 batch_normalization_7 False
# 161 activation_8 False
# 162 conv2d_72 False
# 163 batch_normalization_8 False
# 164 global_average_pooling2d_2 False
# 165 lambda_66 False
# 166 conv2d_73 False
# 167 activation_9 False
# 168 conv2d_74 False
# 169 activation_10 False
# 170 multiply_2 False
# 171 add_2 False
# 172 activation_11 False
# 173 conv2d_75 False
# 174 batch_normalization_9 False
# 175 activation_12 False
# 176 zero_padding2d_5 False
# 177 lambda_67 False
# 178 lambda_68 False
# 179 lambda_69 False
# 180 lambda_70 False
# 181 lambda_71 False
# 182 lambda_72 False
# 183 lambda_73 False
# 184 lambda_74 False
# 185 lambda_75 False
# 186 lambda_76 False
# 187 lambda_77 False
# 188 lambda_78 False
# 189 lambda_79 False
# 190 lambda_80 False
# 191 lambda_81 False
# 192 lambda_82 False
# 193 lambda_83 False
# 194 lambda_84 False
# 195 lambda_85 False
# 196 lambda_86 False
# 197 lambda_87 False
# 198 lambda_88 False
# 199 lambda_89 False
# 200 lambda_90 False
# 201 lambda_91 False
# 202 lambda_92 False
# 203 lambda_93 False
# 204 lambda_94 False
# 205 lambda_95 False
# 206 lambda_96 False
# 207 lambda_97 False
# 208 lambda_98 False
# 209 conv2d_76 False
# 210 conv2d_77 False
# 211 conv2d_78 False
# 212 conv2d_79 False
# 213 conv2d_80 False
# 214 conv2d_81 False
# 215 conv2d_82 False
# 216 conv2d_83 False
# 217 conv2d_84 False
# 218 conv2d_85 False
# 219 conv2d_86 False
# 220 conv2d_87 False
# 221 conv2d_88 False
# 222 conv2d_89 False
# 223 conv2d_90 False
# 224 conv2d_91 False
# 225 conv2d_92 False
# 226 conv2d_93 False
# 227 conv2d_94 False
# 228 conv2d_95 False
# 229 conv2d_96 False
# 230 conv2d_97 False
# 231 conv2d_98 False
# 232 conv2d_99 False
# 233 conv2d_100 False
# 234 conv2d_101 False
# 235 conv2d_102 False
# 236 conv2d_103 False
# 237 conv2d_104 False
# 238 conv2d_105 False
# 239 conv2d_106 False
# 240 conv2d_107 False
# 241 concatenate_3 False
# 242 batch_normalization_10 False
# 243 activation_13 False
# 244 conv2d_108 False
# 245 batch_normalization_11 False
# 246 global_average_pooling2d_3 False
# 247 lambda_99 False
# 248 conv2d_109 False
# 249 activation_14 False
# 250 conv2d_110 False
# 251 activation_15 False
# 252 multiply_3 False
# 253 add_3 False
# 254 activation_16 False
# 255 conv2d_111 False
# 256 batch_normalization_12 False
# 257 activation_17 False
# 258 zero_padding2d_6 False
# 259 lambda_100 False
# 260 lambda_101 False
# 261 lambda_102 False
# 262 lambda_103 False
# 263 lambda_104 False
# 264 lambda_105 False
# 265 lambda_106 False
# 266 lambda_107 False
# 267 lambda_108 False
# 268 lambda_109 False
# 269 lambda_110 False
# 270 lambda_111 False
# 271 lambda_112 False
# 272 lambda_113 False
# 273 lambda_114 False
# 274 lambda_115 False
# 275 lambda_116 False
# 276 lambda_117 False
# 277 lambda_118 False
# 278 lambda_119 False
# 279 lambda_120 False
# 280 lambda_121 False
# 281 lambda_122 False
# 282 lambda_123 False
# 283 lambda_124 False
# 284 lambda_125 False
# 407 concatenate_5 False
# 408 batch_normalization_17 False
# 409 activation_23 False
# 410 conv2d_181 False
# 411 batch_normalization_18 False
# 412 input_2 False
# 413 global_average_pooling2d_5 False
# 414 conv2d_1198 False
# 415 lambda_165 False
# 416 batch_normalization_109 False
# 417 conv2d_182 False
# 418 activation_167 False
# 419 activation_24 False
# 420 conv2d_1199 False
# 421 conv2d_183 False
# 422 batch_normalization_110 False
# 423 activation_25 False
# 424 activation_168 False
# 425 multiply_5 False
# 426 conv2d_1200 False
# 427 add_5 False
# 428 batch_normalization_111 False
# 429 activation_26 False
# 430 activation_169 False
# 431 conv2d_184 False
# 432 max_pooling2d_2 False
# 433 batch_normalization_19 False
# 434 conv2d_1201 False
# 435 activation_27 False
# 436 batch_normalization_112 False
# 437 zero_padding2d_8 False
# 438 activation_170 False
# 439 lambda_166 False
# 440 lambda_167 False
# 441 lambda_168 False
# 442 lambda_169 False
# 443 lambda_170 False
# 444 lambda_171 False
# 445 lambda_172 False
# 446 lambda_173 False
# 447 lambda_174 False
# 448 lambda_175 False
# 449 lambda_176 False
# 450 lambda_177 False
# 451 lambda_178 False
# 452 lambda_179 False
# 453 lambda_180 False
# 454 lambda_181 False
# 455 lambda_182 False
# 456 lambda_183 False
# 457 lambda_184 False
# 458 lambda_185 False
# 459 lambda_186 False
# 460 lambda_187 False
# 461 lambda_188 False
# 462 lambda_189 False
# 463 lambda_190 False
# 464 lambda_191 False
# 465 lambda_192 False
# 466 lambda_193 False
# 467 lambda_194 False
# 468 lambda_195 False
# 469 lambda_196 False
# 470 lambda_197 False
# 471 conv2d_1202 False
# 472 conv2d_185 False
# 473 conv2d_186 False
# 474 conv2d_187 False
# 475 conv2d_188 False
# 476 conv2d_189 False
# 477 conv2d_190 False
# 478 conv2d_191 False
# 479 conv2d_192 False
# 480 conv2d_193 False
# 481 conv2d_194 False
# 482 conv2d_195 False
# 483 conv2d_196 False
# 484 conv2d_197 False
# 485 conv2d_198 False
# 486 conv2d_199 False
# 487 conv2d_200 False
# 488 conv2d_201 False
# 489 conv2d_202 False
# 490 conv2d_203 False
# 491 conv2d_204 False
# 492 conv2d_205 False
# 493 conv2d_206 False
# 494 conv2d_207 False
# 495 conv2d_208 False
# 496 conv2d_209 False
# 497 conv2d_210 False
# 498 conv2d_211 False
# 499 conv2d_212 False
# 500 conv2d_213 False
# 501 conv2d_214 False
# 502 conv2d_215 False
# 503 conv2d_216 False
# 504 batch_normalization_113 False
# 505 concatenate_6 False
# 506 activation_171 False
# 507 batch_normalization_20 False
# 508 max_pooling2d_3 False
# 509 activation_28 False
# 510 conv2d_1206 False
# 511 conv2d_217 False
# 512 batch_normalization_117 False
# 513 batch_normalization_21 False
# 514 activation_175 False
# 515 global_average_pooling2d_6 False
# 516 conv2d_1204 False
# 517 conv2d_1207 False
# 518 lambda_198 False
# 519 batch_normalization_115 False
# 520 batch_normalization_118 False
# 521 conv2d_218 False
# 522 activation_173 False
# 523 activation_176 False
# 524 average_pooling2d_1 False
# 525 activation_29 False
# 526 conv2d_1203 False
# 527 conv2d_1205 False
# 528 conv2d_1208 False
# 529 conv2d_1209 False
# 530 conv2d_219 False
# 531 batch_normalization_114 False
# 532 batch_normalization_116 False
# 533 batch_normalization_119 False
# 534 batch_normalization_120 False
# 535 activation_30 False
# 536 activation_172 False
# 537 activation_174 False
# 538 activation_177 False
# 539 activation_178 False
# 540 multiply_6 False
# 541 mixed_5b False
# 542 add_6 False
# 543 conv2d_1213 False
# 544 activation_31 False
# 545 batch_normalization_124 False
# 546 conv2d_220 False
# 547 activation_182 False
# 548 batch_normalization_22 False
# 549 conv2d_1211 False
# 550 conv2d_1214 False
# 551 activation_32 False
# 552 batch_normalization_122 False
# 553 batch_normalization_125 False
# 554 zero_padding2d_9 False
# 555 activation_180 False
# 556 activation_183 False
# 557 lambda_199 False
# 558 lambda_200 False
# 559 lambda_201 False
# 560 lambda_202 False
# 561 lambda_203 False
# 562 lambda_204 False
# 563 lambda_205 False
# 564 lambda_206 False
# 565 lambda_207 False
# 566 lambda_208 False
# 567 lambda_209 False
# 568 lambda_210 False
# 569 lambda_211 False
# 570 lambda_212 False
# 571 lambda_213 False
# 572 lambda_214 False
# 573 lambda_215 False
# 574 lambda_216 False
# 575 lambda_217 False
# 576 lambda_218 False
# 577 lambda_219 False
# 578 lambda_220 False
# 579 lambda_221 False
# 580 lambda_222 False
# 581 lambda_223 False
# 582 lambda_224 False
# 583 lambda_225 False
# 584 lambda_226 False
# 585 lambda_227 False
# 586 lambda_228 False
# 587 lambda_229 False
# 588 lambda_230 False
# 589 conv2d_1210 False
# 590 conv2d_1212 False
# 591 conv2d_1215 False
# 592 conv2d_221 False
# 593 conv2d_222 False
# 594 conv2d_223 False
# 595 conv2d_224 False
# 596 conv2d_225 False
# 597 conv2d_226 False
# 598 conv2d_227 False
# 599 conv2d_228 False
# 600 conv2d_229 False
# 601 conv2d_230 False
# 602 conv2d_231 False
# 603 conv2d_232 False
# 604 conv2d_233 False
# 605 conv2d_234 False
# 606 conv2d_235 False
# 607 conv2d_236 False
# 608 conv2d_237 False
# 609 conv2d_238 False
# 610 conv2d_239 False
# 611 conv2d_240 False
# 612 conv2d_241 False
# 613 conv2d_242 False
# 614 conv2d_243 False
# 615 conv2d_244 False
# 616 conv2d_245 False
# 617 conv2d_246 False
# 618 conv2d_247 False
# 619 conv2d_248 False
# 620 conv2d_249 False
# 621 conv2d_250 False
# 622 conv2d_251 False
# 623 conv2d_252 False
# 624 batch_normalization_121 False
# 625 batch_normalization_123 False
# 626 batch_normalization_126 False
# 627 concatenate_7 False
# 628 activation_179 False
# 629 activation_181 False
# 630 activation_184 False
# 631 batch_normalization_23 False
# 632 block35_1_mixed False
# 633 activation_33 False
# 634 block35_1_conv False
# 635 conv2d_253 False
# 636 block35_1 False
# 637 batch_normalization_24 False
# 638 block35_1_ac False
# 639 global_average_pooling2d_7 False
# 640 conv2d_1219 False
# 641 lambda_231 False
# 642 batch_normalization_130 False
# 643 conv2d_254 False
# 644 activation_188 False
# 645 activation_34 False
# 646 conv2d_1217 False
# 647 conv2d_1220 False
# 648 conv2d_255 False
# 649 batch_normalization_128 False
# 650 batch_normalization_131 False
# 651 activation_35 False
# 652 activation_186 False
# 653 activation_189 False
# 654 multiply_7 False
# 655 conv2d_1216 False
# 656 conv2d_1218 False
# 657 conv2d_1221 False
# 658 add_7 False
# 659 batch_normalization_127 False
# 660 batch_normalization_129 False
# 661 batch_normalization_132 False
# 662 activation_36 False
# 663 activation_185 False
# 664 activation_187 False
# 665 activation_190 False
# 666 conv2d_256 False
# 667 block35_2_mixed False
# 668 batch_normalization_25 False
# 669 block35_2_conv False
# 670 activation_37 False
# 671 block35_2 False
# 672 zero_padding2d_10 False
# 673 block35_2_ac False
# 674 lambda_232 False
# 675 lambda_233 False
# 676 lambda_234 False
# 677 lambda_235 False
# 678 lambda_236 False
# 679 lambda_237 False
# 680 lambda_238 False
# 681 lambda_239 False
# 682 lambda_240 False
# 683 lambda_241 False
# 684 lambda_242 False
# 685 lambda_243 False
# 686 lambda_244 False
# 687 lambda_245 False
# 688 lambda_246 False
# 689 lambda_247 False
# 690 lambda_248 False
# 691 lambda_249 False
# 692 lambda_250 False
# 693 lambda_251 False
# 694 lambda_252 False
# 695 lambda_253 False
# 696 lambda_254 False
# 697 lambda_255 False
# 698 lambda_256 False
# 699 lambda_257 False
# 700 lambda_258 False
# 701 lambda_259 False
# 702 lambda_260 False
# 703 lambda_261 False
# 704 lambda_262 False
# 705 lambda_263 False
# 706 conv2d_1225 False
# 707 conv2d_257 False
# 708 conv2d_258 False
# 709 conv2d_259 False
# 710 conv2d_260 False
# 711 conv2d_261 False
# 712 conv2d_262 False
# 713 conv2d_263 False
# 714 conv2d_264 False
# 715 conv2d_265 False
# 716 conv2d_266 False
# 717 conv2d_267 False
# 718 conv2d_268 False
# 719 conv2d_269 False
# 720 conv2d_270 False
# 721 conv2d_271 False
# 722 conv2d_272 False
# 723 conv2d_273 False
# 724 conv2d_274 False
# 725 conv2d_275 False
# 726 conv2d_276 False
# 727 conv2d_277 False
# 728 conv2d_278 False
# 729 conv2d_279 False
# 730 conv2d_280 False
# 731 conv2d_281 False
# 732 conv2d_282 False
# 733 conv2d_283 False
# 734 conv2d_284 False
# 735 conv2d_285 False
# 736 conv2d_286 False
# 737 conv2d_287 False
# 738 conv2d_288 False
# 739 batch_normalization_136 False
# 740 concatenate_8 False
# 741 activation_194 False
# 742 batch_normalization_26 False
# 743 conv2d_1223 False
# 744 conv2d_1226 False
# 745 activation_38 False
# 746 batch_normalization_134 False
# 747 batch_normalization_137 False
# 748 conv2d_289 False
# 749 activation_192 False
# 750 activation_195 False
# 751 batch_normalization_27 False
# 752 conv2d_1222 False
# 753 conv2d_1224 False
# 754 conv2d_1227 False
# 755 global_average_pooling2d_8 False
# 756 batch_normalization_133 False
# 757 batch_normalization_135 False
# 758 batch_normalization_138 False
# 759 lambda_264 False
# 760 activation_191 False
# 761 activation_193 False
# 762 activation_196 False
# 763 conv2d_291 False
# 764 block35_3_mixed False
# 765 activation_39 False
# 766 block35_3_conv False
# 767 conv2d_292 False
# 768 block35_3 False
# 769 activation_40 False
# 770 conv2d_290 False
# 771 block35_3_ac False
# 772 multiply_8 False
# 773 batch_normalization_28 False
# 774 conv2d_1231 False
# 775 add_8 False
# 776 batch_normalization_142 False
# 777 activation_41 False
# 778 activation_200 False
# 779 conv2d_293 False
# 780 conv2d_1229 False
# 781 conv2d_1232 False
# 782 batch_normalization_29 False
# 783 batch_normalization_140 False
# 784 batch_normalization_143 False
# 785 activation_42 False
# 786 activation_198 False
# 787 activation_201 False
# 788 zero_padding2d_11 False
# 789 conv2d_1228 False
# 790 conv2d_1230 False
# 791 conv2d_1233 False
# 792 lambda_265 False
# 793 lambda_266 False
# 794 lambda_267 False
# 795 lambda_268 False
# 796 lambda_269 False
# 797 lambda_270 False
# 798 lambda_271 False
# 799 lambda_272 False
# 800 lambda_273 False
# 801 lambda_274 False
# 802 lambda_275 False
# 803 lambda_276 False
# 804 lambda_277 False
# 805 lambda_278 False
# 806 lambda_279 False
# 807 lambda_280 False
# 808 lambda_281 False
# 809 lambda_282 False
# 810 lambda_283 False
# 811 lambda_284 False
# 812 lambda_285 False
# 813 lambda_286 False
# 814 lambda_287 False
# 815 lambda_288 False
# 816 lambda_289 False
# 817 lambda_290 False
# 818 lambda_291 False
# 819 lambda_292 False
# 820 lambda_293 False
# 821 lambda_294 False
# 822 lambda_295 False
# 823 lambda_296 False
# 824 batch_normalization_139 False
# 825 batch_normalization_141 False
# 826 batch_normalization_144 False
# 827 conv2d_294 False
# 828 conv2d_295 False
# 829 conv2d_296 False
# 830 conv2d_297 False
# 831 conv2d_298 False
# 832 conv2d_299 False
# 833 conv2d_300 False
# 834 conv2d_301 False
# 835 conv2d_302 False
# 836 conv2d_303 False
# 837 conv2d_304 False
# 838 conv2d_305 False
# 839 conv2d_306 False
# 840 conv2d_307 False
# 841 conv2d_308 False
# 842 conv2d_309 False
# 843 conv2d_310 False
# 844 conv2d_311 False
# 845 conv2d_312 False
# 846 conv2d_313 False
# 847 conv2d_314 False
# 848 conv2d_315 False
# 849 conv2d_316 False
# 850 conv2d_317 False
# 851 conv2d_318 False
# 852 conv2d_319 False
# 853 conv2d_320 False
# 854 conv2d_321 False
# 855 conv2d_322 False
# 856 conv2d_323 False
# 857 conv2d_324 False
# 858 conv2d_325 False
# 859 activation_197 False
# 860 activation_199 False
# 861 activation_202 False
# 862 concatenate_9 False
# 863 block35_4_mixed False
# 864 batch_normalization_30 False
# 865 block35_4_conv False
# 866 activation_43 False
# 867 block35_4 False
# 868 conv2d_326 False
# 869 block35_4_ac False
# 870 batch_normalization_31 False
# 871 conv2d_1237 False
# 872 global_average_pooling2d_9 False
# 873 batch_normalization_148 False
# 874 lambda_297 False
# 875 activation_206 False
# 876 conv2d_327 False
# 877 conv2d_1235 False
# 878 conv2d_1238 False
# 879 activation_44 False
# 880 batch_normalization_146 False
# 881 batch_normalization_149 False
# 882 conv2d_328 False
# 883 activation_204 False
# 884 activation_207 False
# 885 activation_45 False
# 886 conv2d_1234 False
# 887 conv2d_1236 False
# 888 conv2d_1239 False
# 889 multiply_9 False
# 890 batch_normalization_145 False
# 891 batch_normalization_147 False
# 892 batch_normalization_150 False
# 893 add_9 False
# 894 activation_203 False
# 895 activation_205 False
# 896 activation_208 False
# 897 activation_46 False
# 898 block35_5_mixed False
# 899 conv2d_329 False
# 900 block35_5_conv False
# 901 batch_normalization_32 False
# 902 block35_5 False
# 903 activation_47 False
# 904 block35_5_ac False
# 905 zero_padding2d_12 False
# 906 conv2d_1243 False
# 907 lambda_298 False
# 908 lambda_299 False
# 909 lambda_300 False
# 910 lambda_301 False
# 911 lambda_302 False
# 912 lambda_303 False
# 913 lambda_304 False
# 914 lambda_305 False
# 915 lambda_306 False
# 916 lambda_307 False
# 917 lambda_308 False
# 918 lambda_309 False
# 919 lambda_310 False
# 920 lambda_311 False
# 921 lambda_312 False
# 922 lambda_313 False
# 923 lambda_314 False
# 924 lambda_315 False
# 925 lambda_316 False
# 926 lambda_317 False
# 927 lambda_318 False
# 928 lambda_319 False
# 929 lambda_320 False
# 930 lambda_321 False
# 931 lambda_322 False
# 932 lambda_323 False
# 933 lambda_324 False
# 934 lambda_325 False
# 935 lambda_326 False
# 936 lambda_327 False
# 937 lambda_328 False
# 938 lambda_329 False
# 939 batch_normalization_154 False
# 940 conv2d_330 False
# 941 conv2d_331 False
# 942 conv2d_332 False
# 943 conv2d_333 False
# 944 conv2d_334 False
# 945 conv2d_335 False
# 946 conv2d_336 False
# 947 conv2d_337 False
# 948 conv2d_338 False
# 949 conv2d_339 False
# 950 conv2d_340 False
# 951 conv2d_341 False
# 952 conv2d_342 False
# 953 conv2d_343 False
# 954 conv2d_344 False
# 955 conv2d_345 False
# 956 conv2d_346 False
# 957 conv2d_347 False
# 958 conv2d_348 False
# 959 conv2d_349 False
# 960 conv2d_350 False
# 961 conv2d_351 False
# 962 conv2d_352 False
# 963 conv2d_353 False
# 964 conv2d_354 False
# 965 conv2d_355 False
# 966 conv2d_356 False
# 967 conv2d_357 False
# 968 conv2d_358 False
# 969 conv2d_359 False
# 970 conv2d_360 False
# 971 conv2d_361 False
# 972 activation_212 False
# 973 concatenate_10 False
# 974 conv2d_1241 False
# 975 conv2d_1244 False
# 976 batch_normalization_33 False
# 977 batch_normalization_152 False
# 978 batch_normalization_155 False
# 979 activation_48 False
# 980 activation_210 False
# 981 activation_213 False
# 982 conv2d_362 False
# 983 conv2d_1240 False
# 984 conv2d_1242 False
# 985 conv2d_1245 False
# 986 batch_normalization_34 False
# 987 batch_normalization_151 False
# 988 batch_normalization_153 False
# 989 batch_normalization_156 False
# 990 global_average_pooling2d_10 False
# 991 activation_209 False
# 992 activation_211 False
# 993 activation_214 False
# 994 lambda_330 False
# 995 block35_6_mixed False
# 996 conv2d_363 False
# 997 block35_6_conv False
# 998 activation_49 False
# 999 block35_6 False
# 1000 conv2d_364 False
# 1001 block35_6_ac False
# 1002 activation_50 False
# 1003 conv2d_1249 False
# 1004 multiply_10 False
# 1005 batch_normalization_160 False
# 1006 add_10 False
# 1007 activation_218 False
# 1008 activation_51 False
# 1009 conv2d_1247 False
# 2021 lambda_643 False
# 2022 lambda_644 False
# 2023 lambda_645 False
# 2024 lambda_646 False
# 2025 lambda_647 False
# 2026 lambda_648 False
# 2027 lambda_649 False
# 2028 lambda_650 False
# 2029 lambda_651 False
# 2030 lambda_652 False
# 2031 lambda_653 False
# 2032 lambda_654 False
# 2033 lambda_655 False
# 2034 lambda_656 False
# 2035 lambda_657 False
# 2036 lambda_658 False
# 2037 lambda_659 False
# 2038 block17_10_mixed False
# 2039 conv2d_690 False
# 2040 conv2d_691 False
# 2041 conv2d_692 False
# 2042 conv2d_693 False
# 2043 conv2d_694 False
# 2044 conv2d_695 False
# 2045 conv2d_696 False
# 2046 conv2d_697 False
# 2047 conv2d_698 False
# 2048 conv2d_699 False
# 2049 conv2d_700 False
# 2050 conv2d_701 False
# 2051 conv2d_702 False
# 2052 conv2d_703 False
# 2053 conv2d_704 False
# 2054 conv2d_705 False
# 2055 conv2d_706 False
# 2056 conv2d_707 False
# 2057 conv2d_708 False
# 2058 conv2d_709 False
# 2059 conv2d_710 False
# 2060 conv2d_711 False
# 2061 conv2d_712 False
# 2062 conv2d_713 False
# 2063 conv2d_714 False
# 2064 conv2d_715 False
# 2065 conv2d_716 False
# 2066 conv2d_717 False
# 2067 conv2d_718 False
# 2068 conv2d_719 False
# 2069 conv2d_720 False
# ...
# 3010 batch_normalization_107 False
# 3011 lambda_925 False
# 3012 lambda_926 False
# 3013 lambda_927 False
# 3014 lambda_928 False
# 3015 lambda_929 False
# 3016 lambda_930 False
# 3017 lambda_931 False
# 3018 lambda_932 False
# 3019 lambda_933 False
# 3020 lambda_934 False
# 3021 lambda_935 False
# 3022 lambda_936 False
# 3023 lambda_937 False
# 3024 lambda_938 False
# 3025 lambda_939 False
# 3026 lambda_940 False
# 3027 lambda_941 False
# 3028 lambda_942 False
# 3029 lambda_943 False
# 3030 lambda_944 False
# 3031 lambda_945 False
# 3032 lambda_946 False
# 3033 lambda_947 False
# 3034 lambda_948 False
# 3035 lambda_949 False
# 3036 lambda_950 False
# 3037 lambda_951 False
# 3038 lambda_952 False
# 3039 lambda_953 False
# 3040 lambda_954 False
# 3041 lambda_955 False
# 3042 lambda_956 False
# 3043 block8_3_conv False
# 3044 add_36 False
# 3045 conv2d_1014 False
# 3046 conv2d_1015 False
# 3047 conv2d_1016 False
# 3048 conv2d_1017 False
# 3049 conv2d_1018 False
# 3050 conv2d_1019 False
# 3051 conv2d_1020 False
# 3052 conv2d_1021 False
# 3053 conv2d_1022 False
# 3054 conv2d_1023 False
# 3055 conv2d_1024 False
# 3056 conv2d_1025 False
# 3057 conv2d_1026 False
# 3058 conv2d_1027 False
# 3059 conv2d_1028 False
# 3060 conv2d_1029 False
# 3061 conv2d_1030 False
# 3062 conv2d_1031 False
# 3063 conv2d_1032 False
# 3064 conv2d_1033 False
# 3065 conv2d_1034 False
# 3066 conv2d_1035 False
# 3067 conv2d_1036 False
# 3068 conv2d_1037 False
# 3069 conv2d_1038 False
# 3070 conv2d_1039 False
# 3071 conv2d_1040 False
# 3072 conv2d_1041 False
# 3073 conv2d_1042 False
# 3074 conv2d_1043 False
# 3075 conv2d_1044 False
# 3076 conv2d_1045 False
# 3077 block8_3 False
# 3078 block5_sepconv1_act False
# 3079 concatenate_29 False
# 3080 block8_3_ac False
# 3081 block5_sepconv1 False
# 3082 batch_normalization_90 False
# 3083 conv2d_1374 False
# 3084 block5_sepconv1_bn False
# 3085 activation_143 False
# 3086 batch_normalization_285 False
# 3087 block5_sepconv2_act False
# 3088 conv2d_1046 False
# 3089 activation_343 False
# 3090 block5_sepconv2 False
# 3091 batch_normalization_91 False
# 3092 conv2d_1375 False
# 3093 block5_sepconv2_bn False
# 3094 global_average_pooling2d_29 False
# 3095 batch_normalization_286 False
# 3096 block5_sepconv3_act False
# 3097 lambda_957 False
# 3098 activation_344 False
# 3099 block5_sepconv3 False
# 3100 conv2d_1047 False
# 3101 conv2d_1373 False
# 3102 conv2d_1376 False
# 3103 block5_sepconv3_bn False
# 3104 activation_144 False
# 3105 batch_normalization_284 False
# 3106 batch_normalization_287 False
# 3107 add_37 False
# 3108 conv2d_1048 False
# 3109 activation_342 False
# 3110 activation_345 False
# 3111 block6_sepconv1_act False
# 3112 activation_145 False
# 3113 block8_4_mixed False
# 3114 block6_sepconv1 False
# 3115 multiply_29 False
# 3116 block8_4_conv False
# 3117 block6_sepconv1_bn False
# 3118 add_29 False
# 3119 block8_4 False
# 3120 block6_sepconv2_act False
# 3121 activation_146 False
# 3122 block8_4_ac False
# 3123 block6_sepconv2 False
# 3124 conv2d_1049 False
# 3125 conv2d_1378 False
# 3126 block6_sepconv2_bn False
# 3127 batch_normalization_92 False
# 3128 batch_normalization_289 False
# 3129 block6_sepconv3_act False
# 3130 activation_147 False
# 3131 activation_347 False
# 3132 block6_sepconv3 False
# 3133 zero_padding2d_32 False
# 3134 conv2d_1379 False
# 3135 block6_sepconv3_bn False
# 3136 lambda_958 False
# 3137 lambda_959 False
# 3138 lambda_960 False
# 3139 lambda_961 False
# 3140 lambda_962 False
# 3141 lambda_963 False
# 3142 lambda_964 False
# 3143 lambda_965 False
# 3144 lambda_966 False
# 3145 lambda_967 False
# 3146 lambda_968 False
# 3147 lambda_969 False
# 3148 lambda_970 False
# 3149 lambda_971 False
# 3150 lambda_972 False
# 3151 lambda_973 False
# 3152 lambda_974 False
# 3153 lambda_975 False
# 3154 lambda_976 False
# 3155 lambda_977 False
# 3156 lambda_978 False
# 3157 lambda_979 False
# 3158 lambda_980 False
# 3159 lambda_981 False
# 3160 lambda_982 False
# 3161 lambda_983 False
# 3162 lambda_984 False
# 3163 lambda_985 False
# 3164 lambda_986 False
# 3165 lambda_987 False
# 3166 lambda_988 False
# 3167 lambda_989 False
# 3168 batch_normalization_290 False
# 3169 add_38 False
# 3170 conv2d_1050 False
# 3171 conv2d_1051 False
# 3172 conv2d_1052 False
# 3173 conv2d_1053 False
# 3174 conv2d_1054 False
# 3175 conv2d_1055 False
# 3176 conv2d_1056 False
# 3177 conv2d_1057 False
# 3178 conv2d_1058 False
# 3179 conv2d_1059 False
# 3180 conv2d_1060 False
# 3181 conv2d_1061 False
# 3182 conv2d_1062 False
# 3183 conv2d_1063 False
# 3184 conv2d_1064 False
# 3185 conv2d_1065 False
# 3186 conv2d_1066 False
# 3187 conv2d_1067 False
# 3188 conv2d_1068 False
# 3189 conv2d_1069 False
# 3190 conv2d_1070 False
# 3191 conv2d_1071 False
# 3192 conv2d_1072 False
# 3193 conv2d_1073 False
# 3194 conv2d_1074 False
# 3195 conv2d_1075 False
# 3196 conv2d_1076 False
# 3197 conv2d_1077 False
# 3198 conv2d_1078 False
# 3199 conv2d_1079 False
# 3200 conv2d_1080 False
# 3201 conv2d_1081 False
# 3202 activation_348 False
# 3203 block7_sepconv1_act False
# 3204 concatenate_30 False
# 3205 conv2d_1377 False
# 3206 conv2d_1380 False
# 3207 block7_sepconv1 False
# 3208 batch_normalization_93 False
# 3209 batch_normalization_288 False
# 3210 batch_normalization_291 False
# 3211 block7_sepconv1_bn False
# 3212 activation_148 False
# 3213 activation_346 False
# 3214 activation_349 False
# 3215 block7_sepconv2_act False
# 3216 conv2d_1082 False
# 3217 block8_5_mixed False
# 3218 block7_sepconv2 False
# 3219 batch_normalization_94 False
# 3220 block8_5_conv False
# 3221 block7_sepconv2_bn False
# 3222 global_average_pooling2d_30 False
# 3223 block8_5 False
# 3224 block7_sepconv3_act False
# 3225 lambda_990 False
# 3226 block8_5_ac False
# 3227 block7_sepconv3 False
# 3228 conv2d_1083 False
# 3229 conv2d_1382 False
# 3230 block7_sepconv3_bn False
# 3231 activation_149 False
# 3232 batch_normalization_293 False
# 3233 add_39 False
# 3234 conv2d_1084 False
# 3235 activation_351 False
# 3236 block8_sepconv1_act False
# 3237 activation_150 False
# 3238 conv2d_1383 False
# 3239 block8_sepconv1 False
# 3240 multiply_30 False
# 3241 batch_normalization_294 False
# 3242 block8_sepconv1_bn False
# 3243 add_30 False
# 3244 activation_352 False
# 3245 block8_sepconv2_act False
# 3246 activation_151 False
# 3247 conv2d_1381 False
# 3248 conv2d_1384 False
# 3249 block8_sepconv2 False
# 3250 conv2d_1085 False
# 3251 batch_normalization_292 False
# 3252 batch_normalization_295 False
# 3253 block8_sepconv2_bn False
# 3254 batch_normalization_95 False
# 3255 activation_350 False
# 3256 activation_353 False
# 3257 block8_sepconv3_act False
# 3258 activation_152 False
# 3259 block8_6_mixed False
# 3260 block8_sepconv3 False
# 3261 zero_padding2d_33 False
# 3262 block8_6_conv False
# 3263 block8_sepconv3_bn False
# 3264 lambda_991 False
# 3265 lambda_992 False
# 3266 lambda_993 False
# 3267 lambda_994 False
# 3268 lambda_995 False
# 3269 lambda_996 False
# 3270 lambda_997 False
# 3271 lambda_998 False
# 3272 lambda_999 False
# 3273 lambda_1000 False
# 3274 lambda_1001 False
# 3275 lambda_1002 False
# 3276 lambda_1003 False
# 3277 lambda_1004 False
# 3278 lambda_1005 False
# 3279 lambda_1006 False
# 3280 lambda_1007 False
# 3281 lambda_1008 False
# 3282 lambda_1009 False
# 3283 lambda_1010 False
# 3284 lambda_1011 False
# 3285 lambda_1012 False
# 3286 lambda_1013 False
# 3287 lambda_1014 False
# 3288 lambda_1015 False
# 3289 lambda_1016 False
# 3290 lambda_1017 False
# 3291 lambda_1018 False
# 3292 lambda_1019 False
# 3293 lambda_1020 False
# 3294 lambda_1021 False
# 3295 lambda_1022 False
# 3296 block8_6 False
# 3297 add_40 False
# 3298 conv2d_1086 False
# 3299 conv2d_1087 False
# 3300 conv2d_1088 False
# 3301 conv2d_1089 False
# 3302 conv2d_1090 False
# 3303 conv2d_1091 False
# 3304 conv2d_1092 False
# 3305 conv2d_1093 False
# 3306 conv2d_1094 False
# 3307 conv2d_1095 False
# 3308 conv2d_1096 False
# 3309 conv2d_1097 False
# 3310 conv2d_1098 False
# 3311 conv2d_1099 False
# 3312 conv2d_1100 False
# 3313 conv2d_1101 False
# 3314 conv2d_1102 False
# 3315 conv2d_1103 False
# 3316 conv2d_1104 False
# 3317 conv2d_1105 False
# 3318 conv2d_1106 False
# 3319 conv2d_1107 False
# 3320 conv2d_1108 False
# 3321 conv2d_1109 False
# 3322 conv2d_1110 False
# 3323 conv2d_1111 False
# 3324 conv2d_1112 False
# 3325 conv2d_1113 False
# 3326 conv2d_1114 False
# 3327 conv2d_1115 False
# 3328 conv2d_1116 False
# 3329 conv2d_1117 False
# 3330 block8_6_ac False
# 3331 block9_sepconv1_act False
# 3332 concatenate_31 False
# 3333 conv2d_1386 False
# 3334 block9_sepconv1 False
# 3335 batch_normalization_96 False
# 3336 batch_normalization_297 False
# 3337 block9_sepconv1_bn False
# 3338 activation_153 False
# 3339 activation_355 False
# 3340 block9_sepconv2_act False
# 3341 conv2d_1118 False
# 3342 conv2d_1387 False
# 3343 block9_sepconv2 False
# 3344 batch_normalization_97 False
# 3345 batch_normalization_298 False
# 3346 block9_sepconv2_bn False
# 3347 global_average_pooling2d_31 False
# 3348 activation_356 False
# 3349 block9_sepconv3_act False
# 3350 lambda_1023 False
# 3351 conv2d_1385 False
# 3352 conv2d_1388 False
# 3353 block9_sepconv3 False
# 3354 conv2d_1120 False
# 3355 batch_normalization_296 False
# 3356 batch_normalization_299 False
# 3357 block9_sepconv3_bn False
# 3358 activation_154 False
# 3359 activation_354 False
# 3360 activation_357 False
# 3361 add_41 False
# 3362 conv2d_1121 False
# 3363 block8_7_mixed False
# 3364 block10_sepconv1_act False
# 3365 activation_155 False
# 3366 conv2d_1119 False
# 3367 block8_7_conv False
# 3368 block10_sepconv1 False
# 3369 multiply_31 False
# 3370 batch_normalization_98 False
# 3371 block8_7 False
# 3372 block10_sepconv1_bn False
# 3373 add_31 False
# 3374 block8_7_ac False
# 3375 block10_sepconv2_act False
# 3376 activation_156 False
# 3377 conv2d_1390 False
# 3378 block10_sepconv2 False
# 3379 conv2d_1122 False
# 3380 batch_normalization_301 False
# 3381 block10_sepconv2_bn False
# 3382 batch_normalization_99 False
# 3383 activation_359 False
# 3384 block10_sepconv3_act False
# 3385 activation_157 False
# 3386 conv2d_1391 False
# 3387 block10_sepconv3 False
# 3388 zero_padding2d_34 False
# 3389 batch_normalization_302 False
# 3390 block10_sepconv3_bn False
# 3391 lambda_1024 False
# 3392 lambda_1025 False
# 3393 lambda_1026 False
# 3394 lambda_1027 False
# 3395 lambda_1028 False
# 3396 lambda_1029 False
# 3397 lambda_1030 False
# 3398 lambda_1031 False
# 3399 lambda_1032 False
# 3400 lambda_1033 False
# 3401 lambda_1034 False
# 3402 lambda_1035 False
# 3403 lambda_1036 False
# 3404 lambda_1037 False
# 3405 lambda_1038 False
# 3406 lambda_1039 False
# 3407 lambda_1040 False
# 3408 lambda_1041 False
# 3409 lambda_1042 False
# 3410 lambda_1043 False
# 3411 lambda_1044 False
# 3412 lambda_1045 False
# 3413 lambda_1046 False
# 3414 lambda_1047 False
# 3415 lambda_1048 False
# 3416 lambda_1049 False
# 3417 lambda_1050 False
# 3418 lambda_1051 False
# 3419 lambda_1052 False
# 3420 lambda_1053 False
# 3421 lambda_1054 False
# 3422 lambda_1055 False
# 3423 activation_360 False
# 3424 add_42 False
# 3425 conv2d_1123 False
# 3426 conv2d_1124 False
# 3427 conv2d_1125 False
# 3428 conv2d_1126 False
# 3429 conv2d_1127 False
# 3430 conv2d_1128 False
# 3431 conv2d_1129 False
# 3432 conv2d_1130 False
# 3433 conv2d_1131 False
# 3434 conv2d_1132 False
# 3435 conv2d_1133 False
# 3436 conv2d_1134 False
# 3437 conv2d_1135 False
# 3438 conv2d_1136 False
# 3439 conv2d_1137 False
# 3440 conv2d_1138 False
# 3441 conv2d_1139 False
# 3442 conv2d_1140 False
# 3443 conv2d_1141 False
# 3444 conv2d_1142 False
# 3445 conv2d_1143 False
# 3446 conv2d_1144 False
# 3447 conv2d_1145 False
# 3448 conv2d_1146 False
# 3449 conv2d_1147 False
# 3450 conv2d_1148 False
# 3451 conv2d_1149 False
# 3452 conv2d_1150 False
# 3453 conv2d_1151 False
# 3454 conv2d_1152 False
# 3455 conv2d_1153 False
# 3456 conv2d_1154 False
# 3457 conv2d_1389 False
# 3458 conv2d_1392 False
# 3459 block11_sepconv1_act False
# 3460 concatenate_32 False
# 3461 batch_normalization_300 False
# 3462 batch_normalization_303 False
# 3463 block11_sepconv1 False
# 3464 batch_normalization_100 False
# 3465 activation_358 False
# 3466 activation_361 False
# 3467 block11_sepconv1_bn False
# 3468 activation_158 False
# 3469 block8_8_mixed False
# 3470 block11_sepconv2_act False
# 3471 conv2d_1155 False
# 3472 block8_8_conv False
# 3473 block11_sepconv2 False
# 3474 batch_normalization_101 False
# 3475 block8_8 False
# 3476 block11_sepconv2_bn False
# 3477 global_average_pooling2d_32 False
# 3478 block8_8_ac False
# 3479 block11_sepconv3_act False
# 3480 lambda_1056 False
# 3481 conv2d_1394 False
# 3482 block11_sepconv3 False
# 3483 conv2d_1156 False
# 3484 batch_normalization_305 False
# 3485 block11_sepconv3_bn False
# 3486 activation_159 False
# 3487 activation_363 False
# 3488 add_43 False
# 3489 conv2d_1157 False
# 3490 conv2d_1395 False
# 3491 block12_sepconv1_act False
# 3492 activation_160 False
# 3493 batch_normalization_306 False
# 3494 block12_sepconv1 False
# 3495 multiply_32 False
# 3496 activation_364 False
# 3497 block12_sepconv1_bn False
# 3498 add_32 False
# 3499 conv2d_1393 False
# 3500 conv2d_1396 False
# 3501 block12_sepconv2_act False
# 3502 activation_161 False
# 3503 batch_normalization_304 False
# 3504 batch_normalization_307 False
# 3505 block12_sepconv2 False
# 3506 conv2d_1158 False
# 3507 activation_362 False
# 3508 activation_365 False
# 3509 block12_sepconv2_bn False
# 3510 batch_normalization_102 False
# 3511 block8_9_mixed False
# 3512 block12_sepconv3_act False
# 3513 activation_162 False
# 3514 block8_9_conv False
# 3515 block12_sepconv3 False
# 3516 zero_padding2d_35 False
# 3517 block8_9 False
# 3518 block12_sepconv3_bn False
# 3519 lambda_1057 False
# 3520 lambda_1058 False
# 3521 lambda_1059 False
# 3522 lambda_1060 False
# 3523 lambda_1061 False
# 3524 lambda_1062 False
# 3525 lambda_1063 False
# 3526 lambda_1064 False
# 3527 lambda_1065 False
# 3528 lambda_1066 False
# 3529 lambda_1067 False
# 3530 lambda_1068 False
# 3531 lambda_1069 False
# 3532 lambda_1070 False
# 3533 lambda_1071 False
# 3534 lambda_1072 False
# 3535 lambda_1073 False
# 3536 lambda_1074 False
# 3537 lambda_1075 False
# 3538 lambda_1076 False
# 3539 lambda_1077 False
# 3540 lambda_1078 False
# 3541 lambda_1079 False
# 3542 lambda_1080 False
# 3543 lambda_1081 False
# 3544 lambda_1082 False
# 3545 lambda_1083 False
# 3546 lambda_1084 False
# 3547 lambda_1085 False
# 3548 lambda_1086 False
# 3549 lambda_1087 False
# 3550 lambda_1088 False
# 3551 block8_9_ac False
# 3552 add_44 False
# 3553 conv2d_1159 False
# 3554 conv2d_1160 False
# 3555 conv2d_1161 False
# 3556 conv2d_1162 False
# 3557 conv2d_1163 False
# 3558 conv2d_1164 False
# 3559 conv2d_1165 False
# 3560 conv2d_1166 False
# 3561 conv2d_1167 False
# 3562 conv2d_1168 False
# 3563 conv2d_1169 False
# 3564 conv2d_1170 False
# 3565 conv2d_1171 False
# 3566 conv2d_1172 False
# 3567 conv2d_1173 False
# 3568 conv2d_1174 False
# 3569 conv2d_1175 False
# 3570 conv2d_1176 False
# 3571 conv2d_1177 False
# 3572 conv2d_1178 False
# 3573 conv2d_1179 False
# 3574 conv2d_1180 False
# 3575 conv2d_1181 False
# 3576 conv2d_1182 False
# 3577 conv2d_1183 False
# 3578 conv2d_1184 False
# 3579 conv2d_1185 False
# 3580 conv2d_1186 False
# 3581 conv2d_1187 False
# 3582 conv2d_1188 False
# 3583 conv2d_1189 False
# 3584 conv2d_1190 False
# 3585 conv2d_1398 False
# 3586 block13_sepconv1_act False
# 3587 concatenate_33 False
# 3588 batch_normalization_309 False
# 3589 block13_sepconv1 False
# 3590 batch_normalization_103 False
# 3591 activation_367 False
# 3592 block13_sepconv1_bn False
# 3593 activation_163 False
# 3594 conv2d_1399 False
# 3595 block13_sepconv2_act False
# 3596 conv2d_1191 False
# 3597 batch_normalization_310 False
# 3598 block13_sepconv2 False
# 3599 batch_normalization_104 False
# 3600 activation_368 False
# 3601 block13_sepconv2_bn False
# 3602 conv2d_1197 False
# 3603 global_average_pooling2d_33 False
# 3604 conv2d_1397 False
# 3605 conv2d_1400 False
# 3606 block13_pool False
# 3607 batch_normalization_108 False
# 3608 lambda_1089 False
# 3609 batch_normalization_308 False
# 3610 batch_normalization_311 False
# 3611 add_45 False
# 3612 conv2d_1192 False
# 3613 activation_366 False
# 3614 activation_369 False
# 3615 block14_sepconv1 False
# 3616 activation_164 False
# 3617 block8_10_mixed False
# 3618 block14_sepconv1_bn False
# 3619 conv2d_1193 False
# 3620 block8_10_conv False
# 3621 block14_sepconv1_act False
# 3622 activation_165 False
# 3623 block8_10 False
# 3624 block14_sepconv2 False
# 3625 multiply_33 False
# 3626 conv_7b False
# 3627 block14_sepconv2_bn False
# 3628 add_33 False
# 3629 conv_7b_bn False
# 3630 block14_sepconv2_act False
# 3631 activation_166 False
# 3632 conv_7b_ac False
# 3633 global_average_pooling2d_35 False
# 3634 global_average_pooling2d_34 False
# 3635 global_average_pooling2d_36 False
# 3636 gaussian_noise_2 False
# 3637 gaussian_noise_1 False
# 3638 gaussian_noise_3 False
# 3639 dense_3 False
# 3640 dense_1 False
# 3641 dense_5 False
# 3642 dense_4 False
# 3643 dense_2 False
# 3644 dense_6 False
# 3645 concatenate_37 False
# 3646 dense_13 True
# 3647 leaky_re_lu_4 True
# 3648 dropout_4 True
# 3649 dense_14 True

# %%
# generators for three inputs
def train_generator_three_img(X1, batch_size):
    gen = ImageDataGenerator(    
        rotation_range=30,
        width_shift_range=0.3,
        height_shift_range=0.3,
        shear_range=0.3,
        zoom_range=0.3,
        horizontal_flip=True,
        vertical_flip=True,##
    #     brightness_range=[0.5, 1.5],##
        channel_shift_range=10,##
        fill_mode='nearest')
    
    genX1 = gen.flow_from_directory(X1, batch_size=batch_size, seed=1, target_size = (299, 299))    
    while True:
        X1i = genX1.next()
        yield [X1i[0], X1i[0], X1i[0]], X1i[1]
        
def valid_generator_three_img(X1, batch_size):
    gen = ImageDataGenerator()
    
    # shuffle = False
    genX1 = gen.flow_from_directory(X1, batch_size=batch_size, shuffle = False, target_size = (299, 299))        
    while True:
        X1i = genX1.next()
        yield [X1i[0], X1i[0], X1i[0]], X1i[1]    
    
def test_generator_three_img(X1, batch_size):
    gen = ImageDataGenerator(
#         preprocessing_function=preprocess_input
    )

    genX1 = gen.flow_from_directory(X1, batch_size=batch_size, shuffle=False, target_size = (299, 299))        
    while True:
        X1i_0, X1i_1 = next(genX1)
        yield [X1i_0, X1i_0, X1i_0]

# %%
#Non-Groups
#Split training and validation
#Using Expert Data

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil
import multiprocessing

## fix for multi_gpu_model prediction time longer
from keras.layers import Lambda, concatenate
from keras import Model
import tensorflow as tf

NUM_GPU = 4
batch_size = 120
#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    gpu_model_mul = multi_gpu_model(model_mul, gpus=NUM_GPU)

epochs = 10##!!!
lr = 1e-4
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

if NUM_GPU != 1:
    gpu_model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

train_set = train_datagen.flow_from_directory('train_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('test_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

# model_txt = 'bi-lstm'
# # Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cifar10_LRG299_Mul_Pretrained_V2_SeNet_Xcep_IcpRes_STD_T1.pkl')

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.99, verbose=1)
savecheckpoint = SaveCheckPoint(model_mul, savedfilename)

# # Helper: TensorBoard
# tb = TensorBoard(log_dir=os.path.join('cifar10_output', 'logs', model_txt))

# # Helper: Save results.
# timestamp = time.time()
# csv_logger = CSVLogger(os.path.join('cifar10_output', 'logs', model_txt + '-' + 'training-' + \
#     str(timestamp) + '.log'))

step_size_train=ceil(train_set.n/train_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = gpu_model_mul.fit_generator(
    generator = train_generator_three_img('train_resized_299',batch_size=batch_size), 
    steps_per_epoch = step_size_train,
    validation_data = valid_generator_three_img('test_resized_299',batch_size=batch_size),
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[tb, csv_logger, savecheckpoint, earlystopping], 
    callbacks=[savecheckpoint, earlystopping], 
    verbose=1)
# Out:
# Found 50000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Epoch 1/10
# Found 50000 images belonging to 10 classes.
# 416/417 [============================>.] - ETA: 1s - loss: 0.4334 - acc: 0.9860Found 10000 images belonging to 10 classes.
#
# Saving val_acc 0.979700 at checkpoints/Cifar10_LRG299_Mul_Pretrained_V2_SeNet_Xcep_IcpRes_STD_T1.pkl
# 417/417 [==============================] - 884s 2s/step - loss: 0.4324 - acc: 0.9861 - val_loss: 0.0948 - val_acc: 0.9797
# Epoch 2/10
# 416/417 [============================>.] - ETA: 1s - loss: 0.0193 - acc: 0.9969
# Saving val_acc 0.979700 at checkpoints/Cifar10_LRG299_Mul_Pretrained_V2_SeNet_Xcep_IcpRes_STD_T1.pkl
# 417/417 [==============================] - 837s 2s/step - loss: 0.0193 - acc: 0.9969 - val_loss: 0.0913 - val_acc: 0.9797
# Epoch 3/10
# 417/417 [==============================] - 838s 2s/step - loss: 0.0151 - acc: 0.9968 - val_loss: 0.0932 - val_acc: 0.9795
# Epoch 4/10
# 416/417 [============================>.] - ETA: 1s - loss: 0.0120 - acc: 0.9971
# Saving val_acc 0.979900 at checkpoints/Cifar10_LRG299_Mul_Pretrained_V2_SeNet_Xcep_IcpRes_STD_T1.pkl
# 417/417 [==============================] - 840s 2s/step - loss: 0.0120 - acc: 0.9971 - val_loss: 0.0978 - val_acc: 0.9799
# Epoch 5/10
# 417/417 [==============================] - 836s 2s/step - loss: 0.0108 - acc: 0.9972 - val_loss: 0.0995 - val_acc: 0.9794
# Epoch 6/10
# 417/417 [==============================] - 834s 2s/step - loss: 0.0116 - acc: 0.9970 - val_loss: 0.1006 - val_acc: 0.9798
# Epoch 7/10
# 417/417 [==============================] - 834s 2s/step - loss: 0.0111 - acc: 0.9968 - val_loss: 0.1006 - val_acc: 0.9797
# Epoch 8/10
# 417/417 [==============================] - 837s 2s/step - loss: 0.0113 - acc: 0.9969 - val_loss: 0.1002 - val_acc: 0.9798
# Epoch 9/10
# 417/417 [==============================] - 837s 2s/step - loss: 0.0116 - acc: 0.9969 - val_loss: 0.0993 - val_acc: 0.9795
# Epoch 10/10
# 417/417 [==============================] - 837s 2s/step - loss: 0.0110 - acc: 0.9970 - val_loss: 0.0996 - val_acc: 0.9792

# %%
#use pickle to load model weights
import os
import pickle

pklfile= os.path.join('checkpoints', 'Cifar10_LRG299_Mul_Pretrained_V2_SeNet_Xcep_IcpRes_STD_T1.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

# #use set_weights to load the modelweights into the model architecture
# NUM_GPU = 4
# #Using multiple models if more than 1 GPU
# if NUM_GPU != 1:
#     model_mul = multi_gpu_model(model_2, gpus=NUM_GPU)

gpu_model_mul.set_weights(weigh)

# %%
# Change lr = 1e-5

epochs = 10##!!!
lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

if NUM_GPU != 1:
    gpu_model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

# model_txt = 'bi-lstm'
# # Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cifar10_LRG299_Mul_Pretrained_V2_SeNet_Xcep_IcpRes_STD_T2.pkl')

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.99, verbose=1)
savecheckpoint = SaveCheckPoint(model_mul, savedfilename)

result = gpu_model_mul.fit_generator(
    generator = train_generator_three_img('train_resized_299',batch_size=batch_size), 
    steps_per_epoch = step_size_train,
    validation_data = valid_generator_three_img('test_resized_299',batch_size=batch_size),
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[tb, csv_logger, savecheckpoint, earlystopping], 
    callbacks=[savecheckpoint, earlystopping], 
    verbose=1)
# Out:
# Epoch 1/10
# Found 50000 images belonging to 10 classes.
# 416/417 [============================>.] - ETA: 1s - loss: 0.0118 - acc: 0.9969Found 10000 images belonging to 10 classes.
#
# Saving val_acc 0.979600 at checkpoints/Cifar10_LRG299_Mul_Pretrained_V2_SeNet_Xcep_IcpRes_STD_T2.pkl
# 417/417 [==============================] - 819s 2s/step - loss: 0.0117 - acc: 0.9969 - val_loss: 0.0989 - val_acc: 0.9796
# Epoch 2/10
# 416/417 [============================>.] - ETA: 1s - loss: 0.0114 - acc: 0.9970
# Saving val_acc 0.979700 at checkpoints/Cifar10_LRG299_Mul_Pretrained_V2_SeNet_Xcep_IcpRes_STD_T2.pkl
# 417/417 [==============================] - 776s 2s/step - loss: 0.0113 - acc: 0.9970 - val_loss: 0.0992 - val_acc: 0.9797
# Epoch 3/10
# 417/417 [==============================] - 776s 2s/step - loss: 0.0128 - acc: 0.9969 - val_loss: 0.0986 - val_acc: 0.9795
# Epoch 4/10
# 416/417 [============================>.] - ETA: 1s - loss: 0.0112 - acc: 0.9970
# Saving val_acc 0.980000 at checkpoints/Cifar10_LRG299_Mul_Pretrained_V2_SeNet_Xcep_IcpRes_STD_T2.pkl
# 417/417 [==============================] - 779s 2s/step - loss: 0.0112 - acc: 0.9970 - val_loss: 0.0999 - val_acc: 0.9800
# Epoch 5/10
# 417/417 [==============================] - 780s 2s/step - loss: 0.0108 - acc: 0.9972 - val_loss: 0.1002 - val_acc: 0.9798
# Epoch 6/10
# 417/417 [==============================] - 774s 2s/step - loss: 0.0115 - acc: 0.9970 - val_loss: 0.1002 - val_acc: 0.9797
# Epoch 7/10
# 417/417 [==============================] - 773s 2s/step - loss: 0.0113 - acc: 0.9969 - val_loss: 0.1008 - val_acc: 0.9795
# Epoch 8/10
# 417/417 [==============================] - 777s 2s/step - loss: 0.0114 - acc: 0.9968 - val_loss: 0.1006 - val_acc: 0.9797
# Epoch 9/10
# 417/417 [==============================] - 776s 2s/step - loss: 0.0117 - acc: 0.9968 - val_loss: 0.1000 - val_acc: 0.9799
# Epoch 10/10
# 417/417 [==============================] - 777s 2s/step - loss: 0.0112 - acc: 0.9969 - val_loss: 0.0999 - val_acc: 0.9795

# %%
#use pickle to load model weights
import os
import pickle

pklfile= os.path.join('checkpoints', 'Cifar10_LRG299_Mul_Pretrained_V2_SeNet_Xcep_IcpRes_STD_T2.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

# #use set_weights to load the modelweights into the model architecture
# NUM_GPU = 4
# #Using multiple models if more than 1 GPU
# if NUM_GPU != 1:
#     model_mul = multi_gpu_model(model_2, gpus=NUM_GPU)

gpu_model_mul.set_weights(weigh)

# %%
# Change lr = 1e-6

epochs = 10##!!!
lr = 1e-6
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

if NUM_GPU != 1:
    gpu_model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

# model_txt = 'bi-lstm'
# # Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cifar10_LRG299_Mul_Pretrained_V2_SeNet_Xcep_IcpRes_STD_T3.pkl')

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.99, verbose=1)
savecheckpoint = SaveCheckPoint(model_mul, savedfilename)

result = gpu_model_mul.fit_generator(
    generator = train_generator_three_img('train_resized_299',batch_size=batch_size), 
    steps_per_epoch = step_size_train,
    validation_data = valid_generator_three_img('test_resized_299',batch_size=batch_size),
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[tb, csv_logger, savecheckpoint, earlystopping], 
    callbacks=[savecheckpoint, earlystopping], 
    verbose=1)
# Out:
# Epoch 1/10
# Found 50000 images belonging to 10 classes.
# 416/417 [============================>.] - ETA: 1s - loss: 0.0114 - acc: 0.9971Found 10000 images belonging to 10 classes.
#
# Saving val_acc 0.979800 at checkpoints/Cifar10_LRG299_Mul_Pretrained_V2_SeNet_Xcep_IcpRes_STD_T3.pkl
# 417/417 [==============================] - 830s 2s/step - loss: 0.0114 - acc: 0.9971 - val_loss: 0.1002 - val_acc: 0.9798
# Epoch 2/10
# 417/417 [==============================] - 790s 2s/step - loss: 0.0111 - acc: 0.9971 - val_loss: 0.0999 - val_acc: 0.9798
# Epoch 3/10
# 417/417 [==============================] - 784s 2s/step - loss: 0.0126 - acc: 0.9968 - val_loss: 0.0993 - val_acc: 0.9797
# Epoch 4/10
# 416/417 [============================>.] - ETA: 1s - loss: 0.0114 - acc: 0.9970
# Saving val_acc 0.980000 at checkpoints/Cifar10_LRG299_Mul_Pretrained_V2_SeNet_Xcep_IcpRes_STD_T3.pkl
# 417/417 [==============================] - 786s 2s/step - loss: 0.0114 - acc: 0.9970 - val_loss: 0.1000 - val_acc: 0.9800
# Epoch 5/10
# 417/417 [==============================] - 783s 2s/step - loss: 0.0106 - acc: 0.9973 - val_loss: 0.1003 - val_acc: 0.9798
# Epoch 6/10
# 417/417 [==============================] - 778s 2s/step - loss: 0.0115 - acc: 0.9970 - val_loss: 0.1000 - val_acc: 0.9798
# Epoch 7/10
# 417/417 [==============================] - 778s 2s/step - loss: 0.0116 - acc: 0.9970 - val_loss: 0.1004 - val_acc: 0.9796
# Epoch 8/10
# 417/417 [==============================] - 777s 2s/step - loss: 0.0117 - acc: 0.9965 - val_loss: 0.1003 - val_acc: 0.9795
# Epoch 9/10
# 417/417 [==============================] - 781s 2s/step - loss: 0.0118 - acc: 0.9967 - val_loss: 0.0998 - val_acc: 0.9797
# Epoch 10/10
# 416/417 [============================>.] - ETA: 1s - loss: 0.0115 - acc: 0.9969
# Saving val_acc 0.980000 at checkpoints/Cifar10_LRG299_Mul_Pretrained_V2_SeNet_Xcep_IcpRes_STD_T3.pkl
# 417/417 [==============================] - 790s 2s/step - loss: 0.0117 - acc: 0.9969 - val_loss: 0.0998 - val_acc: 0.9800

# %%
#use pickle to load model weights
import os
import pickle

pklfile= os.path.join('checkpoints', 'Cifar10_LRG299_Mul_Pretrained_V2_SeNet_Xcep_IcpRes_STD_L3.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

# #use set_weights to load the modelweights into the model architecture
# NUM_GPU = 4
# #Using multiple models if more than 1 GPU
# if NUM_GPU != 1:
#     model_mul = multi_gpu_model(model_2, gpus=NUM_GPU)

gpu_model_mul.set_weights(weigh)

# %%
#change test_generator
import numpy as np

# PREDICT ON OFFICIAL TEST
test_datagen1 = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

train_set = train_datagen.flow_from_directory('train_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

test_set1 = test_datagen1.flow_from_directory('test_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

if NUM_GPU != 1:
    predict1=gpu_model_mul.predict_generator(test_generator_three_img('test_resized_299',batch_size), steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
# else:
#     predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
predicted_class_indices=np.argmax(predict1,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions1 = [labels[k] for k in predicted_class_indices]

import pandas as pd

filenames=test_set1.filenames
results=pd.DataFrame({"file_name":filenames,
                      "predicted1":predictions1,
                      })
results.to_csv('Cifar10_MulModels_STD_299_1111_v5.csv')
results.head(10)
# Out:
# Found 50000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# 84/84 [==============================] - 124s 1s/step
#                   file_name predicted1
# 0  0/aeroplane_s_000002.png          0
# 1  0/aeroplane_s_000040.png          0
# 2  0/aeroplane_s_000045.png          0
# 3  0/aeroplane_s_000063.png          0
# 4     0/airbus_s_000009.png          0
# 5     0/airbus_s_000030.png          0
# 6     0/airbus_s_000049.png          0
# 7     0/airbus_s_000099.png          0
# 8     0/airbus_s_000108.png          0
# 9     0/airbus_s_000131.png          0

# %%
cp Cifar10_MulModels_STD_299_1111_v5.csv /home/bribeiro/Phong/Nat19/Cifar10_MulModels_STD_299_1111_v5.csv

# %%
#MULTI GPUS

from keras.preprocessing.image import ImageDataGenerator
from math import ceil
import numpy as np

#Crop-Official Test
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

def crop_generator_three_models(batches, crop_length):
    """Generate random crops from the image batches"""
     
    while True:
        batch_x, _ = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield [batch_crops, batch_crops, batch_crops]

gen = ImageDataGenerator(
#     rescale = 1./255,
#         preprocessing_function=preprocess_input
)

genX1 = gen.flow_from_directory('test_resized_299',
                                 target_size = (320, 320),
                                 batch_size = batch_size,
                                 class_mode = 'categorical',
                                 shuffle=False,
                                 seed=7,
                              )

#steps
step_size_test_crop = ceil(genX1.n/genX1.batch_size)

#customized generator
test_crops = crop_generator_three_models(genX1, 299)

#number of crops
tta_steps = 15
predictions = []

for i in range(tta_steps):
    print('iteration = %d' %i)
    #reset index
    genX1.reset()
    
    preds=gpu_model_mul.predict_generator(test_crops,steps = step_size_test_crop,verbose=1)  
    predictions.append(preds)

mean_pred = np.mean(predictions, axis=0)

predicted_class_indices_mean=np.argmax(mean_pred,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=genX1.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cifar10_MulModels299_STD_v2_TTA15_1111_v7.csv')
results.head(11)
# Out:
# Found 10000 images belonging to 10 classes.
# iteration = 0
# 84/84 [==============================] - 142s 2s/step
# iteration = 1
# 84/84 [==============================] - 144s 2s/step
# iteration = 3
# 84/84 [==============================] - 144s 2s/step
# iteration = 4
# 84/84 [==============================] - 144s 2s/step
# iteration = 5
# 84/84 [==============================] - 143s 2s/step
# iteration = 6
# 84/84 [==============================] - 145s 2s/step
# iteration = 7
# 84/84 [==============================] - 144s 2s/step
# iteration = 8
# 84/84 [==============================] - 144s 2s/step
# iteration = 9
# 84/84 [==============================] - 143s 2s/step
# iteration = 10
# 84/84 [==============================] - 144s 2s/step
# iteration = 11
# 84/84 [==============================] - 144s 2s/step
# iteration = 12
# 84/84 [==============================] - 143s 2s/step
# iteration = 13
# 84/84 [==============================] - 143s 2s/step
# iteration = 14
# 84/84 [==============================] - 145s 2s/step
#                           id predicted
# 0   0/aeroplane_s_000002.png         0
# 1   0/aeroplane_s_000040.png         0
# 2   0/aeroplane_s_000045.png         0
# 3   0/aeroplane_s_000063.png         0
# 4      0/airbus_s_000009.png         0
# 5      0/airbus_s_000030.png         0
# 6      0/airbus_s_000049.png         0
# 7      0/airbus_s_000099.png         0
# 8      0/airbus_s_000108.png         0
# 9      0/airbus_s_000131.png         0
# 10     0/airbus_s_000136.png         0

# %%
cp Cifar10_MulModels299_STD_v2_TTA15_1111_v7.csv /home/bribeiro/Phong/Nat19/Cifar10_MulModels299_STD_v2_TTA15_1111_v7.csv

# %%
# 3 models
# 501
# pre-trainned weight
# get pretrained [-1] layer

from keras.applications import InceptionV3
from keras.applications import Xception
from keras.applications.inception_resnet_v2 import InceptionResNetV2

from keras.preprocessing import image
from keras.models import Model
from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM, LeakyReLU, Dropout
#from keras.applications.inception_v3 import preprocess_input
from keras_applications.imagenet_utils import preprocess_input

f1_mul_x = model_1.layers[-1].output 
f2_mul_x = model_2.layers[-1].output
f3_mul_x = model_3.layers[-1].output

x = concatenate([f1_mul_x, f2_mul_x, f3_mul_x])

x = Reshape([1,30])(x)  
x = Bidirectional(LSTM(1024, 
                                 return_sequences=False, 
#                                  dropout=0.8
                                ),
                            input_shape=[1,30],
                            merge_mode='concat')(x)

# x = Dropout(0.5)(x)
x = Dense(10, activation='softmax')(x)
model_mul = Model(inputs=[model_1.get_input_at(0),model_2.get_input_at(0),model_3.get_input_at(0)],outputs=[x])

print(model_mul.summary())

# %%
#Non-Groups
#Split training and validation
#Using Expert Data

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil
import multiprocessing

## fix for multi_gpu_model prediction time longer
from keras.layers import Lambda, concatenate
from keras import Model
import tensorflow as tf

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

NUM_GPU = 4
batch_size = 120

training_set = train_datagen.flow_from_directory('fashion_mnist_train_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('fashion_mnist_test_resized_299',
                                                 target_size = (299, 299),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'FashionMNIST_LRG299_Mul_Pretrained_SeNet_Xcep_IcpRes_BiLSTM.hdf5')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=False)

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('fmnist_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('fmnist_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

from keras.callbacks import Callback
class EarlyStoppingByAccVal(Callback):
    def __init__(self, monitor='val_acc', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current >= self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping" % epoch)
            self.model.stop_training = True

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.99, verbose=1)

#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    model_mul = multi_gpu_model(model_mul, gpus=NUM_GPU)

# print('Loading pretrained weights')
# if NUM_GPU != 1:
#     model_mul.load_weights(savedfilename)
# else:
#     model.load_weights(savedfilename)

epochs = 20##!!!
lr = 1e-4
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

step_size_train=ceil(training_set.n/training_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = model_mul.fit_generator(
    generator = train_generator_three_img('fashion_mnist_train_resized_299',batch_size=batch_size), 
    steps_per_epoch = step_size_train,
    validation_data = valid_generator_three_img('fashion_mnist_test_resized_299',batch_size=batch_size),
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[tb, csv_logger, checkpointer, earlystopping], 
    callbacks=[tb, csv_logger, earlystopping], 
    verbose=1)

# %%
#change test_generator
import numpy as np

# PREDICT ON OFFICIAL TEST
test_datagen1 = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

train_set = train_datagen.flow_from_directory('train',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

test_set1 = test_datagen1.flow_from_directory('test',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

if NUM_GPU != 1:
    predict1=model_mul.predict_generator(test_generator_three_img('test',batch_size), steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
# else:
#     predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
predicted_class_indices=np.argmax(predict1,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions1 = [labels[k] for k in predicted_class_indices]

import pandas as pd

filenames=test_set1.filenames
results=pd.DataFrame({"file_name":filenames,
                      "predicted1":predictions1,
                      })
results.to_csv('Cassava_NonGrp_MulModels501_2208_v1.csv')
results.head(10)

# %%
cp Cassava_NonGrp_MulModels501_2208_v1.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels501_2208_v1.csv

# %%
#MULTI GPUS

from keras.preprocessing.image import ImageDataGenerator
from math import ceil
import numpy as np

#Crop-Official Test
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

def crop_generator_three_models(batches, crop_length):
    """Generate random crops from the image batches"""
     
    while True:
        batch_x, _ = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield [batch_crops, batch_crops, batch_crops]

gen = ImageDataGenerator(
#     rescale = 1./255,
#         preprocessing_function=preprocess_input
)

genX1 = gen.flow_from_directory('test',
                                 target_size = (541, 541),
                                 batch_size = batch_size,
                                 class_mode = 'categorical',
                                 shuffle=False,
                                 seed=7,
                              )

#steps
step_size_test_crop = ceil(genX1.n/genX1.batch_size)

#customized generator
test_crops = crop_generator_three_models(genX1, 501)

#number of crops
tta_steps = 7
# predictions = []

for i in range(tta_steps):
    print('iteration = %d' %i)
    #reset index
    genX1.reset()
    
    preds=model_mul.predict_generator(test_crops,steps = step_size_test_crop,verbose=1)  
    predictions.append(preds)

mean_pred = np.mean(predictions, axis=0)

predicted_class_indices_mean=np.argmax(mean_pred,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cassava_NonGrp_MulModels501_2208_v5.csv')
results.head(11)

# %%
cp Cassava_NonGrp_MulModels501_2208_v5.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels501_2208_v5.csv

# %%
# import pickle

# #use get_weights() command to get your model weights
# weigh= model_mul.get_weights()

# #now, use pickle to save your model weights, instead of .h5
# #for heavy model architectures, .h5 file is unsupported.
# pklfile= os.path.join('checkpoints', 'Cassava_NonGrp_S1_LRG501_Mul_Pretrained_STD_09076.pkl')

# fpkl= open(pklfile, 'wb') #Python 3
# pickle.dump(weigh, fpkl, protocol= pickle.HIGHEST_PROTOCOL)
# fpkl.close()

# %%
#use pickle to load model weights

pklfile= os.path.join('checkpoints', 'Cassava_NonGrp_S1_LRG501_Mul_Pretrained_STD_09076.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

gpus_model_mul = multi_gpu_model(model_mul, gpus=NUM_GPU)
#use set_weights to load the modelweights into the model architecture
gpus_model_mul.set_weights(weigh)

# %%
epochs = 50##!!!

result = model_mul.fit_generator(
    generator = train_generator_three_img('train',batch_size=batch_size), 
    steps_per_epoch = step_size_train,
    validation_data = valid_generator_three_img('valid',batch_size=batch_size),
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[tb, csv_logger, checkpointer, earlystopping], 
    callbacks=[tb, csv_logger, earlystopping], 
    verbose=1)

# %%
# Visualize training history
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy

# list all data in history
# history = result.history
#print(history.history.keys())
# summarize history for accuracy
plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Mul-ResNext - 501 - Noise model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Mul-ResNext - 501 - Noise model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#change test_generator
import numpy as np

# PREDICT ON OFFICIAL TEST
test_datagen1 = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

train_set = train_datagen.flow_from_directory('train',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

test_set1 = test_datagen1.flow_from_directory('test',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

if NUM_GPU != 1:
    predict1=model_mul.predict_generator(test_generator_three_img('test',batch_size), steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
# else:
#     predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
predicted_class_indices=np.argmax(predict1,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions1 = [labels[k] for k in predicted_class_indices]

import pandas as pd

filenames=test_set1.filenames
results=pd.DataFrame({"file_name":filenames,
                      "predicted1":predictions1,
                      })
results.to_csv('Cassava_NonGrp_MulModels501_2208_v6.csv')
results.head(10)

# %%
cp Cassava_NonGrp_MulModels501_2208_v6.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels501_2208_v6.csv

# %%
epochs = 10##!!!

lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)
model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.91, verbose=1)

result = model_mul.fit_generator(
    generator = train_generator_three_img('train',batch_size=batch_size), 
    steps_per_epoch = step_size_train,
    validation_data = valid_generator_three_img('valid',batch_size=batch_size),
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[tb, csv_logger, checkpointer, earlystopping], 
    callbacks=[tb, csv_logger, earlystopping], 
    verbose=1)

# %%
#train after reload weight (val_acc: 0.9076)

epochs = 40##!!!

lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)
gpus_model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.913, verbose=1)

result = gpus_model_mul.fit_generator(
    generator = train_generator_three_img('train',batch_size=batch_size), 
    steps_per_epoch = step_size_train,
    validation_data = valid_generator_three_img('valid',batch_size=batch_size),
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[tb, csv_logger, checkpointer, earlystopping], 
    callbacks=[tb, csv_logger, earlystopping], 
    verbose=1)

# %%
#change test_generator
import numpy as np

# PREDICT ON OFFICIAL TEST
test_datagen1 = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

train_set = train_datagen.flow_from_directory('train',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

test_set1 = test_datagen1.flow_from_directory('test',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

if NUM_GPU != 1:
    predict1=gpus_model_mul.predict_generator(test_generator_three_img('test',batch_size), steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
# else:
#     predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
predicted_class_indices=np.argmax(predict1,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions1 = [labels[k] for k in predicted_class_indices]

import pandas as pd

filenames=test_set1.filenames
results=pd.DataFrame({"file_name":filenames,
                      "predicted1":predictions1,
                      })
results.to_csv('Cassava_NonGrp_MulModels501_2208_v8.csv')
results.head(10)

# %%
cp Cassava_NonGrp_MulModels501_2208_v8.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels501_2208_v8.csv

# %%
#MULTI GPUS

from keras.preprocessing.image import ImageDataGenerator
from math import ceil
import numpy as np

#Crop-Official Test
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

def crop_generator_three_models(batches, crop_length):
    """Generate random crops from the image batches"""
     
    while True:
        batch_x, _ = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield [batch_crops, batch_crops, batch_crops]

gen = ImageDataGenerator(
#     rescale = 1./255,
#         preprocessing_function=preprocess_input
)

genX1 = gen.flow_from_directory('test',
                                 target_size = (541, 541),
                                 batch_size = batch_size,
                                 class_mode = 'categorical',
                                 shuffle=False,
                                 seed=7,
                              )

#steps
step_size_test_crop = ceil(genX1.n/genX1.batch_size)

#customized generator
test_crops = crop_generator_three_models(genX1, 501)

#number of crops
tta_steps = 5
predictions = []

for i in range(tta_steps):
    print('iteration = %d / %d' %(i+1,tta_steps))
    #reset index
    genX1.reset()
    
    preds=gpus_model_mul.predict_generator(test_crops,steps = step_size_test_crop,verbose=1)  
    predictions.append(preds)

mean_pred = np.mean(predictions, axis=0)

predicted_class_indices_mean=np.argmax(mean_pred,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cassava_NonGrp_MulModels501_2208_v10.csv')
results.head(11)

# %%
cp Cassava_NonGrp_MulModels501_2208_v10.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels501_2208_v11.csv

# %%
#train after reload weight (val_acc: 0.9076)

epochs = 40##!!!

lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)
gpus_model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.919, verbose=1)

result = gpus_model_mul.fit_generator(
    generator = train_generator_three_img('train',batch_size=batch_size), 
    steps_per_epoch = step_size_train,
    validation_data = valid_generator_three_img('valid',batch_size=batch_size),
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[tb, csv_logger, checkpointer, earlystopping], 
    callbacks=[tb, csv_logger, earlystopping], 
    verbose=1)

# %%
# Visualize training history
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy

# list all data in history
# history = result.history
#print(history.history.keys())
# summarize history for accuracy
plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Mul-ResNext - 501 - Noise model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Mul-ResNext - 501 - Noise model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#change test_generator
import numpy as np

# PREDICT ON OFFICIAL TEST
test_datagen1 = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

train_set = train_datagen.flow_from_directory('train',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

test_set1 = test_datagen1.flow_from_directory('test',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

if NUM_GPU != 1:
    predict1=gpus_model_mul.predict_generator(test_generator_three_img('test',batch_size), steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
# else:
#     predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
predicted_class_indices=np.argmax(predict1,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions1 = [labels[k] for k in predicted_class_indices]

import pandas as pd

filenames=test_set1.filenames
results=pd.DataFrame({"file_name":filenames,
                      "predicted1":predictions1,
                      })
results.to_csv('Cassava_NonGrp_MulModels501_2208_v12.csv')
results.head(10)

# %%
cp Cassava_NonGrp_MulModels501_2208_v12.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels501_2208_v12.csv

# %%
#train after reload weight (val_acc: 0.9076)

epochs = 40##!!!

# lr = 1e-5
# decay = lr/epochs
lr = 1e-6
decay = 0
optimizer = Adam(lr=lr, decay=decay)
gpus_model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.925, verbose=1)

result = gpus_model_mul.fit_generator(
    generator = train_generator_three_img('train',batch_size=batch_size), 
    steps_per_epoch = step_size_train,
    validation_data = valid_generator_three_img('valid',batch_size=batch_size),
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[tb, csv_logger, checkpointer, earlystopping], 
    callbacks=[tb, csv_logger, earlystopping], 
    verbose=1)

# %%
#seresnext50
#Non-Groups
#Split training and validation

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil
import multiprocessing

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

NUM_GPU = 4
batch_size = 20

train_set = train_datagen.flow_from_directory('train',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('valid',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cassava_NonGrp_S1_SEResNext50_LRG501_Mul_Pretrained_STD_L4.hdf5')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('cassava_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('cassava_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

from keras.callbacks import Callback
class EarlyStoppingByAccVal(Callback):
    def __init__(self, monitor='val_acc', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current >= self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping" % epoch)
            self.model.stop_training = True

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.8870, verbose=1)##!!!!!!

#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    model_mul = multi_gpu_model(model_2, gpus=NUM_GPU)

# print('Loading pretrained weights')
# if NUM_GPU != 1:
#     model_mul.load_weights(savedfilename)
# # else:
# #     model.load_weights(savedfilename)

epochs = 30##!!!
lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

step_size_train=ceil(train_set.n/train_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
#     callbacks=[tb, csv_logger, checkpointer, earlystopping], 
    callbacks=[tb, csv_logger, earlystopping],
    verbose=1)

# %%
#0.8898756673450369
#0.8827708640911651
max(result.history['val_acc'])

# %%
# Visualize training history
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy

# list all data in history
# history = result.history
#print(history.history.keys())
# summarize history for accuracy
plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('SeNet50 - 501 - Noise model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('SeNet50 - 501 - Noise model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model_mul.save_weights(savedfilename)

# %%
model_mul.save_weights(savedfilename)
f2_sgl = model_mul.layers[-2]
f2_sgl.save(os.path.join('checkpoints', 'Cassava_NonGrp_S1_SEResNext50_LRG450_Mul_Pretrained_STD_L3_SGL.hdf5'))

# %%
import numpy as np

# PREDICT ON OFFICIAL TEST
test_datagen1 = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

train_set = train_datagen.flow_from_directory('train',
                                                 target_size = (450, 450),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

test_set1 = test_datagen1.flow_from_directory('test',
                                                 target_size = (450, 450),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

if NUM_GPU != 1:
    predict1=model_mul.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
# else:
#     predict1=model.predict_generator(test_set1, steps = ceil(test_set1.n/test_set1.batch_size),verbose=1)
    
predicted_class_indices=np.argmax(predict1,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions1 = [labels[k] for k in predicted_class_indices]

import pandas as pd

filenames=test_set1.filenames
results=pd.DataFrame({"file_name":filenames,
                      "predicted1":predictions1,
                      })
results.to_csv('Cassava_NonGrp_MulModels450_2108_v1.csv')
results.head()

# %%
cp Cassava_NonGrp_MulModels450_2108_v1.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels450_2108_v1.csv

# %%
model_2.load_weights(os.path.join('checkpoints', 'Cassava_NonGrp_S1_SEResNext50_LRG450_Mul_Pretrained_STD_L3_SGL.hdf5'))

# %%
from keras.preprocessing.image import ImageDataGenerator
from math import ceil
import numpy as np

batch_size = 20

#Crop-Official Test
def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]

def crop_generator(batches, crop_length):
    """Generate random crops from the image batches"""
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

test_datagen_crop = ImageDataGenerator(
#     rescale = 1./255,
    preprocessing_function=preprocess_input
)

testing_set_crop = test_datagen_crop.flow_from_directory('test',
                                                 target_size = (500, 500),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="training"
                                              )
#customized generator
test_crops = crop_generator(testing_set_crop, 450)

step_size_test_crop = ceil(testing_set_crop.n/testing_set_crop.batch_size)

tta_steps = 3
predictions = []

# import tensorflow as tf
# with tf.device('/gpu:0'):
for i in range(tta_steps):
    print(i)
    testing_set_crop.reset()
#     if NUM_GPU != 1:
#         preds=mul_model.predict_generator(test_crops, 
#                                            steps = step_size_test_crop,
#                                            max_queue_size=16,
# #                                                use_multiprocessing=True,
#                                            workers=1,
#                                            verbose=1)    
#     else:
#         preds=model.predict_generator(test_crops, 
#                                            steps = step_size_test_crop,
#                                            max_queue_size=16,
# #                                                use_multiprocessing=True,
#                                            workers=1,
#                                            verbose=1)  
    preds=model_2.predict_generator(test_crops,steps = step_size_test_crop,verbose=1)  
    predictions.append(preds)

mean_pred = np.mean(predictions, axis=0)

predicted_class_indices_mean=np.argmax(mean_pred,axis=1)
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
finalpre = [labels[k] for k in predicted_class_indices_mean]

import pandas as pd
filenames=testing_set_crop.filenames
results=pd.DataFrame({"id":filenames,
                      "predicted":finalpre,
                      })
results.to_csv('Cassava_NonGrp_MulModels450_2108_v3.csv')
results.head(10)

# %%
cp Cassava_NonGrp_MulModels450_2108_v3.csv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_MulModels450_2108_v3.csv

# %%
result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)

# %%
from classification_models.keras import Classifiers
from keras.models import Model
# from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM
# from keras.applications.inception_v3 import preprocess_input

from keras.layers import GaussianNoise

nasnet, preprocess_input = Classifiers.get('senet154')

f4_base = nasnet(input_shape=(501,501,3), weights=None, include_top=False)

f4_x = GlobalAveragePooling2D()(f4_base.output)

# # #Regularization with noise
f4_x = GaussianNoise(0.1)(f4_x)

f4_x = Dense(2048, activation='relu')(f4_x)
f4_x = Dense(5, activation='softmax')(f4_x)
model_4 = Model(inputs=[f4_base.input],outputs=[f4_x])

print(model_4.summary())
# # print(f2_base.summary())

# %%
ls -l

# %%
#use pickle to load model weights
import os
import pickle

pklfile= os.path.join('Cassava_NonGrp_S1_SENet154_LRG501_STD.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

# restoredmodel= mymodel()
#use set_weights to load the modelweights into the model architecture
model_4.set_weights(weigh)

# %%
for layer in model_4.layers[:-4]:
    layer.trainable=False
# for layer in model.layers[87:]:
#     layer.trainable=True)
for i,layer in enumerate(model_4.layers):
    print(i,layer.name,layer.trainable)

# %%
#Non-Groups
#Split training and validation
#Using Expert Data

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil
import multiprocessing

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

NUM_GPU = 4
batch_size = 80

train_set = train_datagen.flow_from_directory('train',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('valid',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cassava_NonGrp_S1_SENet154_LRG501_STD.hdf5')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('cassava_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('cassava_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

from keras.callbacks import Callback
class EarlyStoppingByAccVal(Callback):
    def __init__(self, monitor='val_acc', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current >= self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping" % epoch)
            self.model.stop_training = True

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.8850, verbose=1)

#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    model_mul = multi_gpu_model(model_4, gpus=NUM_GPU)

# print('Loading pretrained weights')
# if NUM_GPU != 1:
#     model_mul.load_weights(savedfilename)
# # else:
# #     model.load_weights(savedfilename)

epochs = 30##!!!
lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

step_size_train=ceil(train_set.n/train_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[earlystopping],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)

# %%
# !wget https://github.com/qubvel/classification_models/releases/download/0.0.1/senet154_imagenet_1000_no_top.h5

# %%
mv /home/bribeiro/Phong/Nat19/Cassava_NonGrp_S1_NASNetLarge_LRG501_STD.pkl Cassava_NonGrp_S1_NASNetLarge_LRG501_STD.pkl

# %%
from classification_models.keras import Classifiers
from keras.models import Model
# from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM
# from keras.applications.inception_v3 import preprocess_input

from keras.layers import GaussianNoise

nasnet, preprocess_input = Classifiers.get('nasnetlarge')

f4_base = nasnet(input_shape=(501,501,3), weights=None, include_top=False)

f4_x = GlobalAveragePooling2D()(f4_base.output)

# # #Regularization with noise
f4_x = GaussianNoise(0.1)(f4_x)

f4_x = Dense(2048, activation='relu')(f4_x)
f4_x = Dense(5, activation='softmax')(f4_x)
model_4 = Model(inputs=[f4_base.input],outputs=[f4_x])

print(model_4.summary())
# # print(f2_base.summary())

# %%
#use pickle to load model weights
import os
import pickle

pklfile= os.path.join('Cassava_NonGrp_S1_NASNetLarge_LRG501_STD.pkl')

f= open(pklfile, 'rb')     #Python 3                 
weigh= pickle.load(f);                
f.close();

# restoredmodel= mymodel()
#use set_weights to load the modelweights into the model architecture
model_4.set_weights(weigh)

# %%
#Non-Groups
#Split training and validation
#Using Expert Data

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from keras.optimizers import Adam
# from keras.utils import multi_gpu_model

import time, os
from math import ceil
import multiprocessing

train_datagen = ImageDataGenerator(
#     rescale = 1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,##
#     brightness_range=[0.5, 1.5],##
    channel_shift_range=10,##
    fill_mode='nearest',
    preprocessing_function=preprocess_input,
)

test_datagen = ImageDataGenerator(
#     rescale = 1./255
    preprocessing_function=preprocess_input
)

NUM_GPU = 4
batch_size = 12

train_set = train_datagen.flow_from_directory('train',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=7,
#                                                  subset="training"
                                              )

valid_set = test_datagen.flow_from_directory('valid',
                                                 target_size = (501, 501),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical',
                                                 shuffle=False,
                                                 seed=7,
#                                                  subset="validation"
                                             )

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cassava_NonGrp_S1_NASNetLarge_LRG501_STD.hdf5')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=True)########

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('cassava_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('cassava_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

from keras.callbacks import Callback
class EarlyStoppingByAccVal(Callback):
    def __init__(self, monitor='val_acc', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current >= self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping" % epoch)
            self.model.stop_training = True

earlystopping = EarlyStoppingByAccVal(monitor='val_acc', value=0.8850, verbose=1)

#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    model_mul = multi_gpu_model(model_4, gpus=NUM_GPU)

# print('Loading pretrained weights')
# if NUM_GPU != 1:
#     model_mul.load_weights(savedfilename)
# # else:
# #     model.load_weights(savedfilename)

epochs = 30##!!!
lr = 1e-5
decay = lr/epochs
optimizer = Adam(lr=lr, decay=decay)

model_mul.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

step_size_train=ceil(train_set.n/train_set.batch_size)
step_size_valid=ceil(valid_set.n/valid_set.batch_size)
# step_size_test=ceil(testing_set.n//testing_set.batch_size)

result = model_mul.fit_generator(
    generator = train_set, 
    steps_per_epoch = step_size_train,
    validation_data = valid_set,
    validation_steps = step_size_valid,
    shuffle=True,
    epochs=epochs,
    callbacks=[earlystopping],
#     callbacks=[tb, csv_logger, checkpointer, earlystopping],        
    verbose=1)

# %%
#MUL 2 - Inception
#501
import keras

# from keras_applications.resnext import ResNeXt101, preprocess_input
# from keras.applications.resnet50 import ResNet50
# from keras.applications import InceptionV3
# from keras.applications import Xception
# from keras.applications.inception_resnet_v2 import InceptionResNetV2
# from classification_models.senet import SEResNet101, preprocess_input
# from classification_models.keras import Classifiers


from keras.models import Model
from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM
# from keras.applications.inception_v3 import preprocess_input

from keras.layers import GaussianNoise

# ResNext101, preprocess_input = Classifiers.get('resnext101')
# NASNetLarge = preprocess_input = Classifiers.get('nasnetlarge')

# SENet154, preprocess_input = Classifiers.get('senet154')

f2_base = SEInceptionResNetV2(include_top=True,
                        weights=None,
                        input_tensor=None,
                        input_shape=(501,501,3),
                        pooling=None)

# # f2_base = Classifiers.get('nasnetlarge')[0]((501, 501, 3), weights=None)
# f2_base = SENet154((501, 501, 3), weights=None)
# # f2_base = SeNet154((501,501,3), weights = 'imagenet', include_top=False) 
# # f2_base = ResNext101((501,501,3), weights = 'imagenet') 
# # # f2_base = NASNetLarge((501,501,3), weights = 'imagenet')

# # # for layer in f3_base.layers:
# # #     layer.trainable = False 
f2_x = f2_base.layers[-2].output
# # # f2_x = GlobalAveragePooling2D()(f2_x)

# # #Regularization with noise
# f2_x = GaussianNoise(0.1)(f2_x)

f2_x = Dense(2048, activation='relu')(f2_x)
f2_x = Dense(5, activation='softmax')(f2_x)
model_2 = Model(inputs=[f2_base.input],outputs=[f2_x])

print(model_2.summary())
# print(f2_base.summary())

# %%
# !pip install pretrainedmodels

# %%
import pretrainedmodels

# %%
print(pretrainedmodels.model_names)

# %%
from classification_models.keras import Classifiers
from keras.models import Model
# from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM
# from keras.applications.inception_v3 import preprocess_input

from keras.layers import GaussianNoise

senet, preprocess_input = Classifiers.get('seresnext101')

f2_base = senet(input_shape=(501,501,3), weights='imagenet', include_top=False)
f2_x = GlobalAveragePooling2D()(f2_base.output)

# # #Regularization with noise
f2_x = GaussianNoise(0.1)(f2_x)

f2_x = Dense(2048, activation='relu')(f2_x)
f2_x = Dense(5, activation='softmax')(f2_x)
model_2 = Model(inputs=[f2_base.input],outputs=[f2_x])

print(model_2.summary())
# # print(f2_base.summary())

# %%
for layer in model_2.layers[:-3]:
    layer.trainable=False
# for layer in model.layers[87:]:
#     layer.trainable=True)
for i,layer in enumerate(model_2.layers):
    print(i,layer.name,layer.trainable)

# %%
from keras.utils import to_categorical
import numpy as np
import random
import csv
import glob
import os
import os.path

def get_data():
    """Load data from file."""
    with open(os.path.join('cassava_data_senet.csv'), 'r') as fin:
        reader = csv.reader(fin)
        data = list(reader)

    return data

def get_extracted_sequence(sample):
    """Get the extracted features."""
    filename = sample[0] + '_' + sample[1] + '_' + sample[2]
    path = os.path.join('sequences', filename + '.npy')
    #print(path)
    if os.path.isfile(path):
        return np.load(path)
    else:
        return None
    
def get_classes():
    """Extract the classes from data"""
    classes = []
    for item in data:
        if item[1] not in classes:
            classes.append(item[1])

    # Sort them.
    classes = sorted(classes)

    # Return.
    return classes

def get_class_one_hot(class_str):
    """Encode and one-hot classes for training.
    Given a class as a string, return its number in the classes list. """
    # Encode
    label_encoded = classes.index(class_str)

    # One-hot
    label_hot = to_categorical(label_encoded, len(classes))

    assert len(label_hot) == len(classes)

    return label_hot

def get_all_sequences_in_memory(train_test):
    """
    Load everything into memory
    """
    # Get the right dataset.
    train, test = split_train_test()
    data = train if train_test == 'train' else test
    
    print("Loading %d samples into memory for %sing." % (len(data), train_test))
    
    X, y = [], []
    for row in data:
        sequence = get_extracted_sequence(row)
        # modify for single sequence
        sequence = np.expand_dims(sequence, axis=0)

        if sequence is None:
            print("Can't find sequence?")
            raise

        X.append(sequence)
        y.append(get_class_one_hot(row[1]))

    return np.array(X), np.array(y)

def split_train_test():
    """Split the data into train and test sets."""
    train = []
    test = []
    for item in data:
        if item[0] == 'train':
            train.append(item)
        else:
            test.append(item)
    return train, test

# %%
from classification_models.keras import Classifiers
from keras.models import Model
# from keras.layers import concatenate
from keras.layers import Dense, GlobalAveragePooling2D, Input, Embedding, LSTM
# from keras.applications.inception_v3 import preprocess_input

from keras.layers import GaussianNoise

senet, preprocess_input = Classifiers.get('seresnext101')

f3_base = senet(input_shape=(501,501,3), weights='imagenet', include_top=False)
f3_x = GlobalAveragePooling2D()(f3_base.output)

# # # #Regularization with noise
# f2_x = GaussianNoise(0.1)(f2_x)

# f2_x = Dense(2048, activation='relu')(f2_x)
# f2_x = Dense(5, activation='softmax')(f2_x)
model_3 = Model(inputs=[f3_base.input],outputs=[f3_x])

print(model_3.summary())
# # print(f2_base.summary())

# %%
from keras.preprocessing import image as imgload
# from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras.models import Model, load_model
from keras.layers import Input
import numpy as np

class Extractor_SeNet():
    def __init__(self, weights=None):

        # assign model_1 (Xception)
        self.model = model_3
            
    def extract(self, image_path):
        img = imgload.load_img(image_path, target_size=(501, 501)) #input size
        #img = imgload.load_img(image_path, target_size=(224, 224)) #densenet, mobilenet
        x = imgload.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)

        # Get the prediction.
        features = self.model.predict(x)

#         if self.weights is None:
#             # For imagenet/default network:
#             features = features[0]
#         else:
#             # For loaded network:
#             features = features[0]

        return features[0]

# %%
mv sequences sequences_bkp

# %%
rm -r sequences

# %%
mkdir sequences

# %%
# Feature Extraction
#

import numpy as np
import os.path
from tqdm import tqdm
import sys
import os

import csv
import glob
import os
import os.path

# Get model
model = Extractor_SeNet()

# Multiple GPUs
NUM_GPU = 4
model.model = multi_gpu_model(model.model, gpus=NUM_GPU)

# Load weights
# model.model.load_weights(os.path.join('checkpoints', 'Cassava_NonGrp_S1_Xception_LRG501_Mul_Pretrained_STD.hdf5'))

# Get the dataset.
data = get_data()
print(len(data))

# Get the model.
# model = Extractor_InceptionV3()

# Loop through data.
pbar = tqdm(total=len(data))
for images in data:
    feature_path = os.path.join('sequences', images[0] + '_' + images[1] + '_' + images[2])

    # Skip if the file already existed.
    if os.path.isfile(feature_path + '.npy'):
        pbar.update(1)
        continue

    image_path = os.path.join(images[0], images[1], images[2])
    feature = model.extract(image_path)

    # Save the feature.
    np.save(feature_path, feature)
    
    pbar.update(1)

pbar.close()

# %%
from keras.utils import to_categorical
import numpy as np
import random

def get_extracted_sequences_one_model(dir1, sample):
    """Get the extracted features."""
    filename = sample[0] + '_' + sample[1] + '_' + sample[2]
    path1 = os.path.join(dir1, filename + '.npy')
    #print(path)
    if os.path.isfile(path1):
        return np.load(path1)
    else:
        return None
    
def get_all_sequences_one_model_in_memory(dir1, train_test):
    """
    Load everything into memory
    """
    # Get the right dataset.
    train, test = split_train_test()
    data = train if train_test == 'train' else test
    
    print("Loading %d samples into memory for %sing." % (len(data), train_test))
    
    X, y = [], []
    for row in data:
        sequence1 = get_extracted_sequences_one_model(dir1, row)
        
        # add two sequences
#         sequence = np.concatenate(sequence1, axis=0)
        # modify for single sequence
        sequence = np.expand_dims(sequence1, axis=0)

        if sequence is None:
            print("Can't find sequence?")
            raise

        X.append(sequence)
        y.append(get_class_one_hot(row[1]))

    return np.array(X), np.array(y)

# %%
from keras.layers import Dense, Flatten, Dropout, ZeroPadding3D, LeakyReLU
from keras.layers.recurrent import LSTM
from keras.models import Sequential, load_model
from keras.optimizers import Adam, RMSprop
from keras.layers.convolutional import (Conv2D, MaxPooling3D, Conv3D,
    MaxPooling2D)

def base_line_one_model():
    """Build a simple model"""
    # Model.
    model = Sequential()
#     model.add(Dense(32, input_shape=(16,)))
    model.add(Flatten(input_shape=(1,2048)))
#     model.add(Dense(1024, activation='relu'))#inceptionv3
#     model.add(Dense(2048, activation='relu'))
    model.add(Dense(1024))
    model.add(LeakyReLU(0.2))
    model.add(Dropout(0.5))
    model.add(Dense(5, activation='softmax'))

    return model

# %%
senet_model = base_line_one_model()
senet_model.summary()

# %%
# Get the dataset.
data = get_data()
print(len(data))

# Get the classes.
classes = get_classes()
print(classes)

# %%
#3 models
#IcpResNet, Inception, Xception
#501

from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
import time, os

model_txt = 'bi-lstm'
# Helper: Save the model.
savedfilename = os.path.join('checkpoints', 'Cassava_NonGrp_S1_TL_SeNet501_Mul_Pretrained_STD.hdf5')

checkpointer = ModelCheckpoint(savedfilename,
                          monitor='val_acc', verbose=1, 
                          save_best_only=True, mode='max',save_weights_only=False)

# Helper: TensorBoard
tb = TensorBoard(log_dir=os.path.join('cassava_output', 'logs', model_txt))

# Helper: Save results.
timestamp = time.time()
csv_logger = CSVLogger(os.path.join('cassava_output', 'logs', model_txt + '-' + 'training-' + \
    str(timestamp) + '.log'))

from keras.callbacks import Callback
class EarlyStoppingByAccVal(Callback):
    def __init__(self, monitor='val_acc', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current >= self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping" % epoch)
            self.model.stop_training = True

early_stopper = EarlyStoppingByAccVal(monitor='val_acc', value=0.99, verbose=1)


X_train, y_train = get_all_sequences_one_model_in_memory('sequences','train')
X_valid, y_valid = get_all_sequences_one_model_in_memory('sequences','valid')

from keras.optimizers import Adam

NUM_GPU = 4
batch_size = 60
nb_epoch = 500

lr = 1e-5
decay = lr/nb_epoch
optimizer = Adam(lr=lr, decay=decay)

#Using multiple models if more than 1 GPU
if NUM_GPU != 1:
    mul_model = multi_gpu_model(senet_model, gpus=NUM_GPU)

if NUM_GPU != 1:
    mul_model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

result = mul_model.fit(
            X_train,
            y_train,
            batch_size=batch_size,
            validation_data=(X_valid, y_valid),
            verbose=1,
            callbacks=[tb, csv_logger, checkpointer, early_stopper],
            epochs=nb_epoch)
